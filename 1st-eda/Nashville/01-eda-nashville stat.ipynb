# %% [markdown]
# # Nashville

# %%
import pandas as pd
import numpy as np

# %%
calendar = pd.read_csv('usa/Nashville/calendar.csv')
listings = pd.read_csv('usa/Nashville/listings.csv')
listings_detailed = pd.read_csv('usa/Nashville/listings_detailed.csv')
neighbor = pd.read_csv('usa/Nashville/neighbourhoods.csv')
neighbor_json = pd.read_json('usa/Nashville/neighbourhoods.geojson')
review = pd.read_csv('usa/Nashville/reviews.csv')
review_detailed = pd.read_csv('usa/Nashville/reviews_detailed.csv')

# %%
data_list = [
    ("calendar", calendar.shape),  
    ("listings", listings.shape),
    ("listings_detailed", listings_detailed.shape),
    ("neighbor", neighbor.shape),
    ("neighbor_json", neighbor_json.shape),  # JSON structure might be more complex than what .shape can describe
    ("review", review.shape),
    ("review_detailed", review_detailed.shape)
]

for name, shape in data_list:
    print(f"The shape of '{name}' dataframe is: {shape}")
# Out:
# The shape of 'calendar' dataframe is: (3119707, 7)
# The shape of 'listings' dataframe is: (8548, 18)
# The shape of 'listings_detailed' dataframe is: (8548, 75)
# The shape of 'neighbor' dataframe is: (35, 2)
# The shape of 'neighbor_json' dataframe is: (35, 2)
# The shape of 'review' dataframe is: (541576, 2)
# The shape of 'review_detailed' dataframe is: (541576, 6)

# %%
# Function to perform EDA
def perform_eda(df):
    print("Rows, Columns:", df.shape)
    print("Missing Values:\n", df.isnull().sum())
    numerical_features = df.select_dtypes(include=[np.number])
    categorical_features = df.select_dtypes(include=[object])
    print("Numerical Features:", numerical_features.columns.tolist())
    print("Categorical Features:", categorical_features.columns.tolist())
    if not numerical_features.empty:
        print("Mean of Numerical Features:\n", numerical_features.mean())
        print("Standard Deviation of Numerical Features:\n", numerical_features.std())
        for col in numerical_features.columns:
            print(f"Range of {col}: {numerical_features[col].min()} - {numerical_features[col].max()}")

# %%
dataframes = {
    "calendar": calendar,
    "listings": listings,
    "listings_detailed": listings_detailed,
    "neighbor": neighbor,
    # For neighbor_json, since it's a GeoJSON, the EDA will be different and not covered in this general function.
    "review": review,
    "review_detailed": review_detailed
}

for name, df in dataframes.items():
    print(f"EDA for {name}:")
    perform_eda(df)
    print('=================='*10)
# Out:
# EDA for calendar:
# Rows, Columns: (3119707, 7)
# Missing Values:
#  listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    1
# maximum_nights    1
# dtype: int64
# Numerical Features: ['listing_id', 'minimum_nights', 'maximum_nights']
# Categorical Features: ['date', 'available', 'price', 'adjusted_price']
# Mean of Numerical Features:
#  listing_id        2.780580e+17
# minimum_nights    6.559823e+00
# maximum_nights    1.242534e+06
# dtype: float64
# Standard Deviation of Numerical Features:
#  listing_id        3.490456e+17
# minimum_nights    1.778989e+01
# maximum_nights    5.162566e+07
# dtype: float64
# Range of listing_id: 6422 - 849420841551486570
# Range of minimum_nights: 1.0 - 999.0
# Range of maximum_nights: 1.0 - 2147483647.0
# ====================================================================================================================================================================================
# EDA for listings:
# Rows, Columns: (8548, 18)
# Missing Values:
#  id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               8548
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1188
# reviews_per_month                 1188
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           8548
# dtype: int64
# Numerical Features: ['id', 'host_id', 'neighbourhood_group', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license']
# Categorical Features: ['name', 'host_name', 'neighbourhood', 'room_type', 'last_review']
# Mean of Numerical Features:
#  id                                2.780270e+17
# host_id                           1.673970e+08
# neighbourhood_group                        NaN
# latitude                          3.616433e+01
# longitude                        -8.676761e+01
# price                             2.816040e+02
# minimum_nights                    6.392255e+00
# number_of_reviews                 6.335704e+01
# reviews_per_month                 2.282732e+00
# calculated_host_listings_count    2.633832e+01
# availability_365                  2.067284e+02
# number_of_reviews_ltm             1.962845e+01
# license                                    NaN
# dtype: float64
# Standard Deviation of Numerical Features:
#  id                                3.490591e+17
# host_id                           1.572298e+08
# neighbourhood_group                        NaN
# latitude                          4.099799e-02
# longitude                         5.235070e-02
# price                             9.239190e+02
# minimum_nights                    2.506984e+01
# number_of_reviews                 1.050299e+02
# reviews_per_month                 2.463789e+00
# calculated_host_listings_count    4.522738e+01
# availability_365                  1.204022e+02
# number_of_reviews_ltm             2.957633e+01
# license                                    NaN
# dtype: float64
# Range of id: 6422 - 849420841551486570
# Range of host_id: 1147 - 505238097
# Range of neighbourhood_group: nan - nan
# Range of latitude: 35.9833 - 36.39848
# Range of longitude: -87.03521 - -86.54606
# Range of price: 0 - 78200
# Range of minimum_nights: 1 - 999
# Range of number_of_reviews: 0 - 1425
# Range of reviews_per_month: 0.01 - 99.19
# Range of calculated_host_listings_count: 1 - 185
# Range of availability_365: 0 - 365
# Range of number_of_reviews_ltm: 0 - 1314
# Range of license: nan - nan
# ====================================================================================================================================================================================
# EDA for listings_detailed:
# Rows, Columns: (8548, 75)
# Missing Values:
#  id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1188
# Length: 75, dtype: int64
# Numerical Features: ['id', 'scrape_id', 'host_id', 'host_listings_count', 'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']
# Categorical Features: ['listing_url', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type', 'bathrooms_text', 'amenities', 'price', 'has_availability', 'calendar_last_scraped', 'first_review', 'last_review', 'instant_bookable']
# Mean of Numerical Features:
#  id                                              2.780270e+17
# scrape_id                                       2.023032e+13
# host_id                                         1.673970e+08
# host_listings_count                             1.005838e+02
# host_total_listings_count                       1.759953e+02
# neighbourhood_group_cleansed                             NaN
# latitude                                        3.616433e+01
# longitude                                      -8.676761e+01
# accommodates                                    6.643191e+00
# bathrooms                                                NaN
# bedrooms                                        2.424331e+00
# beds                                            4.086111e+00
# minimum_nights                                  6.392255e+00
# maximum_nights                                  5.099055e+02
# minimum_minimum_nights                          5.881713e+00
# maximum_minimum_nights                          7.611677e+00
# minimum_maximum_nights                          6.855404e+02
# maximum_maximum_nights                          1.257030e+06
# minimum_nights_avg_ntm                          6.558676e+00
# maximum_nights_avg_ntm                          1.245072e+06
# calendar_updated                                         NaN
# availability_30                                 1.277585e+01
# availability_60                                 2.786933e+01
# availability_90                                 4.591226e+01
# availability_365                                2.067284e+02
# number_of_reviews                               6.335704e+01
# number_of_reviews_ltm                           1.962845e+01
# number_of_reviews_l30d                          1.536383e+00
# review_scores_rating                            4.795717e+00
# review_scores_accuracy                          4.842300e+00
# review_scores_cleanliness                       4.796308e+00
# review_scores_checkin                           4.862884e+00
# review_scores_communication                     4.873029e+00
# review_scores_location                          4.767893e+00
# review_scores_value                             4.746413e+00
# license                                                  NaN
# calculated_host_listings_count                  2.633832e+01
# calculated_host_listings_count_entire_homes     2.377305e+01
# calculated_host_listings_count_private_rooms    2.222976e+00
# calculated_host_listings_count_shared_rooms     6.200281e-03
# reviews_per_month                               2.282732e+00
# dtype: float64
# Standard Deviation of Numerical Features:
#  id                                              3.490591e+17
# scrape_id                                       1.789167e+00
# host_id                                         1.572298e+08
# host_listings_count                             3.692466e+02
# host_total_listings_count                       7.622756e+02
# neighbourhood_group_cleansed                             NaN
# latitude                                        4.099799e-02
# longitude                                       5.235070e-02
# accommodates                                    3.795611e+00
# bathrooms                                                NaN
# bedrooms                                        1.589187e+00
# beds                                            3.771452e+00
# minimum_nights                                  2.506984e+01
# maximum_nights                                  4.415724e+02
# minimum_minimum_nights                          1.684501e+01
# maximum_minimum_nights                          2.272533e+01
# minimum_maximum_nights                          4.760718e+02
# maximum_maximum_nights                          5.192855e+07
# minimum_nights_avg_ntm                          1.763803e+01
# maximum_nights_avg_ntm                          5.143739e+07
# calendar_updated                                         NaN
# availability_30                                 9.216381e+00
# availability_60                                 1.767237e+01
# availability_90                                 2.649599e+01
# availability_365                                1.204022e+02
# number_of_reviews                               1.050299e+02
# number_of_reviews_ltm                           2.957633e+01
# number_of_reviews_l30d                          2.460681e+00
# review_scores_rating                            3.817138e-01
# review_scores_accuracy                          3.243615e-01
# review_scores_cleanliness                       3.174514e-01
# review_scores_checkin                           3.230028e-01
# review_scores_communication                     3.152549e-01
# review_scores_location                          3.302610e-01
# review_scores_value                             3.493944e-01
# license                                                  NaN
# calculated_host_listings_count                  4.522738e+01
# calculated_host_listings_count_entire_homes     4.451997e+01
# calculated_host_listings_count_private_rooms    9.994517e+00
# calculated_host_listings_count_shared_rooms     1.018556e-01
# reviews_per_month                               2.463789e+00
# dtype: float64
# Range of id: 6422 - 849420841551486570
# Range of scrape_id: 20230319180930 - 20230319180930
# Range of host_id: 1147 - 505238097
# Range of host_listings_count: 1 - 3297
# Range of host_total_listings_count: 1 - 7800
# Range of neighbourhood_group_cleansed: nan - nan
# Range of latitude: 35.9833 - 36.39848
# Range of longitude: -87.03521 - -86.54606
# Range of accommodates: 0 - 16
# Range of bathrooms: nan - nan
# Range of bedrooms: 1.0 - 18.0
# Range of beds: 1.0 - 111.0
# Range of minimum_nights: 1 - 999
# Range of maximum_nights: 1 - 1500
# Range of minimum_minimum_nights: 1.0 - 999.0
# Range of maximum_minimum_nights: 1.0 - 999.0
# Range of minimum_maximum_nights: 1.0 - 1500.0
# Range of maximum_maximum_nights: 1.0 - 2147483647.0
# Range of minimum_nights_avg_ntm: 1.0 - 999.0
# Range of maximum_nights_avg_ntm: 1.0 - 2142625087.5
# Range of calendar_updated: nan - nan
# Range of availability_30: 0 - 30
# Range of availability_60: 0 - 60
# Range of availability_90: 0 - 90
# Range of availability_365: 0 - 365
# Range of number_of_reviews: 0 - 1425
# Range of number_of_reviews_ltm: 0 - 1314
# Range of number_of_reviews_l30d: 0 - 102
# Range of review_scores_rating: 0.0 - 5.0
# Range of review_scores_accuracy: 1.0 - 5.0
# Range of review_scores_cleanliness: 1.0 - 5.0
# Range of review_scores_checkin: 1.0 - 5.0
# Range of review_scores_communication: 1.0 - 5.0
# Range of review_scores_location: 1.0 - 5.0
# Range of review_scores_value: 1.0 - 5.0
# Range of license: nan - nan
# Range of calculated_host_listings_count: 1 - 185
# Range of calculated_host_listings_count_entire_homes: 0 - 185
# Range of calculated_host_listings_count_private_rooms: 0 - 73
# Range of calculated_host_listings_count_shared_rooms: 0 - 2
# Range of reviews_per_month: 0.01 - 99.19
# ====================================================================================================================================================================================
# EDA for neighbor:
# Rows, Columns: (35, 2)
# Missing Values:
#  neighbourhood_group    35
# neighbourhood           0
# dtype: int64
# Numerical Features: ['neighbourhood_group']
# Categorical Features: ['neighbourhood']
# Mean of Numerical Features:
#  neighbourhood_group   NaN
# dtype: float64
# Standard Deviation of Numerical Features:
#  neighbourhood_group   NaN
# dtype: float64
# Range of neighbourhood_group: nan - nan
# ====================================================================================================================================================================================
# EDA for review:
# Rows, Columns: (541576, 2)
# Missing Values:
#  listing_id    0
# date          0
# dtype: int64
# Numerical Features: ['listing_id']
# Categorical Features: ['date']
# Mean of Numerical Features:
#  listing_id    4.397761e+16
# dtype: float64
# Standard Deviation of Numerical Features:
#  listing_id    1.626376e+17
# dtype: float64
# Range of listing_id: 6422 - 845011400506473008
# ====================================================================================================================================================================================
# EDA for review_detailed:
# Rows, Columns: (541576, 6)
# Missing Values:
#  listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      1
# comments         188
# dtype: int64
# Numerical Features: ['listing_id', 'id', 'reviewer_id']
# Categorical Features: ['date', 'reviewer_name', 'comments']
# Mean of Numerical Features:
#  listing_id     4.397761e+16
# id             3.039408e+17
# reviewer_id    1.755143e+08
# dtype: float64
# Standard Deviation of Numerical Features:
#  listing_id     1.626376e+17
# id             3.269955e+17
# reviewer_id    1.363403e+08
# dtype: float64
# Range of listing_id: 6422 - 845011400506473008
# Range of id: 1927 - 856554681632079117
# Range of reviewer_id: 2 - 505446639
# ====================================================================================================================================================================================
