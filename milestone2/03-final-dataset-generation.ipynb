# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /Users/eunji/Desktop/SP2024/big-data/project

# %%
df = pd.read_csv('clean-data/final-df.csv')

# %%
df
# Out:
#                         id    host_id             host_name  host_since  \
# 0       827736378366911479  475630606                  Sean  2022-08-18
# 1       592589963829194972   66506549                  Ryan  2016-04-09
# 2       772438920837360569  382318476                Maggie  2020-12-30
# 3                 33271346  118856968          Steve And Jo  2017-03-02
# 4                   484515     637272                Bianca  2011-05-28
# ...                    ...        ...                   ...         ...
# 185913               25879     101521                   Red  2010-03-31
# 185914               28749      27506                 Lauri  2009-07-25
# 185915               37738     162364         Mat And Randy  2010-07-09
# 185916               71930     334241  Michael And Veronica  2011-01-03
# 185917               84042     334241  Michael And Veronica  2011-01-03
#
#                  host_location  host_response_time host_response_rate  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                            10
# host_since                            0
# host_location                         0
# host_response_time                37230
# host_response_rate                37230
# host_acceptance_rate              31246
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# ...

# %%
df[df['review_scores_value'] == 0]
# Out:
#               id   host_id host_name  host_since             host_location  \
# 23566    9511685  49286334    Tairan  2015-11-17             Beijing China
# 31180   12876883  11452065    Arthur  2014-01-19                Atlanta GA
# 37712    6989258   7339760   Maritza  2013-07-07               New York NY
# 53622    5191617   3977023     Vaida  2012-10-25               New York NY
# 80708    6785526  35526082  Emmanuel  2015-06-11            Los Angeles CA
# 86417    3372295   2155564     Mitch  2012-04-16             United States
# 86443    6764023  35410289    Kandis  2015-06-09                   unknown
# 102366   3219230   8501813    Audrey  2013-08-28            Los Angeles CA
# 103984   1393501    157662     Libby  2010-07-03            Los Angeles CA
# 106191  12468950  48281835   Matthew  2015-11-05  California United States
# 117597     59831    287859  Lawrence  2010-11-15          San Francisco CA
# ...

# %%
df[df['number_of_reviews'] == 0]
# Out:
#                         id    host_id   host_name  host_since  \
# 0       827736378366911479  475630606        Sean  2022-08-18
# 1       592589963829194972   66506549        Ryan  2016-04-09
# 12                53654833   67343737      Martin  2016-04-15
# 13      851311584457624749  250715779       Ebony  2019-03-23
# 19                51864926   12568111  Antoinette  2014-02-25
# ...                    ...        ...         ...         ...
# 185817  848982732370093638  107434423  Blueground  2016-12-16
# 185818  849181288802249186   31669178       Donna  2015-04-21
# 185819  849355136099814004  165881852       Jacob  2018-01-04
# 185820  849539062724535549     100179     Kenneth  2010-03-28
# 185888             1417110    7622794        Leah  2013-07-21
#
#            host_location  host_response_time host_response_rate  \
# 0                Unknown      within an hour               100%
# 1          Alpharetta GA      within an hour                98%
# ...

# %%
non_zero = df[df['number_of_reviews'] != 0]

# %%
non_zero
# Out:
#                         id    host_id             host_name  host_since  \
# 2       772438920837360569  382318476                Maggie  2020-12-30
# 3                 33271346  118856968          Steve And Jo  2017-03-02
# 4                   484515     637272                Bianca  2011-05-28
# 5                 45990221  365280298           ResortShare  2020-08-31
# 6                 48030650  131978491                Daniel  2017-05-25
# ...                    ...        ...                   ...         ...
# 185913               25879     101521                   Red  2010-03-31
# 185914               28749      27506                 Lauri  2009-07-25
# 185915               37738     162364         Mat And Randy  2010-07-09
# 185916               71930     334241  Michael And Veronica  2011-01-03
# 185917               84042     334241  Michael And Veronica  2011-01-03
#
#                  host_location  host_response_time host_response_rate  \
# ...

# %%
non_zero.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             6
# host_since                            0
# host_location                         0
# host_response_time                25776
# host_response_rate                25776
# host_acceptance_rate              19832
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# ...

# %%
non_zero_not_null = non_zero[non_zero['review_scores_value'].notnull()]
non_zero_not_null
# Out:
#                         id    host_id             host_name  host_since  \
# 2       772438920837360569  382318476                Maggie  2020-12-30
# 3                 33271346  118856968          Steve And Jo  2017-03-02
# 4                   484515     637272                Bianca  2011-05-28
# 5                 45990221  365280298           ResortShare  2020-08-31
# 6                 48030650  131978491                Daniel  2017-05-25
# ...                    ...        ...                   ...         ...
# 185913               25879     101521                   Red  2010-03-31
# 185914               28749      27506                 Lauri  2009-07-25
# 185915               37738     162364         Mat And Randy  2010-07-09
# 185916               71930     334241  Michael And Veronica  2011-01-03
# 185917               84042     334241  Michael And Veronica  2011-01-03
#
#                  host_location  host_response_time host_response_rate  \
# ...

# %%
non_zero_not_null.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             2
# host_since                            0
# host_location                         0
# host_response_time                24953
# host_response_rate                24953
# host_acceptance_rate              19027
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# ...

# %%
non_zero_not_null = non_zero_not_null.drop(columns=['host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_name'])
non_zero_not_null
# Out:
#                         id    host_id  host_since           host_location  \
# 2       772438920837360569  382318476  2020-12-30                 Unknown
# 3                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 4                   484515     637272  2011-05-28  Buenos Aires Argentina
# 5                 45990221  365280298  2020-08-31               Irvine CA
# 6                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 185913               25879     101521  2010-03-31              Chicago IL
# 185914               28749      27506  2009-07-25                   Italy
# 185915               37738     162364  2010-07-09              Chicago IL
# 185916               71930     334241  2011-01-03              Chicago IL
# 185917               84042     334241  2011-01-03              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
non_zero_not_null.isnull().sum()
# Out:
# id                                0
# host_id                           0
# host_since                        0
# host_location                     0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_has_profile_pic              0
# host_identity_verified            0
# neighborhood                      0
# latitude                          0
# longitude                         0
# room_type                         0
# accommodates                      0
# num_bath                          0
# bedrooms                          0
# beds                              0
# price                             0
# number_of_reviews                 0
# review_scores_value               0
# calculated_host_listings_count    0
# city                              0
# amenities_count                   0
# neighborhood_city                 0
# full_time_host                    0
# host_verifications_clean          0
# ...

# %%
non_zero_not_null.to_csv('clean-data/zero-review-final.csv', index=False)

# %%
zero = df[df['number_of_reviews'] == 0]

# %%
zero
# Out:
#                         id    host_id   host_name  host_since  \
# 0       827736378366911479  475630606        Sean  2022-08-18
# 1       592589963829194972   66506549        Ryan  2016-04-09
# 12                53654833   67343737      Martin  2016-04-15
# 13      851311584457624749  250715779       Ebony  2019-03-23
# 19                51864926   12568111  Antoinette  2014-02-25
# ...                    ...        ...         ...         ...
# 185817  848982732370093638  107434423  Blueground  2016-12-16
# 185818  849181288802249186   31669178       Donna  2015-04-21
# 185819  849355136099814004  165881852       Jacob  2018-01-04
# 185820  849539062724535549     100179     Kenneth  2010-03-28
# 185888             1417110    7622794        Leah  2013-07-21
#
#            host_location  host_response_time host_response_rate  \
# 0                Unknown      within an hour               100%
# 1          Alpharetta GA      within an hour                98%
# ...

# %%
zero.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             4
# host_since                            0
# host_location                         0
# host_response_time                11454
# host_response_rate                11454
# host_acceptance_rate              11414
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# ...

# %%
zero = zero.drop(columns=['host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_name'])
zero
# Out:
#                         id    host_id  host_since     host_location  \
# 0       827736378366911479  475630606  2022-08-18           Unknown
# 1       592589963829194972   66506549  2016-04-09     Alpharetta GA
# 12                53654833   67343737  2016-04-15     Boca Raton FL
# 13      851311584457624749  250715779  2019-03-23  Pompano Beach FL
# 19                51864926   12568111  2014-02-25    Los Angeles CA
# ...                    ...        ...         ...               ...
# 185817  848982732370093638  107434423  2016-12-16       New York NY
# 185818  849181288802249186   31669178  2015-04-21        Chicago IL
# 185819  849355136099814004  165881852  2018-01-04        Chicago IL
# 185820  849539062724535549     100179  2010-03-28        Chicago IL
# 185888             1417110    7622794  2013-07-21        Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                      f                  1.0                        3.0
# ...

# %%
zero.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_since                            0
# host_location                         0
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# review_scores_value               40989
# calculated_host_listings_count        0
# city                                  0
# amenities_count                       0
# ...

# %%
zero.to_csv('clean-data/zero-review.csv', index=False)

# %%
concatenated_df = pd.concat([non_zero_not_null, zero])
concatenated_df
# Out:
#                         id    host_id  host_since           host_location  \
# 2       772438920837360569  382318476  2020-12-30                 Unknown
# 3                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 4                   484515     637272  2011-05-28  Buenos Aires Argentina
# 5                 45990221  365280298  2020-08-31               Irvine CA
# 6                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 185817  848982732370093638  107434423  2016-12-16             New York NY
# 185818  849181288802249186   31669178  2015-04-21              Chicago IL
# 185819  849355136099814004  165881852  2018-01-04              Chicago IL
# 185820  849539062724535549     100179  2010-03-28              Chicago IL
# 185888             1417110    7622794  2013-07-21              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
concatenated_df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_since                            0
# host_location                         0
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# review_scores_value               40989
# calculated_host_listings_count        0
# city                                  0
# amenities_count                       0
# ...

# %%
concatenated_df.to_csv('clean-data/final-final-df.csv', index=False)
