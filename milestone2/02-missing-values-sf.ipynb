# %% [markdown]
# # San Franciso

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/San Francisco/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (6936, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (6936, 29)

# %%
# Save as a new csv file
listings_detailed.to_csv('listings_detailed_clean_sf.csv', index=False)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 10]
filtered_df
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count]
# Index: []
#
# [0 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 3

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id host_name  host_since      host_location  \
# 4519  48693144  392829961     Emily  2021-03-16                NaN
# 4690  48973911  394984266     Hotel  2021-03-31                NaN
# 5450  52498132    2577011     Sarah  2012-06-07  San Francisco, CA
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 4519                NaN                NaN                   0%
# 4690     within an hour               100%                 100%
# 5450     within an hour               100%                  71%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 4519               NaN                    4  ...             0       NaN
# 4690               NaN                    5  ...             0       NaN
# 5450                 t                    2  ...             2       NaN
#
#       bathrooms_text bedrooms beds  \
# 4519             NaN      NaN  NaN
# 4690             NaN      NaN  NaN
# 5450  1 private bath      1.0  1.0
#
#                                               amenities  price  \
# 4519  ["Bed sheets and pillows", "Free wifi", "ROIL ...    0.0
# 4690  ["Toiletries", "Free wifi", "Limited housekeep...    0.0
# 5450  ["Essentials", "Carbon monoxide alarm", "Share...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 4519                  0                 NaN                               1
# 4690                 10                 4.2                               1
# 5450                  3                 5.0                               2
#
# [3 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id host_name  host_since host_location  \
# 4519  48693144  392829961     Emily  2021-03-16           NaN
# 4690  48973911  394984266     Hotel  2021-03-31           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 4519                NaN                NaN                   0%
# 4690     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 4519               NaN                    4  ...             0       NaN
# 4690               NaN                    5  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 4519            NaN      NaN  NaN
# 4690            NaN      NaN  NaN
#
#                                               amenities  price  \
# 4519  ["Bed sheets and pillows", "Free wifi", "ROIL ...    0.0
# 4690  ["Toiletries", "Free wifi", "Limited housekeep...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 4519                  0                 NaN                               1
# 4690                 10                 4.2                               1
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 3

# %%
cleaned_listings.shape
# Out:
# (6933, 29)

# %% [markdown]
# # Count 'amenities'

# %%
import ast
def count_amenities(amenities_str):
    try:
        # Convert the string representation of the list back into a list
        amenities_list = ast.literal_eval(amenities_str)
        # Return the count of items in the list
        return len(amenities_list)
    except (ValueError, SyntaxError):
        # In case of any error during conversion, return 0 (or you may choose to return NaN)
        return 0

# Apply the function to each row in the 'amenities' column and create a new column 'amenities_count'
cleaned_listings['amenities_count'] = cleaned_listings['amenities'].apply(count_amenities)

# %%
cleaned_listings['amenities_count']
# Out:
# 0       51
# 1       15
# 2       21
# 3       35
# 4       35
#         ..
# 6931    44
# 6932    42
# 6933    23
# 6934    13
# 6935    14
# Name: amenities_count, Length: 6933, dtype: int64

# %% [markdown]
# # Add 'city' column

# %%
# Add in a city column to each dataframe so that we can use this as part of the primary key/use it to conduct groupby for
# future EDA or additional analysis as final table will contain all of our listings data
cleaned_listings['city'] = 'San Francisco'

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 bath', '4 shared baths', '1.5 baths', '1 private bath',
#        '1.5 shared baths', '2 baths', nan, '3 shared baths', 'Half-bath',
#        '2 shared baths', '2.5 baths', '3 baths', '1 shared bath',
#        '3.5 baths', 'Shared half-bath', '0 shared baths',
#        'Private half-bath', '0 baths', '10 shared baths', '10 baths',
#        '4.5 baths', '4 baths', '2.5 shared baths', '5 shared baths',
#        '8 shared baths', '6 shared baths', '3.5 shared baths', '5 baths',
#        '6.5 shared baths', '5.5 baths', '6.5 baths', '8.5 baths',
#        '6 baths'], dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 bath' '4 shared baths' '1.5 baths' '1 private bath' '1.5 shared baths'
#  '2 baths' '' '3 shared baths' '0.5 baths' '2 shared baths' '2.5 baths'
#  '3 baths' '1 shared bath' '3.5 baths' '0 shared baths' '0 baths'
#  '10 shared baths' '10 baths' '4.5 baths' '4 baths' '2.5 shared baths'
#  '5 shared baths' '8 shared baths' '6 shared baths' '3.5 shared baths'
#  '5 baths' '6.5 shared baths' '5.5 baths' '6.5 baths' '8.5 baths'
#  '6 baths']

# %%
count_half_baths = (cleaned_listings['bathrooms_text'] == '0.5 baths').sum()
count_half_baths
# Out:
# 15

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#                       id    host_id host_name  host_since      host_location  \
# 11                144978     216682       Jay  2010-08-29  San Francisco, CA
# 70                596042     216682       Jay  2010-08-29  San Francisco, CA
# 162               745957     576273    Darren  2011-05-10    San Anselmo, CA
# 163               747167     576273    Darren  2011-05-10    San Anselmo, CA
# 284              1031899    5678214     Glenn  2013-03-29  San Francisco, CA
# 289              1273394    4836128    Vivian  2013-01-24      Kentfield, CA
# 317              1094764     172460     Leila  2010-07-19        Raleigh, NC
# 4496            48327527  369574451    Angela  2020-09-27  San Francisco, CA
# 4723            50169742  131200418      Lois  2017-05-20  San Francisco, CA
# 5296            52426464  420182099       Sam  2021-08-25  San Francisco, CA
# 5606            52842642   68432368     Brian  2016-04-22  San Francisco, CA
# 6821  836205079175974186  351395739      Tony  2020-06-22                NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 11    within a few hours               100%                 100%
# 70    within a few hours               100%                 100%
# 162                  NaN                NaN                  NaN
# 163                  NaN                NaN                  NaN
# 284   within a few hours               100%                 100%
# 289       within an hour               100%                  NaN
# 317   within a few hours               100%                  54%
# 4496  a few days or more                 0%                   0%
# 4723      within an hour               100%                  95%
# 5296      within an hour               100%                 100%
# 5606        within a day               100%                  60%
# 6821  within a few hours                60%                 100%
#
#      host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms  \
# 11                   t                    9  ...                      1.0
# 70                   t                    9  ...                      1.0
# 162                  f                    3  ...                      1.0
# 163                  f                    3  ...                      1.0
# 284                  f                    2  ...                      1.0
# 289                  f                    2  ...                      1.0
# 317                  f                    2  ...                      1.0
# 4496                 f                    1  ...                      1.0
# 4723                 t                   49  ...                      1.0
# 5296                 t                   10  ...                      1.0
# 5606                 t                    4  ...                      1.0
# 6821                 f                    3  ...                      1.0
#
#      beds                                          amenities  price  \
# 11    1.0  ["Essentials", "Bed linens", "Carbon monoxide ...   55.0
# 70    1.0  ["Oven", "Cooking basics", "Host greets you", ...   60.0
# 162   1.0  ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  500.0
# 163   1.0  ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  600.0
# 284   NaN        ["Dryer", "Dedicated workspace", "Kitchen"]  110.0
# 289   NaN  ["Courtyard view", "TV", "Free parking on prem...  500.0
# 317   1.0                                                 []  150.0
# 4496  1.0  ["Cooking basics", "Shampoo", "TV", "Free park...   47.0
# 4723  1.0  ["Oven", "Self check-in", "Luggage dropoff all...   55.0
# 5296  1.0  ["Cooking basics", "Shampoo", "TV", "Dining ta...   43.0
# 5606  2.0  ["Oven", "Self check-in", "Cooking basics", "L...   66.0
# 6821  1.0  ["Essentials", "Carbon monoxide alarm", "Dishe...   46.0
#
#      number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 11                 121                 4.67                               9
# 70                 101                 4.70                               9
# 162                  0                  NaN                               3
# 163                  0                  NaN                               3
# 284                  7                 4.86                               2
# 289                  0                  NaN                               2
# 317                  1                 5.00                               2
# 4496                 1                 5.00                               1
# 4723                 7                 4.71                              25
# 5296                 4                 5.00                              10
# 5606                 3                 4.67                               2
# 6821                 0                  NaN                               3
#
#      amenities_count           city
# 11                19  San Francisco
# 70                24  San Francisco
# 162                5  San Francisco
# 163                5  San Francisco
# 284                3  San Francisco
# 289               10  San Francisco
# 317                0  San Francisco
# 4496              28  San Francisco
# 4723              35  San Francisco
# 5296              32  San Francisco
# 5606              28  San Francisco
# 6821              20  San Francisco
#
# [12 rows x 31 columns]

# %%
empty_bathrooms_text_ids = cleaned_listings[cleaned_listings['bathrooms_text'] == '']['id']
print(len(empty_bathrooms_text_ids))
# Out:
# 12

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#                       id  bedrooms  beds  bathrooms_text
# 0                    958       1.0   2.0          1 bath
# 1                   5858       2.0   2.0          1 bath
# 2                   8142       1.0   1.0  4 shared baths
# 3                   8339       2.0   2.0       1.5 baths
# 4                   8739       1.0   1.0  1 private bath
# ...                  ...       ...   ...             ...
# 6931  818195233784141985       1.0   1.0          1 bath
# 6932  818231243893035313       1.0   1.0          1 bath
# 6933  818396267693629070       1.0   1.0   1 shared bath
# 6934  818474518435984613       1.0   1.0   1 shared bath
# 6935  818887060432463897       1.0   1.0          1 bath
#
# [6933 rows x 4 columns]

# %%
# # check for the previous NA rows in bathrooms text
filled_cleaned_listings[filled_cleaned_listings['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                       id    host_id host_name  host_since      host_location  \
# 11                144978     216682       Jay  2010-08-29  San Francisco, CA
# 70                596042     216682       Jay  2010-08-29  San Francisco, CA
# 162               745957     576273    Darren  2011-05-10    San Anselmo, CA
# 163               747167     576273    Darren  2011-05-10    San Anselmo, CA
# 284              1031899    5678214     Glenn  2013-03-29  San Francisco, CA
# 289              1273394    4836128    Vivian  2013-01-24      Kentfield, CA
# 317              1094764     172460     Leila  2010-07-19        Raleigh, NC
# 4496            48327527  369574451    Angela  2020-09-27  San Francisco, CA
# 4723            50169742  131200418      Lois  2017-05-20  San Francisco, CA
# 5296            52426464  420182099       Sam  2021-08-25  San Francisco, CA
# 5606            52842642   68432368     Brian  2016-04-22  San Francisco, CA
# 6821  836205079175974186  351395739      Tony  2020-06-22                NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 11    within a few hours               100%                 100%
# 70    within a few hours               100%                 100%
# 162                  NaN                NaN                  NaN
# 163                  NaN                NaN                  NaN
# 284   within a few hours               100%                 100%
# 289       within an hour               100%                  NaN
# 317   within a few hours               100%                  54%
# 4496  a few days or more                 0%                   0%
# 4723      within an hour               100%                  95%
# 5296      within an hour               100%                 100%
# 5606        within a day               100%                  60%
# 6821  within a few hours                60%                 100%
#
#      host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms  \
# 11                   t                    9  ...        1.0 bath      1.0
# 70                   t                    9  ...        1.0 bath      1.0
# 162                  f                    3  ...        1.0 bath      1.0
# 163                  f                    3  ...        1.0 bath      1.0
# 284                  f                    2  ...        1.0 bath      1.0
# 289                  f                    2  ...        1.0 bath      1.0
# 317                  f                    2  ...        1.0 bath      1.0
# 4496                 f                    1  ...        1.0 bath      1.0
# 4723                 t                   49  ...        1.0 bath      1.0
# 5296                 t                   10  ...        1.0 bath      1.0
# 5606                 t                    4  ...        1.0 bath      1.0
# 6821                 f                    3  ...        1.0 bath      1.0
#
#      beds                                          amenities  price  \
# 11    1.0  ["Essentials", "Bed linens", "Carbon monoxide ...   55.0
# 70    1.0  ["Oven", "Cooking basics", "Host greets you", ...   60.0
# 162   1.0  ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  500.0
# 163   1.0  ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  600.0
# 284   NaN        ["Dryer", "Dedicated workspace", "Kitchen"]  110.0
# 289   NaN  ["Courtyard view", "TV", "Free parking on prem...  500.0
# 317   1.0                                                 []  150.0
# 4496  1.0  ["Cooking basics", "Shampoo", "TV", "Free park...   47.0
# 4723  1.0  ["Oven", "Self check-in", "Luggage dropoff all...   55.0
# 5296  1.0  ["Cooking basics", "Shampoo", "TV", "Dining ta...   43.0
# 5606  2.0  ["Oven", "Self check-in", "Cooking basics", "L...   66.0
# 6821  1.0  ["Essentials", "Carbon monoxide alarm", "Dishe...   46.0
#
#      number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 11                 121                 4.67                               9
# 70                 101                 4.70                               9
# 162                  0                  NaN                               3
# 163                  0                  NaN                               3
# 284                  7                 4.86                               2
# 289                  0                  NaN                               2
# 317                  1                 5.00                               2
# 4496                 1                 5.00                               1
# 4723                 7                 4.71                              25
# 5296                 4                 5.00                              10
# 5606                 3                 4.67                               2
# 6821                 0                  NaN                               3
#
#      amenities_count           city
# 11                19  San Francisco
# 70                24  San Francisco
# 162                5  San Francisco
# 163                5  San Francisco
# 284                3  San Francisco
# 289               10  San Francisco
# 317                0  San Francisco
# 4496              28  San Francisco
# 4723              35  San Francisco
# 5296              32  San Francisco
# 5606              28  San Francisco
# 6821              20  San Francisco
#
# [12 rows x 31 columns]

# %% [markdown]
# Note: Looking back to the oringinal data original data, the entries with id '49229073' was deleted in the begging as it had 0 accomodates

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#       bathrooms_text  num_bath
# 0             1 bath       1.0
# 1             1 bath       1.0
# 2     4 shared baths       4.0
# 3          1.5 baths       1.5
# 4     1 private bath       1.0
# ...              ...       ...
# 6931          1 bath       1.0
# 6932          1 bath       1.0
# 6933   1 shared bath       1.0
# 6934   1 shared bath       1.0
# 6935          1 bath       1.0
#
# [6933 rows x 2 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 32 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  4. ,  1.5,  2. ,  3. ,  0.5,  2.5,  3.5,  0. , 10. ,  4.5,
#         5. ,  8. ,  6. ,  6.5,  5.5,  8.5])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#      id  host_id         host_name  host_since      host_location  \
# 0   958     1169             Holly  2008-07-31  San Francisco, CA
# 1  5858     8904  Philip And Tania  2009-03-02  San Francisco, CA
# 2  8142    21994             Aaron  2009-06-17  San Francisco, CA
# 3  8339    24215              Rosy  2009-07-02  San Francisco, CA
# 4  8739     7149      Ivan & Wendy  2009-01-27  San Francisco, CA
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0      within an hour               100%                 100%
# 1  within a few hours                80%                  71%
# 2      within an hour               100%                  73%
# 3  within a few hours               100%                   0%
# 4      within an hour               100%                  90%
#
#   host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                 t                    1  ...       1.0  2.0
# 1                 f                    2  ...       2.0  2.0
# 2                 f                   13  ...       1.0  1.0
# 3                 f                    2  ...       2.0  2.0
# 4                 t                    2  ...       1.0  1.0
#
#                                            amenities  price number_of_reviews  \
# 0  ["Oven", "Self check-in", "Cooking basics", "L...  202.0               383
# 1  ["Essentials", "Carbon monoxide alarm", "Hange...  235.0               111
# 2  ["Security cameras on property", "Host greets ...   56.0                 9
# 3  ["Oven", "Cooking basics", "TV", "Smoke alarm"...  575.0                28
# 4  ["Paid parking garage off premises", "Luggage ...  110.0               770
#
#   review_scores_value  calculated_host_listings_count  amenities_count  \
# 0                4.76                               1               51
# 1                4.68                               1               15
# 2                4.67                              13               21
# 3                4.75                               2               35
# 4                4.74                               2               35
#
#             city  num_bath
# 0  San Francisco       1.0
# 1  San Francisco       1.0
# 2  San Francisco       4.0
# 3  San Francisco       1.5
# 4  San Francisco       1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  2.,  3., nan,  4.,  5.,  6.,  7.,  8.,  9., 11.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 2.,  1.,  3.,  6.,  5.,  4.,  7., nan,  8., 10., 12.,  9., 16.,
#        11.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                       id    host_id       host_name  host_since  \
# 10                 10578      37049          Andrew  2009-09-08
# 20                504146    2486135           Laura  2012-05-28
# 28                 18231      70224  Arlene Helfand  2010-01-13
# 34                175090     127367        Michelle  2010-05-18
# 35                175102     127367        Michelle  2010-05-18
# ...                  ...        ...             ...         ...
# 6807  808622297875325704  389697794           David  2021-02-22
# 6808  808622402293119774  389697794           David  2021-02-22
# 6852  831285327472387448  415840703        Anyplace  2021-07-29
# 6853  831287715236252567  415840703        Anyplace  2021-07-29
# 6914  815566499839011227  263502162         Landing  2019-05-22
#
#                host_location  host_response_time host_response_rate  \
# 10         San Francisco, CA        within a day               100%
# 20         San Francisco, CA  within a few hours               100%
# 28         San Francisco, CA  within a few hours               100%
# 34                Sonoma, CA  within a few hours               100%
# 35                Sonoma, CA  within a few hours               100%
# ...                      ...                 ...                ...
# 6807  North Myrtle Beach, SC      within an hour                99%
# 6808  North Myrtle Beach, SC      within an hour                99%
# 6852       San Francisco, CA      within an hour               100%
# 6853       San Francisco, CA      within an hour               100%
# 6914       San Francisco, CA  within a few hours                91%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 10                    NaN                 f                    1  ...
# 20                    93%                 t                    1  ...
# 28                    60%                 f                    1  ...
# 34                    87%                 f                    8  ...
# 35                    87%                 f                    8  ...
# ...                   ...               ...                  ...  ...
# 6807                  70%                 t                  795  ...
# 6808                  70%                 t                  795  ...
# 6852                  80%                 t                   66  ...
# 6853                  80%                 t                   66  ...
# 6914                  99%                 f                 3282  ...
#
#       bedrooms beds                                          amenities  price  \
# 10         NaN  1.0  ["Essentials", "Carbon monoxide alarm", "Hange...   79.0
# 20         NaN  2.0  ["Self check-in", "Luggage dropoff allowed", "...  295.0
# 28         NaN  2.0  ["Oven", "Cooking basics", "Shampoo", "Host gr...   95.0
# 34         NaN  2.0  ["Self check-in", "Cooking basics", "Luggage d...  120.0
# 35         NaN  2.0  ["Oven", "Self check-in", "Cooking basics", "L...  130.0
# ...        ...  ...                                                ...    ...
# 6807       NaN  2.0  ["Self check-in", "Cooking basics", "Luggage d...  243.0
# 6808       NaN  2.0  ["Self check-in", "Cooking basics", "Luggage d...  243.0
# 6852       NaN  1.0  ["Free resort access", "Self check-in", "Cooki...  135.0
# 6853       NaN  1.0  ["Free resort access", "Self check-in", "Cooki...  135.0
# 6914       NaN  1.0  ["Essentials", "Bed linens", "Carbon monoxide ...  153.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 10                  18                4.75                               1
# 20                 111                4.78                               1
# 28                  69                4.75                               1
# 34                  26                4.31                               6
# 35                  54                4.49                               6
# ...                ...                 ...                             ...
# 6807                 0                 NaN                              25
# 6808                 0                 NaN                              25
# 6852                 0                 NaN                              24
# 6853                 0                 NaN                              24
# 6914                 0                 NaN                               7
#
#       amenities_count           city  num_bath
# 10                 14  San Francisco       1.0
# 20                 39  San Francisco       1.0
# 28                 31  San Francisco       1.0
# 34                 26  San Francisco       1.0
# 35                 30  San Francisco       1.0
# ...               ...            ...       ...
# 6807               32  San Francisco       1.0
# 6808               32  San Francisco       1.0
# 6852               62  San Francisco       1.0
# 6853               61  San Francisco       1.0
# 6914               17  San Francisco       1.0
#
# [943 rows x 31 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                       id    host_id               host_name  host_since  \
# 253              1201159    6561127                    Omid  2013-05-24
# 284              1031899    5678214                   Glenn  2013-03-29
# 289              1273394    4836128                  Vivian  2013-01-24
# 356               137129     639671                    Mark  2011-05-29
# 371              1531273     104075                  Jeanne  2010-04-06
# ...                  ...        ...                     ...         ...
# 5528            52759127  157999191                  Berlin  2017-11-09
# 5973  700262606800867046   17213536                    Kris  2014-06-24
# 6782  827557831626079015  219930816  Sonder (San Francisco)  2018-10-10
# 6784  827563145102538925  219930816  Sonder (San Francisco)  2018-10-10
# 6785  827572923404164888  219930816  Sonder (San Francisco)  2018-10-10
#
#           host_location  host_response_time host_response_rate  \
# 253   San Francisco, CA  within a few hours               100%
# 284   San Francisco, CA  within a few hours               100%
# 289       Kentfield, CA      within an hour               100%
# 356   San Francisco, CA  within a few hours               100%
# 371   San Francisco, CA                 NaN                NaN
# ...                 ...                 ...                ...
# 5528      Lafayette, CA      within an hour               100%
# 5973       Carlsbad, CA        within a day               100%
# 6782  San Francisco, CA      within an hour               100%
# 6784  San Francisco, CA      within an hour               100%
# 6785  San Francisco, CA      within an hour               100%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 253                  100%                 t                    1  ...
# 284                  100%                 f                    2  ...
# 289                   NaN                 f                    2  ...
# 356                   38%                 f                    2  ...
# 371                   NaN                 f                    1  ...
# ...                   ...               ...                  ...  ...
# 5528                  98%                 f                   24  ...
# 5973                  NaN                 f                    1  ...
# 6782                  99%                 f                   18  ...
# 6784                  99%                 f                   18  ...
# 6785                  99%                 f                   18  ...
#
#       bedrooms beds                                          amenities  price  \
# 253        NaN  NaN  ["Oven", "Cooking basics", "Luggage dropoff al...   80.0
# 284        1.0  NaN        ["Dryer", "Dedicated workspace", "Kitchen"]  110.0
# 289        1.0  NaN  ["Courtyard view", "TV", "Free parking on prem...  500.0
# 356        3.0  NaN  ["Oven", "Cooking basics", "Dining table", "Sm...  695.0
# 371        1.0  NaN  ["Oven", "Self check-in", "Cooking basics", "L...  235.0
# ...        ...  ...                                                ...    ...
# 5528       1.0  NaN  ["Essentials", "Carbon monoxide alarm", "Hange...   55.0
# 5973       1.0  NaN                     ["Elevator", "Washer", "Wifi"]  100.0
# 6782       NaN  NaN  ["Essentials", "Bed linens", "Coffee maker", "...  289.0
# 6784       NaN  NaN  ["Essentials", "Bed linens", "Coffee maker", "...  222.0
# 6785       NaN  NaN  ["Essentials", "Bed linens", "Coffee maker", "...  222.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 253                 44                4.70                               1
# 284                  7                4.86                               2
# 289                  0                 NaN                               2
# 356                  2                4.50                               1
# 371                104                4.55                               1
# ...                ...                 ...                             ...
# 5528                 5                3.40                              24
# 5973                 0                 NaN                               1
# 6782                 0                 NaN                              18
# 6784                 0                 NaN                              18
# 6785                 0                 NaN                              18
#
#       amenities_count           city  num_bath
# 253                36  San Francisco       1.0
# 284                 3  San Francisco       1.0
# 289                10  San Francisco       1.0
# 356                36  San Francisco       2.5
# 371                30  San Francisco       1.0
# ...               ...            ...       ...
# 5528               17  San Francisco       1.0
# 5973                3  San Francisco       0.0
# 6782               16  San Francisco       1.0
# 6784               16  San Francisco       1.0
# 6785               16  San Francisco       1.0
#
# [118 rows x 31 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[updated_df['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                       id    host_id host_name  host_since      host_location  \
# 11                144978     216682       Jay  2010-08-29  San Francisco, CA
# 70                596042     216682       Jay  2010-08-29  San Francisco, CA
# 162               745957     576273    Darren  2011-05-10    San Anselmo, CA
# 163               747167     576273    Darren  2011-05-10    San Anselmo, CA
# 284              1031899    5678214     Glenn  2013-03-29  San Francisco, CA
# 289              1273394    4836128    Vivian  2013-01-24      Kentfield, CA
# 317              1094764     172460     Leila  2010-07-19        Raleigh, NC
# 4496            48327527  369574451    Angela  2020-09-27  San Francisco, CA
# 4723            50169742  131200418      Lois  2017-05-20  San Francisco, CA
# 5296            52426464  420182099       Sam  2021-08-25  San Francisco, CA
# 5606            52842642   68432368     Brian  2016-04-22  San Francisco, CA
# 6821  836205079175974186  351395739      Tony  2020-06-22                NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 11    within a few hours               100%                 100%
# 70    within a few hours               100%                 100%
# 162                  NaN                NaN                  NaN
# 163                  NaN                NaN                  NaN
# 284   within a few hours               100%                 100%
# 289       within an hour               100%                  NaN
# 317   within a few hours               100%                  54%
# 4496  a few days or more                 0%                   0%
# 4723      within an hour               100%                  95%
# 5296      within an hour               100%                 100%
# 5606        within a day               100%                  60%
# 6821  within a few hours                60%                 100%
#
#      host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 11                   t                    9  ...       1.0  1.0
# 70                   t                    9  ...       1.0  1.0
# 162                  f                    3  ...       1.0  1.0
# 163                  f                    3  ...       1.0  1.0
# 284                  f                    2  ...       1.0  1.0
# 289                  f                    2  ...       1.0  1.0
# 317                  f                    2  ...       1.0  1.0
# 4496                 f                    1  ...       1.0  1.0
# 4723                 t                   49  ...       1.0  1.0
# 5296                 t                   10  ...       1.0  1.0
# 5606                 t                    4  ...       1.0  2.0
# 6821                 f                    3  ...       1.0  1.0
#
#                                               amenities  price  \
# 11    ["Essentials", "Bed linens", "Carbon monoxide ...   55.0
# 70    ["Oven", "Cooking basics", "Host greets you", ...   60.0
# 162   ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  500.0
# 163   ["Washer", "Dryer", "Wifi", "Heating", "Kitchen"]  600.0
# 284         ["Dryer", "Dedicated workspace", "Kitchen"]  110.0
# 289   ["Courtyard view", "TV", "Free parking on prem...  500.0
# 317                                                  []  150.0
# 4496  ["Cooking basics", "Shampoo", "TV", "Free park...   47.0
# 4723  ["Oven", "Self check-in", "Luggage dropoff all...   55.0
# 5296  ["Cooking basics", "Shampoo", "TV", "Dining ta...   43.0
# 5606  ["Oven", "Self check-in", "Cooking basics", "L...   66.0
# 6821  ["Essentials", "Carbon monoxide alarm", "Dishe...   46.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 11                 121                4.67                               9
# 70                 101                4.70                               9
# 162                  0                 NaN                               3
# 163                  0                 NaN                               3
# 284                  7                4.86                               2
# 289                  0                 NaN                               2
# 317                  1                5.00                               2
# 4496                 1                5.00                               1
# 4723                 7                4.71                              25
# 5296                 4                5.00                              10
# 5606                 3                4.67                               2
# 6821                 0                 NaN                               3
#
#       amenities_count           city  num_bath
# 11                 19  San Francisco       1.0
# 70                 24  San Francisco       1.0
# 162                 5  San Francisco       1.0
# 163                 5  San Francisco       1.0
# 284                 3  San Francisco       1.0
# 289                10  San Francisco       1.0
# 317                 0  San Francisco       1.0
# 4496               28  San Francisco       1.0
# 4723               35  San Francisco       1.0
# 5296               32  San Francisco       1.0
# 5606               28  San Francisco       1.0
# 6821               20  San Francisco       1.0
#
# [12 rows x 31 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 2.,  1.,  3.,  6.,  5.,  4.,  7.,  8., 10., 12.,  0.,  9., 16.,
#        11.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6.,  7.,  0.,  8.,  9., 11.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2008-07-31', '2009-03-02', '2009-06-17', ..., '2023-01-31',
#        '2023-02-03', '2023-02-02'], dtype=object)

# %%
updated_df[updated_df['host_since'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 1219 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 1219

# %%
updated_df['host_location'].unique()
# Out:
# array(['San Francisco, CA', 'Palm Springs, CA', 'Austin, TX',
#        'Sonoma, CA', 'Santa Fe, NM', 'Dublin, CA', 'Mariposa, CA',
#        'United States', 'San Anselmo, CA', 'California, United States',
#        'Los Angeles, CA', 'Castro Valley, CA', 'unknown',
#        'Connecticut, United States', 'Seattle, WA', 'Kentfield, CA',
#        'Raleigh, NC', 'Berkeley, CA', 'Sausalito, CA', 'Oakland, CA',
#        'Chicago, IL', 'Palo Alto, CA', 'Portland, OR', 'Holland, MI',
#        'Napa, CA', 'Sacramento, CA', 'Bozeman, MT', 'Portola Valley, CA',
#        'Bali, Indonesia', 'Wilson, WY', 'Belmont, CA', 'Menlo Park, CA',
#        'Reno, NV', 'New York, NY', 'Troy, NY', 'Redwood City, CA',
#        'New Orleans, LA', 'Bellevue, WA', 'Atherton, CA',
#        'New York, United States', 'Honolulu, HI', 'Denver, CO',
#        'Auckland, New Zealand', 'Santa Barbara, CA', 'Boulder, CO',
#        'San Diego, CA', 'Brisbane, CA', 'Danville, CA', 'Penn Valley, CA',
#        'Discovery Bay, CA', 'Aptos, CA', 'Kansas City, MO',
#        'Los Altos, CA', 'Truckee, CA', 'Alamo, CA',
#        'London, United Kingdom', 'Stanford, CA', 'Papaikou, HI',
#        'San Jose, CA', 'El Dorado Hills, CA', 'Davie, FL',
#        'Fukuoka, Japan', 'Salt Lake City, UT', 'Athens, GA',
#        'Del Mar, CA', 'St. Helena, CA', 'Troncones, Mexico',
#        'Daly City, CA', 'Malibu, CA', 'Hackensack, NJ', 'Toronto, Canada',
#        'Cathedral City, CA', 'San Rafael, CA', 'Yucca Valley, CA',
#        'Woodside, CA', 'Irvine, CA', 'Novato, CA',
#        'Amsterdam, Netherlands', 'Aurora, CO', 'West Menlo Park, CA',
#        'Monaco', 'Kowloon, Hong Kong', 'Salvador, Brazil',
#        'Victoria, Canada', 'Calgary, Canada', 'Foster City, CA',
#        'Henderson, NV', 'Glendale, CA', 'Boca Raton, FL',
#        'Santa Cruz, CA', 'Carlsbad, CA', 'Las Vegas, NV',
#        'East Lansing, MI', 'Vancouver, Canada', 'San Mateo, CA',
#        'Mill Valley, CA', 'Edgware, United Kingdom', 'Bangkok, Thailand',
#        'San Bruno, CA', 'Tel Aviv-Yafo, Israel', 'Cleveland, OH',
#        'Emeryville, CA', 'Nevada City, CA', 'Manor, TX',
#        'West Palm Beach, FL', 'Sutter Creek, CA', 'Spanish Flat, CA',
#        'Richmond, CA', 'Hausen bei Würzburg, Germany',
#        'Mountain View, CA', 'Palm Beach, FL', 'Medellín, Colombia',
#        'Orlando, FL', 'Boston, MA', 'St Helena, CA', 'Los Gatos, CA',
#        'Barcelona, Spain', 'La Rochelle, France', 'Hillsborough, CA',
#        'Miami, FL', 'Grover Beach, CA', 'Florianópolis, Brazil',
#        'Bridgeport, CT', 'North Bergen, NJ', 'Cambridge, MA',
#        'Montreal, Canada', 'Toledo, OH', 'Sunnyvale, CA',
#        'Burlingame, CA', 'Grass Valley, CA', 'Michigan, United States',
#        'Cupertino, CA', 'Badamsha, Kazakhstan', 'New Delhi, India',
#        'Fort Lauderdale, FL', 'Tucson, AZ', 'Petaluma, CA',
#        'Millbrae, CA', 'Fremont, CA', 'Medford, MA',
#        'South Lake Tahoe, CA', 'Nairobi, Kenya', 'Ocean Ridge, FL',
#        'Santa Clara, CA', 'Lahaina, HI', 'Lafayette, CA', 'Milpitas, CA',
#        'Alameda, CA', 'Union City, CA', 'Missouri, United States',
#        'Hawthorne, NJ', 'Mumbai, India', 'Corte Madera, CA',
#        'Somerville, MA', 'Lafayette Springs, MS', 'Saratoga, CA',
#        'Arizona, United States', 'Sandy, UT', 'San Leandro, CA',
#        'Scottsdale, AZ', 'Dallas, TX', 'Crystal Bay, NV', 'Park City, UT',
#        'Costa Mesa, CA', 'Northbrook, IL', 'San Ramon, CA',
#        'Beech Mountain, NC', 'Hong Kong', 'Fairfield, CA',
#        'Florida, United States', 'Walnut Creek, CA', 'Claremore, OK',
#        'Larkspur, CA', 'Kingsburg, CA', 'Myrtle Beach, SC', 'Atlanta, GA',
#        'Alpharetta, GA', 'Stockholm, Sweden', 'Stirling City, CA',
#        'Paris, France', 'Stockton, CA', 'La Cañada Flintridge, CA',
#        'Chico, CA', 'Concord, CA', 'Chapel Hill, NC',
#        'Lagraulière, France', 'Pittsburgh, PA', 'San Clemente, CA',
#        'Santiago, Chile', 'Lima, Peru', 'Cardiff, United Kingdom',
#        'Den Helder, Netherlands', 'South San Francisco, CA',
#        'Marina del Rey, CA', 'Hayward, CA', 'Pleasanton, CA', 'Boise, ID',
#        'Parkland, FL', 'North Myrtle Beach, SC', 'Campbell, CA',
#        'Little River, SC', 'Independence, MO', 'Guerneville, CA',
#        'Lisbon, Portugal', 'Chula Vista, CA', 'Detroit, MI'], dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df[updated_df['host_location'] ==' ']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 7 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 4065

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   1,    2,   13,    9,    5,    6,    7,    8,    4,    3,   36,
#          31,   11,   22,   57,   20,   10,   46,   18,   16,   17,   79,
#         119,   19,   40,   29,   91,  120,  154,   25,   49,   12, 1512,
#          15,  249,   43,   14,   21,  489,   33,   32,   61,  130, 4774,
#          27,   50,   41,   77,   23,   73,  421,   44,  658,   24,   26,
#          37,   67,   68,   51,  101,  226,  245,  168,  197,  636,  289,
#         521,   47,   39,   66,  368,  173,  192,  172, 3282,  152,   34,
#         430,  374,   95,   38,   42,  273, 2600,   30, 2508,  279,  165,
#          64,  795,   28])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   1,    2,   14,    6,    3,    9,    5,   12,   17,    4,   70,
#          13,    8,   15,    7,   48,   56,   11,   10,   20,   65,   81,
#          16,   61,  129,   62,   18,   33,   66,   87,  122,   31,   34,
#         113,  138,  154,   37,   92, 1962,   25,   26,   30,   45,  403,
#          51,   40,   75,  918,   46,   50,   63,  205,   21,  169, 5310,
#          38,   27,   24,   28,   77,   19,   90,   22,  397,   55,  128,
#          83,  105,   39,  123,  570,   44,  709,   59,   86,   94,   97,
#         979,  288,   43,  177,   47,  211,  736,  415,  840,  207,  838,
#         664,  222, 4522,  118,   52,  323,   29,  179,  770,  375,  108,
#          64,  236,  163,  374, 8278, 2750,  290,  167,   58,   68,  841,
#         252])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone']", "['phone', 'work_email']", "['email']"], dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone']", "['phone', 'work_email']", "['email']"], dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  1,  13,   2,   9,   5,   6,   3,  28,  22,   4,  29,   7,  17,
#         10,  46,  12,  16,  25,  19,  15,  14,  27,  43, 154,  24,  31,
#         20,   8,  61,  41,  38, 138,  21,  11,  18,  55,  23,  36,  26])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
na = updated_df['host_has_profile_pic'].isnull().sum()
print(f'There are {na} missing values in the "host_has_profile_pic" column.')

updated_df['host_has_profile_pic'].fillna('f', inplace=True)
# Out:
# There are 0 missing values in the "host_has_profile_pic" column.

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['San Francisco, California, United States', nan,
#        'san francisco, California, United States',
#        'San Francisco, Hayes Valley, California, United States',
#        'Noe Valley - San Francisco, California, United States',
#        'San Francisco , Ca, United States',
#        'Tiburon, California, United States',
#        'Pacifica, California, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 2084

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Western Addition', 'Bernal Heights', 'Haight Ashbury', 'Mission',
#        'Outer Richmond', 'Bayview', 'Inner Richmond', 'Nob Hill',
#        'Pacific Heights', 'Outer Mission', 'Diamond Heights', 'Marina',
#        'Financial District', 'Twin Peaks', 'Castro/Upper Market',
#        'Russian Hill', 'Noe Valley', 'Chinatown', 'Glen Park',
#        'North Beach', 'Downtown/Civic Center', 'Excelsior',
#        'Potrero Hill', 'Inner Sunset', 'Parkside', 'Outer Sunset',
#        'South of Market', 'Lakeshore', 'West of Twin Peaks',
#        'Presidio Heights', 'Ocean View', 'Visitacion Valley',
#        'Crocker Amazon', 'Presidio', 'Seacliff'], dtype=object)

# %% [markdown]
# ### We are going to drop neighbourhood column for SF Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                   0
# host_id                              0
# host_name                            0
# host_since                           0
# host_location                        0
# host_response_time                1018
# host_response_rate                1018
# host_acceptance_rate               801
# host_is_superhost                    0
# host_listings_count                  0
# host_total_listings_count            0
# host_verifications                   0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# number_of_reviews                    0
# review_scores_value               1346
# calculated_host_listings_count       0
# amenities_count                      0
# city                                 0
# num_bath                             0
# dtype: int64

# %% [markdown]
# # Save the Final Dataframe

# %%
updated_df.to_csv('data/listings_detailed_after_na_sf.csv', index=False)
