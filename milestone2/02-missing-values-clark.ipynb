# %% [markdown]
# # Clark County

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/Clark County NV/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (13933, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (13933, 29)

# %%
# Save as a new csv file
listings_detailed.to_csv('listings_detailed_clean_clark.csv', index=False)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 0]
filtered_df
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count]
# Index: []
#
# [0 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 0

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 0

# %%
cleaned_listings.shape
# Out:
# (13933, 29)

# %% [markdown]
# # Count 'amenities'

# %%
import ast
def count_amenities(amenities_str):
    try:
        # Convert the string representation of the list back into a list
        amenities_list = ast.literal_eval(amenities_str)
        # Return the count of items in the list
        return len(amenities_list)
    except (ValueError, SyntaxError):
        # In case of any error during conversion, return 0 (or you may choose to return NaN)
        return 0

# Apply the function to each row in the 'amenities' column and create a new column 'amenities_count'
cleaned_listings['amenities_count'] = cleaned_listings['amenities'].apply(count_amenities)

# %%
cleaned_listings['amenities_count']
# Out:
# 0        56
# 1        46
# 2        37
# 3        25
# 4        21
#          ..
# 13928    32
# 13929    55
# 13930    34
# 13931    10
# 13932     8
# Name: amenities_count, Length: 13933, dtype: int64

# %% [markdown]
# # Add 'city' column

# %%
# Add in a city column to each dataframe so that we can use this as part of the primary key/use it to conduct groupby for
# future EDA or additional analysis as final table will contain all of our listings data
cleaned_listings['city'] = 'Clark County NV'

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['2.5 baths', '2 baths', '1.5 baths', '1 bath', '1 private bath',
#        '3 baths', '1 shared bath', '3.5 baths', '4.5 baths',
#        '1.5 shared baths', '4 baths', '2 shared baths', nan, '5 baths',
#        '0 baths', 'Shared half-bath', '0 shared baths', '3 shared baths',
#        '5.5 baths', '6 baths', '4 shared baths', '2.5 shared baths',
#        '8 baths', '6.5 baths', '9.5 baths', '7 baths', '8.5 baths',
#        '7.5 baths', '12 baths', '13.5 baths', 'Private half-bath',
#        '11 baths', '14 baths', 'Half-bath', '5.5 shared baths',
#        '10 baths', '9 baths', '3.5 shared baths'], dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['2.5 baths' '2 baths' '1.5 baths' '1 bath' '1 private bath' '3 baths'
#  '1 shared bath' '3.5 baths' '4.5 baths' '1.5 shared baths' '4 baths'
#  '2 shared baths' '' '5 baths' '0 baths' '0.5 baths' '0 shared baths'
#  '3 shared baths' '5.5 baths' '6 baths' '4 shared baths'
#  '2.5 shared baths' '8 baths' '6.5 baths' '9.5 baths' '7 baths'
#  '8.5 baths' '7.5 baths' '12 baths' '13.5 baths' '11 baths' '14 baths'
#  '5.5 shared baths' '10 baths' '9 baths' '3.5 shared baths']

# %%
count_half_baths = (cleaned_listings['bathrooms_text'] == '0.5 baths').sum()
count_half_baths
# Out:
# 8

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#                        id    host_id host_name  host_since  \
# 236               6923653   12018637       888  2014-02-07
# 308              10237778   12018637       888  2014-02-07
# 343              10426936   12018637       888  2014-02-07
# 349              11457043   12018637       888  2014-02-07
# 385              11981837   12018637       888  2014-02-07
# ...                   ...        ...       ...         ...
# 4674             49075800  231157127    Steven  2018-12-17
# 13347  840112485953424789   23020599     Ramzi  2014-10-27
# 13537  846251343784208947    3696404      Mike  2012-09-27
# 13733  851483198327421322    3696404      Mike  2012-09-27
# 13844  853523665224432797    3696404      Mike  2012-09-27
#
#                    host_location host_response_time host_response_rate  \
# 236                Las Vegas, NV     within an hour               100%
# 308                Las Vegas, NV     within an hour               100%
# 343                Las Vegas, NV     within an hour               100%
# 349                Las Vegas, NV     within an hour               100%
# 385                Las Vegas, NV     within an hour               100%
# ...                          ...                ...                ...
# 4674               Las Vegas, NV     within an hour                90%
# 13347       Jeddah, Saudi Arabia                NaN                NaN
# 13537  New Jersey, United States     within an hour                99%
# 13733  New Jersey, United States     within an hour                99%
# 13844  New Jersey, United States     within an hour                99%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 236                    73%                 f                  262  ...
# 308                    73%                 f                  262  ...
# 343                    73%                 f                  262  ...
# 349                    73%                 f                  262  ...
# 385                    73%                 f                  262  ...
# ...                    ...               ...                  ...  ...
# 4674                   56%                 f                   17  ...
# 13347                  NaN                 f                    1  ...
# 13537                  97%                 t                  282  ...
# 13733                  97%                 t                  282  ...
# 13844                  97%                 t                  282  ...
#
#        bathrooms_text bedrooms beds  \
# 236                        1.0  2.0
# 308                        1.0  2.0
# 343                        2.0  4.0
# 349                        2.0  4.0
# 385                        2.0  4.0
# ...               ...      ...  ...
# 4674                       NaN  1.0
# 13347                      1.0  1.0
# 13537                      1.0  2.0
# 13733                      1.0  2.0
# 13844                      1.0  2.0
#
#                                                amenities   price  \
# 236    ["Toaster", "Essentials", "Fire extinguisher",...  1663.0
# 308    ["Toaster", "Essentials", "Fire extinguisher",...  1663.0
# 343    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# 349    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# 385    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# ...                                                  ...     ...
# 4674   ["Essentials", "Carbon monoxide alarm", "Shamp...   350.0
# 13347                                                 []   245.0
# 13537  ["Essentials", "Fire extinguisher", "Pool", "I...    76.0
# 13733  ["Essentials", "Fire extinguisher", "Pool", "I...    75.0
# 13844  ["Toaster", "Essentials", "Fire extinguisher",...    75.0
#
#       number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 236                  55                 4.72                             262
# 308                   8                 4.13                             262
# 343                   9                 4.33                             262
# 349                  13                 4.75                             262
# 385                  11                 4.64                             262
# ...                 ...                  ...                             ...
# 4674                  2                 5.00                              15
# 13347                 0                  NaN                               1
# 13537                 0                  NaN                              39
# 13733                 0                  NaN                              39
# 13844                 0                  NaN                              39
#
#       amenities_count             city
# 236                49  Clark County NV
# 308                48  Clark County NV
# 343                54  Clark County NV
# 349                54  Clark County NV
# 385                54  Clark County NV
# ...               ...              ...
# 4674               19  Clark County NV
# 13347               0  Clark County NV
# 13537              38  Clark County NV
# 13733              30  Clark County NV
# 13844              39  Clark County NV
#
# [194 rows x 31 columns]

# %%
empty_bathrooms_text_ids = cleaned_listings[cleaned_listings['bathrooms_text'] == '']['id']
print(len(empty_bathrooms_text_ids))
# Out:
# 194

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#                        id  bedrooms  beds bathrooms_text
# 0                  875406       4.0   4.0      2.5 baths
# 1                 4024858       4.0   5.0      2.5 baths
# 2                  883590       2.0   2.0        2 baths
# 3                  890332       3.0   5.0        2 baths
# 4                 4066692       2.0   1.0      1.5 baths
# ...                   ...       ...   ...            ...
# 13928  855016574002133491       1.0   2.0         1 bath
# 13929  855024616816114216       3.0   4.0        3 baths
# 13930  855048492607950318       1.0   1.0  1 shared bath
# 13931  855207553051003465       3.0   4.0        4 baths
# 13932  855226655228223699       5.0   5.0        3 baths
#
# [13933 rows x 4 columns]

# %%
# # check for the previous NA rows in bathrooms text
filled_cleaned_listings[filled_cleaned_listings['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                        id    host_id host_name  host_since  \
# 236               6923653   12018637       888  2014-02-07
# 308              10237778   12018637       888  2014-02-07
# 343              10426936   12018637       888  2014-02-07
# 349              11457043   12018637       888  2014-02-07
# 385              11981837   12018637       888  2014-02-07
# ...                   ...        ...       ...         ...
# 4674             49075800  231157127    Steven  2018-12-17
# 13347  840112485953424789   23020599     Ramzi  2014-10-27
# 13537  846251343784208947    3696404      Mike  2012-09-27
# 13733  851483198327421322    3696404      Mike  2012-09-27
# 13844  853523665224432797    3696404      Mike  2012-09-27
#
#                    host_location host_response_time host_response_rate  \
# 236                Las Vegas, NV     within an hour               100%
# 308                Las Vegas, NV     within an hour               100%
# 343                Las Vegas, NV     within an hour               100%
# 349                Las Vegas, NV     within an hour               100%
# 385                Las Vegas, NV     within an hour               100%
# ...                          ...                ...                ...
# 4674               Las Vegas, NV     within an hour                90%
# 13347       Jeddah, Saudi Arabia                NaN                NaN
# 13537  New Jersey, United States     within an hour                99%
# 13733  New Jersey, United States     within an hour                99%
# 13844  New Jersey, United States     within an hour                99%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 236                    73%                 f                  262  ...
# 308                    73%                 f                  262  ...
# 343                    73%                 f                  262  ...
# 349                    73%                 f                  262  ...
# 385                    73%                 f                  262  ...
# ...                    ...               ...                  ...  ...
# 4674                   56%                 f                   17  ...
# 13347                  NaN                 f                    1  ...
# 13537                  97%                 t                  282  ...
# 13733                  97%                 t                  282  ...
# 13844                  97%                 t                  282  ...
#
#        bathrooms_text bedrooms beds  \
# 236          1.0 bath      1.0  2.0
# 308          1.0 bath      1.0  2.0
# 343          2.0 bath      2.0  4.0
# 349          2.0 bath      2.0  4.0
# 385          2.0 bath      2.0  4.0
# ...               ...      ...  ...
# 4674         0.5 bath      NaN  1.0
# 13347        1.0 bath      1.0  1.0
# 13537        1.0 bath      1.0  2.0
# 13733        1.0 bath      1.0  2.0
# 13844        1.0 bath      1.0  2.0
#
#                                                amenities   price  \
# 236    ["Toaster", "Essentials", "Fire extinguisher",...  1663.0
# 308    ["Toaster", "Essentials", "Fire extinguisher",...  1663.0
# 343    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# 349    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# 385    ["Toaster", "Essentials", "UN conditioner", "F...  2136.0
# ...                                                  ...     ...
# 4674   ["Essentials", "Carbon monoxide alarm", "Shamp...   350.0
# 13347                                                 []   245.0
# 13537  ["Essentials", "Fire extinguisher", "Pool", "I...    76.0
# 13733  ["Essentials", "Fire extinguisher", "Pool", "I...    75.0
# 13844  ["Toaster", "Essentials", "Fire extinguisher",...    75.0
#
#       number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 236                  55                 4.72                             262
# 308                   8                 4.13                             262
# 343                   9                 4.33                             262
# 349                  13                 4.75                             262
# 385                  11                 4.64                             262
# ...                 ...                  ...                             ...
# 4674                  2                 5.00                              15
# 13347                 0                  NaN                               1
# 13537                 0                  NaN                              39
# 13733                 0                  NaN                              39
# 13844                 0                  NaN                              39
#
#       amenities_count             city
# 236                49  Clark County NV
# 308                48  Clark County NV
# 343                54  Clark County NV
# 349                54  Clark County NV
# 385                54  Clark County NV
# ...               ...              ...
# 4674               19  Clark County NV
# 13347               0  Clark County NV
# 13537              38  Clark County NV
# 13733              30  Clark County NV
# 13844              39  Clark County NV
#
# [194 rows x 31 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#       bathrooms_text  num_bath
# 0          2.5 baths       2.5
# 1          2.5 baths       2.5
# 2            2 baths       2.0
# 3            2 baths       2.0
# 4          1.5 baths       1.5
# ...              ...       ...
# 13928         1 bath       1.0
# 13929        3 baths       3.0
# 13930  1 shared bath       1.0
# 13931        4 baths       4.0
# 13932        3 baths       3.0
#
# [13933 rows x 2 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 32 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 2.5,  2. ,  1.5,  1. ,  3. ,  3.5,  4.5,  4. ,  5. ,  0. ,  0.5,
#         5.5,  6. ,  8. ,  6.5,  9.5,  7. ,  8.5,  7.5, 12. , 13.5, 11. ,
#        14. , 10. ,  9. ])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#         id   host_id      host_name  host_since    host_location  \
# 0   875406   4621737         Jordan  2013-01-07    Las Vegas, NV
# 1  4024858  20866230          Shaun  2014-09-02    Las Vegas, NV
# 2   883590   4677994         Markus  2013-01-12  Los Angeles, CA
# 3   890332    981582  Jason & Kevin  2011-08-17    Las Vegas, NV
# 4  4066692  21090523          Maria  2014-09-08    Las Vegas, NV
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day                50%                  59%
# 1      within an hour               100%                 100%
# 2      within an hour               100%                  63%
# 3  within a few hours                84%                  27%
# 4  within a few hours               100%                 100%
#
#   host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                 f                    1  ...       4.0  4.0
# 1                 t                    1  ...       4.0  5.0
# 2                 f                    5  ...       2.0  2.0
# 3                 f                    9  ...       3.0  5.0
# 4                 f                    1  ...       2.0  1.0
#
#                                            amenities  price number_of_reviews  \
# 0  ["Toaster", "Essentials", "Free washer \u2013 ...  518.0                24
# 1  ["Essentials", "Free washer \u2013 In unit", "...  292.0               533
# 2  ["Essentials", "Free washer \u2013 In unit", "...  130.0                61
# 3  ["Washer", "First aid kit", "Backyard", "Kitch...  220.0                63
# 4  ["Essentials", "Fire extinguisher", "Washer", ...  114.0               184
#
#   review_scores_value  calculated_host_listings_count  amenities_count  \
# 0                4.62                               1               56
# 1                4.91                               1               46
# 2                4.70                               3               37
# 3                4.38                               9               25
# 4                4.77                               1               21
#
#               city  num_bath
# 0  Clark County NV       2.5
# 1  Clark County NV       2.5
# 2  Clark County NV       2.0
# 3  Clark County NV       2.0
# 4  Clark County NV       1.5
#
# [5 rows x 31 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 4.,  2.,  3., nan,  1.,  5.,  6.,  7.,  8., 10.,  9., 11., 16.,
#        12.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 4.,  5.,  2.,  1.,  3.,  7.,  6.,  9.,  8., 14., 11., 10., nan,
#        15., 12., 13., 16., 17., 18., 27., 19., 26., 25., 21., 20., 24.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                        id    host_id       host_name  host_since  \
# 5                 4068810   20488262           Harry  2014-08-24
# 32                4349688   22554257            Mark  2014-10-15
# 60                4527410   23471743           Vimal  2014-11-08
# 63                 658643    3321660  Mike And Penny  2012-08-20
# 117               4997188   12018637             888  2014-02-07
# ...                   ...        ...             ...         ...
# 13890  853718190488833928  411236970            Mari  2021-07-06
# 13893  853818133226101261  411236970            Mari  2021-07-06
# 13908  854172538995763143  411236970            Mari  2021-07-06
# 13912  854236101053187823  411236970            Mari  2021-07-06
# 13914  854257474582185307  411236970            Mari  2021-07-06
#
#        host_location  host_response_time host_response_rate  \
# 5      Las Vegas, NV      within an hour                95%
# 32        Irvine, CA                 NaN                NaN
# 60        Dallas, TX      within an hour               100%
# 63     Las Vegas, NV  within a few hours               100%
# 117    Las Vegas, NV      within an hour               100%
# ...              ...                 ...                ...
# 13890            NaN  within a few hours                96%
# 13893            NaN  within a few hours                96%
# 13908            NaN  within a few hours                96%
# 13912            NaN  within a few hours                96%
# 13914            NaN  within a few hours                96%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 5                     100%                 f                    1  ...
# 32                    100%                 t                    1  ...
# 60                    100%                 t                    1  ...
# 63                     82%                 f                    2  ...
# 117                    73%                 f                  262  ...
# ...                    ...               ...                  ...  ...
# 13890                  38%                 f                   58  ...
# 13893                  38%                 f                   58  ...
# 13908                  38%                 f                   58  ...
# 13912                  38%                 f                   58  ...
# 13914                  38%                 f                   58  ...
#
#        bedrooms beds                                          amenities  \
# 5           NaN  2.0  ["Essentials", "Shared pool", "Fire extinguish...
# 32          NaN  2.0  ["Essentials", "Pool", "Iron", "Gym", "Kitchen...
# 60          NaN  2.0  ["Essentials", "Shared pool", "Iron", "Gym", "...
# 63          NaN  2.0  ["Essentials", "Gym", "Kitchen", "Free parking...
# 117         NaN  2.0  ["Essentials", "Fire extinguisher", "Iron", "O...
# ...         ...  ...                                                ...
# 13890       NaN  1.0  ["Outdoor dining area", "Hot tub", "Carbon mon...
# 13893       NaN  2.0  ["Outdoor dining area", "Hot tub", "Carbon mon...
# 13908       NaN  1.0  ["Outdoor dining area", "Mountain view", "Carb...
# 13912       NaN  2.0  ["Carbon monoxide alarm", "Exercise equipment"...
# 13914       NaN  2.0  ["Carbon monoxide alarm", "Dedicated workspace...
#
#         price number_of_reviews review_scores_value  \
# 5       138.0               355                4.68
# 32      150.0               627                4.86
# 60      126.0               127                4.90
# 63      115.0               382                4.81
# 117    1663.0                37                4.71
# ...       ...               ...                 ...
# 13890   236.0                 0                 NaN
# 13893   308.0                 0                 NaN
# 13908   324.0                 0                 NaN
# 13912   216.0                 0                 NaN
# 13914   220.0                 0                 NaN
#
#        calculated_host_listings_count  amenities_count             city  \
# 5                                   1               47  Clark County NV
# 32                                  1               23  Clark County NV
# 60                                  1               32  Clark County NV
# 63                                  2               25  Clark County NV
# 117                               262               42  Clark County NV
# ...                               ...              ...              ...
# 13890                              30               13  Clark County NV
# 13893                              30               13  Clark County NV
# 13908                              30               16  Clark County NV
# 13912                              30               10  Clark County NV
# 13914                              30                9  Clark County NV
#
#        num_bath
# 5           1.0
# 32          1.0
# 60          1.0
# 63          1.0
# 117         1.0
# ...         ...
# 13890       1.0
# 13893       1.0
# 13908       1.0
# 13912       1.0
# 13914       1.0
#
# [1096 rows x 31 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                        id    host_id  host_name  host_since  \
# 238               9755691   48171296  LuckyStar  2015-11-04
# 256               9862496   50760426       Mark  2015-12-07
# 336               9132839   47568376     Ronnie  2015-10-27
# 341              10370600   34412723    Crystal  2015-05-28
# 373               9664608   19139775      Lorie  2014-07-29
# ...                   ...        ...        ...         ...
# 10432  734022480115189255   57287561     Eileen  2016-02-03
# 11658  789380805989716365  426975381     Sky702  2021-10-11
# 13019  830016870731731653  501737618  Bnb Green  2023-02-18
# 13338  837251708903341283    2981129      Mamie  2012-07-18
# 13840  850323740886437709  416050615      Kaori  2021-07-30
#
#             host_location  host_response_time host_response_rate  \
# 238         Las Vegas, NV      within an hour               100%
# 256         Charlotte, NC      within an hour               100%
# 336         Las Vegas, NV      within an hour                94%
# 341         Las Vegas, NV  within a few hours               100%
# 373    Cathedral City, CA  a few days or more                48%
# ...                   ...                 ...                ...
# 10432     West Covina, CA      within an hour               100%
# 11658                 NaN      within an hour               100%
# 13019                 NaN      within an hour               100%
# 13338     Los Angeles, CA      within an hour                75%
# 13840                 NaN      within an hour               100%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 238                   100%                 f                    7  ...
# 256                    99%                 t                    4  ...
# 336                    96%                 t                    4  ...
# 341                    99%                 t                    2  ...
# 373                    22%                 f                  249  ...
# ...                    ...               ...                  ...  ...
# 10432                 100%                 f                    2  ...
# 11658                 100%                 f                   51  ...
# 13019                 100%                 f                    1  ...
# 13338                   0%                 f                    3  ...
# 13840                 100%                 f                    2  ...
#
#        bedrooms beds                                          amenities  \
# 238         NaN  NaN  ["Toaster", "Essentials", "Fire extinguisher",...
# 256         NaN  NaN  ["Toaster", "Essentials", "Coffee maker: drip ...
# 336         NaN  NaN  ["Essentials", "Coffee maker: Keurig coffee ma...
# 341         NaN  NaN  ["Essentials", "Fire extinguisher", "Iron", "F...
# 373         1.0  NaN  ["Essentials", "Fire extinguisher", "Pool", "I...
# ...         ...  ...                                                ...
# 10432       1.0  NaN  ["Refrigerator", "Essentials", "Carbon monoxid...
# 11658       NaN  NaN  ["Essentials", "Free washer \u2013 In unit", "...
# 13019       NaN  NaN  ["Essentials", "Fire extinguisher", "Room-dark...
# 13338       1.0  NaN                      ["Host greets you", "Washer"]
# 13840       1.0  NaN  ["Outdoor dining area", "Shared hot tub", "Car...
#
#        price number_of_reviews review_scores_value  \
# 238    142.0               359                4.80
# 256    125.0                76                4.86
# 336     88.0               272                4.91
# 341     92.0                43                4.93
# 373    439.0                 1                5.00
# ...      ...               ...                 ...
# 10432   56.0                 3                4.00
# 11658   94.0                 6                4.67
# 13019   81.0                 0                 NaN
# 13338   70.0                 0                 NaN
# 13840   39.0                 1                5.00
#
#        calculated_host_listings_count  amenities_count             city  \
# 238                                 7               56  Clark County NV
# 256                                 3               38  Clark County NV
# 336                                 2               37  Clark County NV
# 341                                 2               22  Clark County NV
# 373                                17               27  Clark County NV
# ...                               ...              ...              ...
# 10432                               2               20  Clark County NV
# 11658                              51               42  Clark County NV
# 13019                               1               37  Clark County NV
# 13338                               2                2  Clark County NV
# 13840                               2               18  Clark County NV
#
#        num_bath
# 238         1.5
# 256         0.0
# 336         1.0
# 341         1.0
# 373         1.0
# ...         ...
# 10432       1.0
# 11658       1.0
# 13019       1.0
# 13338       0.0
# 13840       1.0
#
# [82 rows x 31 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[updated_df['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                        id    host_id host_name  host_since  \
# 236               6923653   12018637       888  2014-02-07
# 308              10237778   12018637       888  2014-02-07
# 343              10426936   12018637       888  2014-02-07
# 349              11457043   12018637       888  2014-02-07
# 385              11981837   12018637       888  2014-02-07
# ...                   ...        ...       ...         ...
# 4674             49075800  231157127    Steven  2018-12-17
# 13347  840112485953424789   23020599     Ramzi  2014-10-27
# 13537  846251343784208947    3696404      Mike  2012-09-27
# 13733  851483198327421322    3696404      Mike  2012-09-27
# 13844  853523665224432797    3696404      Mike  2012-09-27
#
#                    host_location host_response_time host_response_rate  \
# 236                Las Vegas, NV     within an hour               100%
# 308                Las Vegas, NV     within an hour               100%
# 343                Las Vegas, NV     within an hour               100%
# 349                Las Vegas, NV     within an hour               100%
# 385                Las Vegas, NV     within an hour               100%
# ...                          ...                ...                ...
# 4674               Las Vegas, NV     within an hour                90%
# 13347       Jeddah, Saudi Arabia                NaN                NaN
# 13537  New Jersey, United States     within an hour                99%
# 13733  New Jersey, United States     within an hour                99%
# 13844  New Jersey, United States     within an hour                99%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 236                    73%                 f                  262  ...
# 308                    73%                 f                  262  ...
# 343                    73%                 f                  262  ...
# 349                    73%                 f                  262  ...
# 385                    73%                 f                  262  ...
# ...                    ...               ...                  ...  ...
# 4674                   56%                 f                   17  ...
# 13347                  NaN                 f                    1  ...
# 13537                  97%                 t                  282  ...
# 13733                  97%                 t                  282  ...
# 13844                  97%                 t                  282  ...
#
#        bedrooms beds                                          amenities  \
# 236         1.0  2.0  ["Toaster", "Essentials", "Fire extinguisher",...
# 308         1.0  2.0  ["Toaster", "Essentials", "Fire extinguisher",...
# 343         2.0  4.0  ["Toaster", "Essentials", "UN conditioner", "F...
# 349         2.0  4.0  ["Toaster", "Essentials", "UN conditioner", "F...
# 385         2.0  4.0  ["Toaster", "Essentials", "UN conditioner", "F...
# ...         ...  ...                                                ...
# 4674        1.0  1.0  ["Essentials", "Carbon monoxide alarm", "Shamp...
# 13347       1.0  1.0                                                 []
# 13537       1.0  2.0  ["Essentials", "Fire extinguisher", "Pool", "I...
# 13733       1.0  2.0  ["Essentials", "Fire extinguisher", "Pool", "I...
# 13844       1.0  2.0  ["Toaster", "Essentials", "Fire extinguisher",...
#
#         price number_of_reviews review_scores_value  \
# 236    1663.0                55                4.72
# 308    1663.0                 8                4.13
# 343    2136.0                 9                4.33
# 349    2136.0                13                4.75
# 385    2136.0                11                4.64
# ...       ...               ...                 ...
# 4674    350.0                 2                5.00
# 13347   245.0                 0                 NaN
# 13537    76.0                 0                 NaN
# 13733    75.0                 0                 NaN
# 13844    75.0                 0                 NaN
#
#        calculated_host_listings_count  amenities_count             city  \
# 236                               262               49  Clark County NV
# 308                               262               48  Clark County NV
# 343                               262               54  Clark County NV
# 349                               262               54  Clark County NV
# 385                               262               54  Clark County NV
# ...                               ...              ...              ...
# 4674                               15               19  Clark County NV
# 13347                               1                0  Clark County NV
# 13537                              39               38  Clark County NV
# 13733                              39               30  Clark County NV
# 13844                              39               39  Clark County NV
#
#        num_bath
# 236         1.0
# 308         1.0
# 343         2.0
# 349         2.0
# 385         2.0
# ...         ...
# 4674        0.5
# 13347       1.0
# 13537       1.0
# 13733       1.0
# 13844       1.0
#
# [194 rows x 31 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 4.,  5.,  2.,  1.,  3.,  7.,  6.,  9.,  8., 14., 11., 10.,  0.,
#        15., 12., 13., 16., 17., 18., 27., 19., 26., 25., 21., 20., 24.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 4.,  2.,  3.,  1.,  5.,  6.,  7.,  0.,  8., 10.,  9., 11., 16.,
#        12.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2013-01-07', '2014-09-02', '2013-01-12', ..., '2023-03-24',
#        '2023-01-16', '2015-03-25'], dtype=object)

# %%
updated_df[updated_df['host_since'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 4028 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 4028

# %%
updated_df['host_location'].unique()
# Out:
# array(['Las Vegas, NV', 'Los Angeles, CA', 'unknown', 'New York, NY',
#        'United States', 'New Orleans, LA', 'Prague, Czechia',
#        'San Diego, CA', 'New Jersey, United States', 'San Francisco, CA',
#        'Chicago, IL', 'Irvine, CA', 'Rancho Santa Fe, CA', 'Phoenix, AZ',
#        'Sacramento, CA', 'Pennsylvania, United States', 'San Jose, CA',
#        'Dallas, TX', 'Huntington Beach, CA', 'Henderson, NV',
#        'Fontana, CA', 'Reno, NV', 'North Las Vegas, NV',
#        'Fort Pierce, FL', 'Arizona, United States', 'Paradise Valley, AZ',
#        'Oakland, CA', 'Rowland Heights, CA', 'Mukilteo, WA', 'Miami, FL',
#        'La Mirada, CA', 'Fort Lauderdale, FL', 'Vancouver, Canada',
#        'California, United States', 'Ciudad Obregón, Mexico',
#        'Hermosa Beach, CA', 'Cathedral City, CA', 'Valley Stream, NY',
#        'Nevada, United States', 'Maple Grove, MN', 'Little Silver, NJ',
#        'Toronto, Canada', 'Seattle, WA', 'Rome, Italy', 'Mt. Juliet, TN',
#        'Lake Charles, LA', 'France', 'Destin, FL', 'Beverly Hills, CA',
#        'San Clemente, CA', 'Williamsburg, VA', 'Boulder, CO',
#        'Charlotte, NC', 'Surprise, AZ', 'Bradenton, FL', 'United Kingdom',
#        'Bluffton, SC', 'Santa Clarita, CA', 'Saint-Lazare, Canada',
#        'Union, NJ', 'Macau', 'Prescott, AZ', 'Pasadena, CA',
#        'Spring Valley, NV', 'Palm Springs, CA', 'Bathurst, Canada',
#        'Chino Hills, CA', 'Frankfurt, Germany', 'Simi Valley, CA',
#        'Redding, CA', 'Denver, CO', 'Carmel, IN', 'Grants Pass, OR',
#        'Carson City, NV', 'Indianapolis, IN', 'Clearwater, FL',
#        'Ciales, Puerto Rico', 'Baja California Sur, Mexico',
#        'West Sacramento, CA', 'South Pasadena, CA', 'Broomfield, CO',
#        'Sarasota, FL', 'Lawrence, NY', 'Montego Bay, Jamaica',
#        'Anaheim, CA', 'Bellevue, WA', 'Edmonton, Canada',
#        'Gaithersburg, MD', 'Bountiful, UT', 'Nassau, Bahamas',
#        'Boyds, MD', 'Seaside, CA', 'Long Beach, CA', 'Austin, TX',
#        'Barcelona, Spain', 'São Paulo, Brazil', 'Newport Beach, CA',
#        'Eagle, ID', 'Agoura Hills, CA', 'Lindenhurst, NY', 'Raleigh, NC',
#        'San Gabriel, CA', 'Riverside, CA', 'Aptos, CA', 'Cortland, NY',
#        'San Juan, Puerto Rico', 'Chino, CA', 'Desert Hot Springs, CA',
#        'Edmonds, WA', 'Florida, United States', 'Grand Prairie, TX',
#        'West Jordan, UT', 'Carrollton, TX', 'St. Louis, MO',
#        'Kingman, KS', 'Arlington, TX', 'Placitas, NM', 'Winchester, IN',
#        'St. George, UT', 'Jacksonville, FL', 'Traverse Bay, Canada',
#        'Alhambra, CA', 'Thousand Oaks, CA', 'Martinez, CA',
#        'Milwaukee, WI', 'La Paz, Mexico', 'Garden Grove, CA',
#        'Elkhart, IN', 'Melbourne, FL', 'Boynton Beach, FL',
#        'Sunnyvale, CA', 'Massachusetts, United States',
#        'Ramat Gan, Israel', 'Hacienda Heights, CA', 'Orlando, FL',
#        'Brechin, Canada', 'Durango, CO', 'Cedar City, UT', 'Spokane, WA',
#        'Santa Barbara, CA', 'Redondo Beach, CA', 'Jupiter, FL',
#        'Portland, OR', 'London, United Kingdom', 'Littleton, CO',
#        'Palo Alto, CA', 'Aurora, IL', 'Campbell River, Canada',
#        'Highland, UT', 'Cremorne, Australia', 'Paradise, NV',
#        'Arcadia, CA', 'Costa Mesa, CA', 'Pico Rivera, CA', 'Capitola, CA',
#        'Cuttagee, Australia', 'Bakersfield, CA', 'Honolulu, HI',
#        'Mesquite, NV', 'Marina del Rey, CA', 'Cottonwood Heights, UT',
#        'Boise, ID', 'Granite Bay, CA', 'Belmont, CA', 'Millbrae, CA',
#        'Half Moon Bay, CA', 'New York, United States', 'Alberta, Canada',
#        'Moorpark, CA', 'Madisonville, KY', 'Culver City, CA',
#        'Downey, CA', 'Humboldt, Canada', 'Westlake Village, CA',
#        'Hawaii, United States', 'Rancho Cucamonga, CA', 'Inglewood, CA',
#        'Kingman, AZ', 'Ontario, CA', 'Brookfield, WI',
#        'Fort Washington, MD', 'Aubrey, TX', 'Ho Chi Minh City, Vietnam',
#        'Albuquerque, NM', 'Sutter Creek, CA', 'Fullerton, CA',
#        'Fremont, CA', 'Georgia, United States', 'Boulder City, NV',
#        'Semmes, AL', 'Corpus Christi, TX', 'Colorado Springs, CO',
#        'British Columbia, Canada', 'Winter Park, FL', 'Oak Park, CA',
#        'Dubai, United Arab Emirates', 'Union City, CA',
#        'Salt Lake City, UT', 'Virginia Beach, VA', 'Bevaix, Switzerland',
#        'Houston, TX', 'St. Helens, OR', 'Monroeville, PA', 'Hooper, UT',
#        'Montreal, Canada', 'Emeryville, CA', 'Montclair, NJ',
#        'Highlands Ranch, CO', 'Redlands, CA', 'Upland, CA',
#        'Welland, Canada', 'Lawrenceville, GA', 'San Leandro, CA',
#        'Mesquite, TX', 'Getzville, NY', 'Goodyear, AZ', 'Fort Myers, FL',
#        'Washington, DC', 'San Tan Valley, AZ', 'Folsom, CA',
#        'Surrey, Canada', 'Ventura, CA', 'Plant City, FL', 'Newark, NJ',
#        'Buenos Aires, Argentina', 'Hayward, CA', 'Panama City, Panama',
#        'Alameda, CA', 'West Hollywood, CA', 'Davenport, IA',
#        'Coarsegold, CA', 'Bloomington, IL', 'Lehi, UT', 'Livermore, CA',
#        'El Paso, TX', 'Solarino, Italy', 'Brasilia, Brazil',
#        'Cottage Grove, OR', 'Monroe, UT', 'Kamloops, Canada',
#        'Clovis, CA', 'Spring Hill, FL', 'Clearlake, CA',
#        'Pleasant Grove, UT', 'Clarksville, TN', 'Utah, United States',
#        'Monterey Park, CA', 'Beauvernois, France', 'Farmington Hills, MI',
#        'Lake Elsinore, CA', 'Malibu, CA', 'Seal Beach, CA',
#        'Hawthorne, CA', 'Durham, NC', 'Buena Park, CA', 'Norwalk, CA',
#        'Weehawken, NJ', 'Magna, UT', 'Windsor, Canada', 'Torrance, CA',
#        'Ojai, CA', 'Westminster, CO', 'Parkersburg, WV',
#        'West Virginia, United States', 'Philadelphia, PA', 'Arvada, CO',
#        'Myrtle Beach, SC', 'Springfield, MO', 'Puerto Peñasco, Mexico',
#        'North Myrtle Beach, SC', 'Mexico, NY', 'Monrovia, CA',
#        'Tacoma, WA', 'Bogotá, Colombia', 'Kailua-Kona, HI', 'Provo, UT',
#        'Lake Havasu City, AZ', 'Key West, FL', 'West Covina, CA',
#        'Columbus, OH', 'Missouri, United States', 'Moscow, Russia',
#        'Murrieta, CA', 'Scottsdale, AZ', 'Slidell, LA', 'Camdenton, MO',
#        'Renton, WA', 'Ruther Glen, VA', 'Decatur, GA', 'Milpitas, CA',
#        'Rialto, CA', 'Oxnard, CA', 'San Ramon, CA', 'Winchester Bay, OR',
#        'Adelaide, CA', 'Walnut, CA', 'Yorba Linda, CA',
#        'Winston-Salem, NC', 'North Carolina, United States',
#        'Atlanta, GA', 'Coronado, CA', 'Menifee, CA', 'Leadville, CO',
#        'Creston, MT', 'South Jordan, UT', 'Billings, MT',
#        'Taylorsville, UT', 'Potomac Falls, VA',
#        'Redford Charter Township, MI', 'Peachtree Corners, GA',
#        'Pacifica, CA', 'Detroit, MI', 'Puyallup, WA', 'Miami Beach, FL',
#        'São José dos Campos, Brazil', 'Pueblo West, CO', 'Heber City, UT',
#        'Franklin, TN', 'Mountain View, CA', 'Gardena, CA', 'Beaver, UT',
#        'Anchorage, AK', 'Delray Beach, FL', 'San Bernardino, CA',
#        'Gijón, Spain', 'Hollywood, FL', 'Santa Monica, CA', 'South Korea',
#        'San Mateo, CA', 'Joint Base Pearl Harbor-Hickam, HI',
#        'Covina, CA', 'Mesa, AZ', 'Roseville, CA', 'Cumming, GA',
#        'Belle Isle, FL', 'Carmel-by-the-Sea, CA', 'Fair Oaks, CA',
#        'Tehachapi, CA', 'Copperopolis, CA', 'Cleveland, OH',
#        'San Dimas, CA', 'Paris, France', 'Herriman, UT', 'Tampa, FL',
#        'Mexico City, Mexico', 'Beaverton, OR', 'Burlington, NC',
#        'Greensboro, NC', 'Woodland Park, CO', 'Watford City, ND',
#        'Lafayette, CA', 'Oak Lawn, IL', 'Verona, NJ', 'Holly, MI',
#        'Saluda, VA', 'Ohio, United States', 'Bloomfield Township, MI',
#        'Fort Calhoun, NE', 'Garner, NC', 'Fayetteville, GA',
#        'Mission Viejo, CA', 'Kitty Hawk, NC', 'Fort Irwin, CA',
#        'Franklin Square, NY', 'Gulfport, MS', 'South Lake Tahoe, CA',
#        'Compton, CA', 'Idaho Falls, ID', 'Seminole, FL',
#        'Shelburne Falls, MA', 'Oakdale, MN', 'Cerritos, CA',
#        'Medellín, Colombia', 'Laguna Niguel, CA', 'Texas, United States',
#        'Saratoga, CA', 'Enterprise, NV', 'San Antonio, TX',
#        'Holladay, UT', 'Bullhead City, AZ', 'Minnesota City, MN',
#        'Fountain Valley, CA', 'Maryland City, MD', 'Salem, UT',
#        'Conroe, TX', 'Naples, FL', 'Kihei, HI', 'Berkeley, CA',
#        'Riverton, UT', 'Buffalo, NY', 'Trinity, NC', 'Orange, CA',
#        'Washington, UT', 'Big Bear Lake, CA', 'Mobile, AL',
#        'Coldwater, Canada', 'Lakewood, CA', 'Rochester, NY',
#        'Chandler, AZ', 'Victor, ID', 'Eden, UT', 'Kings Beach, CA',
#        'Carson, CA', 'Draper, UT', 'Norcross, GA', 'Alpharetta, GA',
#        'Hemet, CA', 'Hugo, MN', 'Norco, CA', 'Castro Valley, CA',
#        'Prayagraj, India', 'Montclair, CA', 'Saratov, Russia',
#        'Trenton, NJ', 'Stony Brook, NY', "Coeur d'Alene, ID",
#        'Elkins Park, PA', 'Rochester, MI', 'Fort Worth, TX',
#        'Temecula, CA', 'Glendale, CA', 'Las Vegas, NM', 'Wellington, FL',
#        'Manhattan Beach, CA', 'Napoleon, OH', 'Palm Desert, CA',
#        'Laurel, MD', 'Cypress, CA', 'Weeki Wachee, FL', 'Canton, MI',
#        'Hesperia, CA', 'Kloten, ND', 'Summerlin South, NV',
#        'Alexandria, VA', 'Jurupa Valley, CA', 'Islandia, NY', 'Doral, FL',
#        'Florissant, MO', 'Ocean Springs, MS', 'Ewa Beach, HI',
#        'Ellicott City, MD', 'Memphis, TN', 'San Marino, CA', 'Conway, SC',
#        'Burbank, CA', 'Porterville, CA', 'Cabo San Lucas, Mexico',
#        'Newnan, GA', 'Germantown, MD', 'Kissimmee, FL', 'Columbia, SC',
#        'Pasig, Philippines', 'Michigan, United States', 'Campbell, CA',
#        'Moorhead, MN', 'Vancouver, WA', 'Santa Maria, CA',
#        'California City, CA', 'Upper Marlboro, MD', 'Bunkerville, NV',
#        'Buford, GA', 'Johannesburg, South Africa', 'Rosemead, CA',
#        'Savannah, GA', 'Kahuku, HI', 'Santa Rosa, CA', 'Vallejo, CA',
#        'Lawndale, CA', 'Fort Saskatchewan, Canada', 'McDonough, GA',
#        'New Mexico, United States', 'Little River, SC', 'Newark, CA',
#        'Duck Creek Village, UT', 'Sun City, AZ', 'Corona, CA',
#        'Lake Stevens, WA', 'Andheri, India', 'Grantsville, UT',
#        'Lafayette, LA', 'Daly City, CA', 'Florida City, FL',
#        'Monument, CO', 'Los Gatos, CA', 'Loveland, OH', 'Kansas City, MO',
#        'Safford, AZ', 'Saint Charles, MO', 'Larned, KS', 'Kearney, MO',
#        'Gilroy, CA', 'Matteson, IL', 'Mount Charleston, NV',
#        'Baltimore, MD', 'Sparks, NV', 'Nashville, TN', 'Newport News, VA',
#        'Maumelle, AR', 'South Gate, CA', 'Lithia, FL', 'Bayonne, NJ',
#        'Laughlin, NV', 'Black Diamond, WA', 'Layton, UT', 'Whittier, CA',
#        'Buffalo Creek, CO', 'Snowshoe, WV', 'Carol Stream, IL',
#        'Eugene, OR', 'Moreno Valley, CA', 'Lake Leelanau, MI',
#        'Burnaby, Canada', 'Wingate, NC', 'Kernersville, NC',
#        'Parkland, FL', 'Erda, UT', 'Oceanside, CA', 'Lampe, MO',
#        'San José, Costa Rica', 'Lomita, CA', 'Napa, CA', 'Kaneohe, HI',
#        'Hawaiian Gardens, CA', 'Sanford, NC', 'Palmdale, CA',
#        'Lithonia, GA', 'Courtenay, France', 'Englewood Cliffs, NJ',
#        'Ocean Ridge, FL', 'Charleston, SC', 'Merritt, Canada',
#        'Jefferson, TX', 'Chesapeake, VA', 'Kingsburg, CA', 'Artesia, CA',
#        'Concord, CA', 'Baton Rouge, LA', 'Norfolk, VA',
#        'Quepos, Costa Rica', 'Ocala, FL', 'Nellis Air Force Base, NV',
#        'Glendora, CA', 'Tucson, AZ', 'Colton, CA', 'Hualapai, AZ',
#        'Jeddah, Saudi Arabia', 'El Centro, CA', 'Brea, CA',
#        'Diamond Bar, CA', 'Pittsburgh, PA', 'Fredonia, AZ', 'Kenner, LA',
#        'East Amherst, NY', 'Asheville, NC', 'Evanston, IL',
#        'El Segundo, CA', 'Santa Clara, CA', 'Minneapolis, MN',
#        'Lecanto, FL'], dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df[updated_df['host_location'] ==' ']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 8631

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   1,    5,    9,    3,   12,    2,  119,   15,   28,  186,   36,
#          18,   20,   79,    8,   26,  382,    4,  262,   14,   69,   13,
#           6,   10,  256,  249,  205,   11,   16,   87,  171,   33,   75,
#           7,   93,   37,   42,  524,   29,  318, 1613,   31,  301,  284,
#         161,   57,  293,   21,  350,   59,  461,   27,   67,   17,   58,
#          35,   22,  296,   19,  326,   25,  165,  388,   56,  424,  157,
#          34,  120,   24,   89,   32,  314,   49,  132,   85,   78,   23,
#          77,  136,  194,  188,  130,  415,   61,  176,  126,  325,  657,
#         497,   63,   30,   43,  478,  101,   38,   51,  144,   65,  199,
#         145,  158,   52, 3302,  505,  114,  617,  308,   46,  173,  116,
#        2321,  108,  677,  792,  645,  282,   83,  203,   40,  154,  611,
#         320,  213,  191,   97,  287,  361,   41,  231, 2492,   62,  184,
#         192,   47,   86,  220,  228, 2647,   68,   82,   76,   60,  348,
#         671, 2067,   48,  148,   54,   39,  104,  844])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   4,    1,    8,   14,    2,   11,   54,   12,  122,    3,   23,
#           6,   46,    5,   16,   24,  286,  190,   21,   56,    7,   87,
#          10,   32,  465,   13,  296,   25,  101,   18,    9,   28,   39,
#         851,  198,   27,   15,  403,  238,  155,  355,   44,  165,  147,
#          37,   57,  662,   43,   62,  712,  366, 1930,   49,   60,  375,
#          29,  335,  290,   64,  363,   40,   19,  391,  129,  550,   36,
#          71,   45,  106,   83,   66,   41,   33,   34,  390,   22,  399,
#          30,  301,  512,   17,   70,  898,  179,   48,  126,  145,   20,
#          42,   90,   85,  393,   65,   35,   58,   38,   80,   59,   69,
#         351,  220,  257,   31,  169,  569,   26,  312,  151,  382,  716,
#         566,   55,  105, 1022,  138,   93,  204,  158,  239,  310,  299,
#          99, 4535, 1049,  167,  690,  524,   47,  241,  156,  427,  121,
#        7825,  117, 1772,  107,  672, 1714,  163,   52,  236,  231,  326,
#         640, 1155,  214,  150,  206,  112,  378,  372,  140,  123,  234,
#         110, 2776,   94,  277,   75,   86,   73,  249, 8427,   68,  100,
#          78,   53,  308,   89,  705, 2327,  270,   51,  125, 1101,   63])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']", '[]'],
#       dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
#                        id    host_id host_name  host_since host_location  \
# 12326  808187260428649948  496997931      Lynn  2023-01-19       unknown
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 12326     within an hour               100%                 100%
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 12326                 f                    1  ...       3.0  3.0
#
#                                                amenities  price  \
# 12326  ["Toaster", "Essentials", "Cleaning products",...  191.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count  \
# 12326                 2                 5.0                               1
#
#        amenities_count             city  num_bath
# 12326               43  Clark County NV       2.5
#
# [1 rows x 31 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']", 'None'],
#       dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  1,   3,   9,  12,   2,  11,  14,   4,   6,   5,  18,  19,  66,
#        262,   7,  10,  17, 202,   8,  22,  24,  67,  21,  29,  13,  28,
#         34,  38,  35,  16,  72,  27,  54,  33,  15,  89,  30,  85, 193,
#         23,  26,  43,  53, 327, 101,  69,  57,  39,  51, 106, 178,  65,
#         44,  79,  52,  25, 118,  73])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
na = updated_df['host_has_profile_pic'].isnull().sum()
print(f'There are {na} missing values in the "host_has_profile_pic" column.')

updated_df['host_has_profile_pic'].fillna('f', inplace=True)
# Out:
# There are 0 missing values in the "host_has_profile_pic" column.

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['Las Vegas, Nevada, United States', nan,
#        'Henderson, Nevada, United States',
#        'North Las Vegas, Nevada, United States',
#        'Las Vegas , Nevada, United States',
#        'Laughlin, Nevada, United States',
#        'Sandy Valley, Nevada, United States',
#        'lake las vegas, Nevada, United States',
#        'Paradise, Nevada, United States',
#        'Mesquite, Nevada, United States', 'Las Vegas, United States',
#        'Lake Las Vegas, Henderson, Nevada, United States',
#        'Boulder City, Nevada, United States',
#        'Enterprise, Nevada, United States',
#        'Las vegas, Nevada, United States',
#        'Las Vegas , Nv, United States',
#        'St Henderson, Nevada, United States',
#        '拉斯维加斯, Nevada, United States',
#        'Spring Valley, Nevada, United States',
#        'las vegas, Nevada, United States',
#        'Sunrise Manor, Nevada, United States',
#        'Mount Charleston, Nevada, United States',
#        'Bullhead City, Arizona, United States',
#        'Goodsprings, Nevada, United States',
#        'Mountain Springs, Nevada, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 6151

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Unincorporated Areas', 'City of Las Vegas', 'City of Henderson',
#        'City of North Las Vegas', 'City of Mesquite', 'Nellis AFB',
#        'Boulder City'], dtype=object)

# %% [markdown]
# ### We are going to drop neighbourhood column for Clark County Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                   0
# host_id                              0
# host_name                            0
# host_since                           0
# host_location                        0
# host_response_time                 683
# host_response_rate                 683
# host_acceptance_rate               464
# host_is_superhost                    0
# host_listings_count                  0
# host_total_listings_count            0
# host_verifications                   0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# number_of_reviews                    0
# review_scores_value               3650
# calculated_host_listings_count       0
# amenities_count                      0
# city                                 0
# num_bath                             0
# dtype: int64

# %% [markdown]
# # Save the Final Dataframe

# %%
updated_df.to_csv('data/listings_detailed_after_na_clark.csv', index=False)
