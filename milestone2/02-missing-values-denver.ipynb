# %% [markdown]
# # Denver

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/Denver/listings_detailed-denver.csv')

# %%
listings_detailed.shape
# Out:
# (5362, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (5362, 29)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 10]
filtered_df
# Out:
#                       id    host_id    host_name  host_since host_location  \
# 1624            42757920  340401226         Jake  2020-03-05           NaN
# 1870            45725617  176075890        Debra  2018-03-01           NaN
# 4665  761561137710874547  392360868  Lincolnwood  2021-03-13           NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 1624        within a day                60%                  33%
# 1870  a few days or more                29%                  46%
# 4665      within an hour                96%                  96%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 1624                 f                    1  ...             2       NaN
# 1870                 f                    2  ...             1       NaN
# 4665                 t                   15  ...             3       NaN
#
#       bathrooms_text bedrooms beds  \
# 1624  1 private bath      1.0  NaN
# 1870         0 baths      NaN  NaN
# 4665          1 bath      1.0  1.0
#
#                                               amenities  price  \
# 1624  ["Private living room", "Iron", "Essentials", ...   10.0
# 1870                                                 []   10.0
# 4665  ["Dishes and silverware", "Radiant heating", "...   10.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 1624                  1                5.00                               1
# 1870                  8                4.88                               2
# 4665                  0                 NaN                              15
#
# [3 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 1

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id host_name  host_since host_location  \
# 1651  43095918  323075243     Louie  2019-12-31           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1651                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 1651               NaN                    8  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 1651            NaN      NaN  NaN
#
#                                               amenities  price  \
# 1651  ["Bed sheets and pillows", "Complimentary self...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 1651                  0                 NaN                               1
#
# [1 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id host_name  host_since host_location  \
# 1651  43095918  323075243     Louie  2019-12-31           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1651                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 1651               NaN                    8  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 1651            NaN      NaN  NaN
#
#                                               amenities  price  \
# 1651  ["Bed sheets and pillows", "Complimentary self...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 1651                  0                 NaN                               1
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 1

# %%
cleaned_listings.head()
# Out:
#         id  host_id       host_name  host_since host_location  \
# 0      177      615             Joe  2008-07-07    Denver, CO
# 1  1223612  6674631         Cynthia  2013-05-31    Denver, CO
# 2  1313699  7138728             Ann  2013-06-26    Denver, CO
# 3  1327856  7206373  Leila And Alex  2013-06-30    Denver, CO
# 4  1402409  1382900          Pamela  2011-11-07    Denver, CO
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day               100%                 100%
# 1  within a few hours               100%                  70%
# 2                 NaN                NaN                  83%
# 3      within an hour               100%                 100%
# 4      within an hour               100%                  97%
#
#   host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 0                 t                    2  ...             2       NaN
# 1                 t                    3  ...             3       NaN
# 2                 f                    1  ...            10       NaN
# 3                 t                    2  ...             6       NaN
# 4                 t                    1  ...            10       NaN
#
#   bathrooms_text bedrooms beds  \
# 0         1 bath      NaN  1.0
# 1         1 bath      1.0  2.0
# 2        2 baths      5.0  5.0
# 3        2 baths      2.0  2.0
# 4        2 baths      5.0  6.0
#
#                                            amenities  price  \
# 0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0
# 1  ["Hot water", "Iron", "Essentials", "Heating",...   58.0
# 2  ["Dishes and silverware", "Dryer", "Essentials...  218.0
# 3  ["Dishes and silverware", "Dryer", "Indoor fir...  139.0
# 4  ["Dishes and silverware", "Dryer", "Outlet cov...  256.0
#
#    number_of_reviews review_scores_value  calculated_host_listings_count
# 0                120                4.78                               2
# 1                184                4.76                               3
# 2                 24                4.92                               1
# 3                174                4.75                               1
# 4                142                4.95                               1
#
# [5 rows x 29 columns]

# %%
cleaned_listings.shape
# Out:
# (5361, 29)

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 bath', '2 baths', '1 shared bath', '1 private bath',
#        '1.5 shared baths', '1.5 baths', '2.5 baths', '3 baths',
#        '4.5 baths', '4 baths', '5 baths', '3.5 baths', '2 shared baths',
#        '5.5 baths', '17 shared baths', nan, '0 baths', '9.5 baths',
#        '4 shared baths', 'Half-bath', '2.5 shared baths',
#        '0 shared baths', '6 baths', '6.5 baths', 'Shared half-bath'],
#       dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 bath' '2 baths' '1 shared bath' '1 private bath' '1.5 shared baths'
#  '1.5 baths' '2.5 baths' '3 baths' '4.5 baths' '4 baths' '5 baths'
#  '3.5 baths' '2 shared baths' '5.5 baths' '17 shared baths' '' '0 baths'
#  '9.5 baths' '4 shared baths' '0.5 baths' '2.5 shared baths'
#  '0 shared baths' '6 baths' '6.5 baths']

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#                       id    host_id       host_name  host_since host_location  \
# 732             24180313  160449770           Ember  2017-11-28           NaN
# 1873            45756783  213457607       Borauzima  2018-09-04   Chicago, IL
# 5209  849934100277878013  486880651  Tailored Stays  2022-11-08           NaN
# 5329              283162    1475137             Lee  2011-12-05  Portland, OR
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 732       within an hour                93%                  99%
# 1873                 NaN                NaN                  NaN
# 5209      within an hour               100%                  96%
# 5329  within a few hours                67%                  60%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 732                  t                    6  ...             1       NaN
# 1873                 f                    1  ...             2       NaN
# 5209                 f                   11  ...             4       NaN
# 5329                 t                    2  ...             4       NaN
#
#      bathrooms_text bedrooms beds  \
# 732                      1.0  1.0
# 1873                     1.0  1.0
# 5209                     1.0  2.0
# 5329                     2.0  3.0
#
#                                               amenities  price  \
# 732   ["Dishes and silverware", "Dryer", "Coffee mak...   57.0
# 1873  ["Dishes and silverware", "Dryer", "Essentials...  119.0
# 5209  ["Dishes and silverware", "Dryer", "Smoking al...  125.0
# 5329  ["Dryer", "Pool", "Elevator", "Heating", "Gym"...  165.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 732                 224                4.75                               6
# 1873                  0                 NaN                               1
# 5209                  0                 NaN                               2
# 5329                  4                4.50                               1
#
# [4 rows x 29 columns]

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#            id  bedrooms  beds bathrooms_text
# 0         177       NaN   1.0         1 bath
# 1     1223612       1.0   2.0         1 bath
# 2     1313699       5.0   5.0        2 baths
# 3     1327856       2.0   2.0        2 baths
# 4     1402409       5.0   6.0        2 baths
# ...       ...       ...   ...            ...
# 5357  1069351       2.0   2.0      1.5 baths
# 5358  1074386       1.0   1.0         1 bath
# 5359  1082572       1.0   2.0         1 bath
# 5360  1087609       NaN   NaN         1 bath
# 5361  1223593       1.0   1.0         1 bath
#
# [5361 rows x 4 columns]

# %%
# check for the previous NA rows in bathrooms text
filled_cleaned_listings[
    (filled_cleaned_listings['id'] == 24180313) | 
    (filled_cleaned_listings['id'] == 45756783) | 
    (filled_cleaned_listings['id'] == 849934100277878013) | 
    (filled_cleaned_listings['id'] == 283162) ]
# Out:
#                       id    host_id       host_name  host_since host_location  \
# 732             24180313  160449770           Ember  2017-11-28           NaN
# 1873            45756783  213457607       Borauzima  2018-09-04   Chicago, IL
# 5209  849934100277878013  486880651  Tailored Stays  2022-11-08           NaN
# 5329              283162    1475137             Lee  2011-12-05  Portland, OR
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 732       within an hour                93%                  99%
# 1873                 NaN                NaN                  NaN
# 5209      within an hour               100%                  96%
# 5329  within a few hours                67%                  60%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 732                  t                    6  ...             1       NaN
# 1873                 f                    1  ...             2       NaN
# 5209                 f                   11  ...             4       NaN
# 5329                 t                    2  ...             4       NaN
#
#      bathrooms_text bedrooms beds  \
# 732        1.0 bath      1.0  1.0
# 1873       1.0 bath      1.0  1.0
# 5209       1.0 bath      1.0  2.0
# 5329       2.0 bath      2.0  3.0
#
#                                               amenities  price  \
# 732   ["Dishes and silverware", "Dryer", "Coffee mak...   57.0
# 1873  ["Dishes and silverware", "Dryer", "Essentials...  119.0
# 5209  ["Dishes and silverware", "Dryer", "Smoking al...  125.0
# 5329  ["Dryer", "Pool", "Elevator", "Heating", "Gym"...  165.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 732                 224                4.75                               6
# 1873                  0                 NaN                               1
# 5209                  0                 NaN                               2
# 5329                  4                4.50                               1
#
# [4 rows x 29 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#      bathrooms_text  num_bath
# 0            1 bath       1.0
# 1            1 bath       1.0
# 2           2 baths       2.0
# 3           2 baths       2.0
# 4           2 baths       2.0
# ...             ...       ...
# 5357      1.5 baths       1.5
# 5358         1 bath       1.0
# 5359         1 bath       1.0
# 5360         1 bath       1.0
# 5361         1 bath       1.0
#
# [5361 rows x 2 columns]

# %%
updated_df.head()
# Out:
#         id  host_id       host_name  host_since host_location  \
# 0      177      615             Joe  2008-07-07    Denver, CO
# 1  1223612  6674631         Cynthia  2013-05-31    Denver, CO
# 2  1313699  7138728             Ann  2013-06-26    Denver, CO
# 3  1327856  7206373  Leila And Alex  2013-06-30    Denver, CO
# 4  1402409  1382900          Pamela  2011-11-07    Denver, CO
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day               100%                 100%
# 1  within a few hours               100%                  70%
# 2                 NaN                NaN                  83%
# 3      within an hour               100%                 100%
# 4      within an hour               100%                  97%
#
#   host_is_superhost  host_listings_count  ...  bathrooms bathrooms_text  \
# 0                 t                    2  ...        NaN         1 bath
# 1                 t                    3  ...        NaN         1 bath
# 2                 f                    1  ...        NaN        2 baths
# 3                 t                    2  ...        NaN        2 baths
# 4                 t                    1  ...        NaN        2 baths
#
#   bedrooms beds                                          amenities  price  \
# 0      NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0
# 1      1.0  2.0  ["Hot water", "Iron", "Essentials", "Heating",...   58.0
# 2      5.0  5.0  ["Dishes and silverware", "Dryer", "Essentials...  218.0
# 3      2.0  2.0  ["Dishes and silverware", "Dryer", "Indoor fir...  139.0
# 4      5.0  6.0  ["Dishes and silverware", "Dryer", "Outlet cov...  256.0
#
#    number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                120                 4.78                              2
# 1                184                 4.76                              3
# 2                 24                 4.92                              1
# 3                174                 4.75                              1
# 4                142                 4.95                              1
#
#    num_bath
# 0       1.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       2.0
#
# [5 rows x 30 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 30 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  2. ,  1.5,  2.5,  3. ,  4.5,  4. ,  5. ,  3.5,  5.5, 17. ,
#         0. ,  9.5,  0.5,  6. ,  6.5])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df
# Out:
#            id  host_id       host_name  host_since host_location  \
# 0         177      615             Joe  2008-07-07    Denver, CO
# 1     1223612  6674631         Cynthia  2013-05-31    Denver, CO
# 2     1313699  7138728             Ann  2013-06-26    Denver, CO
# 3     1327856  7206373  Leila And Alex  2013-06-30    Denver, CO
# 4     1402409  1382900          Pamela  2011-11-07    Denver, CO
# ...       ...      ...             ...         ...           ...
# 5357  1069351  3577356          Bonnie  2012-09-15    Denver, CO
# 5358  1074386  5910663            Tony  2013-04-13    Denver, CO
# 5359  1082572   879998        Jennifer  2011-07-27           NaN
# 5360  1087609  5124037           Darja  2013-02-17    Denver, CO
# 5361  1223593  6674631         Cynthia  2013-05-31    Denver, CO
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0           within a day               100%                 100%
# 1     within a few hours               100%                  70%
# 2                    NaN                NaN                  83%
# 3         within an hour               100%                 100%
# 4         within an hour               100%                  97%
# ...                  ...                ...                  ...
# 5357        within a day                50%                  50%
# 5358      within an hour               100%                 100%
# 5359      within an hour               100%                  96%
# 5360  within a few hours               100%                  31%
# 5361  within a few hours               100%                  70%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 0                    t                    2  ...             2         1 bath
# 1                    t                    3  ...             3         1 bath
# 2                    f                    1  ...            10        2 baths
# 3                    t                    2  ...             6        2 baths
# 4                    t                    1  ...            10        2 baths
# ...                ...                  ...  ...           ...            ...
# 5357                 f                    1  ...             4      1.5 baths
# 5358                 t                    2  ...             2         1 bath
# 5359                 t                    7  ...             3         1 bath
# 5360                 t                    1  ...             2         1 bath
# 5361                 t                    3  ...             2         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 0         NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0
# 1         1.0  2.0  ["Hot water", "Iron", "Essentials", "Heating",...   58.0
# 2         5.0  5.0  ["Dishes and silverware", "Dryer", "Essentials...  218.0
# 3         2.0  2.0  ["Dishes and silverware", "Dryer", "Indoor fir...  139.0
# 4         5.0  6.0  ["Dishes and silverware", "Dryer", "Outlet cov...  256.0
# ...       ...  ...                                                ...    ...
# 5357      2.0  2.0  ["Dishes and silverware", "Dryer", "Cooking ba...  100.0
# 5358      1.0  1.0  ["Dishes and silverware", "Dryer", "Coffee mak...  208.0
# 5359      1.0  2.0  ["Dishes and silverware", "Dryer", "Smoking al...  150.0
# 5360      NaN  NaN  ["Dishes and silverware", "Dryer", "Coffee mak...   94.0
# 5361      1.0  1.0  ["Hot water", "Iron", "Essentials", "Heating",...   68.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                   120                 4.78                              2
# 1                   184                 4.76                              3
# 2                    24                 4.92                              1
# 3                   174                 4.75                              1
# 4                   142                 4.95                              1
# ...                 ...                  ...                            ...
# 5357                  5                 5.00                              1
# 5358                107                 4.57                              2
# 5359                 46                 4.88                              4
# 5360                 23                 4.48                              1
# 5361                160                 4.76                              3
#
#       num_bath
# 0          1.0
# 1          1.0
# 2          2.0
# 3          2.0
# 4          2.0
# ...        ...
# 5357       1.5
# 5358       1.0
# 5359       1.0
# 5360       1.0
# 5361       1.0
#
# [5361 rows x 29 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([nan,  1.,  5.,  2.,  3.,  4.,  6.,  7.,  9.,  8.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  2.,  5.,  6.,  3.,  4.,  7., 13.,  9., nan,  8., 18., 10.,
#        11., 12., 16., 14., 17.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#            id   host_id        host_name  host_since  host_location  \
# 0         177       615              Joe  2008-07-07     Denver, CO
# 11    1737365   3378084        Alexandra  2012-08-26     Denver, CO
# 25    2216969  10917089          Jeffrey  2013-12-30  United States
# 100   8366762   9153888            Brian  2013-09-30            NaN
# 118   8941796  46741655            Chris  2015-10-16     Denver, CO
# ...       ...       ...              ...         ...            ...
# 5262  4753876  24532369      Ryan & Tina  2014-12-05     Denver, CO
# 5264  4766503  23195393  Laurel And Paul  2014-10-31     Denver, CO
# 5281  5558992  26125748      Adi & Edwin  2015-01-14     Denver, CO
# 5321     1940      2150           Joanne  2008-08-16     Denver, CO
# 5360  1087609   5124037            Darja  2013-02-17     Denver, CO
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0           within a day               100%                 100%
# 11    within a few hours               100%                  75%
# 25        within an hour               100%                 100%
# 100       within an hour               100%                  97%
# 118   within a few hours               100%                  85%
# ...                  ...                ...                  ...
# 5262      within an hour               100%                  99%
# 5264      within an hour               100%                 100%
# 5281      within an hour               100%                 100%
# 5321      within an hour               100%                 100%
# 5360  within a few hours               100%                  31%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 0                    t                    2  ...             2         1 bath
# 11                   t                    2  ...             2         1 bath
# 25                   t                    5  ...             2         1 bath
# 100                  f                    9  ...             2         1 bath
# 118                  t                    2  ...             2         1 bath
# ...                ...                  ...  ...           ...            ...
# 5262                 t                    2  ...             2         1 bath
# 5264                 t                    1  ...             2         1 bath
# 5281                 t                    1  ...             2         1 bath
# 5321                 t                    1  ...             2         1 bath
# 5360                 t                    1  ...             2         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 0         NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0
# 11        NaN  1.0  ["Dishes and silverware", "Dryer", "Coffee mak...  100.0
# 25        NaN  1.0  ["Dishes and silverware", "Essentials", "Heati...   70.0
# 100       NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   55.0
# 118       NaN  1.0  ["Coffee maker", "Essentials", "Heating", "HDT...   72.0
# ...       ...  ...                                                ...    ...
# 5262      NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   95.0
# 5264      NaN  2.0  ["Dishes and silverware", "Essentials", "Cloth...   75.0
# 5281      NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   80.0
# 5321      NaN  1.0  ["Dishes and silverware", "Coffee maker", "Ess...   87.0
# 5360      NaN  NaN  ["Dishes and silverware", "Dryer", "Coffee mak...   94.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                   120                 4.78                              2
# 11                   74                 4.76                              2
# 25                  156                 4.90                              4
# 100                 144                 4.59                              1
# 118                 711                 4.90                              1
# ...                 ...                  ...                            ...
# 5262                482                 4.82                              1
# 5264                295                 4.94                              1
# 5281                157                 4.82                              1
# 5321                122                 4.86                              1
# 5360                 23                 4.48                              1
#
#       num_bath
# 0          1.0
# 11         1.0
# 25         1.0
# 100        1.0
# 118        1.0
# ...        ...
# 5262       1.0
# 5264       1.0
# 5281       1.0
# 5321       1.0
# 5360       1.0
#
# [285 rows x 29 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                       id    host_id        host_name  host_since  \
# 418             18002228   24326234        Christina  2014-11-30
# 573             21241714   65787978             Luis  2016-04-04
# 574             21241977   65787978             Luis  2016-04-04
# 659             22727793  160449770            Ember  2017-11-28
# 741             24452403  176075890            Debra  2018-03-01
# 748             24631282   55376910           Kelsey  2016-01-20
# 1428            39296756  291640238           Bahman  2019-09-03
# 1441            39392919  219524979  Sonder (Denver)  2018-10-08
# 1568            41745650   23332515             Beth  2014-11-04
# 1578            41976040  219524979  Sonder (Denver)  2018-10-08
# 1585            42063900  219524979  Sonder (Denver)  2018-10-08
# 1586            42064645  219524979  Sonder (Denver)  2018-10-08
# 1593            42146167  187048377            Frank  2018-04-30
# 1619            42654409  275411185            Gerry  2019-07-11
# 1624            42757920  340401226             Jake  2020-03-05
# 1695            43713166   80287548           Bailey  2016-06-27
# 1724            44018089    7882686         Jennifer  2013-08-01
# 1805            45256355  193108199              Amy  2018-06-02
# 1870            45725617  176075890            Debra  2018-03-01
# 1921            46058269  347036002            Malik  2020-05-21
# 1991            46799502    5935008            Chase  2013-04-15
# 2004            46971561  379742504             Mark  2020-12-11
# 2195            48695518  360560535          Kathryn  2020-08-04
# 2245            49080110   68765251       Sam Sadegh  2016-04-25
# 2282            49348267    8464417               Jp  2013-08-27
# 2474            50422078  406033071           Austin  2021-06-08
# 2529            50790427   26514357            Bryan  2015-01-22
# 2566            51018382   10557035             Jill  2013-12-10
# 2657            51574411  417802010          Leticia  2021-08-10
# 2693            51787986  419532827            Craig  2021-08-21
# 2974            53189906   63941537            Emily  2016-03-21
# 3021            53383964  403051979         Meredith  2021-05-23
# 3038            53482844  415112454            Jules  2021-07-25
# 3044            53491342  306507919           Hayley  2019-11-03
# 3057            53546394   84304554              Joe  2016-07-17
# 3139            53970186  435252208         Courtney  2021-12-08
# 3183            54260808  251773242           Moneeb  2019-03-28
# 4147  689085319927829820   41414078          Melissa  2015-08-13
# 4954  808113326309550237    5804853          Natalie  2013-04-07
# 5351              921485    3378084        Alexandra  2012-08-26
# 5360             1087609    5124037            Darja  2013-02-17
#
#           host_location  host_response_time host_response_rate  \
# 418          Denver, CO      within an hour               100%
# 573          Denver, CO      within an hour               100%
# 574          Denver, CO      within an hour               100%
# 659                 NaN      within an hour                93%
# 741                 NaN  a few days or more                29%
# 748          Denver, CO      within an hour               100%
# 1428         Denver, CO  a few days or more                 0%
# 1441         Denver, CO      within an hour                97%
# 1568         Denver, CO      within an hour               100%
# 1578         Denver, CO      within an hour                97%
# 1585         Denver, CO      within an hour                97%
# 1586         Denver, CO      within an hour                97%
# 1593         Denver, CO                 NaN                NaN
# 1619         Denver, CO  within a few hours               100%
# 1624                NaN        within a day                60%
# 1695         Denver, CO      within an hour                75%
# 1724         Denver, CO                 NaN                NaN
# 1805         Denver, CO  within a few hours                96%
# 1870                NaN  a few days or more                29%
# 1921         Denver, CO                 NaN                NaN
# 1991  Santa Barbara, CA      within an hour               100%
# 2004                NaN                 NaN                NaN
# 2195         Denver, CO      within an hour                87%
# 2245         Denver, CO                 NaN                NaN
# 2282         Denver, CO      within an hour               100%
# 2474                NaN  within a few hours                71%
# 2529        Midland, MI      within an hour               100%
# 2566         Denver, CO      within an hour               100%
# 2657         Denver, CO      within an hour               100%
# 2693                NaN        within a day                90%
# 2974         Denver, CO  within a few hours               100%
# 3021                NaN      within an hour               100%
# 3038                NaN      within an hour               100%
# 3044         Denver, CO      within an hour                92%
# 3057         Denver, CO      within an hour               100%
# 3139         Denver, CO      within an hour               100%
# 3183         Denver, CO      within an hour               100%
# 4147         Denver, CO      within an hour               100%
# 4954         Denver, CO      within an hour               100%
# 5351         Denver, CO  within a few hours               100%
# 5360         Denver, CO  within a few hours               100%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 418                  100%                 f                    3  ...
# 573                  100%                 f                    3  ...
# 574                  100%                 f                    3  ...
# 659                   99%                 t                    6  ...
# 741                   46%                 f                    2  ...
# 748                  100%                 t                    2  ...
# 1428                   0%                 f                    1  ...
# 1441                  99%                 f                   12  ...
# 1568                  98%                 t                    1  ...
# 1578                  99%                 f                   12  ...
# 1585                  99%                 f                   12  ...
# 1586                  99%                 f                   12  ...
# 1593                  NaN                 f                    1  ...
# 1619                   0%                 f                    2  ...
# 1624                  33%                 f                    1  ...
# 1695                  63%                 f                    2  ...
# 1724                  NaN                 f                    2  ...
# 1805                  99%                 t                   39  ...
# 1870                  46%                 f                    2  ...
# 1921                  NaN                 f                    1  ...
# 1991                  NaN                 f                    1  ...
# 2004                  NaN                 f                    1  ...
# 2195                  80%                 f                   26  ...
# 2245                  NaN                 f                    2  ...
# 2282                 100%                 f                    3  ...
# 2474                  94%                 f                   15  ...
# 2529                 100%                 t                    1  ...
# 2566                  75%                 t                    3  ...
# 2657                  92%                 f                    2  ...
# 2693                  89%                 t                    1  ...
# 2974                  92%                 f                    2  ...
# 3021                 100%                 f                    1  ...
# 3038                 100%                 t                    4  ...
# 3044                  89%                 t                   27  ...
# 3057                  99%                 t                    3  ...
# 3139                 100%                 f                   21  ...
# 3183                 100%                 t                    1  ...
# 4147                  94%                 f                    1  ...
# 4954                 100%                 f                    1  ...
# 5351                  75%                 t                    2  ...
# 5360                  31%                 t                    1  ...
#
#       accommodates    bathrooms_text bedrooms beds  \
# 418              5            1 bath      2.0  NaN
# 573              2  1.5 shared baths      1.0  NaN
# 574              2  1.5 shared baths      1.0  NaN
# 659             16   17 shared baths      1.0  NaN
# 741              1           0 baths      NaN  NaN
# 748              2            1 bath      1.0  NaN
# 1428             2            1 bath      1.0  NaN
# 1441             2            1 bath      NaN  NaN
# 1568             2            1 bath      NaN  NaN
# 1578             2            1 bath      NaN  NaN
# 1585             4            1 bath      1.0  NaN
# 1586             4            1 bath      1.0  NaN
# 1593             2         1.5 baths      1.0  NaN
# 1619             1    1 private bath      1.0  NaN
# 1624             2    1 private bath      1.0  NaN
# 1695             2            1 bath      1.0  NaN
# 1724             2    1 private bath      1.0  NaN
# 1805             2            1 bath      NaN  NaN
# 1870             1           0 baths      NaN  NaN
# 1921             2            1 bath      1.0  NaN
# 1991             2            1 bath      1.0  NaN
# 2004             2    1 private bath      1.0  NaN
# 2195             2    1 private bath      1.0  NaN
# 2245             3            1 bath      1.0  NaN
# 2282             2     1 shared bath      1.0  NaN
# 2474             2    2 shared baths      1.0  NaN
# 2529             2         1.5 baths      1.0  NaN
# 2566             6           2 baths      2.0  NaN
# 2657             7         2.5 baths      3.0  NaN
# 2693             2            1 bath      1.0  NaN
# 2974             2            1 bath      1.0  NaN
# 3021             4         2.5 baths      2.0  NaN
# 3038             2         1.5 baths      1.0  NaN
# 3044             4            1 bath      NaN  NaN
# 3057             3  1.5 shared baths      1.0  NaN
# 3139             1         1.5 baths      1.0  NaN
# 3183             1     1 shared bath      1.0  NaN
# 4147             6           2 baths      3.0  NaN
# 4954             2            1 bath      1.0  NaN
# 5351             2            1 bath      1.0  NaN
# 5360             2            1 bath      NaN  NaN
#
#                                               amenities  price  \
# 418   ["Dishes and silverware", "Dryer", "Essentials...  120.0
# 573   ["Dishes and silverware", "Coffee maker", "Ess...   30.0
# 574   ["Dishes and silverware", "Coffee maker", "Ess...   30.0
# 659   ["Dishes and silverware", "Dryer", "Coffee mak...   53.0
# 741                                                  []   74.0
# 748   ["Dishes and silverware", "Dryer", "Coffee mak...  129.0
# 1428  ["Dryer", "Paid parking on premises", "Pool", ...   85.0
# 1441  ["Dishes and silverware", "Dryer", "Coffee mak...  158.0
# 1568  ["Dishes and silverware", "Carbon monoxide ala...   74.0
# 1578  ["Dishes and silverware", "Dryer", "Coffee mak...  150.0
# 1585  ["Dishes and silverware", "Dryer", "Coffee mak...  168.0
# 1586  ["Dishes and silverware", "Dryer", "Coffee mak...  168.0
# 1593  ["Dryer", "Essentials", "Heating", "Free parki...   75.0
# 1619  ["Dishes and silverware", "Dryer", "Coffee mak...   50.0
# 1624  ["Private living room", "Iron", "Essentials", ...   10.0
# 1695  ["Dryer", "Essentials", "Heating", "Free parki...  100.0
# 1724  ["Dryer", "Hot water", "Iron", "Smoke alarm", ...   27.0
# 1805  ["Dishes and silverware", "Coffee maker", "Ess...   51.0
# 1870                                                 []   10.0
# 1921  ["Air conditioning", "Dryer", "Hot water", "Ir...  600.0
# 1991  ["Air conditioning", "Dryer", "Breakfast", "De...  205.0
# 2004  ["Iron", "Fire extinguisher", "Lock on bedroom...   85.0
# 2195  ["Coffee maker", "Essentials", "Heating", "Bod...  179.0
# 2245  ["Shared hot tub", "Air conditioning", "Dryer"...   85.0
# 2282  ["Dishes and silverware", "Dedicated workspace...   55.0
# 2474  ["Dishes and silverware", "Smoking allowed", "...   30.0
# 2529  ["Dishes and silverware", "Sound system", "Ess...  114.0
# 2566  ["Dishes and silverware", "Sound system", "Rad...  282.0
# 2657  ["Dishes and silverware", "Essentials", "Coffe...  175.0
# 2693  ["Dishes and silverware", "Dryer", "Free resor...  120.0
# 2974  ["Dishes and silverware", "Essentials", "Body ...   77.0
# 3021  ["Dishes and silverware", "Dryer", "Clothing s...   87.0
# 3038  ["Shower gel", "Dryer", "Dishes and silverware...  250.0
# 3044  ["Pets allowed", "Dedicated workspace", "Fire ...  100.0
# 3057  ["Dishes and silverware", "Clothing storage: d...   86.0
# 3139  ["City skyline view", "Air conditioning", "Bui...  130.0
# 3183  ["Dishes and silverware", "Radiant heating", "...   55.0
# 4147  ["Dishes and silverware", "Gas stove", "Indoor...  639.0
# 4954  ["Dishes and silverware", "Essentials", "Hot w...   73.0
# 5351  ["Dishes and silverware", "Dryer", "Essentials...  125.0
# 5360  ["Dishes and silverware", "Dryer", "Coffee mak...   94.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 418                 232                 4.83                              3
# 573                  91                 4.74                              3
# 574                 103                 4.55                              3
# 659                  99                 4.85                              6
# 741                  34                 4.68                              2
# 748                  52                 4.73                              2
# 1428                  1                  NaN                              1
# 1441                213                 4.52                             12
# 1568                136                 4.86                              1
# 1578                417                 4.63                             12
# 1585                 13                 4.69                             12
# 1586                133                 4.63                             12
# 1593                  0                  NaN                              1
# 1619                  0                  NaN                              2
# 1624                  1                 5.00                              1
# 1695                  9                 5.00                              2
# 1724                  2                 5.00                              2
# 1805                 15                 4.87                             10
# 1870                  8                 4.88                              2
# 1921                  0                  NaN                              1
# 1991                  3                 4.00                              1
# 2004                  0                  NaN                              1
# 2195                 67                 4.58                             26
# 2245                  0                  NaN                              1
# 2282                  2                 5.00                              1
# 2474                  2                 3.00                             12
# 2529                 20                 4.85                              1
# 2566                  2                 5.00                              2
# 2657                  5                 5.00                              2
# 2693                  4                 4.75                              1
# 2974                  7                 5.00                              1
# 3021                  8                 4.75                              1
# 3038                  0                  NaN                              4
# 3044                  1                 2.00                             16
# 3057                 68                 4.94                              1
# 3139                  1                 5.00                             21
# 3183                 18                 4.94                              1
# 4147                 10                 5.00                              1
# 4954                 12                 4.92                              1
# 5351                 70                 4.76                              2
# 5360                 23                 4.48                              1
#
#       num_bath
# 418        1.0
# 573        1.5
# 574        1.5
# 659       17.0
# 741        0.0
# 748        1.0
# 1428       1.0
# 1441       1.0
# 1568       1.0
# 1578       1.0
# 1585       1.0
# 1586       1.0
# 1593       1.5
# 1619       1.0
# 1624       1.0
# 1695       1.0
# 1724       1.0
# 1805       1.0
# 1870       0.0
# 1921       1.0
# 1991       1.0
# 2004       1.0
# 2195       1.0
# 2245       1.0
# 2282       1.0
# 2474       2.0
# 2529       1.5
# 2566       2.0
# 2657       2.5
# 2693       1.0
# 2974       1.0
# 3021       2.5
# 3038       1.5
# 3044       1.0
# 3057       1.5
# 3139       1.5
# 3183       1.0
# 4147       2.0
# 4954       1.0
# 5351       1.0
# 5360       1.0
#
# [41 rows x 29 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[
    (updated_df['id'] == 42757920) | 
    (updated_df['id'] == 50422078) | 
    (updated_df['id'] == 689085319927829820) 
]
# Out:
#                       id    host_id host_name  host_since host_location  \
# 1624            42757920  340401226      Jake  2020-03-05           NaN
# 2474            50422078  406033071    Austin  2021-06-08           NaN
# 4147  689085319927829820   41414078   Melissa  2015-08-13    Denver, CO
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 1624        within a day                60%                  33%
# 2474  within a few hours                71%                  94%
# 4147      within an hour               100%                  94%
#
#      host_is_superhost  host_listings_count  ...  accommodates  \
# 1624                 f                    1  ...             2
# 2474                 f                   15  ...             2
# 4147                 f                    1  ...             6
#
#       bathrooms_text bedrooms beds  \
# 1624  1 private bath      1.0  1.0
# 2474  2 shared baths      1.0  1.0
# 4147         2 baths      3.0  3.0
#
#                                               amenities  price  \
# 1624  ["Private living room", "Iron", "Essentials", ...   10.0
# 2474  ["Dishes and silverware", "Smoking allowed", "...   30.0
# 4147  ["Dishes and silverware", "Gas stove", "Indoor...  639.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 1624                  1                  5.0                              1
# 2474                  2                  3.0                             12
# 4147                 10                  5.0                              1
#
#       num_bath
# 1624       1.0
# 2474       2.0
# 4147       2.0
#
# [3 rows x 29 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  2.,  5.,  6.,  3.,  4.,  7., 13.,  9.,  8., 18.,  0., 10.,
#        11., 12., 16., 14., 17.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([1., 5., 2., 3., 4., 6., 7., 0., 9., 8.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['host_since'] == 'N/A']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['host_since'].unique()
# Out:
# array(['2008-07-07', '2013-05-31', '2013-06-26', ..., '2012-09-21',
#        '2013-02-21', '2012-09-15'], dtype=object)

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 0 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 752

# %%
updated_df['host_location'].unique()
# Out:
# array(['Denver, CO', 'United States', 'Colorado, United States',
#        'Aspen, CO', 'unknown', 'Seattle, WA', 'Silverthorne, CO',
#        'Englewood, CO', 'Fort Collins, CO', 'Aurora, CO',
#        'Santa Monica, CA', 'Newport Beach, CA', 'Louisville, CO',
#        'Tucson, AZ', 'Las Vegas, NV', 'London, United Kingdom',
#        'Bocas del Toro Province, Panama', 'Atlanta, GA', 'Windsor, CO',
#        'San Francisco, CA', 'Highlands Ranch, CO', 'Austin, TX',
#        'Castle Rock, CO', 'Boulder, CO', 'Golden, CO', 'Calabasas, CA',
#        'New York, NY', 'Eagle, CO', 'Westminster, CO', 'Chattanooga, TN',
#        'Scottsdale, AZ', 'Wheat Ridge, CO', 'Nashville, TN',
#        'Vila Nova de Poiares, Portugal', 'Philadelphia, PA',
#        'Evergreen, CO', 'Lakewood, CO', 'Minneapolis, MN',
#        'Greenwood Village, CO', 'San Juan, Puerto Rico', 'Tempe, AZ',
#        'Casablanca, Morocco', 'Vail, CO', 'Tampa, FL',
#        'Steamboat Springs, CO', 'Centennial, CO', 'Yorba Linda, CA',
#        'Valley Center, CA', 'Saint Charles, MO', 'Thornton, CO',
#        'Littleton, CO', 'Los Angeles, CA', 'Boston, MA', 'Arvada, CO',
#        'Lafayette, CO', 'Brentwood, CA', 'Garland, TX',
#        'Fergus Falls, MN', 'Zanesville, OH', 'Santa Fe, NM',
#        'Maricopa, AZ', 'Colorado Springs, CO', 'Brighton, MI',
#        'Louisville, KY', 'Edgewater, CO', 'Leadville, CO',
#        'Broomfield, CO', 'Brighton, CO', 'Livingston, MT',
#        'Laguna Beach, CA', 'San Diego, CA', 'Nederland, CO', 'Avon, CO',
#        'Oklahoma City, OK', 'Haxtun, CO', 'Mount Hood, OR', 'Lenexa, KS',
#        'Gilbert, AZ', 'Chicago, IL', 'Oakton, VA', 'Breckenridge, CO',
#        'Dallas, TX', 'Long Beach, CA', 'St Petersburg, FL',
#        'Cambridge, VT', 'Santa Barbara, CA', 'Kaneohe, HI', 'Edmond, OK',
#        'Waxhaw, NC', 'Houston, TX', 'Frisco, CO',
#        'Winchester, United Kingdom', 'Morrison, CO', 'Medellín, Colombia',
#        'Ann Arbor, MI', 'Wimberley, TX', 'Rocklin, CA', 'Gunnison, CO',
#        'Midland, MI', 'Fort Lauderdale, FL', 'Cincinnati, OH',
#        'Ottawa, Canada', 'Alma, CO', 'Saint Augustine, FL',
#        'Greenville, SC', 'Berthoud, CO', 'Sacramento, CA', 'Butte, MT',
#        'Fresno, CA', 'Kittredge, CO', 'Spring Grove, IL',
#        'Coquitlam, Canada', 'Portland, OR', 'Miami, FL', 'Baltimore, MD',
#        'Saint Helena, CA', 'Diamond Bar, CA', 'Cape Elizabeth, ME',
#        'South Houston, TX', 'Holland, MI', 'Chantilly, VA', 'Pine, CO',
#        'Sedona, AZ', 'Concord, CA', 'Salida, CO', 'McLean, VA',
#        'Tallahassee, FL', 'Incline Village, NV', 'Jacksonville, FL',
#        'Billings, MT', 'Oak Bluffs, MA', 'Munich, Germany', 'Phoenix, AZ',
#        'Rio de Janeiro, Brazil', 'Washington, United States',
#        'Emeryville, CA', 'Cottonwood Heights, UT', 'Albuquerque, NM',
#        'Eagle Point, OR', 'Sonoma, CA', 'Loveland, CO', 'Boca Raton, FL',
#        'Knoxville, TN', 'Sturgis, SD', 'Santa Cruz, CA', 'Coronado, CA',
#        'Gainesville, FL', 'Manhattan Beach, CA', 'Bethesda, MD',
#        'Parker, CO', 'Spokane, WA', 'Gulf Stream, FL',
#        'Rincón, Puerto Rico', 'Washington, DC', 'College Park, MD',
#        'Lynchburg, VA', 'Delray Beach, FL', 'Niwot, CO', 'Kapaʻa, HI',
#        'Elko, NV', 'Huntington, NY', 'Buffalo, NY', 'Greeley, CO',
#        'Kansas City, MO', 'Surprise, AZ', 'Dillon, CO', 'Clark, CO'],
#       dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 2799

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   2,    3,    1,    8,    4,    5,    6,   11,    9,   14,   18,
#          21,   17,    7,   10,   40,   68,   24,   77,   53,   96,   23,
#          46,   71,   22,  253,   27,   15,   32,   16,   39,   26,   12,
#          80,   19,  246,  826,  178,  777,   38, 3305, 4818,   57,  146,
#          13,   44,   31,   28,  157,   62,  171,   36, 2314,  348,  572,
#          65,   33])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   2,    3,    1,    4,   11,    8,    5,    6,    7,   31,    9,
#          17,   10,   16,   13,   28,   38,   65,   73,   29,   35,   14,
#          93,   32,   63,   15,   33,  110,   36,   61,   41,   25,  729,
#          48,   12,   18,   56,   77,   94,   20,   21,  294, 1280,   26,
#         433, 1534,   45,  107,   24, 4537, 5399,   84,  281,   23,   19,
#          22,  124,   34,   58,  208,   44,   68,  181,   86, 7847,  384,
#        1018,   57,   71])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone']", "['phone', 'work_email']", "['email']"], dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  2,   3,   1,   7,   4,   5,   6,  11,  21,  25,  20,  10,  18,
#         43,  12,  14,   9,  16,   8,  13,  53,  93,  26,  38,  86, 253,
#         17,  15,  44,  24,  48])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['Denver, Colorado, United States', nan,
#        'Englewood, Colorado, United States',
#        'Wheat Ridge, Colorado, United States',
#        'DENVER , Colorado, United States',
#        'Aurora, Colorado, United States',
#        'Wheat ridge, Colorado, United States',
#        'Stapleton, Denver, Colorado, United States',
#        'Lakewood, Colorado, United States',
#        'Denver , Colorado, United States', 'Denver , Co, United States',
#        'Denver, United States', 'Lakewood , Colorado, United States',
#        'Edgewater, Colorado, United States',
#        'Littleton, Colorado, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 1501

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Virginia Village', 'Cheesman Park', 'Platt Park', 'Capitol Hill',
#        'West Colfax', 'Berkeley', 'West Highland', 'Speer',
#        'South Park Hill', 'Sloan Lake', 'Highland', 'Washington Park',
#        'Congress Park', 'CBD', 'University', 'Clayton', 'City Park West',
#        'Lincoln Park', 'Hilltop', 'Country Club', 'Union Station',
#        'Cory - Merrill', 'Athmar Park', 'Stapleton', 'Five Points',
#        'Windsor', 'Baker', 'Gateway - Green Valley Ranch', 'Cole',
#        'Rosedale', 'Whittier', 'Fort Logan', 'Sunnyside', 'City Park',
#        'Skyland', 'North Capitol Hill', 'Wellshire', 'Goldsmith',
#        'Hampden', 'Hampden South', 'Washington Park West', 'Hale',
#        'North Park Hill', 'University Park', 'Jefferson Park',
#        'Barnum West', 'Overland', 'Barnum', 'University Hills',
#        'Lowry Field', 'East Colfax', 'Washington Virginia Vale',
#        'Cherry Creek', 'Regis', 'Northeast Park Hill', 'Civic Center',
#        'Montclair', 'Villa Park', 'Ruby Hill', 'Indian Creek',
#        'Globeville', 'Mar Lee', 'Chaffee Park', 'Montbello',
#        'College View - South Platte', 'DIA', 'Bear Valley',
#        'Harvey Park South', 'Westwood', 'Belcaro', 'Valverde',
#        'Harvey Park', 'Sun Valley', 'Kennedy', 'Auraria',
#        'Elyria Swansea', 'Southmoor Park', 'Marston'], dtype=object)

# %%
updated_df['neighbourhood_cleansed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### We are going to drop neighbourhood column for Denver Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # host_response_time

# %%
updated_df['host_response_time'].unique()
# Out:
# array(['within a day', 'within a few hours', nan, 'within an hour',
#        'a few days or more'], dtype=object)

# %% [markdown]
# # host_response_rate

# %%
updated_df['host_response_rate'].unique()
# Out:
# array(['100%', nan, '90%', '96%', '97%', '88%', '73%', '80%', '86%',
#        '67%', '0%', '92%', '75%', '50%', '93%', '98%', '29%', '25%',
#        '83%', '70%', '99%', '91%', '60%', '89%', '87%', '94%', '33%',
#        '71%', '78%', '40%', '74%', '64%'], dtype=object)

# %% [markdown]
# # host_acceptance_rate

# %%
updated_df['host_acceptance_rate'].unique()
# Out:
# array(['100%', '70%', '83%', '97%', '99%', '87%', '75%', nan, '77%',
#        '84%', '20%', '59%', '67%', '80%', '0%', '88%', '44%', '91%',
#        '79%', '95%', '93%', '98%', '50%', '85%', '86%', '33%', '81%',
#        '96%', '94%', '52%', '89%', '82%', '90%', '40%', '92%', '58%',
#        '60%', '64%', '73%', '69%', '78%', '63%', '56%', '46%', '25%',
#        '57%', '22%', '43%', '29%', '53%', '38%', '71%', '55%', '36%',
#        '76%', '68%', '54%', '14%', '49%', '30%', '74%', '62%', '42%',
#        '41%', '19%', '65%', '27%', '61%', '31%'], dtype=object)

# %% [markdown]
# # Adding new columns for city
#
# Add new column and put 'Denver' for all rows for later joining purpose

# %%
updated_df['city'] = 'Denver'
updated_df.head()
# Out:
#         id  host_id       host_name  host_since host_location  \
# 0      177      615             Joe  2008-07-07    Denver, CO
# 1  1223612  6674631         Cynthia  2013-05-31    Denver, CO
# 2  1313699  7138728             Ann  2013-06-26    Denver, CO
# 3  1327856  7206373  Leila And Alex  2013-06-30    Denver, CO
# 4  1402409  1382900          Pamela  2011-11-07    Denver, CO
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day               100%                 100%
# 1  within a few hours               100%                  70%
# 2                 NaN                NaN                  83%
# 3      within an hour               100%                 100%
# 4      within an hour               100%                  97%
#
#   host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms beds  \
# 0                 t                    2  ...          1 bath      1.0  1.0
# 1                 t                    3  ...          1 bath      1.0  2.0
# 2                 f                    1  ...         2 baths      5.0  5.0
# 3                 t                    2  ...         2 baths      2.0  2.0
# 4                 t                    1  ...         2 baths      5.0  6.0
#
#                                            amenities  price  \
# 0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0
# 1  ["Hot water", "Iron", "Essentials", "Heating",...   58.0
# 2  ["Dishes and silverware", "Dryer", "Essentials...  218.0
# 3  ["Dishes and silverware", "Dryer", "Indoor fir...  139.0
# 4  ["Dishes and silverware", "Dryer", "Outlet cov...  256.0
#
#    number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                120                 4.78                              2
# 1                184                 4.76                              3
# 2                 24                 4.92                              1
# 3                174                 4.75                              1
# 4                142                 4.95                              1
#
#    num_bath    city
# 0       1.0  Denver
# 1       1.0  Denver
# 2       2.0  Denver
# 3       2.0  Denver
# 4       2.0  Denver
#
# [5 rows x 29 columns]

# %% [markdown]
# # Count number of amenities

# %%
import ast

# Convert the 'amenities' string to a list using ast.literal_eval
updated_df['amenities_list'] = updated_df['amenities'].apply(lambda x: ast.literal_eval(x))

# Count the number of amenities in each list and create a new column with these counts
updated_df['amenities_count'] = updated_df['amenities_list'].apply(lambda x: len(x))

updated_df.drop('amenities_list', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#         id  host_id       host_name  host_since host_location  \
# 0      177      615             Joe  2008-07-07    Denver, CO
# 1  1223612  6674631         Cynthia  2013-05-31    Denver, CO
# 2  1313699  7138728             Ann  2013-06-26    Denver, CO
# 3  1327856  7206373  Leila And Alex  2013-06-30    Denver, CO
# 4  1402409  1382900          Pamela  2011-11-07    Denver, CO
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day               100%                 100%
# 1  within a few hours               100%                  70%
# 2                 NaN                NaN                  83%
# 3      within an hour               100%                 100%
# 4      within an hour               100%                  97%
#
#   host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                 t                    2  ...       1.0  1.0
# 1                 t                    3  ...       1.0  2.0
# 2                 f                    1  ...       5.0  5.0
# 3                 t                    2  ...       2.0  2.0
# 4                 t                    1  ...       5.0  6.0
#
#                                            amenities  price number_of_reviews  \
# 0  ["Dishes and silverware", "Coffee maker", "Ess...   79.0               120
# 1  ["Hot water", "Iron", "Essentials", "Heating",...   58.0               184
# 2  ["Dishes and silverware", "Dryer", "Essentials...  218.0                24
# 3  ["Dishes and silverware", "Dryer", "Indoor fir...  139.0               174
# 4  ["Dishes and silverware", "Dryer", "Outlet cov...  256.0               142
#
#    review_scores_value  calculated_host_listings_count num_bath    city  \
# 0                 4.78                               2      1.0  Denver
# 1                 4.76                               3      1.0  Denver
# 2                 4.92                               1      2.0  Denver
# 3                 4.75                               1      2.0  Denver
# 4                 4.95                               1      2.0  Denver
#
#   amenities_count
# 0              29
# 1              12
# 2              49
# 3              35
# 4              74
#
# [5 rows x 30 columns]

# %%
# sanity check

see = updated_df.loc[updated_df['id'] == 1223612]


amenities_text = see['amenities'].iloc[0]

# Print the extracted 'amenities' list
print(amenities_text)
# Out:
# ["Hot water", "Iron", "Essentials", "Heating", "Extra pillows and blankets", "Hangers", "Wifi", "Shampoo", "Indoor fireplace", "Hair dryer", "Kitchen", "Bed linens"]

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                  0
# host_id                             0
# host_name                           0
# host_since                          0
# host_location                       0
# host_response_time                675
# host_response_rate                675
# host_acceptance_rate              436
# host_is_superhost                   0
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# host_has_profile_pic                0
# host_identity_verified              0
# neighbourhood_cleansed              0
# latitude                            0
# longitude                           0
# room_type                           0
# accommodates                        0
# bathrooms_text                      0
# bedrooms                            0
# beds                                0
# amenities                           0
# price                               0
# number_of_reviews                   0
# review_scores_value               963
# calculated_host_listings_count      0
# num_bath                            0
# city                                0
# amenities_count                     0
# dtype: int64

# %%
# Save as a new csv file
updated_df.to_csv('clean-data/listings_detailed_clean_denver.csv', index=False)
