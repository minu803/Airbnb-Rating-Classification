# %% [markdown]
# # Austin

# %%
import pandas as pd
import numpy as np

# %%
# calendar = pd.read_csv('usa/Seattle/calendar.csv')
# listings = pd.read_csv('usa/Seattle/listings.csv')
listings_detailed = pd.read_csv('usa/Austin/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (14368, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (14368, 29)

# %%
# Save as a new csv file
listings_detailed.to_csv('listings_detailed_clean_austin.csv', index=False)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 10]
filtered_df
# Out:
#             id    host_id  host_name  host_since       host_location  \
# 3050  20647325   28367024       John  2015-02-25  Stuttgart, Germany
# 3063  20691399   51672309      Jamie  2015-12-18          Austin, TX
# 3067  20713150    3864713       Jeff  2012-10-14        New York, NY
# 3322  21946737  160198833       Matt  2017-11-26                 NaN
# 5114  36770125    3440175      James  2012-09-01          Austin, TX
# 5987  42664390  192261997  Christian  2018-05-29    Ensenada, Mexico
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 3050                NaN                NaN                  NaN
# 3063                NaN                NaN                  NaN
# 3067                NaN                NaN                  NaN
# 3322                NaN                NaN                  NaN
# 5114     within an hour               100%                 100%
# 5987                NaN                NaN                 100%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 3050                 f                  1.0  ...             3       NaN
# 3063                 f                  1.0  ...             2       NaN
# 3067                 f                  1.0  ...             1       NaN
# 3322                 f                  1.0  ...             2       NaN
# 5114                 f                  9.0  ...             2       NaN
# 5987                 f                  1.0  ...             4       NaN
#
#       bathrooms_text bedrooms beds  \
# 3050   1 shared bath      1.0  1.0
# 3063  1 private bath      1.0  1.0
# 3067   1 shared bath      1.0  1.0
# 3322   1 shared bath      1.0  1.0
# 5114          1 bath      NaN  1.0
# 5987  1 private bath      NaN  1.0
#
#                                               amenities  price  \
# 3050  ["Free parking on premises", "Backyard", "Dish...   10.0
# 3063  ["Security cameras on property", "Washer", "Es...   10.0
# 3067  ["Carbon monoxide alarm", "Essentials", "TV", ...   10.0
# 3322  ["Essentials", "Heating", "TV", "Pets allowed"...   10.0
# 5114  ["Free parking on premises", "Heating", "Backy...   10.0
# 5987  ["Washer", "Free parking on premises", "TV", "...   10.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 3050                  1                5.00                               1
# 3063                  0                 NaN                               1
# 3067                  0                 NaN                               1
# 3322                  0                 NaN                               1
# 5114                 23                4.91                               8
# 5987                  1                5.00                               1
#
# [6 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 2

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id            host_name  host_since host_location  \
# 5998  42738847  314291208       Hotel Granduca  2019-12-03    Austin, TX
# 6413  45895289  260188286  Hotel Saint Cecilia  2019-05-06           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 5998                NaN                NaN                  NaN
# 6413                NaN                NaN                   0%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 5998               NaN                  5.0  ...             0       NaN
# 6413               NaN                  8.0  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 5998            NaN      NaN  NaN
# 6413            NaN      NaN  NaN
#
#                                               amenities  price  \
# 5998  ["Bottled water", "Garden", "First aid kit", "...    0.0
# 6413  ["Pack \u2019n play/Travel crib", "Heating", "...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 5998                  0                 NaN                               1
# 6413                  0                 NaN                               1
#
# [2 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id            host_name  host_since host_location  \
# 5998  42738847  314291208       Hotel Granduca  2019-12-03    Austin, TX
# 6413  45895289  260188286  Hotel Saint Cecilia  2019-05-06           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 5998                NaN                NaN                  NaN
# 6413                NaN                NaN                   0%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 5998               NaN                  5.0  ...             0       NaN
# 6413               NaN                  8.0  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 5998            NaN      NaN  NaN
# 6413            NaN      NaN  NaN
#
#                                               amenities  price  \
# 5998  ["Bottled water", "Garden", "First aid kit", "...    0.0
# 6413  ["Pack \u2019n play/Travel crib", "Heating", "...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 5998                  0                 NaN                               1
# 6413                  0                 NaN                               1
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 2

# %%
cleaned_listings.head()
# Out:
#      id  host_id  host_name  host_since host_location  host_response_time  \
# 0  5456     8028     Sylvia  2009-02-16    Austin, TX      within an hour
# 1  5769     8186  Elizabeth  2009-02-19    Austin, TX  within a few hours
# 2  6413    13879       Todd  2009-04-17    Austin, TX                 NaN
# 3  6448    14156        Amy  2009-04-20    Austin, TX      within an hour
# 4  8502    25298      Karen  2009-07-11    Austin, TX        within a day
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  95%                 t
# 1               100%                  95%                 t
# 2                NaN                 100%                 t
# 3               100%                 100%                 t
# 4                60%                  70%                 f
#
#    host_listings_count  ...  accommodates bathrooms bathrooms_text bedrooms  \
# 0                  2.0  ...             3       NaN         1 bath      1.0
# 1                  1.0  ...             2       NaN  1 shared bath      1.0
# 2                  1.0  ...             2       NaN         1 bath      NaN
# 3                  1.0  ...             2       NaN         1 bath      1.0
# 4                  1.0  ...             2       NaN         1 bath      1.0
#
#   beds                                          amenities  price  \
# 0  2.0  ["Heating", "Backyard", "Bed linens", "Hot wat...  176.0
# 1  1.0  ["Private backyard", "Free parking on premises...   42.0
# 2  1.0  ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 3  2.0  ["Pack \u2019n play/Travel crib", "Free parkin...  240.0
# 4  1.0  ["Essentials", "Heating", "Central air conditi...   85.0
#
#    number_of_reviews review_scores_value  calculated_host_listings_count
# 0                630                4.79                               2
# 1                275                4.92                               1
# 2                122                4.93                               1
# 3                295                4.90                               1
# 4                 48                4.57                               1
#
# [5 rows x 29 columns]

# %%
cleaned_listings.shape
# Out:
# (14366, 29)

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 bath', '1 shared bath', '2 baths', '1.5 baths', '2.5 baths',
#        '3 baths', '1 private bath', nan, '3.5 baths', '0 baths',
#        '4 baths', '4.5 baths', '2.5 shared baths', '0 shared baths',
#        '1.5 shared baths', 'Half-bath', '5 baths', '8 baths', '5.5 baths',
#        '2 shared baths', 'Private half-bath', '6.5 baths', '6 baths',
#        '3 shared baths', '4 shared baths', '10.5 baths', '17 baths',
#        '7.5 baths', '7 baths', '8.5 baths', '11.5 baths',
#        'Shared half-bath', '9.5 baths', '3.5 shared baths', '10 baths'],
#       dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 bath' '1 shared bath' '2 baths' '1.5 baths' '2.5 baths' '3 baths'
#  '1 private bath' '' '3.5 baths' '0 baths' '4 baths' '4.5 baths'
#  '2.5 shared baths' '0 shared baths' '1.5 shared baths' '0.5 baths'
#  '5 baths' '8 baths' '5.5 baths' '2 shared baths' '6.5 baths' '6 baths'
#  '3 shared baths' '4 shared baths' '10.5 baths' '17 baths' '7.5 baths'
#  '7 baths' '8.5 baths' '11.5 baths' '9.5 baths' '3.5 shared baths'
#  '10 baths']

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#             id    host_id    host_name  host_since      host_location  \
# 70      247770    1298575       Gloria  2011-10-16         Austin, TX
# 84      314152    1614097       Denise  2012-01-16         Austin, TX
# 105     337125     261883      Carolyn  2010-10-14         Austin, TX
# 126     353955    1792021        Mykel  2012-02-22         Austin, TX
# 131     355232    1798084      Jeffrey  2012-02-23         Austin, TX
# 197     666768    2350380        Nessa  2012-05-11         Austin, TX
# 220     711149    3659932          Ken  2012-09-24         Austin, TX
# 290     929579    5004628       Lauren  2013-02-07         Austin, TX
# 313     957405    5206723    Jeannette  2013-02-24         Austin, TX
# 326     978089    5352009       Daniel  2013-03-06         Austin, TX
# 4444  30198612  226833445  The Wayback  2018-11-21         Austin, TX
# 4622  32171574   77021411     Jennifer  2016-06-10  San Francisco, CA
# 4972  35002301  226833445  The Wayback  2018-11-21         Austin, TX
# 6970  49062579  299606671         Dina  2019-10-02         Austin, TX
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 70                  NaN                NaN                  NaN
# 84                  NaN                NaN                  NaN
# 105                 NaN                NaN                  NaN
# 126                 NaN                NaN                  NaN
# 131                 NaN                NaN                   0%
# 197        within a day                86%                  21%
# 220                 NaN                NaN                   0%
# 290                 NaN                NaN                  NaN
# 313                 NaN                NaN                  NaN
# 326                 NaN                NaN                  NaN
# 4444       within a day               100%                  67%
# 4622     within an hour               100%                 100%
# 4972       within a day               100%                  67%
# 6970     within an hour               100%                  99%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 70                   f                  1.0  ...             5       NaN
# 84                   f                  1.0  ...             4       NaN
# 105                  f                  1.0  ...             2       NaN
# 126                  f                  1.0  ...             2       NaN
# 131                  f                  1.0  ...             7       NaN
# 197                  f                  3.0  ...             2       NaN
# 220                  f                  2.0  ...             6       NaN
# 290                  f                  1.0  ...             2       NaN
# 313                  f                  1.0  ...             4       NaN
# 326                  f                  1.0  ...             2       NaN
# 4444                 f                 10.0  ...            16       NaN
# 4622                 f                 17.0  ...             6       NaN
# 4972                 f                 10.0  ...             9       NaN
# 6970                 f                 11.0  ...             1       NaN
#
#      bathrooms_text bedrooms  beds  \
# 70                       3.0   2.0
# 84                       2.0   NaN
# 105                      1.0   2.0
# 126                      2.0   1.0
# 131                      3.0   7.0
# 197                      1.0   1.0
# 220                      3.0   4.0
# 290                      2.0   NaN
# 313                      1.0   1.0
# 326                      1.0   NaN
# 4444                     8.0  13.0
# 4622                     2.0   3.0
# 4972                     4.0   8.0
# 6970                     1.0   1.0
#
#                                               amenities   price  \
# 70    ["Washer", "Free parking on premises", "Heatin...   175.0
# 84                                                   []   350.0
# 105   ["Washer", "Essentials", "Fire extinguisher", ...    80.0
# 126   ["Washer", "Free parking on premises", "Heatin...   225.0
# 131   ["Washer", "Free parking on premises", "Heatin...  1000.0
# 197   ["Washer", "Free parking on premises", "Heatin...   100.0
# 220   ["Washer", "Essentials", "Extra pillows and bl...  1100.0
# 290                                                  []   800.0
# 313                           ["Wifi", "TV", "Kitchen"]   350.0
# 326                                                  []   200.0
# 4444  ["Free parking on premises", "Heating", "Hot w...  3350.0
# 4622  ["Heating", "Bed linens", "Dishwasher", "Hot w...   200.0
# 4972  ["Carbon monoxide alarm", "Fire extinguisher",...  1750.0
# 6970  ["Carbon monoxide alarm", "Washer", "Essential...    42.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 70                    1                5.00                               1
# 84                    0                 NaN                               1
# 105                  33                4.88                               1
# 126                   1                5.00                               1
# 131                   3                5.00                               1
# 197                   8                4.88                               3
# 220                   0                 NaN                               1
# 290                   0                 NaN                               1
# 313                   0                 NaN                               1
# 326                   1                5.00                               1
# 4444                  2                5.00                              10
# 4622                  1                5.00                               3
# 4972                  0                 NaN                              10
# 6970                  2                5.00                               8
#
# [14 rows x 29 columns]

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#                        id  bedrooms  beds bathrooms_text
# 0                    5456       1.0   2.0         1 bath
# 1                    5769       1.0   1.0  1 shared bath
# 2                    6413       NaN   1.0         1 bath
# 3                    6448       1.0   2.0         1 bath
# 4                    8502       1.0   1.0         1 bath
# ...                   ...       ...   ...            ...
# 14363  847159076072987428       4.0   5.0        2 baths
# 14364  847171709264672413       NaN   1.0         1 bath
# 14365  847178203609366885       2.0   3.0         1 bath
# 14366  847256590826352221       2.0   4.0        2 baths
# 14367  847304715126157738       1.0   2.0         1 bath
#
# [14366 rows x 4 columns]

# %%
# check for the previous NA rows in bathrooms text
filled_cleaned_listings[
    (filled_cleaned_listings['id'] == 247770) | 
    (filled_cleaned_listings['id'] == 314152) | 
    (filled_cleaned_listings['id'] == 337125) | 
    (filled_cleaned_listings['id'] == 353955) |
    (filled_cleaned_listings['id'] == 666768) | 
    (filled_cleaned_listings['id'] == 355232) | 
    (filled_cleaned_listings['id'] == 711149) 
]
# Out:
#          id  host_id host_name  host_since host_location host_response_time  \
# 70   247770  1298575    Gloria  2011-10-16    Austin, TX                NaN
# 84   314152  1614097    Denise  2012-01-16    Austin, TX                NaN
# 105  337125   261883   Carolyn  2010-10-14    Austin, TX                NaN
# 126  353955  1792021     Mykel  2012-02-22    Austin, TX                NaN
# 131  355232  1798084   Jeffrey  2012-02-23    Austin, TX                NaN
# 197  666768  2350380     Nessa  2012-05-11    Austin, TX       within a day
# 220  711149  3659932       Ken  2012-09-24    Austin, TX                NaN
#
#     host_response_rate host_acceptance_rate host_is_superhost  \
# 70                 NaN                  NaN                 f
# 84                 NaN                  NaN                 f
# 105                NaN                  NaN                 f
# 126                NaN                  NaN                 f
# 131                NaN                   0%                 f
# 197                86%                  21%                 f
# 220                NaN                   0%                 f
#
#      host_listings_count  ...  accommodates bathrooms bathrooms_text bedrooms  \
# 70                   1.0  ...             5       NaN       3.0 bath      3.0
# 84                   1.0  ...             4       NaN       2.0 bath      2.0
# 105                  1.0  ...             2       NaN       1.0 bath      1.0
# 126                  1.0  ...             2       NaN       2.0 bath      2.0
# 131                  1.0  ...             7       NaN       3.0 bath      3.0
# 197                  3.0  ...             2       NaN       1.0 bath      1.0
# 220                  2.0  ...             6       NaN       3.0 bath      3.0
#
#     beds                                          amenities   price  \
# 70   2.0  ["Washer", "Free parking on premises", "Heatin...   175.0
# 84   NaN                                                 []   350.0
# 105  2.0  ["Washer", "Essentials", "Fire extinguisher", ...    80.0
# 126  1.0  ["Washer", "Free parking on premises", "Heatin...   225.0
# 131  7.0  ["Washer", "Free parking on premises", "Heatin...  1000.0
# 197  1.0  ["Washer", "Free parking on premises", "Heatin...   100.0
# 220  4.0  ["Washer", "Essentials", "Extra pillows and bl...  1100.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count
# 70                   1                5.00                               1
# 84                   0                 NaN                               1
# 105                 33                4.88                               1
# 126                  1                5.00                               1
# 131                  3                5.00                               1
# 197                  8                4.88                               3
# 220                  0                 NaN                               1
#
# [7 rows x 29 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#       bathrooms_text  num_bath
# 0             1 bath       1.0
# 1      1 shared bath       1.0
# 2             1 bath       1.0
# 3             1 bath       1.0
# 4             1 bath       1.0
# ...              ...       ...
# 14363        2 baths       2.0
# 14364         1 bath       1.0
# 14365         1 bath       1.0
# 14366        2 baths       2.0
# 14367         1 bath       1.0
#
# [14366 rows x 2 columns]

# %%
updated_df
# Out:
#                        id    host_id  host_name  host_since host_location  \
# 0                    5456       8028     Sylvia  2009-02-16    Austin, TX
# 1                    5769       8186  Elizabeth  2009-02-19    Austin, TX
# 2                    6413      13879       Todd  2009-04-17    Austin, TX
# 3                    6448      14156        Amy  2009-04-20    Austin, TX
# 4                    8502      25298      Karen  2009-07-11    Austin, TX
# ...                   ...        ...        ...         ...           ...
# 14363  847159076072987428  276920863     Susana  2019-07-17    Austin, TX
# 14364  847171709264672413  276920863     Susana  2019-07-17    Austin, TX
# 14365  847178203609366885  276920863     Susana  2019-07-17    Austin, TX
# 14366  847256590826352221  499116561      Edwin  2023-02-01   Phoenix, AZ
# 14367  847304715126157738  243684594    Shirley  2019-02-17    Austin, TX
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 0          within an hour               100%                  95%
# 1      within a few hours               100%                  95%
# 2                     NaN                NaN                 100%
# 3          within an hour               100%                 100%
# 4            within a day                60%                  70%
# ...                   ...                ...                  ...
# 14363      within an hour                95%                 100%
# 14364      within an hour                95%                 100%
# 14365      within an hour                95%                 100%
# 14366      within an hour               100%                 100%
# 14367      within an hour                98%                  96%
#
#       host_is_superhost  host_listings_count  ...  bathrooms bathrooms_text  \
# 0                     t                  2.0  ...        NaN         1 bath
# 1                     t                  1.0  ...        NaN  1 shared bath
# 2                     t                  1.0  ...        NaN         1 bath
# 3                     t                  1.0  ...        NaN         1 bath
# 4                     f                  1.0  ...        NaN         1 bath
# ...                 ...                  ...  ...        ...            ...
# 14363                 f                 43.0  ...        NaN        2 baths
# 14364                 f                 43.0  ...        NaN         1 bath
# 14365                 f                 43.0  ...        NaN         1 bath
# 14366                 f                  2.0  ...        NaN        2 baths
# 14367                 f                 68.0  ...        NaN         1 bath
#
#       bedrooms beds                                          amenities  price  \
# 0          1.0  2.0  ["Heating", "Backyard", "Bed linens", "Hot wat...  176.0
# 1          1.0  1.0  ["Private backyard", "Free parking on premises...   42.0
# 2          NaN  1.0  ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 3          1.0  2.0  ["Pack \u2019n play/Travel crib", "Free parkin...  240.0
# 4          1.0  1.0  ["Essentials", "Heating", "Central air conditi...   85.0
# ...        ...  ...                                                ...    ...
# 14363      4.0  5.0  ["Washer", "Fire extinguisher", "Free parking ...  129.0
# 14364      NaN  1.0  ["Heating", "Bed linens", "Dishwasher", "Hot w...   54.0
# 14365      2.0  3.0  ["Free parking on premises", "Heating", "Bed l...  145.0
# 14366      2.0  4.0  ["Free parking on premises", "Heating", "Bed l...  144.0
# 14367      1.0  2.0  ["Free parking on premises", "Heating", "Backy...   80.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                    630                 4.79                              2
# 1                    275                 4.92                              1
# 2                    122                 4.93                              1
# 3                    295                 4.90                              1
# 4                     48                 4.57                              1
# ...                  ...                  ...                            ...
# 14363                  0                  NaN                             41
# 14364                  0                  NaN                             41
# 14365                  0                  NaN                             41
# 14366                  0                  NaN                              1
# 14367                  0                  NaN                             62
#
#        num_bath
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ...         ...
# 14363       2.0
# 14364       1.0
# 14365       1.0
# 14366       2.0
# 14367       1.0
#
# [14366 rows x 30 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 30 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  2. ,  1.5,  2.5,  3. ,  3.5,  0. ,  4. ,  4.5,  0.5,  5. ,
#         8. ,  5.5,  6.5,  6. , 10.5, 17. ,  7.5,  7. ,  8.5, 11.5,  9.5,
#        10. ])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df
# Out:
#                        id    host_id  host_name  host_since host_location  \
# 0                    5456       8028     Sylvia  2009-02-16    Austin, TX
# 1                    5769       8186  Elizabeth  2009-02-19    Austin, TX
# 2                    6413      13879       Todd  2009-04-17    Austin, TX
# 3                    6448      14156        Amy  2009-04-20    Austin, TX
# 4                    8502      25298      Karen  2009-07-11    Austin, TX
# ...                   ...        ...        ...         ...           ...
# 14363  847159076072987428  276920863     Susana  2019-07-17    Austin, TX
# 14364  847171709264672413  276920863     Susana  2019-07-17    Austin, TX
# 14365  847178203609366885  276920863     Susana  2019-07-17    Austin, TX
# 14366  847256590826352221  499116561      Edwin  2023-02-01   Phoenix, AZ
# 14367  847304715126157738  243684594    Shirley  2019-02-17    Austin, TX
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 0          within an hour               100%                  95%
# 1      within a few hours               100%                  95%
# 2                     NaN                NaN                 100%
# 3          within an hour               100%                 100%
# 4            within a day                60%                  70%
# ...                   ...                ...                  ...
# 14363      within an hour                95%                 100%
# 14364      within an hour                95%                 100%
# 14365      within an hour                95%                 100%
# 14366      within an hour               100%                 100%
# 14367      within an hour                98%                  96%
#
#       host_is_superhost  host_listings_count  ...  accommodates  \
# 0                     t                  2.0  ...             3
# 1                     t                  1.0  ...             2
# 2                     t                  1.0  ...             2
# 3                     t                  1.0  ...             2
# 4                     f                  1.0  ...             2
# ...                 ...                  ...  ...           ...
# 14363                 f                 43.0  ...            10
# 14364                 f                 43.0  ...             2
# 14365                 f                 43.0  ...             5
# 14366                 f                  2.0  ...             6
# 14367                 f                 68.0  ...             5
#
#       bathrooms_text bedrooms beds  \
# 0             1 bath      1.0  2.0
# 1      1 shared bath      1.0  1.0
# 2             1 bath      NaN  1.0
# 3             1 bath      1.0  2.0
# 4             1 bath      1.0  1.0
# ...              ...      ...  ...
# 14363        2 baths      4.0  5.0
# 14364         1 bath      NaN  1.0
# 14365         1 bath      2.0  3.0
# 14366        2 baths      2.0  4.0
# 14367         1 bath      1.0  2.0
#
#                                                amenities  price  \
# 0      ["Heating", "Backyard", "Bed linens", "Hot wat...  176.0
# 1      ["Private backyard", "Free parking on premises...   42.0
# 2      ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 3      ["Pack \u2019n play/Travel crib", "Free parkin...  240.0
# 4      ["Essentials", "Heating", "Central air conditi...   85.0
# ...                                                  ...    ...
# 14363  ["Washer", "Fire extinguisher", "Free parking ...  129.0
# 14364  ["Heating", "Bed linens", "Dishwasher", "Hot w...   54.0
# 14365  ["Free parking on premises", "Heating", "Bed l...  145.0
# 14366  ["Free parking on premises", "Heating", "Bed l...  144.0
# 14367  ["Free parking on premises", "Heating", "Backy...   80.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                    630                 4.79                              2
# 1                    275                 4.92                              1
# 2                    122                 4.93                              1
# 3                    295                 4.90                              1
# 4                     48                 4.57                              1
# ...                  ...                  ...                            ...
# 14363                  0                  NaN                             41
# 14364                  0                  NaN                             41
# 14365                  0                  NaN                             41
# 14366                  0                  NaN                              1
# 14367                  0                  NaN                             62
#
#        num_bath
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ...         ...
# 14363       2.0
# 14364       1.0
# 14365       1.0
# 14366       2.0
# 14367       1.0
#
# [14366 rows x 29 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1., nan,  2.,  3.,  5.,  4.,  8.,  6.,  7., 13., 15., 23., 14.,
#         9., 10., 12.])

# %%
updated_df['beds'].unique()
# Out:
# array([  2.,   1.,   4.,   3.,  14.,   5.,  13.,  nan,   9.,   6.,   7.,
#         10.,   8.,  16.,  12.,  15.,  22.,  11.,  36.,  18.,  39.,  61.,
#        132.,  17.,  26.,  24.,  21.,  20.,  23.,  25.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                        id    host_id         host_name  host_since  \
# 2                    6413      13879              Todd  2009-04-17
# 33                  78884    2157243              Sean  2012-04-17
# 63                 219168    1134580              Kalu  2011-09-09
# 65                 224603    1169129  David And Kristy  2011-09-16
# 113                343889    1744639             Darcy  2012-02-13
# ...                   ...        ...               ...         ...
# 14319  844959293264278924  482174715        Suite Life  2022-10-04
# 14320  844959370029376106  482174715        Suite Life  2022-10-04
# 14321  844959440493704150  482174715        Suite Life  2022-10-04
# 14322  844959652169052749  482174715        Suite Life  2022-10-04
# 14364  847171709264672413  276920863            Susana  2019-07-17
#
#       host_location  host_response_time host_response_rate  \
# 2        Austin, TX                 NaN                NaN
# 33       Austin, TX      within an hour               100%
# 63       Austin, TX                 NaN                NaN
# 65       Austin, TX        within a day               100%
# 113      Austin, TX  within a few hours               100%
# ...             ...                 ...                ...
# 14319           NaN      within an hour                99%
# 14320           NaN      within an hour                99%
# 14321           NaN      within an hour                99%
# 14322           NaN      within an hour                99%
# 14364    Austin, TX      within an hour                95%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 2                     100%                 t                  1.0  ...
# 33                    100%                 t                  8.0  ...
# 63                     NaN                 f                  1.0  ...
# 65                     70%                 t                  2.0  ...
# 113                   100%                 f                  1.0  ...
# ...                    ...               ...                  ...  ...
# 14319                  76%                 t                620.0  ...
# 14320                  76%                 t                620.0  ...
# 14321                  76%                 t                620.0  ...
# 14322                  76%                 t                620.0  ...
# 14364                 100%                 f                 43.0  ...
#
#        accommodates bathrooms_text bedrooms beds  \
# 2                 2         1 bath      NaN  1.0
# 33                2         1 bath      NaN  2.0
# 63                2         1 bath      NaN  1.0
# 65                2         1 bath      NaN  1.0
# 113               2         1 bath      NaN  1.0
# ...             ...            ...      ...  ...
# 14319             4         1 bath      NaN  2.0
# 14320             4         1 bath      NaN  2.0
# 14321             4         1 bath      NaN  2.0
# 14322             4         1 bath      NaN  2.0
# 14364             2         1 bath      NaN  1.0
#
#                                                amenities  price  \
# 2      ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 33     ["Paid dryer \u2013 In building", "Free parkin...  148.0
# 63     ["Essentials", "Free parking on premises", "He...  250.0
# 65     ["Free parking on premises", "Bed linens", "Ho...  112.0
# 113    ["Clothing storage: wardrobe", "Free parking o...   47.0
# ...                                                  ...    ...
# 14319  ["Heating", "Bed linens", "Dishwasher", "Hot w...  460.0
# 14320  ["Heating", "Bed linens", "Dishwasher", "Hot w...  460.0
# 14321  ["Heating", "Bed linens", "Dishwasher", "Hot w...  479.0
# 14322  ["Heating", "Bed linens", "Dishwasher", "Hot w...  460.0
# 14364  ["Heating", "Bed linens", "Dishwasher", "Hot w...   54.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 2                    122                 4.93                              1
# 33                   190                 4.75                              8
# 63                     8                 4.88                              1
# 65                   114                 4.87                              2
# 113                   35                 4.69                              1
# ...                  ...                  ...                            ...
# 14319                  0                  NaN                             30
# 14320                  0                  NaN                             30
# 14321                  0                  NaN                             30
# 14322                  0                  NaN                             30
# 14364                  0                  NaN                             41
#
#        num_bath
# 2           1.0
# 33          1.0
# 63          1.0
# 65          1.0
# 113         1.0
# ...         ...
# 14319       1.0
# 14320       1.0
# 14321       1.0
# 14322       1.0
# 14364       1.0
#
# [759 rows x 29 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                        id    host_id        host_name  host_since  \
# 84                 314152    1614097           Denise  2012-01-16
# 290                929579    5004628           Lauren  2013-02-07
# 326                978089    5352009           Daniel  2013-03-06
# 474               2045501   10487205  Kirk And Linley  2013-12-07
# 516               2299148    3951061         Benjamin  2012-10-23
# ...                   ...        ...              ...         ...
# 13488  811145863352252309  497674468          Sih-Chi  2023-01-23
# 13489  811148816301434481  477499127             Drew  2022-08-31
# 13491  811154636754995673  477499127             Drew  2022-08-31
# 13944  834072988781055677  416217784             Anna  2021-07-31
# 14163  841380979307790669  202724860             Anna  2018-07-16
#
#         host_location host_response_time host_response_rate  \
# 84         Austin, TX                NaN                NaN
# 290        Austin, TX                NaN                NaN
# 326        Austin, TX                NaN                NaN
# 474        Austin, TX                NaN                NaN
# 516        Austin, TX       within a day                60%
# ...               ...                ...                ...
# 13488             NaN     within an hour               100%
# 13489  Louisville, KY     within an hour               100%
# 13491  Louisville, KY     within an hour               100%
# 13944             NaN                NaN                NaN
# 14163      Austin, TX     within an hour                80%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 84                     NaN                 f                  1.0  ...
# 290                    NaN                 f                  1.0  ...
# 326                    NaN                 f                  1.0  ...
# 474                     0%                 f                  1.0  ...
# 516                    52%                 f                  3.0  ...
# ...                    ...               ...                  ...  ...
# 13488                 100%                 f                  1.0  ...
# 13489                  99%                 t                  6.0  ...
# 13491                  99%                 t                  6.0  ...
# 13944                  NaN                 f                  1.0  ...
# 14163                 100%                 f                  1.0  ...
#
#        accommodates  bathrooms_text bedrooms beds  \
# 84                4        2.0 bath      2.0  NaN
# 290               2        2.0 bath      2.0  NaN
# 326               2        1.0 bath      1.0  NaN
# 474               8         3 baths      3.0  NaN
# 516               2  1 private bath      1.0  NaN
# ...             ...             ...      ...  ...
# 13488             6         2 baths      2.0  NaN
# 13489            11         4 baths      NaN  NaN
# 13491            11         4 baths      NaN  NaN
# 13944            12         5 baths      NaN  NaN
# 14163             2          1 bath      1.0  NaN
#
#                                                amenities  price  \
# 84                                                    []  350.0
# 290                                                   []  800.0
# 326                                                   []  200.0
# 474    ["Washer", "Free parking on premises", "Heatin...  975.0
# 516    ["Free parking on premises", "Heating", "Backy...   55.0
# ...                                                  ...    ...
# 13488  ["Carbon monoxide alarm", "Washer", "Fire exti...  204.0
# 13489  ["Free parking on premises", "Heating", "Backy...  168.0
# 13491  ["Free parking on premises", "Heating", "Backy...  135.0
# 13944  ["Outdoor kitchen", "Free parking on premises"...  899.0
# 14163  ["Free parking on premises", "Indoor fireplace...  100.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 84                     0                  NaN                              1
# 290                    0                  NaN                              1
# 326                    1                 5.00                              1
# 474                    5                 5.00                              1
# 516                    6                 4.33                              3
# ...                  ...                  ...                            ...
# 13488                  0                  NaN                              1
# 13489                  2                 4.50                              6
# 13491                  3                 5.00                              6
# 13944                  0                  NaN                              1
# 14163                  1                 5.00                              1
#
#        num_bath
# 84          2.0
# 290         2.0
# 326         1.0
# 474         3.0
# 516         1.0
# ...         ...
# 13488       2.0
# 13489       4.0
# 13491       4.0
# 13944       5.0
# 14163       1.0
#
# [136 rows x 29 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[
    (updated_df['id'] == 6413) | 
    (updated_df['id'] == 78884) | 
    (updated_df['id'] == 219168) | 
    (updated_df['id'] == 224603) |
    (updated_df['id'] == 343889) | 
    (updated_df['id'] == 844959293264278924) | 
    (updated_df['id'] == 834072988781055677) 
]
# Out:
#                        id    host_id         host_name  host_since  \
# 2                    6413      13879              Todd  2009-04-17
# 33                  78884    2157243              Sean  2012-04-17
# 63                 219168    1134580              Kalu  2011-09-09
# 65                 224603    1169129  David And Kristy  2011-09-16
# 113                343889    1744639             Darcy  2012-02-13
# 13944  834072988781055677  416217784              Anna  2021-07-31
# 14319  844959293264278924  482174715        Suite Life  2022-10-04
#
#       host_location  host_response_time host_response_rate  \
# 2        Austin, TX                 NaN                NaN
# 33       Austin, TX      within an hour               100%
# 63       Austin, TX                 NaN                NaN
# 65       Austin, TX        within a day               100%
# 113      Austin, TX  within a few hours               100%
# 13944           NaN                 NaN                NaN
# 14319           NaN      within an hour                99%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 2                     100%                 t                  1.0  ...
# 33                    100%                 t                  8.0  ...
# 63                     NaN                 f                  1.0  ...
# 65                     70%                 t                  2.0  ...
# 113                   100%                 f                  1.0  ...
# 13944                  NaN                 f                  1.0  ...
# 14319                  76%                 t                620.0  ...
#
#        accommodates bathrooms_text bedrooms beds  \
# 2                 2         1 bath      1.0  1.0
# 33                2         1 bath      1.0  2.0
# 63                2         1 bath      1.0  1.0
# 65                2         1 bath      1.0  1.0
# 113               2         1 bath      1.0  1.0
# 13944            12        5 baths      5.0  5.0
# 14319             4         1 bath      1.0  2.0
#
#                                                amenities  price  \
# 2      ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 33     ["Paid dryer \u2013 In building", "Free parkin...  148.0
# 63     ["Essentials", "Free parking on premises", "He...  250.0
# 65     ["Free parking on premises", "Bed linens", "Ho...  112.0
# 113    ["Clothing storage: wardrobe", "Free parking o...   47.0
# 13944  ["Outdoor kitchen", "Free parking on premises"...  899.0
# 14319  ["Heating", "Bed linens", "Dishwasher", "Hot w...  460.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 2                    122                 4.93                              1
# 33                   190                 4.75                              8
# 63                     8                 4.88                              1
# 65                   114                 4.87                              2
# 113                   35                 4.69                              1
# 13944                  0                  NaN                              1
# 14319                  0                  NaN                             30
#
#        num_bath
# 2           1.0
# 33          1.0
# 63          1.0
# 65          1.0
# 113         1.0
# 13944       5.0
# 14319       1.0
#
# [7 rows x 29 columns]

# %%
# check for the previous NA rows in beds
updated_df[
    (updated_df['id'] == 929579) | 
    (updated_df['id'] == 978089) | 
    (updated_df['id'] == 2045501) | 
    (updated_df['id'] == 811145863352252309) |
    (updated_df['id'] == 841380979307790669) | 
    (updated_df['id'] == 834072988781055677) | 
    (updated_df['id'] == 811154636754995673) 
]
# Out:
#                        id    host_id        host_name  host_since  \
# 290                929579    5004628           Lauren  2013-02-07
# 326                978089    5352009           Daniel  2013-03-06
# 474               2045501   10487205  Kirk And Linley  2013-12-07
# 13488  811145863352252309  497674468          Sih-Chi  2023-01-23
# 13491  811154636754995673  477499127             Drew  2022-08-31
# 13944  834072988781055677  416217784             Anna  2021-07-31
# 14163  841380979307790669  202724860             Anna  2018-07-16
#
#         host_location host_response_time host_response_rate  \
# 290        Austin, TX                NaN                NaN
# 326        Austin, TX                NaN                NaN
# 474        Austin, TX                NaN                NaN
# 13488             NaN     within an hour               100%
# 13491  Louisville, KY     within an hour               100%
# 13944             NaN                NaN                NaN
# 14163      Austin, TX     within an hour                80%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 290                    NaN                 f                  1.0  ...
# 326                    NaN                 f                  1.0  ...
# 474                     0%                 f                  1.0  ...
# 13488                 100%                 f                  1.0  ...
# 13491                  99%                 t                  6.0  ...
# 13944                  NaN                 f                  1.0  ...
# 14163                 100%                 f                  1.0  ...
#
#        accommodates bathrooms_text bedrooms beds  \
# 290               2       2.0 bath      2.0  2.0
# 326               2       1.0 bath      1.0  1.0
# 474               8        3 baths      3.0  3.0
# 13488             6        2 baths      2.0  2.0
# 13491            11        4 baths      4.0  4.0
# 13944            12        5 baths      5.0  5.0
# 14163             2         1 bath      1.0  1.0
#
#                                                amenities  price  \
# 290                                                   []  800.0
# 326                                                   []  200.0
# 474    ["Washer", "Free parking on premises", "Heatin...  975.0
# 13488  ["Carbon monoxide alarm", "Washer", "Fire exti...  204.0
# 13491  ["Free parking on premises", "Heating", "Backy...  135.0
# 13944  ["Outdoor kitchen", "Free parking on premises"...  899.0
# 14163  ["Free parking on premises", "Indoor fireplace...  100.0
#
#        number_of_reviews  review_scores_value calculated_host_listings_count  \
# 290                    0                  NaN                              1
# 326                    1                  5.0                              1
# 474                    5                  5.0                              1
# 13488                  0                  NaN                              1
# 13491                  3                  5.0                              6
# 13944                  0                  NaN                              1
# 14163                  1                  5.0                              1
#
#        num_bath
# 290         2.0
# 326         1.0
# 474         3.0
# 13488       2.0
# 13491       4.0
# 13944       5.0
# 14163       1.0
#
# [7 rows x 29 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([  2.,   1.,   4.,   3.,  14.,   5.,  13.,   9.,   6.,   7.,  10.,
#          8.,  16.,  12.,  15.,  22.,  11.,  36.,  18.,  39.,  61., 132.,
#         17.,  26.,  24.,  21.,  20.,  23.,  25.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  2.,  3.,  5.,  4.,  8.,  6.,  7., 13.,  0., 15., 23., 14.,
#         9., 10., 12.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 2 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2009-02-16', '2009-02-19', '2009-04-17', ..., '2023-03-12',
#        '2023-03-13', '2014-04-04'], dtype=object)

# %%
updated_df[updated_df['host_since'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 2062 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 2062

# %%
updated_df['host_location'].unique()
# Out:
# array(['Austin, TX', 'unknown', 'New Orleans, LA', 'Dallas, TX',
#        'Houston, TX', 'Fair Oaks Ranch, TX', 'Eugene, OR',
#        'San Francisco, CA', 'New York, United States',
#        'Dripping Springs, TX', 'Honolulu, HI', 'Boston, MA',
#        'Texas, United States', 'Washington, DC', 'Bastrop, TX',
#        'Gonzales, TX', 'Round Rock, TX', 'New York, NY', 'Santa Rosa, CA',
#        'Oakland, CA', 'San Antonio, TX', 'Thun, Switzerland',
#        'Ontario, Canada', 'Denver, CO', 'Minneapolis, MN', 'Edinburg, TX',
#        'Richmond, VA', 'Longview, TX', 'Manchaca, TX',
#        'New Braunfels, TX', 'Pagosa Springs, CO', 'Salado, TX',
#        'Waco, TX', 'Blacklick, OH', 'Lucerne, Switzerland',
#        'Westfield, IN', 'Portland, OR', 'Nashville, TN',
#        'Los Angeles, CA', 'Vigo, Spain', 'Framingham, MA',
#        'Baltimore, MD', 'Blacksburg, VA', 'Santa Clarita, CA',
#        'Omaha, NE', 'Miami, FL', 'Australia', 'Brechin, United Kingdom',
#        'Indianapolis, IN', 'United States', 'Paris, France',
#        'Royse City, TX', 'Cleveland, OH', 'Singapore', 'Alicante, Spain',
#        'Newport News, VA', 'Fayetteville, NC',
#        'California, United States', 'Hamburg, Germany', 'Chicago, IL',
#        'San Diego, CA', 'Laredo, TX', 'Santa Fe, NM', 'Oklahoma City, OK',
#        'Todos Santos, Mexico', 'Cedar Park, TX', 'Flower Mound, TX',
#        'Melbourne, Australia', 'Berkeley, CA', 'Centennial, CO',
#        'Taos, NM', 'Pflugerville, TX', 'Lubbock, TX',
#        'Hawaii, United States', 'Plano, TX', 'San Jose, CA',
#        'Gleason, TN', 'Boulder, CO', 'Cincinnati, OH', 'Bear, DE',
#        'London, United Kingdom', 'Philadelphia, PA', 'Las Vegas, NV',
#        'Northampton, PA', 'Copenhagen, Denmark', 'Lakeway, TX',
#        'Lindale, TX', 'Sunset Valley, TX', 'Little Rock, AR',
#        'Leyden, MA', 'Albuquerque, NM', 'Belton, TX', 'Bedford, TX',
#        'Angers, France', 'Amarillo, TX', 'Edinboro, PA', 'Pearland, TX',
#        'Ojai, CA', 'Columbus, OH', 'Wicklow, Ireland', 'Midland, TX',
#        'Bee Cave, TX', 'Chiang Mai, Thailand', 'Sterling, IL',
#        'Woodland, CA', 'Berlin, Germany', 'Belfast, United Kingdom',
#        'Montreal, Canada', 'Joshua Tree, CA', 'Pittsburgh, PA',
#        'Bath, OH', 'McAllen, TX', 'Concord, MA', 'Leander, TX',
#        'Cairo, Egypt', 'Kemah, TX', 'Sugar Grove, IL',
#        'Buenos Aires, Argentina', 'Athens, GA', 'Detroit, MI',
#        'St. Louis, MO', 'Langley, Canada', 'Kirkland, WA', 'Alpine, WY',
#        'Gainesville, FL', 'San Marcos, TX', 'Nacogdoches, TX',
#        'Ithaca, NY', 'Sydney, Australia', 'Odessa, TX', 'Aurora, NY',
#        'Taiwan', 'Kyle, TX', 'Columbia, MO', 'Spring Branch, TX',
#        'Sugar Land, TX', 'New Hampshire, United States', 'Winhall, VT',
#        'Orinda, CA', 'Reading, United Kingdom', 'Wildomar, CA',
#        'Sandy, UT', 'Erie, PA', 'Woodland Park, CO', 'Stuttgart, Germany',
#        'Temple, TX', 'Saint Louis, MO', 'Lahaina, HI',
#        'Hasbrouck Heights, NJ', 'Santa Monica, CA', 'Weston, FL',
#        'Seattle, WA', 'Lower Saxony, Germany', 'Fort Smith, AR',
#        'College Station, TX', 'Lincolnwood, IL', 'Antonito, CO',
#        'Sunnyvale, CA', 'Montrose, CO', 'West Palm Beach, FL',
#        'Orange, TX', 'State of Rio Grande do Sul, Brazil', 'Marfa, TX',
#        'Lewisburg, PA', 'Marble Falls, TX', 'San Juan Capistrano, CA',
#        'Mexico City, Mexico', 'Calgary, Canada', 'Fort Worth, TX',
#        'Arlington, TX', 'Decatur, GA', 'Petaluma, CA', 'Dublin, Ireland',
#        'Woodway, TX', 'Absecon, NJ', 'Savannah, GA', 'Barrie, Canada',
#        'Turin, Italy', 'Queensland, Australia', 'Katy, TX',
#        'North Tustin, CA', 'Shreveport, LA', 'Madison, WI', 'Allen, TX',
#        'Lake Jackson, TX', 'Brussels, Belgium', 'Georgetown, TX',
#        'Cypress, TX', 'Burlingame, CA', 'Scottsdale, AZ', 'El Paso, TX',
#        'Clearwater, FL', 'Santa Cruz, CA', 'Spicewood, TX',
#        'Pennsylvania, United States', 'Ashburn, VA',
#        'Palos Verdes Estates, CA', 'La Grange Park, IL', 'North Pole, AK',
#        'Maine, United States', 'Toronto, Canada', 'Fredericksburg, TX',
#        'North Carolina, United States', 'Raleigh, NC', 'Bellville, TX',
#        'Arlington, VA', 'New York, IA', 'Santiago, Chile', 'Lincoln, NE',
#        'Littleton, CO', 'Maryland, United States', 'Frisco, TX',
#        'Hyattsville, MD', 'Baytown, TX', 'Wimberley, TX',
#        'Springdale, AR', 'Kihei, HI', 'Denton, TX', 'Spring, TX',
#        'Dale, TX', 'Atxondo, Spain', 'Orlando, FL', 'Daly City, CA',
#        'Pare, Indonesia', 'Dana Point, CA', 'West Sacramento, CA',
#        'Harrisburg, PA', 'West Lake Hills, TX', 'Encinitas, CA',
#        'Newport Beach, CA', 'Westwood, NJ', 'Atlanta, GA',
#        'Jacksonville, FL', 'Algonquin, IL', 'Ledbetter, TX', 'Manor, TX',
#        'San Ramon, CA', 'Kilauea, HI', 'Cambridge, MA', 'Costa Mesa, CA',
#        'Montgomery, TX', 'Saint Paul, TX', 'Newington, NH', 'Proctor, MT',
#        'Webberville, TX', 'Winter Park, CO', 'Madrid, Spain',
#        'Barcelona, Spain', 'Del Valle, TX', 'Bend, OR',
#        'St Petersburg, FL', 'Seguin, TX', 'Garland, TX',
#        'Acapulco, Mexico', 'Palm Springs, CA', 'Bakersfield, CA',
#        'Canyon Lake, TX', 'Knoxville, TN', 'Henderson, NV',
#        'McKinney, TX', 'Karachi, Pakistan', 'Ensenada, Mexico',
#        'Desert Hot Springs, CA', 'Columbus, TX', 'Vermont, United States',
#        'Jersey Village, TX', 'The Hills, TX', 'New Brunswick, NJ',
#        'Missouri City, TX', 'Pittsburg, TX', 'Liberty Hill, TX',
#        'Richardson, TX', 'Issaquah, WA', 'Asheville, NC',
#        'South Padre Island, TX', "Morgan's Point Resort, TX",
#        'Kahului, HI', 'Hilton Head Island, SC', 'Orem, UT',
#        'Rancho Santa Margarita, CA', 'North Myrtle Beach, SC',
#        'South Carolina, United States', 'Vienna, VA', 'Rochester, NY',
#        'Los Gatos, CA', 'El Sobrante, CA', 'San Mateo, CA',
#        'Chapel Hill, NC', 'Olathe, KS', 'Riverwoods, IL',
#        'The Woodlands, TX', 'Dorris, CA', 'Richland, MS', 'Vestal, NY',
#        'Jackson, MS', 'Colorado Springs, CO', 'Westport, CT',
#        'Ladera Ranch, CA', 'Canton, TX', 'Saxman, AK', 'Little Elm, TX',
#        'Chandler, AZ', 'Atlantic Beach, NY', 'Akron, OH',
#        'Santa Barbara, CA', 'Telluride, CO', 'Davis, CA',
#        'Kensington, CA', 'Pfafftown, NC', 'San Rafael, CA',
#        'Alberta, Canada', 'Oak Park, IL', 'Rockledge, FL', 'Durham, NC',
#        'Bulverde, TX', 'Sarasota, FL', 'Eden, UT', 'Aspen, CO',
#        'Kailua-Kona, HI', 'Phoenix, AZ', 'Port Angeles, WA',
#        'Slidell, LA', 'Buda, TX', 'Farmington, NM', 'Mount Pleasant, SC',
#        'Corpus Christi, TX', 'Palmdale, CA', 'Emeryville, CA',
#        'Austin, NY', 'Alpharetta, GA', 'Springfield, MO',
#        'San Clemente, CA', 'Redding, CA', 'Corral de Tierra, CA',
#        'Rotterdam, Netherlands', 'Hickory, NC', 'Kimball, NE',
#        'Laguna Beach, CA', 'Weston, CT', 'Monterey Park, CA',
#        'West Hollywood, CA', 'Benicia, CA', 'Torrance, CA',
#        'Stamford, CT', 'Everett, WA', 'Sebastopol, CA', 'Boise, ID',
#        'Hudson Bend, TX', 'Flemington, NJ', 'Dublin, CA',
#        'Vancouver, Canada', 'Bellaire, TX', 'Killeen, TX',
#        'Levittown, NY', 'Ashland, OR', 'Pensacola, FL', 'Deerfield, IL',
#        'Fairbanks, AK', 'Wichita, KS', 'Indio, CA', 'Bandera, TX',
#        'Anaheim, CA', 'Leesburg, VA', 'Rancho Palos Verdes, CA',
#        'Ventura, CA', 'San Marcos, CA', 'Gaithersburg, MD',
#        'Puerto Vallarta, Mexico', 'Westlake, OH', 'Incline Village, NV',
#        'Wylie, TX', 'Culver City, CA', 'Bryan, TX', 'Tampa, FL',
#        'Whittier, CA', 'Kenmore, WA', 'Grapevine, TX', 'Beaumont, TX',
#        'Twentynine Palms, CA', 'Tulsa, OK', 'Centre, AL', 'Columbia, SC',
#        'Hanover, NH', 'Myrtle Beach, SC', 'Glendora, CA',
#        'Islamorada, FL', 'Virginia Beach, VA', 'Charleston, SC',
#        'Vancouver, WA', 'Aptos, CA', 'Morongo Valley, CA', 'Buffalo, NY',
#        'Rancho Cucamonga, CA', 'Louisville, KY', 'Delray Beach, FL',
#        'Bettendorf, IA', 'Lewisville, TX', 'Mount Vernon, NY',
#        'Jarrell, TX', 'Tulum, Mexico', 'Ohio, United States',
#        'Monterey, CA', 'Kansas City, MO', 'Hutto, TX',
#        'Point Venture, TX', 'Jupiter, FL', 'Grand Prairie, TX',
#        'Medellín, Colombia', 'Miami Beach, FL', 'Brownsville, TX',
#        'West Point, NY', 'Rumson, NJ', 'Providence, RI', 'Upton, MA',
#        'Dover, NJ', 'Inglewood, CA', 'Pittsburg, CA', 'Waterford, ME',
#        'Glendale, AZ', 'Sacramento, CA', 'Powell, OH', 'Mobile, AL',
#        'Adelphi, MD', 'San Luis Obispo, CA', 'Williamsburg, VA',
#        'Cambridge, Canada', 'Des Moines, IA', 'Pasadena, CA',
#        'Little Silver, NJ', 'San Juan, Puerto Rico', 'Rockville, MD',
#        'Syracuse, NY', 'Missouri, United States', 'Wallingford, CT',
#        'New Jersey, United States', 'Bar Harbor, ME', 'North Augusta, SC',
#        'Montclair, NJ', 'Foster City, CA', 'Lumberton, TX', 'Tempe, AZ',
#        'Connecticut, United States', 'Novato, CA', 'Des Moines, WA',
#        'Coleman, TX', 'Falls Church, VA', 'Milan, Italy',
#        'Alexandria, VA', 'Oceanside, CA', 'Charlotte, NC',
#        'Mill Neck, NY', 'Conway, SC', 'Freeport, NY', 'Jersey City, NJ',
#        'Tel Aviv, Israel', 'Fullerton, CA', 'Pembroke Park, FL',
#        'Coventry, CT', 'Utah, United States', 'Kentfield, CA',
#        'Ocala, FL', 'Kingsbury, TX', 'Danville, CA', 'Fort Wayne, IN',
#        'Grafton, OH', 'Wichita Falls, TX', 'Downingtown, PA',
#        'Arcata, CA', 'Reno, NV', 'Silver Spring, PA', 'Lowell, MA',
#        'India', 'Mill Valley, CA'], dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df[updated_df['host_location'] ==' ']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 3 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 9409

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 2 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([2.000e+00, 1.000e+00, 3.000e+00, 8.000e+00, 1.200e+01, 1.000e+01,
#        5.000e+00, 2.500e+01, 4.000e+00, 2.700e+01, 1.700e+01, 7.000e+00,
#        6.000e+00, 9.000e+00, 2.300e+01, 1.100e+01, 6.500e+01, 1.400e+01,
#        3.500e+01, 8.000e+01, 3.900e+01, 2.800e+01, 1.900e+01, 1.300e+01,
#        4.900e+01, 8.700e+01, 3.400e+01, 9.200e+01, 4.400e+01, 2.900e+01,
#        1.160e+02, 7.650e+02, 1.629e+03, 1.500e+01, 3.040e+02, 1.190e+02,
#        2.600e+01, 3.880e+02, 4.000e+01, 3.200e+01, 4.300e+01, 3.800e+01,
#        1.670e+02, 5.900e+01, 8.500e+01, 2.930e+02, 2.400e+01, 7.800e+01,
#        1.910e+02, 4.100e+01, 6.800e+01, 4.290e+02, 3.540e+02, 3.900e+02,
#        4.100e+02, 1.550e+02, 1.600e+01, 3.700e+01, 4.490e+02, 4.200e+01,
#        9.800e+01, 3.710e+02, 5.000e+01, 7.400e+01, 4.800e+01, 2.460e+02,
#        6.840e+02, 2.870e+02, 1.800e+01, 1.700e+02, 1.100e+02, 3.294e+03,
#        1.680e+02, 5.800e+01, 8.040e+02, 5.600e+01, 3.600e+01, 1.200e+02,
#        4.600e+01, 6.630e+02, 3.840e+02, 4.806e+03, 2.200e+01, 2.790e+02,
#        5.200e+01, 4.380e+02, 2.000e+01, 1.510e+02, 4.270e+02, 6.590e+02,
#        5.300e+01, 3.660e+02, 6.200e+01, 6.340e+02, 9.700e+01, 1.040e+02,
#        4.500e+01, 8.400e+01, 6.100e+01, 2.504e+03, 4.860e+02, 5.400e+01,
#        7.500e+01, 6.900e+01, 1.698e+03, 1.480e+02, 1.170e+02, 7.900e+01,
#        2.100e+01, 5.330e+02, 9.900e+01, 3.720e+02, 6.300e+02, 2.980e+02,
#        3.480e+02, 6.000e+01, 2.330e+03, 2.900e+02, 6.200e+02])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 2 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([4.000e+00, 1.000e+00, 2.000e+00, 5.000e+00, 3.000e+00, 3.000e+01,
#        9.000e+00, 1.900e+01, 3.300e+01, 1.800e+01, 1.000e+01, 6.000e+00,
#        3.400e+01, 6.900e+01, 2.800e+01, 1.300e+01, 8.000e+00, 8.500e+01,
#        7.000e+00, 2.100e+01, 4.200e+01, 1.500e+01, 1.200e+01, 1.400e+01,
#        4.700e+01, 2.600e+01, 1.060e+02, 3.500e+01, 2.200e+01, 2.500e+01,
#        1.600e+01, 1.100e+01, 3.900e+01, 1.400e+02, 4.000e+01, 2.900e+01,
#        2.400e+01, 1.700e+01, 5.100e+01, 2.000e+01, 5.400e+01, 3.100e+01,
#        8.800e+01, 2.300e+01, 7.700e+01, 7.900e+01, 2.260e+02, 3.700e+01,
#        9.700e+01, 3.200e+01, 3.920e+02, 1.486e+03, 1.930e+03, 4.210e+02,
#        2.050e+02, 2.700e+01, 5.120e+02, 7.100e+01, 1.770e+02, 2.620e+02,
#        3.600e+01, 4.800e+01, 9.200e+01, 3.870e+02, 2.470e+02, 8.000e+01,
#        4.680e+02, 4.400e+01, 1.280e+02, 8.970e+02, 3.910e+02, 7.700e+02,
#        5.700e+02, 2.670e+02, 4.100e+01, 4.910e+02, 1.340e+02, 1.360e+02,
#        6.400e+02, 1.670e+02, 1.050e+02, 2.940e+02, 2.420e+03, 6.000e+01,
#        3.350e+02, 4.230e+02, 1.610e+02, 4.530e+03, 2.990e+02, 6.400e+01,
#        1.560e+02, 8.490e+02, 8.700e+01, 1.460e+02, 4.600e+01, 4.500e+01,
#        6.720e+02, 4.640e+02, 5.355e+03, 3.210e+02, 9.040e+02, 3.230e+02,
#        7.300e+01, 8.520e+02, 7.160e+02, 5.200e+01, 2.360e+02, 8.380e+02,
#        4.300e+01, 1.302e+03, 1.080e+02, 3.780e+02, 8.200e+01, 1.250e+02,
#        8.100e+01, 9.300e+01, 1.040e+02, 1.000e+02, 6.200e+01, 2.775e+03,
#        7.210e+02, 6.100e+01, 1.120e+02, 1.660e+02, 9.000e+01, 3.035e+03,
#        3.030e+02, 1.970e+02, 2.220e+02, 6.620e+02, 1.260e+02, 1.530e+02,
#        3.720e+02, 7.360e+02, 3.080e+02, 5.000e+01, 3.530e+02, 1.390e+02,
#        7.794e+03, 3.320e+02, 7.890e+02])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 2 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']",
#        "['email', 'work_email']", '[]', 'None',
#        "['email', 'phone', 'photographer', 'work_email']"], dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
#                       id    host_id        host_name  host_since  \
# 739              3979017   20622469            Katie  2014-08-27
# 5762            41692584  323798409  Edwin & Rebecca  2020-01-02
# 7891            51805850  323798409  Edwin & Rebecca  2020-01-02
# 9883  613816981640175932  456682563            April  2022-04-29
#
#      host_location host_response_time host_response_rate host_acceptance_rate  \
# 739     Austin, TX                NaN                NaN                  NaN
# 5762    Austin, TX     within an hour               100%                  71%
# 7891    Austin, TX     within an hour               100%                  71%
# 9883    Austin, TX                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 739                  f                  1.0  ...             2         1 bath
# 5762                 f                  2.0  ...             4         1 bath
# 7891                 f                  2.0  ...             4        2 baths
# 9883                 f                  1.0  ...             7        3 baths
#
#      bedrooms beds                                          amenities   price  \
# 739       1.0  1.0  ["Carbon monoxide alarm", "Washer", "Essential...    72.0
# 5762      3.0  2.0  ["Free parking on premises", "Heating", "Bed l...   115.0
# 7891      3.0  2.0  ["Outdoor dining area", "Bed linens", "Dishwas...   121.0
# 9883      3.0  3.0  ["Free parking on premises", "Outdoor dining a...  1315.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 739                 128                 4.78                              1
# 5762                 20                 4.45                              2
# 7891                  4                 3.25                              2
# 9883                 23                 4.91                              1
#
#       num_bath
# 739        1.0
# 5762       1.0
# 7891       2.0
# 9883       3.0
#
# [4 rows x 29 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']",
#        "['email', 'work_email']", 'None',
#        "['email', 'phone', 'photographer', 'work_email']"], dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 2 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  2,   1,   3,   8,   4,  12,  10,   5,  11,  22,  17,  16,   6,
#         27,  13,   9,  25,  48,   7,  80,  20,  19,  24,  14,  86,  77,
#         28,  34,  64,  54,  23,  32,  51,  37,  62,  26,  29,  74, 162,
#         21,  41, 103,  46,  30, 134,  52,  15,  35,  56,  57,  18, 102])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
#            id   host_id host_name  host_since host_location  \
# 834   4356661  21791967       NaN  March 2023       unknown
# 1422  8214182  21556779       NaN  March 2023       unknown
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 834                 NaN                NaN                  NaN
# 1422                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 834                  f                  1.0  ...             2         1 bath
# 1422                 f                  1.0  ...             1         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 834       1.0  1.0  ["Carbon monoxide alarm", "Washer", "Fire exti...   75.0
# 1422      1.0  1.0  ["Washer", "Essentials", "Fire extinguisher", ...   27.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 834                   1                  NaN                              1
# 1422                  4                  5.0                              1
#
#       num_bath
# 834        1.0
# 1422       1.0
#
# [2 rows x 29 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
#            id   host_id host_name  host_since host_location  \
# 834   4356661  21791967       NaN  March 2023       unknown
# 1422  8214182  21556779       NaN  March 2023       unknown
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 834                 NaN                NaN                  NaN
# 1422                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 834                  f                  1.0  ...             2         1 bath
# 1422                 f                  1.0  ...             1         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 834       1.0  1.0  ["Carbon monoxide alarm", "Washer", "Fire exti...   75.0
# 1422      1.0  1.0  ["Washer", "Essentials", "Fire extinguisher", ...   27.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 834                   1                  NaN                              1
# 1422                  4                  5.0                              1
#
#       num_bath
# 834        1.0
# 1422       1.0
#
# [2 rows x 29 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
na = updated_df['host_has_profile_pic'].isnull().sum()
print(f'There are {na} missing values in the "host_has_profile_pic" column.')

updated_df['host_has_profile_pic'].fillna('f', inplace=True)
# Out:
# There are 2 missing values in the "host_has_profile_pic" column.

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['Austin, Texas, United States', nan, 'Austin Texas, United States',
#        'West Lake Hills, Texas, United States',
#        'Lakeway, Texas, United States',
#        'Sunset Valley, Texas, United States',
#        'Dripping Springs, Texas, United States',
#        'Bouldin, Austin, Texas, United States',
#        'Rollingwood, Texas, United States',
#        'Westlake Hills, Austin, Texas, United States',
#        'Austin , Texas, United States', 'Del Valle, Texas, United States',
#        'The Hills, Texas, United States', 'Austin, United States',
#        'Clarksville, Texas, United States', 'Austin, Tx, United States',
#        'Lake Travis, Texas, United States',
#        'Round Rock, Texas, United States',
#        'Travis County, Texas, United States',
#        'Bee Cave, Texas, United States', 'Manchaca, Texas, United States',
#        'Leander, Texas, United States',
#        'Cedar Park, Texas, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 5598

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array([78702, 78729, 78704, 78741, 78745, 78703, 78757, 78731, 78758,
#        78705, 78727, 78722, 78733, 78701, 78723, 78752, 78751, 78736,
#        78732, 78746, 78754, 78730, 78724, 78756, 78725, 78749, 78759,
#        78721, 78737, 78748, 78734, 78744, 78738, 78726, 78753, 78735,
#        78728, 78739, 78750, 78742, 78747, 78717, 78712, 78719])

# %% [markdown]
# ### We are going to drop neighbourhood column for Austin Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# #

# %% [markdown]
# # host_response_time

# %%
updated_df['host_response_time'].unique()
# Out:
# array(['within an hour', 'within a few hours', nan, 'within a day',
#        'a few days or more'], dtype=object)

# %% [markdown]
# # host_response_rate

# %%
updated_df['host_response_rate'].unique()
# Out:
# array(['100%', nan, '60%', '83%', '80%', '86%', '70%', '98%', '90%',
#        '91%', '99%', '92%', '0%', '89%', '97%', '50%', '88%', '67%',
#        '93%', '75%', '40%', '82%', '96%', '33%', '95%', '85%', '71%',
#        '20%', '94%', '22%', '30%', '84%', '57%', '25%', '47%', '87%',
#        '43%', '72%', '17%', '29%', '18%', '68%', '56%', '63%', '62%',
#        '76%', '64%', '74%', '11%', '39%'], dtype=object)

# %% [markdown]
# # host_acceptance_rate

# %%
updated_df['host_acceptance_rate'].unique()
# Out:
# array(['95%', '100%', '70%', '94%', '98%', '91%', '86%', nan, '25%',
#        '71%', '80%', '82%', '83%', '87%', '97%', '50%', '92%', '62%',
#        '67%', '0%', '58%', '60%', '81%', '99%', '84%', '96%', '43%',
#        '15%', '89%', '69%', '73%', '88%', '93%', '21%', '75%', '78%',
#        '17%', '90%', '77%', '85%', '29%', '33%', '20%', '56%', '39%',
#        '66%', '65%', '52%', '72%', '46%', '68%', '54%', '61%', '63%',
#        '40%', '23%', '57%', '53%', '45%', '74%', '76%', '59%', '36%',
#        '47%', '64%', '79%', '55%', '38%', '44%', '22%', '24%', '30%',
#        '11%', '27%', '12%', '41%', '16%', '13%', '31%', '48%', '14%',
#        '49%', '32%', '18%', '37%'], dtype=object)

# %% [markdown]
# # Adding new columns for city
#
# Add new column and put 'Austin' for all rows for later joining purpose

# %%
updated_df['city'] = 'Austin'

# %%
updated_df.head()
# Out:
#      id  host_id  host_name  host_since host_location  host_response_time  \
# 0  5456     8028     Sylvia  2009-02-16    Austin, TX      within an hour
# 1  5769     8186  Elizabeth  2009-02-19    Austin, TX  within a few hours
# 2  6413    13879       Todd  2009-04-17    Austin, TX                 NaN
# 3  6448    14156        Amy  2009-04-20    Austin, TX      within an hour
# 4  8502    25298      Karen  2009-07-11    Austin, TX        within a day
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  95%                 t
# 1               100%                  95%                 t
# 2                NaN                 100%                 t
# 3               100%                 100%                 t
# 4                60%                  70%                 f
#
#    host_listings_count  ...  bathrooms_text bedrooms beds  \
# 0                  2.0  ...          1 bath      1.0  2.0
# 1                  1.0  ...   1 shared bath      1.0  1.0
# 2                  1.0  ...          1 bath      1.0  1.0
# 3                  1.0  ...          1 bath      1.0  2.0
# 4                  1.0  ...          1 bath      1.0  1.0
#
#                                            amenities  price  \
# 0  ["Heating", "Backyard", "Bed linens", "Hot wat...  176.0
# 1  ["Private backyard", "Free parking on premises...   42.0
# 2  ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 3  ["Pack \u2019n play/Travel crib", "Free parkin...  240.0
# 4  ["Essentials", "Heating", "Central air conditi...   85.0
#
#    number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                630                 4.79                              2
# 1                275                 4.92                              1
# 2                122                 4.93                              1
# 3                295                 4.90                              1
# 4                 48                 4.57                              1
#
#    num_bath    city
# 0       1.0  Austin
# 1       1.0  Austin
# 2       1.0  Austin
# 3       1.0  Austin
# 4       1.0  Austin
#
# [5 rows x 29 columns]

# %% [markdown]
# # Count number of amenities

# %%
import ast

# Convert the 'amenities' string to a list using ast.literal_eval
updated_df['amenities_list'] = updated_df['amenities'].apply(lambda x: ast.literal_eval(x))

# Count the number of amenities in each list and create a new column with these counts
updated_df['amenities_count'] = updated_df['amenities_list'].apply(lambda x: len(x))

updated_df.drop('amenities_list', axis=1, inplace=True)

# %%
updated_df
# Out:
#                        id    host_id  host_name  host_since host_location  \
# 0                    5456       8028     Sylvia  2009-02-16    Austin, TX
# 1                    5769       8186  Elizabeth  2009-02-19    Austin, TX
# 2                    6413      13879       Todd  2009-04-17    Austin, TX
# 3                    6448      14156        Amy  2009-04-20    Austin, TX
# 4                    8502      25298      Karen  2009-07-11    Austin, TX
# ...                   ...        ...        ...         ...           ...
# 14363  847159076072987428  276920863     Susana  2019-07-17    Austin, TX
# 14364  847171709264672413  276920863     Susana  2019-07-17    Austin, TX
# 14365  847178203609366885  276920863     Susana  2019-07-17    Austin, TX
# 14366  847256590826352221  499116561      Edwin  2023-02-01   Phoenix, AZ
# 14367  847304715126157738  243684594    Shirley  2019-02-17    Austin, TX
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 0          within an hour               100%                  95%
# 1      within a few hours               100%                  95%
# 2                     NaN                NaN                 100%
# 3          within an hour               100%                 100%
# 4            within a day                60%                  70%
# ...                   ...                ...                  ...
# 14363      within an hour                95%                 100%
# 14364      within an hour                95%                 100%
# 14365      within an hour                95%                 100%
# 14366      within an hour               100%                 100%
# 14367      within an hour                98%                  96%
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                     t                  2.0  ...       1.0  2.0
# 1                     t                  1.0  ...       1.0  1.0
# 2                     t                  1.0  ...       1.0  1.0
# 3                     t                  1.0  ...       1.0  2.0
# 4                     f                  1.0  ...       1.0  1.0
# ...                 ...                  ...  ...       ...  ...
# 14363                 f                 43.0  ...       4.0  5.0
# 14364                 f                 43.0  ...       1.0  1.0
# 14365                 f                 43.0  ...       2.0  3.0
# 14366                 f                  2.0  ...       2.0  4.0
# 14367                 f                 68.0  ...       1.0  2.0
#
#                                                amenities  price  \
# 0      ["Heating", "Backyard", "Bed linens", "Hot wat...  176.0
# 1      ["Private backyard", "Free parking on premises...   42.0
# 2      ["Heating", "Outdoor dining area", "Dove body ...  109.0
# 3      ["Pack \u2019n play/Travel crib", "Free parkin...  240.0
# 4      ["Essentials", "Heating", "Central air conditi...   85.0
# ...                                                  ...    ...
# 14363  ["Washer", "Fire extinguisher", "Free parking ...  129.0
# 14364  ["Heating", "Bed linens", "Dishwasher", "Hot w...   54.0
# 14365  ["Free parking on premises", "Heating", "Bed l...  145.0
# 14366  ["Free parking on premises", "Heating", "Bed l...  144.0
# 14367  ["Free parking on premises", "Heating", "Backy...   80.0
#
#        number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 0                    630                 4.79                               2
# 1                    275                 4.92                               1
# 2                    122                 4.93                               1
# 3                    295                 4.90                               1
# 4                     48                 4.57                               1
# ...                  ...                  ...                             ...
# 14363                  0                  NaN                              41
# 14364                  0                  NaN                              41
# 14365                  0                  NaN                              41
# 14366                  0                  NaN                               1
# 14367                  0                  NaN                              62
#
#       num_bath    city amenities_count
# 0          1.0  Austin              27
# 1          1.0  Austin              36
# 2          1.0  Austin              48
# 3          1.0  Austin              61
# 4          1.0  Austin              12
# ...        ...     ...             ...
# 14363      2.0  Austin               8
# 14364      1.0  Austin              38
# 14365      1.0  Austin              43
# 14366      2.0  Austin              39
# 14367      1.0  Austin              58
#
# [14366 rows x 30 columns]

# %%
# sanity check

updated_df[updated_df['id'] == 847159076072987428]
# Out:
#                        id    host_id host_name  host_since host_location  \
# 14363  847159076072987428  276920863    Susana  2019-07-17    Austin, TX
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 14363     within an hour                95%                 100%
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 14363                 f                 43.0  ...       4.0  5.0
#
#                                                amenities  price  \
# 14363  ["Washer", "Fire extinguisher", "Free parking ...  129.0
#
#        number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 14363                  0                  NaN                              41
#
#       num_bath    city amenities_count
# 14363      2.0  Austin               8
#
# [1 rows x 30 columns]

# %%
# sanity check
updated_df.loc[updated_df['id'] == 847159076072987428, ['amenities', 'amenities_count']]
# Out:
#                                                amenities  amenities_count
# 14363  ["Washer", "Fire extinguisher", "Free parking ...                8

# %%
see = updated_df.loc[updated_df['id'] == 847159076072987428]


amenities_text = see['amenities'].iloc[0]

# Print the extracted 'amenities' list
print(amenities_text)
# Out:
# ["Washer", "Fire extinguisher", "Free parking on premises", "TV", "Smoke alarm", "Wifi", "Kitchen", "Air conditioning"]

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                   0
# host_id                              0
# host_name                            2
# host_since                           0
# host_location                        0
# host_response_time                3791
# host_response_rate                3791
# host_acceptance_rate              3188
# host_is_superhost                    0
# host_listings_count                  0
# host_total_listings_count            0
# host_verifications                   0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# number_of_reviews                    0
# review_scores_value               3099
# calculated_host_listings_count       0
# num_bath                             0
# city                                 0
# amenities_count                      0
# dtype: int64

# %%
# Save as a new csv file
updated_df.to_csv('clean-data/listings_detailed_clean_austin.csv', index=False)
