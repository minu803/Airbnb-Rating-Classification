# %% [markdown]
# # Portland

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/Portland/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (4587, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (4587, 29)

# %%
# Save as a new csv file
listings_detailed.to_csv('listings_detailed_clean_portland.csv', index=False)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 0]
filtered_df
# Out:
#             id    host_id           host_name  host_since host_location  \
# 2202  42384560  267899000         Hotel Lucia  2019-06-11           NaN
# 2589  49089774  267675881  The Heathman Hotel  2019-06-10           NaN
# 2668  49725603  290375303            Woodlark  2019-08-30           NaN
# 2732  50342231  268592756        Hotel DeLuxe  2019-06-14           NaN
# 2746  50481448  268188940      Sentinel Hotel  2019-06-12           NaN
# 2957  52566619  290348655             Dossier  2019-08-30           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2202     within an hour               100%                  66%
# 2589     within an hour               100%                 100%
# 2668     within an hour               100%                  84%
# 2732                NaN                NaN                  89%
# 2746                NaN                NaN                  80%
# 2957                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 2202               NaN                   10  ...             4       NaN
# 2589               NaN                   12  ...             0       NaN
# 2668               NaN                   15  ...             0       NaN
# 2732               NaN                   12  ...             0       NaN
# 2746               NaN                   12  ...             0       NaN
# 2957               NaN                    2  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 2202            NaN      NaN  NaN
# 2589            NaN      NaN  NaN
# 2668            NaN      NaN  NaN
# 2732            NaN      NaN  NaN
# 2746            NaN      NaN  NaN
# 2957            NaN      NaN  NaN
#
#                                               amenities  price  \
# 2202  ["Carbon monoxide alarm", "Pack \u2019n play/T...    0.0
# 2589  ["Carbon monoxide alarm", "First aid kit", "TV...    0.0
# 2668  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2732  ["Carbon monoxide alarm", "Pack \u2019n play/T...    0.0
# 2746  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2957  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 2202                292                4.72                               1
# 2589                 62                4.55                               1
# 2668                 62                4.52                               1
# 2732                 18                3.94                               1
# 2746                  6                4.33                               1
# 2957                 16                4.81                               1
#
# [6 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 6

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id           host_name  host_since host_location  \
# 2202  42384560  267899000         Hotel Lucia  2019-06-11           NaN
# 2589  49089774  267675881  The Heathman Hotel  2019-06-10           NaN
# 2668  49725603  290375303            Woodlark  2019-08-30           NaN
# 2732  50342231  268592756        Hotel DeLuxe  2019-06-14           NaN
# 2746  50481448  268188940      Sentinel Hotel  2019-06-12           NaN
# 2957  52566619  290348655             Dossier  2019-08-30           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2202     within an hour               100%                  66%
# 2589     within an hour               100%                 100%
# 2668     within an hour               100%                  84%
# 2732                NaN                NaN                  89%
# 2746                NaN                NaN                  80%
# 2957                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 2202               NaN                   10  ...             4       NaN
# 2589               NaN                   12  ...             0       NaN
# 2668               NaN                   15  ...             0       NaN
# 2732               NaN                   12  ...             0       NaN
# 2746               NaN                   12  ...             0       NaN
# 2957               NaN                    2  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 2202            NaN      NaN  NaN
# 2589            NaN      NaN  NaN
# 2668            NaN      NaN  NaN
# 2732            NaN      NaN  NaN
# 2746            NaN      NaN  NaN
# 2957            NaN      NaN  NaN
#
#                                               amenities  price  \
# 2202  ["Carbon monoxide alarm", "Pack \u2019n play/T...    0.0
# 2589  ["Carbon monoxide alarm", "First aid kit", "TV...    0.0
# 2668  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2732  ["Carbon monoxide alarm", "Pack \u2019n play/T...    0.0
# 2746  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2957  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 2202                292                4.72                               1
# 2589                 62                4.55                               1
# 2668                 62                4.52                               1
# 2732                 18                3.94                               1
# 2746                  6                4.33                               1
# 2957                 16                4.81                               1
#
# [6 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id           host_name  host_since host_location  \
# 2589  49089774  267675881  The Heathman Hotel  2019-06-10           NaN
# 2668  49725603  290375303            Woodlark  2019-08-30           NaN
# 2732  50342231  268592756        Hotel DeLuxe  2019-06-14           NaN
# 2746  50481448  268188940      Sentinel Hotel  2019-06-12           NaN
# 2957  52566619  290348655             Dossier  2019-08-30           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2589     within an hour               100%                 100%
# 2668     within an hour               100%                  84%
# 2732                NaN                NaN                  89%
# 2746                NaN                NaN                  80%
# 2957                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 2589               NaN                   12  ...             0       NaN
# 2668               NaN                   15  ...             0       NaN
# 2732               NaN                   12  ...             0       NaN
# 2746               NaN                   12  ...             0       NaN
# 2957               NaN                    2  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 2589            NaN      NaN  NaN
# 2668            NaN      NaN  NaN
# 2732            NaN      NaN  NaN
# 2746            NaN      NaN  NaN
# 2957            NaN      NaN  NaN
#
#                                               amenities  price  \
# 2589  ["Carbon monoxide alarm", "First aid kit", "TV...    0.0
# 2668  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2732  ["Carbon monoxide alarm", "Pack \u2019n play/T...    0.0
# 2746  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
# 2957  ["Carbon monoxide alarm", "Bed sheets and pill...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 2589                 62                4.55                               1
# 2668                 62                4.52                               1
# 2732                 18                3.94                               1
# 2746                  6                4.33                               1
# 2957                 16                4.81                               1
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 6

# %%
cleaned_listings.shape
# Out:
# (4581, 29)

# %% [markdown]
# # Count 'amenities'

# %%
import ast
def count_amenities(amenities_str):
    try:
        # Convert the string representation of the list back into a list
        amenities_list = ast.literal_eval(amenities_str)
        # Return the count of items in the list
        return len(amenities_list)
    except (ValueError, SyntaxError):
        # In case of any error during conversion, return 0 (or you may choose to return NaN)
        return 0

# Apply the function to each row in the 'amenities' column and create a new column 'amenities_count'
cleaned_listings['amenities_count'] = cleaned_listings['amenities'].apply(count_amenities)

# %%
cleaned_listings['amenities_count']
# Out:
# 0       35
# 1       27
# 2       44
# 3       36
# 4       44
#         ..
# 4582    67
# 4583    60
# 4584    28
# 4585    43
# 4586    47
# Name: amenities_count, Length: 4581, dtype: int64

# %% [markdown]
# # Add 'city' column

# %%
# Add in a city column to each dataframe so that we can use this as part of the primary key/use it to conduct groupby for
# future EDA or additional analysis as final table will contain all of our listings data
cleaned_listings['city'] = 'Portland'

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 bath', '1 shared bath', '1 private bath', '2 baths',
#        '1.5 baths', '1.5 shared baths', '3 baths', '2.5 baths',
#        '2 shared baths', '3 shared baths', '3.5 baths', '4 shared baths',
#        '2.5 shared baths', '4 baths', 'Shared half-bath',
#        'Private half-bath', nan, '5 baths', '3.5 shared baths',
#        '11 shared baths', '12 shared baths', '12 baths', '0 shared baths',
#        'Half-bath', '6 baths', '5 shared baths', '5.5 baths', '18 baths'],
#       dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 bath' '1 shared bath' '1 private bath' '2 baths' '1.5 baths'
#  '1.5 shared baths' '3 baths' '2.5 baths' '2 shared baths'
#  '3 shared baths' '3.5 baths' '4 shared baths' '2.5 shared baths'
#  '4 baths' '0.5 baths' '' '5 baths' '3.5 shared baths' '11 shared baths'
#  '12 shared baths' '12 baths' '0 shared baths' '6 baths' '5 shared baths'
#  '5.5 baths' '18 baths']

# %%
count_half_baths = (cleaned_listings['bathrooms_text'] == '0.5 baths').sum()
count_half_baths
# Out:
# 5

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#             id    host_id host_name  host_since host_location  \
# 1131  21422556    2915808   Stephen  2012-07-12  Portland, OR
# 1217  22599038    2915808   Stephen  2012-07-12  Portland, OR
# 1220  22614995    2915808   Stephen  2012-07-12  Portland, OR
# 1603  29996383  224911430     Robin  2018-11-09  Portland, OR
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1131     within an hour               100%                  98%
# 1217     within an hour               100%                  98%
# 1220     within an hour               100%                  98%
# 1603     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms  \
# 1131                 t                    5  ...                      1.0
# 1217                 t                    5  ...                      1.0
# 1220                 t                    5  ...                      1.0
# 1603                 t                    6  ...                      1.0
#
#      beds                                          amenities  price  \
# 1131  2.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...  115.0
# 1217  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...   93.0
# 1220  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...   99.0
# 1603  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...  160.0
#
#      number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 1131                92                 4.88                               5
# 1217               128                 4.86                               5
# 1220               125                 4.88                               5
# 1603                 1                 5.00                               6
#
#      amenities_count      city
# 1131              25  Portland
# 1217              21  Portland
# 1220              24  Portland
# 1603              28  Portland
#
# [4 rows x 31 columns]

# %%
empty_bathrooms_text_ids = cleaned_listings[cleaned_listings['bathrooms_text'] == '']['id']
print(len(empty_bathrooms_text_ids))
# Out:
# 4

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#            id  bedrooms  beds bathrooms_text
# 0       12899       2.0   2.0         1 bath
# 1     1360216       1.0   1.0         1 bath
# 2     1386231       1.0   1.0  1 shared bath
# 3     1386922       1.0   1.0         1 bath
# 4     1408895       1.0   1.0         1 bath
# ...       ...       ...   ...            ...
# 4582   413956       2.0   3.0         1 bath
# 4583   448195       4.0   5.0        2 baths
# 4584   449461       1.0   1.0  1 shared bath
# 4585   450488       1.0   1.0  1 shared bath
# 4586   450660       1.0   1.0  1 shared bath
#
# [4581 rows x 4 columns]

# %%
# # check for the previous NA rows in bathrooms text
filled_cleaned_listings[filled_cleaned_listings['id'].isin(empty_bathrooms_text_ids)]
# Out:
#             id    host_id host_name  host_since host_location  \
# 1131  21422556    2915808   Stephen  2012-07-12  Portland, OR
# 1217  22599038    2915808   Stephen  2012-07-12  Portland, OR
# 1220  22614995    2915808   Stephen  2012-07-12  Portland, OR
# 1603  29996383  224911430     Robin  2018-11-09  Portland, OR
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1131     within an hour               100%                  98%
# 1217     within an hour               100%                  98%
# 1220     within an hour               100%                  98%
# 1603     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms  \
# 1131                 t                    5  ...        1.0 bath      1.0
# 1217                 t                    5  ...        1.0 bath      1.0
# 1220                 t                    5  ...        1.0 bath      1.0
# 1603                 t                    6  ...        1.0 bath      1.0
#
#      beds                                          amenities  price  \
# 1131  2.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...  115.0
# 1217  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...   93.0
# 1220  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...   99.0
# 1603  1.0  ["Carbon monoxide alarm", "Refrigerator", "Smo...  160.0
#
#      number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 1131                92                 4.88                               5
# 1217               128                 4.86                               5
# 1220               125                 4.88                               5
# 1603                 1                 5.00                               6
#
#      amenities_count      city
# 1131              25  Portland
# 1217              21  Portland
# 1220              24  Portland
# 1603              28  Portland
#
# [4 rows x 31 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#      bathrooms_text  num_bath
# 0            1 bath       1.0
# 1            1 bath       1.0
# 2     1 shared bath       1.0
# 3            1 bath       1.0
# 4            1 bath       1.0
# ...             ...       ...
# 4582         1 bath       1.0
# 4583        2 baths       2.0
# 4584  1 shared bath       1.0
# 4585  1 shared bath       1.0
# 4586  1 shared bath       1.0
#
# [4581 rows x 2 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 32 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  2. ,  1.5,  3. ,  2.5,  3.5,  4. ,  0.5,  5. , 11. , 12. ,
#         0. ,  6. ,  5.5, 18. ])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#         id  host_id      host_name  host_since     host_location  \
# 0    12899    49682  Ali And David  2009-10-29      Portland, OR
# 1  1360216  1186353           Fred  2011-09-20  Palm Springs, CA
# 2  1386231  2236909          Shane  2012-04-27      Portland, OR
# 3  1386922  3859198         Justin  2012-10-13      Portland, OR
# 4  1408895   942377          Emily  2011-08-08      Portland, OR
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0                 NaN                NaN                 100%
# 1        within a day               100%                  78%
# 2  within a few hours               100%                  95%
# 3      within an hour               100%                  93%
# 4  within a few hours               100%                  44%
#
#   host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                 t                    1  ...       2.0  2.0
# 1                 t                    6  ...       1.0  1.0
# 2                 f                    6  ...       1.0  1.0
# 3                 f                    2  ...       1.0  1.0
# 4                 t                    1  ...       1.0  1.0
#
#                                            amenities price number_of_reviews  \
# 0  ["Carbon monoxide alarm", "Refrigerator", "Smo...  80.0               617
# 1  ["Carbon monoxide alarm", "Refrigerator", "Smo...  56.0               403
# 2  ["Carbon monoxide alarm", "Refrigerator", "Smo...  45.0                68
# 3  ["Carbon monoxide alarm", "Refrigerator", "Smo...  75.0               190
# 4  ["Carbon monoxide alarm", "Lockbox", "Refriger...  99.0                74
#
#   review_scores_value  calculated_host_listings_count  amenities_count  \
# 0                4.94                               1               35
# 1                4.78                               2               27
# 2                4.76                               6               44
# 3                4.54                               1               36
# 4                4.74                               1               44
#
#        city  num_bath
# 0  Portland       1.0
# 1  Portland       1.0
# 2  Portland       1.0
# 3  Portland       1.0
# 4  Portland       1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 2.,  1., nan,  3.,  5.,  4.,  8.,  7.,  6.,  9., 18.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 2.,  1.,  3.,  5.,  6., 12.,  4.,  7., nan,  9.,  8., 16., 19.,
#        11., 13., 10., 15., 18.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#            id  host_id       host_name  host_since host_location  \
# 8     1525272  8138263       Elizabeth  2013-08-13  Portland, OR
# 18    1646847  8739391           Chris  2013-09-09  Portland, OR
# 19    1650401  1178421       Stephanie  2011-09-19  Portland, OR
# 24    1703888  8036326          Martin  2013-08-08  Portland, OR
# 25    1717606  9055739            Andy  2013-09-25  Portland, OR
# ...       ...      ...             ...         ...           ...
# 4478   637362   869146   Gina And Andy  2011-07-25  Portland, OR
# 4490   760737  2646777            Kyle  2012-06-15  Portland, OR
# 4509   951387  5161731  Debra & Ludger  2013-02-20  Portland, OR
# 4522  1103529  6060622           Norah  2013-04-23  Portland, OR
# 4573   345650    38860          Renata  2009-09-15  Portland, OR
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 8         within an hour               100%                  73%
# 18        within an hour               100%                  50%
# 19          within a day               100%                  95%
# 24        within an hour               100%                  20%
# 25    within a few hours               100%                 100%
# ...                  ...                ...                  ...
# 4478      within an hour               100%                 100%
# 4490      within an hour               100%                  94%
# 4509      within an hour               100%                 100%
# 4522      within an hour               100%                 100%
# 4573                 NaN                NaN                  65%
#
#      host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 8                    t                    1  ...       NaN  1.0
# 18                   f                    2  ...       NaN  1.0
# 19                   t                    1  ...       NaN  3.0
# 24                   t                    1  ...       NaN  2.0
# 25                   t                    1  ...       NaN  2.0
# ...                ...                  ...  ...       ...  ...
# 4478                 t                    2  ...       NaN  1.0
# 4490                 t                    1  ...       NaN  2.0
# 4509                 t                    1  ...       NaN  1.0
# 4522                 t                    3  ...       NaN  2.0
# 4573                 t                    1  ...       NaN  1.0
#
#                                               amenities  price  \
# 8     ["Shampoo", "Essentials", "Carbon monoxide ala...   60.0
# 18    ["Shampoo", "Bed linens", "Essentials", "Carbo...   89.0
# 19    ["Carbon monoxide alarm", "Refrigerator", "Pac...   50.0
# 24    ["Carbon monoxide alarm", "Coffee maker: pour-...  103.0
# 25    ["Carbon monoxide alarm", "Whirlpool refrigera...  110.0
# ...                                                 ...    ...
# 4478  ["Carbon monoxide alarm", "Shared outdoor pool...   98.0
# 4490  ["Carbon monoxide alarm", "Refrigerator", "Smo...   86.0
# 4509  ["Drying rack for clothing", "Carbon monoxide ...   76.0
# 4522  ["Coffee maker: pour-over coffee", "Refrigerat...   69.0
# 4573  ["Carbon monoxide alarm", "Refrigerator", "Smo...  335.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 8                   15                4.67                               1
# 18                 116                4.77                               2
# 19                 460                4.88                               1
# 24                 128                4.90                               1
# 25                  39                4.95                               1
# ...                ...                 ...                             ...
# 4478               305                4.92                               1
# 4490               195                4.93                               1
# 4509               557                4.83                               1
# 4522               732                4.89                               2
# 4573               140                4.89                               1
#
#       amenities_count      city  num_bath
# 8                  12  Portland       1.0
# 18                 19  Portland       1.0
# 19                 28  Portland       1.0
# 24                 38  Portland       1.0
# 25                 66  Portland       1.0
# ...               ...       ...       ...
# 4478               53  Portland       1.0
# 4490               43  Portland       1.0
# 4509               53  Portland       1.0
# 4522               44  Portland       1.0
# 4573               30  Portland       1.0
#
# [531 rows x 31 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                       id    host_id           host_name  host_since  \
# 111              3562307   17615383             Patrick  2014-07-03
# 167              4363516   13243736                 Deb  2014-03-17
# 334              7398659    6465877          Todd & Lea  2013-05-19
# 412              8981600    7644885              Joanna  2013-07-22
# 1065            20458269   48307943       Amy And Derek  2015-11-06
# 1427            26267199    5029238             Jessica  2013-02-09
# 1550            29129259  112893366                 Sam  2017-01-23
# 1649            31284993  123968362              Arvell  2017-04-02
# 1678            31950837   65277088                Reza  2016-03-31
# 1905            36701090  231707604             Charles  2018-12-20
# 1934            37256099  280492756              Conrad  2019-07-29
# 1956            37802604   36909902            Jennifer  2015-06-28
# 1965            37949752  209841180                Anne  2018-08-16
# 2057            39735100     354428               Julie  2011-01-20
# 2115            40775816     714512        Dan & Jackie  2011-06-18
# 2177            41932344  326526800               Villa  2020-01-11
# 2200            42380321  322907763               Villa  2019-12-30
# 2232            42927687  322907763               Villa  2019-12-30
# 2245            43328124  121884165               Villa  2017-03-21
# 2302            44431794   96243932              Hussam  2016-09-22
# 2319            44634964   16545551                Anna  2014-06-08
# 2406            46315610    2820851  NW Portland Hostel  2012-07-03
# 2536            48659466    8336801               James  2013-08-23
# 2623            49367412   36435346               David  2015-06-22
# 2690            49965809   61445011                  Aj  2016-03-03
# 2841            51523122  100544418           Dominique  2016-10-20
# 2846            51552760   48005494                Zeus  2015-11-02
# 2847            51552761   48005494                Zeus  2015-11-02
# 2868            51762640   48005494                Zeus  2015-11-02
# 2881            51828909    3423772              Dustin  2012-08-30
# 2886            51859237   48005494                Zeus  2015-11-02
# 2915            52112336  209841180                Anne  2018-08-16
# 2920            52165460    7182995               David  2013-06-29
# 2996            53106866  273076012             Dalouny  2019-07-02
# 3064            53721503  158074447               Sarah  2017-11-09
# 3066            53759950   50250626    One Fine BNB LLC  2015-12-01
# 3154  544778926258772774   48005494                Zeus  2015-11-02
# 3155  544865941786998856   48005494                Zeus  2015-11-02
# 3296  594940170120232078   43004730  William And Kieren  2015-08-31
# 3540  654491411082606620     650158                 Amy  2011-06-01
# 4243  822723346349351172  501111962             Dynamic  2023-02-14
# 4245  822725151506516398  501111962             Dynamic  2023-02-14
# 4252  824712137951653421  501111962             Dynamic  2023-02-14
# 4294  829790858587040616  501111962             Dynamic  2023-02-14
# 4483              689130    3519465            Carolina  2012-09-09
# 4494              784126    4134978                Huma  2012-11-13
# 4538             1280971    6800964                Isil  2013-06-08
#
#           host_location  host_response_time host_response_rate  \
# 111        Portland, OR        within a day               100%
# 167        Portland, OR  within a few hours               100%
# 334        Portland, OR                 NaN                NaN
# 412        Portland, OR      within an hour               100%
# 1065       Portland, OR                 NaN                NaN
# 1427       Portland, OR      within an hour               100%
# 1550       Portland, OR      within an hour               100%
# 1649       Portland, OR      within an hour               100%
# 1678       Portland, OR      within an hour               100%
# 1905       Portland, OR                 NaN                NaN
# 1934                NaN        within a day               100%
# 1956       Portland, OR      within an hour               100%
# 1965       Portland, OR  within a few hours                90%
# 2057    Los Angeles, CA                 NaN                NaN
# 2115       Portland, OR      within an hour               100%
# 2177                NaN        within a day               100%
# 2200                NaN      within an hour               100%
# 2232                NaN      within an hour               100%
# 2245       Portland, OR      within an hour               100%
# 2302  San Francisco, CA      within an hour               100%
# 2319       New York, NY                 NaN                NaN
# 2406       Portland, OR      within an hour               100%
# 2536       Portland, OR                 NaN                NaN
# 2623       Portland, OR      within an hour               100%
# 2690       Portland, OR      within an hour               100%
# 2841       New York, NY                 NaN                NaN
# 2846  San Francisco, CA      within an hour               100%
# 2847  San Francisco, CA      within an hour               100%
# 2868  San Francisco, CA      within an hour               100%
# 2881       Portland, OR                 NaN                NaN
# 2886  San Francisco, CA      within an hour               100%
# 2915       Portland, OR  within a few hours                90%
# 2920       Portland, OR      within an hour               100%
# 2996       Portland, OR      within an hour               100%
# 3064       Portland, OR      within an hour               100%
# 3066         Austin, TX      within an hour               100%
# 3154  San Francisco, CA      within an hour               100%
# 3155  San Francisco, CA      within an hour               100%
# 3296       Portland, OR                 NaN                NaN
# 3540       Portland, OR  within a few hours               100%
# 4243                NaN                 NaN                NaN
# 4245                NaN                 NaN                NaN
# 4252                NaN                 NaN                NaN
# 4294                NaN                 NaN                NaN
# 4483       Portland, OR      within an hour               100%
# 4494  San Francisco, CA  within a few hours               100%
# 4538       Portland, OR                 NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 111                   50%                 f                    1  ...
# 167                  100%                 f                    1  ...
# 334                  100%                 t                    1  ...
# 412                  100%                 f                    1  ...
# 1065                  67%                 f                    1  ...
# 1427                 100%                 t                    1  ...
# 1550                 100%                 f                    2  ...
# 1649                  83%                 f                    4  ...
# 1678                 100%                 t                    1  ...
# 1905                  NaN                 f                    2  ...
# 1934                  33%                 f                    2  ...
# 1956                 100%                 f                    5  ...
# 1965                 100%                 f                    3  ...
# 2057                  75%                 f                    2  ...
# 2115                 100%                 t                   14  ...
# 2177                  90%                 f                    2  ...
# 2200                 100%                 f                    5  ...
# 2232                 100%                 f                    5  ...
# 2245                 100%                 t                    3  ...
# 2302                  94%                 t                    4  ...
# 2319                  NaN                 f                    1  ...
# 2406                 100%                 t                    8  ...
# 2536                   0%                 f                    1  ...
# 2623                 100%                 f                    8  ...
# 2690                 100%                 f                    4  ...
# 2841                  NaN                 f                    1  ...
# 2846                  97%                 f                 1503  ...
# 2847                  97%                 f                 1503  ...
# 2868                  97%                 f                 1503  ...
# 2881                  NaN                 f                    4  ...
# 2886                  97%                 f                 1503  ...
# 2915                 100%                 f                    3  ...
# 2920                 100%                 t                    1  ...
# 2996                 100%                 t                    5  ...
# 3064                 100%                 t                   11  ...
# 3066                  99%                 f                    8  ...
# 3154                  97%                 f                 1503  ...
# 3155                  97%                 f                 1503  ...
# 3296                  92%                 t                    1  ...
# 3540                  87%                 f                    2  ...
# 4243                  NaN                 f                   42  ...
# 4245                  NaN                 f                   42  ...
# 4252                  NaN                 f                   42  ...
# 4294                  NaN                 f                   42  ...
# 4483                  62%                 f                    1  ...
# 4494                  83%                 f                    2  ...
# 4538                  NaN                 f                    2  ...
#
#       bedrooms beds                                          amenities  price  \
# 111        2.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Bea...   36.0
# 167        NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   80.0
# 334        NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Bar...  100.0
# 412        NaN  NaN  ["Carbon monoxide alarm", "Trader Joes Tea Tre...   65.0
# 1065       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   49.0
# 1427       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   51.0
# 1550       1.0  NaN  ["Drying rack for clothing", "Refrigerator", "...   34.0
# 1649       NaN  NaN  ["Carbon monoxide alarm", "Smoke alarm", "Cook...  250.0
# 1678       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   75.0
# 1905       1.0  NaN  ["Shampoo", "Essentials", "Carbon monoxide ala...   87.0
# 1934       3.0  NaN  ["Essentials", "Kitchen", "Dryer", "TV", "Hot ...  160.0
# 1956       1.0  NaN  ["Essentials", "Carbon monoxide alarm", "Dryer...   90.0
# 1965       1.0  NaN  ["Carbon monoxide alarm", "Smoke alarm", "Cook...   34.0
# 2057       1.0  NaN  ["Shampoo", "Essentials", "Carbon monoxide ala...  356.0
# 2115       NaN  NaN  ["Carbon monoxide alarm", "Clothing storage: w...   74.0
# 2177       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   60.0
# 2200       1.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   54.0
# 2232       1.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   64.0
# 2245       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   58.0
# 2302       1.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   30.0
# 2319       1.0  NaN  ["Carbon monoxide alarm", "Smoke alarm", "Priv...   65.0
# 2406       1.0  NaN  ["Shampoo", "Essentials", "Carbon monoxide ala...   87.0
# 2536       NaN  NaN  ["Shampoo", "Essentials", "Carbon monoxide ala...  120.0
# 2623       1.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   94.0
# 2690       NaN  NaN  ["Carbon monoxide alarm", "Lockbox", "Refriger...   79.0
# 2841       1.0  NaN  ["Dedicated workspace", "Carbon monoxide alarm...  199.0
# 2846       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   83.0
# 2847       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   57.0
# 2868       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   83.0
# 2881       1.0  NaN  ["Dedicated workspace", "Self check-in", "Carb...  115.0
# 2886       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   85.0
# 2915       1.0  NaN  ["Refrigerator", "Baking sheet", "Long term st...   35.0
# 2920       1.0  NaN  ["Carbon monoxide alarm", "Fast wifi \u2013 59...   95.0
# 2996       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   73.0
# 3064       NaN  NaN  ["Dedicated workspace", "Shampoo", "Bed linens...   51.0
# 3066       2.0  NaN  ["Drying rack for clothing", "Carbon monoxide ...   55.0
# 3154       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   93.0
# 3155       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...  127.0
# 3296       1.0  NaN  ["Drying rack for clothing", "Clothing storage...   80.0
# 3540       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...  110.0
# 4243       NaN  NaN  ["Carbon monoxide alarm", "Kitchen", "TV", "Se...   99.0
# 4245       1.0  NaN  ["Carbon monoxide alarm", "Kitchen", "TV", "Se...   69.0
# 4252       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   79.0
# 4294       NaN  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...  143.0
# 4483       1.0  NaN  ["Smoke alarm", "Dishwasher", "Long term stays...   99.0
# 4494       1.0  NaN  ["Refrigerator", "Dishwasher", "Cooking basics...   65.0
# 4538       1.0  NaN  ["Carbon monoxide alarm", "Refrigerator", "Smo...   72.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 111                275                4.79                               1
# 167                  0                 NaN                               1
# 334                296                4.96                               1
# 412                240                4.92                               1
# 1065               135                4.92                               1
# 1427               271                4.93                               1
# 1550                63                4.83                               2
# 1649                 2                4.50                               4
# 1678                90                4.84                               1
# 1905               101                4.79                               2
# 1934                 1                5.00                               1
# 1956                 4                4.75                               5
# 1965                50                4.76                               3
# 2057                 0                 NaN                               1
# 2115               103                4.83                               5
# 2177                 3                4.33                               2
# 2200                 3                4.33                               4
# 2232                10                4.20                               4
# 2245                 3                4.67                               2
# 2302                 3                2.67                               4
# 2319                 0                 NaN                               1
# 2406                35                4.69                               8
# 2536                 5                5.00                               1
# 2623                86                4.84                               8
# 2690               212                4.64                               4
# 2841                 0                 NaN                               1
# 2846                 2                4.50                              33
# 2847                 4                3.00                              33
# 2868                 4                3.75                              33
# 2881                 0                 NaN                               1
# 2886                 0                 NaN                              33
# 2915                 2                5.00                               3
# 2920                19                4.95                               1
# 2996               126                4.75                               5
# 3064                 3                5.00                               8
# 3066                24                4.33                               1
# 3154                 0                 NaN                              33
# 3155                 0                 NaN                              33
# 3296                11                5.00                               1
# 3540                 4                4.00                               2
# 4243                 0                 NaN                              26
# 4245                 0                 NaN                              26
# 4252                 0                 NaN                              26
# 4294                 0                 NaN                              26
# 4483                71                4.75                               1
# 4494                53                4.81                               1
# 4538                15                4.67                               1
#
#       amenities_count      city  num_bath
# 111                30  Portland       1.0
# 167                39  Portland       1.0
# 334                54  Portland       1.0
# 412                36  Portland       1.0
# 1065               52  Portland       1.0
# 1427               39  Portland       1.0
# 1550               56  Portland       1.0
# 1649               24  Portland       1.0
# 1678               47  Portland       1.0
# 1905               17  Portland       1.0
# 1934               16  Portland       3.0
# 1956               14  Portland       1.0
# 1965               21  Portland       1.0
# 2057               18  Portland       1.0
# 2115               37  Portland       1.0
# 2177               32  Portland       1.0
# 2200               31  Portland       1.0
# 2232               39  Portland       1.0
# 2245               29  Portland       1.0
# 2302               30  Portland       2.0
# 2319               21  Portland       1.0
# 2406               16  Portland       2.5
# 2536               15  Portland       1.0
# 2623               32  Portland       1.0
# 2690               36  Portland       1.0
# 2841               10  Portland       1.0
# 2846               35  Portland       1.0
# 2847               35  Portland       1.0
# 2868               35  Portland       1.0
# 2881               13  Portland       1.0
# 2886               37  Portland       1.0
# 2915               35  Portland       0.0
# 2920               33  Portland       1.0
# 2996               35  Portland       1.0
# 3064               20  Portland       1.0
# 3066               48  Portland       0.5
# 3154               35  Portland       1.0
# 3155               33  Portland       1.0
# 3296               49  Portland       1.0
# 3540               28  Portland       1.0
# 4243                9  Portland       2.0
# 4245                9  Portland       1.0
# 4252               32  Portland       1.0
# 4294               30  Portland       2.0
# 4483               34  Portland       1.0
# 4494               28  Portland       1.0
# 4538               30  Portland       1.0
#
# [47 rows x 31 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[updated_df['id'].isin(empty_bathrooms_text_ids)]
# Out:
#             id    host_id host_name  host_since host_location  \
# 1131  21422556    2915808   Stephen  2012-07-12  Portland, OR
# 1217  22599038    2915808   Stephen  2012-07-12  Portland, OR
# 1220  22614995    2915808   Stephen  2012-07-12  Portland, OR
# 1603  29996383  224911430     Robin  2018-11-09  Portland, OR
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1131     within an hour               100%                  98%
# 1217     within an hour               100%                  98%
# 1220     within an hour               100%                  98%
# 1603     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 1131                 t                    5  ...       1.0  2.0
# 1217                 t                    5  ...       1.0  1.0
# 1220                 t                    5  ...       1.0  1.0
# 1603                 t                    6  ...       1.0  1.0
#
#                                               amenities  price  \
# 1131  ["Carbon monoxide alarm", "Refrigerator", "Smo...  115.0
# 1217  ["Carbon monoxide alarm", "Refrigerator", "Smo...   93.0
# 1220  ["Carbon monoxide alarm", "Refrigerator", "Smo...   99.0
# 1603  ["Carbon monoxide alarm", "Refrigerator", "Smo...  160.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 1131                92                4.88                               5
# 1217               128                4.86                               5
# 1220               125                4.88                               5
# 1603                 1                5.00                               6
#
#       amenities_count      city  num_bath
# 1131               25  Portland       1.0
# 1217               21  Portland       1.0
# 1220               24  Portland       1.0
# 1603               28  Portland       1.0
#
# [4 rows x 31 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 2.,  1.,  3.,  5.,  6., 12.,  4.,  7.,  9.,  8., 16., 19., 11.,
#        13., 10., 15., 18.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 2.,  1.,  3.,  5.,  4.,  8.,  7.,  6.,  9., 18.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2009-10-29', '2011-09-20', '2012-04-27', ..., '2011-08-12',
#        '2009-09-15', '2011-04-24'], dtype=object)

# %%
updated_df[updated_df['host_since'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 640 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 640

# %%
updated_df['host_location'].unique()
# Out:
# array(['Portland, OR', 'Palm Springs, CA', 'Stevenson, WA', 'Boise, ID',
#        'unknown', 'New York, NY', 'Eugene, OR', 'Grants Pass, OR',
#        'Hood River, OR', 'United States', 'Cathedral City, CA',
#        'Silverton, OR', 'Seattle, WA', 'Honolulu, HI', 'Los Angeles, CA',
#        'Beaverton, OR', 'Ashland, OR', 'Vancouver, Canada', 'Corbett, OR',
#        'San Francisco, CA', 'Mission Viejo, CA', 'Palm Desert, CA',
#        'Rivergrove, OR', 'Bend, OR', 'Berkeley, CA',
#        'Maine, United States', 'San Diego, CA', 'Canby, OR',
#        'Washington, United States', 'Anaheim, CA', 'Laramie, WY',
#        'Oregon, United States', 'Zagreb, Croatia', 'Lake Oswego, OR',
#        'Santa Cruz, CA', 'Corvallis, OR', 'Mountain View, CA',
#        'San Carlos, CA', 'Camas, WA', 'Redlands, CA', 'Washington, DC',
#        'Allentown, PA', 'Houston, TX', 'Keizer, OR', 'Santa Rosa, CA',
#        'Hillsboro, OR', 'Baton Rouge, LA', 'Omaha, NE', 'Auburn, WA',
#        'Birmingham, AL', 'Georgetown, TX', 'Flinders, Australia',
#        'Hanalei, HI', 'Long Beach, CA', 'Irvine, CA', 'Columbia, SC',
#        'Scottsdale, AZ', 'Hamilton, Canada', 'Mars Hill, NC',
#        'Tucson, AZ', 'Buffalo, NY', 'Tacoma, WA', 'Oakland, CA',
#        'West Hollywood, CA', 'Worcester, MA', 'Brainerd, MN',
#        'Kailua-Kona, HI', 'Grand Forks, ND', 'New Almaden, CA',
#        'Lodi, CA', 'Austin, TX', 'Jersey City, NJ', 'San Ramon, CA',
#        'San Anselmo, CA', 'Florida, United States',
#        'California, United States', 'Vancouver, WA', 'Cannon Beach, OR',
#        'Salt Lake City, UT', 'Springfield, MO', 'Coronado, CA',
#        'Colorado, United States', 'Glenwood, OR', 'Chicago, IL',
#        'Newport, OR', 'Battle Ground, WA', 'Mill Valley, CA',
#        'Whistler, Canada', 'Tualatin, OR', 'Almaty, Kazakhstan',
#        'Happy Valley, OR', 'Valdosta, GA', 'Redwood City, CA',
#        'Sugar Land, TX', 'Philadelphia, PA', 'Chandler, AZ',
#        'Troutdale, OR', 'Essex, MA', 'Miami, FL', 'Magdalena, NM',
#        'Del Mar, CA', 'San Jose, CA', 'El Cerrito, CA', 'Gladstone, OR',
#        'Albany, OR', 'Charleston, SC', 'Kansas City, MO',
#        'Yucca Valley, CA', 'Edmonds, WA', 'Clackamas, OR',
#        'Joshua Tree, CA', 'Ojai, CA', 'Gresham, OR', 'Rhododendron, OR',
#        'Idaho, United States', 'Stayton, OR', 'Sagle, ID',
#        'Myrtle Beach, SC', 'Vernon Hills, IL', 'Kihei, HI', 'Seaside, OR',
#        'Santa Barbara, CA', 'Madrid, Spain', 'Pasadena, CA', 'Orange, CA',
#        'Bowling Green, KY', 'Fresno, CA', 'Kapaʻa, HI', 'Costa Rica',
#        'Tigard, OR', 'Chico, CA', 'North Miami Beach, FL',
#        'Lafayette, OR', 'Tulsa, OK', 'Bainbridge Island, WA',
#        'London, United Kingdom', 'Hayward, CA', 'Tempe, AZ',
#        'Split-Dalmatia County, Croatia', 'Rincón, Puerto Rico',
#        'Norwalk, CA', 'San Clemente, CA', 'Carney, MI', 'Atlanta, GA',
#        'Oregon City, OR', 'West Slope, OR', 'Annapolis, MD',
#        'Wood Village, OR', 'Alameda, CA', 'North Myrtle Beach, SC',
#        'Dover, NH', 'Panama City, Panama', 'Geelong West, Australia',
#        'Golden, CO', 'Phoenix, AZ'], dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df[updated_df['host_location'] ==' ']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 2015

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   1,    6,    2,    3,    8,    4,   34,    7,    5,   42,   12,
#           9,   14,   10,   17,   15,   11,   16,  301,  118,   13,  236,
#         151,  187,  129,   30,   45, 2642,   96,   27,  148,  201, 3302,
#         203,   20, 1046, 1503,   25,   26, 2307,  515,   60,   22,   53,
#          21,  659,  372,  385,  337,  287,   89,   19,   61, 2504,  218,
#         829,  805])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   1,    6,   10,    2,    4,    3,   11,    5,   43,    7,    9,
#           8,   13,   16,   12,   17,   33,   14,   40,   21,  504,  121,
#         264,   19,  286,   42,   22,  292,   35,   49,   36, 8410,   99,
#         303,  239, 4532,  236,   20,   15, 1841, 1967,  125,   30, 7813,
#         724,  124,   48,   93,  716,  372,  465,  542,  378,  109,  165,
#        2776,  277, 1101,  851,   18])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone']", "['phone', 'work_email']", '[]', "['email']"],
#       dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
#             id    host_id host_name  host_since host_location  \
# 2161  41588378  327787591   Katrina  2020-01-15  Portland, OR
# 2692  50000480  420965581       Nan  2021-08-31       unknown
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2161     within an hour                88%                 100%
# 2692                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 2161                 f                    1  ...       1.0  1.0
# 2692                 f                    1  ...       1.0  2.0
#
#                                               amenities price  \
# 2161  ["Shared pool", "Carbon monoxide alarm", "Refr...  60.0
# 2692  ["Drying rack for clothing", "Carbon monoxide ...  96.0
#
#      number_of_reviews review_scores_value  calculated_host_listings_count  \
# 2161                 5                 4.4                               1
# 2692                53                 5.0                               1
#
#       amenities_count      city  num_bath
# 2161               33  Portland       1.0
# 2692               64  Portland       1.0
#
# [2 rows x 31 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone']", "['phone', 'work_email']", 'None', "['email']"],
#       dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([ 1,  2,  6,  3,  8,  4, 28,  5, 26, 12,  7,  9, 13, 11, 16, 33, 15,
#        18, 40, 60, 56, 19, 24, 14, 20, 10])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
na = updated_df['host_has_profile_pic'].isnull().sum()
print(f'There are {na} missing values in the "host_has_profile_pic" column.')

updated_df['host_has_profile_pic'].fillna('f', inplace=True)
# Out:
# There are 0 missing values in the "host_has_profile_pic" column.

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['Portland, Oregon, United States', nan,
#        'Lake Oswego, Oregon, United States', 'United States',
#        'Portland , Oregon, United States',
#        'Happy Valley, Oregon, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 1108

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Concordia', 'Northwest District', 'King', 'Humboldt', 'Roseway',
#        'Richmond', 'South Tabor', 'Cully', 'Irvington', 'Piedmont',
#        'Portland Downtown', 'Eliot', 'Pearl',
#        'Sellwood-Moreland Improvement League', 'Hillsdale', 'Montavilla',
#        'Mt. Tabor', 'Woodlawn', 'Rose City Park', 'Laurelhurst',
#        'Sunnyside', 'Eastmoreland', 'North Tabor', 'Hosford-Abernethy',
#        'Overlook', 'Old Town/Chinatown', 'Vernon', 'Kerns', 'Boise',
#        'Arbor Lodge', 'Buckman', 'West Portland Park', 'Sabin',
#        'Forest Park', 'Southwest Hills', 'Kenton',
#        'Brooklyn Action Corps', 'Grant Park', 'University Park',
#        'St. Johns', "Sullivan's Gulch", 'Beaumont-Wilshire', 'Portsmouth',
#        'Foster-Powell', 'Parkrose', 'Reed', 'Alameda', 'Multnomah',
#        'Hazelwood', 'Cathedral Park', 'Homestead', 'Woodstock',
#        'Arlington Heights', 'South Burlingame', 'Goose Hollow',
#        'Mt. Scott-Arleta', 'South Portland', 'Argay', 'Hillside',
#        'Creston-Kenilworth', 'Far Southwest', 'Collins View',
#        'Brentwood-Darlington', 'Sylvan-Highlands', 'Arnold Creek',
#        'Madison South', 'Hayhurst', 'Linnton', 'Bridlemile', 'Wilkes',
#        'Lents', 'Sunderland', 'Parkrose Heights', 'Ashcreek',
#        'Powellhurst-Gilbert', 'Ardenwald-Johnson Creek', 'Maplewood',
#        'Mill Park', 'Glenfair', 'Pleasant Valley', 'Hayden Island',
#        'Markham', 'Northwest Heights', 'Sumner', 'East Columbia',
#        'Russell', 'Crestwood', 'Hollywood', 'Centennial', 'Bridgeton',
#        'Lloyd District', 'Marshall Park'], dtype=object)

# %% [markdown]
# ### We are going to drop neighbourhood column for Portland Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                  0
# host_id                             0
# host_name                           0
# host_since                          0
# host_location                       0
# host_response_time                681
# host_response_rate                681
# host_acceptance_rate              388
# host_is_superhost                   0
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# host_has_profile_pic                0
# host_identity_verified              0
# neighbourhood_cleansed              0
# latitude                            0
# longitude                           0
# room_type                           0
# accommodates                        0
# bathrooms_text                      0
# bedrooms                            0
# beds                                0
# amenities                           0
# price                               0
# number_of_reviews                   0
# review_scores_value               625
# calculated_host_listings_count      0
# amenities_count                     0
# city                                0
# num_bath                            0
# dtype: int64

# %% [markdown]
# # Save the Final Dataframe

# %%
updated_df.to_csv('data/listings_detailed_after_na_portland.csv', index=False)
