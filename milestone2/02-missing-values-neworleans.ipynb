# %% [markdown]
# # New Orleans

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/New Orleans/listings_detailed-nola.csv')

# %%
listings_detailed.shape
# Out:
# (7056, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (7056, 29)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 120]
filtered_df
# Out:
#                       id    host_id       host_name  host_since  \
# 4               35649853  127726714           Scott  2017-04-26
# 9               52655969   49568908          Robert  2015-11-21
# 53              46541621  266619399  Tim And Kaelyn  2019-06-05
# 112   719124317899114856  140311305         Charles  2017-07-13
# 157             14264317   86915355         Jessica  2016-07-30
# ...                  ...        ...             ...         ...
# 6921            21477155   16783088          Nicole  2014-06-14
# 6949            19458946  124312955            Matt  2017-04-04
# 6985            24312359   29120500         Kendall  2015-03-10
# 7018            25511034    1918545           Henry  2012-03-13
# 7029            27526106  176439104           Liana  2018-03-03
#
#         host_location host_response_time host_response_rate  \
# 4     New Orleans, LA                NaN                NaN
# 9        New York, NY       within a day               100%
# 53      Lafayette, LA     within an hour               100%
# 112   New Orleans, LA     within an hour               100%
# 157               NaN     within an hour               100%
# ...               ...                ...                ...
# 6921  New Orleans, LA                NaN                NaN
# 6949  New Orleans, LA     within an hour               100%
# 6985       Esmont, VA                NaN                NaN
# 7018  New Orleans, LA                NaN                NaN
# 7029  New Orleans, LA                NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 4                     NaN                 f                    4  ...
# 9                     50%                 t                    4  ...
# 53                   100%                 f                    7  ...
# 112                   NaN                 f                    1  ...
# 157                   94%                 t                    1  ...
# ...                   ...               ...                  ...  ...
# 6921                  NaN                 f                    2  ...
# 6949                 100%                 t                    1  ...
# 6985                  NaN                 f                    1  ...
# 7018                  NaN                 f                    1  ...
# 7029                  NaN                 f                    1  ...
#
#       accommodates bathrooms bathrooms_text bedrooms beds  \
# 4                4       NaN         1 bath      2.0  2.0
# 9                4       NaN         1 bath      NaN  1.0
# 53               6       NaN         1 bath      2.0  2.0
# 112              3       NaN         1 bath      1.0  1.0
# 157              4       NaN         1 bath      1.0  2.0
# ...            ...       ...            ...      ...  ...
# 6921             5       NaN         1 bath      2.0  2.0
# 6949             2       NaN         1 bath      1.0  2.0
# 6985             2       NaN      1.5 baths      1.0  2.0
# 7018             2       NaN         1 bath      NaN  1.0
# 7029             4       NaN         1 bath      2.0  2.0
#
#                                               amenities  price  \
# 4     ["Hair dryer", "Air conditioning", "Essentials...  100.0
# 9     ["Air conditioning", "Smoke alarm", "Essential...  100.0
# 53    ["Smoke alarm", "Refrigerator", "Coffee maker"...  100.0
# 112   ["Air conditioning", "Exercise equipment", "Sm...  100.0
# 157   ["Smoke alarm", "Refrigerator", "Coffee maker"...  100.0
# ...                                                 ...    ...
# 6921  ["Smoke alarm", "Refrigerator", "Game console"...  100.0
# 6949  ["Smoke alarm", "Refrigerator", "Coffee maker"...  100.0
# 6985  ["Smoke alarm", "Refrigerator", "Coffee maker"...  100.0
# 7018  ["Smoke alarm", "Refrigerator", "Patio or balc...  100.0
# 7029  ["Smoke alarm", "Refrigerator", "Patio or balc...  100.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 4                     1                5.00                               2
# 9                     2                5.00                               3
# 53                  107                4.39                               7
# 112                   0                 NaN                               1
# 157                 112                4.92                               1
# ...                 ...                 ...                             ...
# 6921                 34                4.94                               2
# 6949                323                4.91                               1
# 6985                  5                5.00                               1
# 7018                 28                4.93                               1
# 7029                  5                5.00                               1
#
# [96 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 8

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id                         host_name  host_since  \
# 0     49751833  267642269  The Old No. 77 Hotel & Chandlery  2019-06-10
# 16    43309170  311900534                    Melrose Suites  2019-11-24
# 103   43309178  311388965                     Streetcar Inn  2019-11-22
# 105   42535097  315008938                 The Drifter Hotel  2019-12-06
# 226   43309185  311388674                     Chateau Hotel  2019-11-22
# 227   43309194  311388025                  Audubon Cottages  2019-11-22
# 3404  43309157  311387788                       Hotel Royal  2019-11-22
# 5674  42875637  266877580                      Federal City  2019-06-07
#
#      host_location host_response_time host_response_rate host_acceptance_rate  \
# 0              NaN     within an hour               100%                  95%
# 16             NaN                NaN                NaN                  NaN
# 103            NaN                NaN                NaN                  NaN
# 105            NaN                NaN                NaN                  NaN
# 226            NaN                NaN                NaN                  NaN
# 227            NaN                NaN                NaN                  NaN
# 3404           NaN                NaN                NaN                  NaN
# 5674           NaN                NaN                NaN                  20%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 0                  NaN                   11  ...             0       NaN
# 16                 NaN                    2  ...             0       NaN
# 103                NaN                    4  ...             0       NaN
# 105                NaN                    5  ...             8       NaN
# 226                NaN                    4  ...             0       NaN
# 227                NaN                    7  ...             0       NaN
# 3404               NaN                    5  ...             0       NaN
# 5674               NaN                    2  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 0               NaN      NaN  NaN
# 16              NaN      NaN  NaN
# 103             NaN      NaN  NaN
# 105             NaN      NaN  NaN
# 226             NaN      NaN  NaN
# 227             NaN      NaN  NaN
# 3404            NaN      NaN  NaN
# 5674            NaN      NaN  NaN
#
#                                               amenities  price  \
# 0     ["Smoke alarm", "Free wifi", "Safe", "Bed shee...    0.0
# 16    ["Smoke alarm", "Coffee maker", "Free wifi", "...    0.0
# 103   ["Air conditioning", "Toiletries", "Hair dryer...    0.0
# 105   ["Air conditioning", "Toiletries", "Hair dryer...    0.0
# 226   ["Toiletries", "Hair dryer", "Smoke alarm", "C...    0.0
# 227   ["Air conditioning", "42\" TV", "Toiletries", ...    0.0
# 3404  ["Air conditioning", "Toiletries", "Hair dryer...    0.0
# 5674  ["Air conditioning", "Toiletries", "Hair dryer...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 0                   284                4.45                               1
# 16                    0                 NaN                               1
# 103                   0                 NaN                               1
# 105                   0                 NaN                               1
# 226                   0                 NaN                               1
# 227                   0                 NaN                               1
# 3404                  0                 NaN                               1
# 5674                  3                1.67                               1
#
# [8 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id                         host_name  host_since  \
# 0     49751833  267642269  The Old No. 77 Hotel & Chandlery  2019-06-10
# 16    43309170  311900534                    Melrose Suites  2019-11-24
# 103   43309178  311388965                     Streetcar Inn  2019-11-22
# 226   43309185  311388674                     Chateau Hotel  2019-11-22
# 227   43309194  311388025                  Audubon Cottages  2019-11-22
# 3404  43309157  311387788                       Hotel Royal  2019-11-22
# 5674  42875637  266877580                      Federal City  2019-06-07
#
#      host_location host_response_time host_response_rate host_acceptance_rate  \
# 0              NaN     within an hour               100%                  95%
# 16             NaN                NaN                NaN                  NaN
# 103            NaN                NaN                NaN                  NaN
# 226            NaN                NaN                NaN                  NaN
# 227            NaN                NaN                NaN                  NaN
# 3404           NaN                NaN                NaN                  NaN
# 5674           NaN                NaN                NaN                  20%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 0                  NaN                   11  ...             0       NaN
# 16                 NaN                    2  ...             0       NaN
# 103                NaN                    4  ...             0       NaN
# 226                NaN                    4  ...             0       NaN
# 227                NaN                    7  ...             0       NaN
# 3404               NaN                    5  ...             0       NaN
# 5674               NaN                    2  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 0               NaN      NaN  NaN
# 16              NaN      NaN  NaN
# 103             NaN      NaN  NaN
# 226             NaN      NaN  NaN
# 227             NaN      NaN  NaN
# 3404            NaN      NaN  NaN
# 5674            NaN      NaN  NaN
#
#                                               amenities  price  \
# 0     ["Smoke alarm", "Free wifi", "Safe", "Bed shee...    0.0
# 16    ["Smoke alarm", "Coffee maker", "Free wifi", "...    0.0
# 103   ["Air conditioning", "Toiletries", "Hair dryer...    0.0
# 226   ["Toiletries", "Hair dryer", "Smoke alarm", "C...    0.0
# 227   ["Air conditioning", "42\" TV", "Toiletries", ...    0.0
# 3404  ["Air conditioning", "Toiletries", "Hair dryer...    0.0
# 5674  ["Air conditioning", "Toiletries", "Hair dryer...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 0                   284                4.45                               1
# 16                    0                 NaN                               1
# 103                   0                 NaN                               1
# 226                   0                 NaN                               1
# 227                   0                 NaN                               1
# 3404                  0                 NaN                               1
# 5674                  3                1.67                               1
#
# [7 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 8

# %%
cleaned_listings.head()
# Out:
#                    id    host_id host_name  host_since    host_location  \
# 1            54052921  227505133       Dan  2018-11-25  New Orleans, LA
# 2  611584572696788093  244418201    Jabari  2019-02-20      Nola, Italy
# 3  806067969324909110    4423079       Guy  2012-12-17  New Orleans, LA
# 4            35649853  127726714     Scott  2017-04-26  New Orleans, LA
# 5  557502553052386952   12305030     Jason  2014-02-16  New Orleans, LA
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 1                NaN                NaN                 100%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                  NaN
# 4                NaN                NaN                  NaN
# 5     within an hour               100%                  94%
#
#   host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 1                 t                    5  ...             1       NaN
# 2                 t                    2  ...            10       NaN
# 3                 f                    1  ...             6       NaN
# 4                 f                    4  ...             4       NaN
# 5                 t                    1  ...             2       NaN
#
#    bathrooms_text bedrooms beds  \
# 1   1 shared bath      1.0  1.0
# 2         2 baths      3.0  3.0
# 3         2 baths      3.0  5.0
# 4          1 bath      2.0  2.0
# 5  1 private bath      1.0  1.0
#
#                                            amenities  price  \
# 1  ["Smoke alarm", "Clothing storage: closet", "D...   42.0
# 2  ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  263.0
# 3  ["Air conditioning", "TV", "Indoor fireplace",...  255.0
# 4  ["Hair dryer", "Air conditioning", "Essentials...  100.0
# 5  ["Hair dryer", "Air conditioning", "Smoke alar...   90.0
#
#    number_of_reviews review_scores_value  calculated_host_listings_count
# 1                  2                5.00                               5
# 2                 24                4.71                               2
# 3                  0                 NaN                               1
# 4                  1                5.00                               2
# 5                 27                4.89                               1
#
# [5 rows x 29 columns]

# %%
cleaned_listings.shape
# Out:
# (7048, 29)

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 shared bath', '2 baths', '1 bath', '1 private bath',
#        '2.5 baths', '3 baths', '4.5 baths', '1.5 baths', '4 baths',
#        '3.5 baths', '1.5 shared baths', '5 baths', '2 shared baths',
#        '5.5 baths', '9 baths', nan, '2.5 shared baths', '0 shared baths',
#        '8.5 baths', '6 baths', '0 baths', '7 baths', '9.5 baths',
#        '10.5 baths', '13.5 baths', '8 baths', '3 shared baths',
#        '18 baths', '6.5 baths', '11 baths', '25 baths', '11.5 baths',
#        '6.5 shared baths'], dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 shared bath' '2 baths' '1 bath' '1 private bath' '2.5 baths' '3 baths'
#  '4.5 baths' '1.5 baths' '4 baths' '3.5 baths' '1.5 shared baths'
#  '5 baths' '2 shared baths' '5.5 baths' '9 baths' '' '2.5 shared baths'
#  '0 shared baths' '8.5 baths' '6 baths' '0 baths' '7 baths' '9.5 baths'
#  '10.5 baths' '13.5 baths' '8 baths' '3 shared baths' '18 baths'
#  '6.5 baths' '11 baths' '25 baths' '11.5 baths' '6.5 shared baths']

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#             id    host_id         host_name  host_since    host_location  \
# 967   24247731  121931799            Monica  2017-03-21  New Orleans, LA
# 1728    665259    1451330  Leron And Dennis  2011-11-28  New Orleans, LA
# 3181  18019499  104792142              Glen  2016-11-22  New Orleans, LA
# 5400  35807105  268586331               Vic  2019-06-14  New Orleans, LA
# 5731  35807260  268586331               Vic  2019-06-14  New Orleans, LA
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 967                 NaN                NaN                  33%
# 1728     within an hour               100%                 100%
# 3181       within a day               100%                  82%
# 5400     within an hour               100%                  99%
# 5731     within an hour               100%                  99%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 967                  f                    1  ...            16       NaN
# 1728                 t                    2  ...             2       NaN
# 3181                 f                    4  ...             4       NaN
# 5400                 t                    7  ...             4       NaN
# 5731                 t                    7  ...             4       NaN
#
#      bathrooms_text bedrooms beds  \
# 967                     11.0  9.0
# 1728                     1.0  1.0
# 3181                     2.0  2.0
# 5400                     2.0  3.0
# 5731                     2.0  4.0
#
#                                               amenities   price  \
# 967   ["Baby monitor", "Smoke alarm", "Refrigerator"...  5400.0
# 1728  ["Smoke alarm", "Refrigerator", "Coffee maker"...    89.0
# 3181  ["Smoke alarm", "Patio or balcony", "Pool", "H...   300.0
# 5400  ["Smoke alarm", "Essentials", "Fire extinguish...   339.0
# 5731  ["Smoke alarm", "Essentials", "Fire extinguish...   359.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 967                   0                 NaN                               1
# 1728                227                4.69                               2
# 3181                  5                4.80                               4
# 5400                 48                4.68                               7
# 5731                 25                4.88                               7
#
# [5 rows x 29 columns]

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#                       id  bedrooms  beds  bathrooms_text
# 1               54052921       1.0   1.0   1 shared bath
# 2     611584572696788093       3.0   3.0         2 baths
# 3     806067969324909110       3.0   5.0         2 baths
# 4               35649853       2.0   2.0          1 bath
# 5     557502553052386952       1.0   1.0  1 private bath
# ...                  ...       ...   ...             ...
# 7051            29336328       2.0   4.0         2 baths
# 7052            29516680       3.0   3.0         2 baths
# 7053            29779203       2.0   2.0          1 bath
# 7054            29799160       2.0   2.0         2 baths
# 7055            29878721       2.0   3.0       1.5 baths
#
# [7048 rows x 4 columns]

# %%
# check for the previous NA rows in bathrooms text
filled_cleaned_listings[
    (filled_cleaned_listings['id'] == 35807260) | 
    (filled_cleaned_listings['id'] == 35807105) | 
    (filled_cleaned_listings['id'] == 18019499) | 
    (filled_cleaned_listings['id'] == 665259) ]
# Out:
#             id    host_id         host_name  host_since    host_location  \
# 1728    665259    1451330  Leron And Dennis  2011-11-28  New Orleans, LA
# 3181  18019499  104792142              Glen  2016-11-22  New Orleans, LA
# 5400  35807105  268586331               Vic  2019-06-14  New Orleans, LA
# 5731  35807260  268586331               Vic  2019-06-14  New Orleans, LA
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1728     within an hour               100%                 100%
# 3181       within a day               100%                  82%
# 5400     within an hour               100%                  99%
# 5731     within an hour               100%                  99%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 1728                 t                    2  ...             2       NaN
# 3181                 f                    4  ...             4       NaN
# 5400                 t                    7  ...             4       NaN
# 5731                 t                    7  ...             4       NaN
#
#      bathrooms_text bedrooms beds  \
# 1728       1.0 bath      1.0  1.0
# 3181       2.0 bath      2.0  2.0
# 5400       2.0 bath      2.0  3.0
# 5731       2.0 bath      2.0  4.0
#
#                                               amenities  price  \
# 1728  ["Smoke alarm", "Refrigerator", "Coffee maker"...   89.0
# 3181  ["Smoke alarm", "Patio or balcony", "Pool", "H...  300.0
# 5400  ["Smoke alarm", "Essentials", "Fire extinguish...  339.0
# 5731  ["Smoke alarm", "Essentials", "Fire extinguish...  359.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 1728                227                4.69                               2
# 3181                  5                4.80                               4
# 5400                 48                4.68                               7
# 5731                 25                4.88                               7
#
# [4 rows x 29 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#       bathrooms_text  num_bath
# 1      1 shared bath       1.0
# 2            2 baths       2.0
# 3            2 baths       2.0
# 4             1 bath       1.0
# 5     1 private bath       1.0
# ...              ...       ...
# 7051         2 baths       2.0
# 7052         2 baths       2.0
# 7053          1 bath       1.0
# 7054         2 baths       2.0
# 7055       1.5 baths       1.5
#
# [7048 rows x 2 columns]

# %%
updated_df.head()
# Out:
#                    id    host_id host_name  host_since    host_location  \
# 1            54052921  227505133       Dan  2018-11-25  New Orleans, LA
# 2  611584572696788093  244418201    Jabari  2019-02-20      Nola, Italy
# 3  806067969324909110    4423079       Guy  2012-12-17  New Orleans, LA
# 4            35649853  127726714     Scott  2017-04-26  New Orleans, LA
# 5  557502553052386952   12305030     Jason  2014-02-16  New Orleans, LA
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 1                NaN                NaN                 100%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                  NaN
# 4                NaN                NaN                  NaN
# 5     within an hour               100%                  94%
#
#   host_is_superhost  host_listings_count  ...  bathrooms  bathrooms_text  \
# 1                 t                    5  ...        NaN   1 shared bath
# 2                 t                    2  ...        NaN         2 baths
# 3                 f                    1  ...        NaN         2 baths
# 4                 f                    4  ...        NaN          1 bath
# 5                 t                    1  ...        NaN  1 private bath
#
#   bedrooms beds                                          amenities  price  \
# 1      1.0  1.0  ["Smoke alarm", "Clothing storage: closet", "D...   42.0
# 2      3.0  3.0  ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  263.0
# 3      3.0  5.0  ["Air conditioning", "TV", "Indoor fireplace",...  255.0
# 4      2.0  2.0  ["Hair dryer", "Air conditioning", "Essentials...  100.0
# 5      1.0  1.0  ["Hair dryer", "Air conditioning", "Smoke alar...   90.0
#
#    number_of_reviews  review_scores_value calculated_host_listings_count  \
# 1                  2                 5.00                              5
# 2                 24                 4.71                              2
# 3                  0                  NaN                              1
# 4                  1                 5.00                              2
# 5                 27                 4.89                              1
#
#    num_bath
# 1       1.0
# 2       2.0
# 3       2.0
# 4       1.0
# 5       1.0
#
# [5 rows x 30 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 30 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  2. ,  2.5,  3. ,  4.5,  1.5,  4. ,  3.5,  5. ,  5.5,  9. ,
#        11. ,  0. ,  8.5,  6. ,  7. ,  9.5, 10.5, 13.5,  8. , 18. ,  6.5,
#        25. , 11.5])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df
# Out:
#                       id    host_id host_name  host_since    host_location  \
# 1               54052921  227505133       Dan  2018-11-25  New Orleans, LA
# 2     611584572696788093  244418201    Jabari  2019-02-20      Nola, Italy
# 3     806067969324909110    4423079       Guy  2012-12-17  New Orleans, LA
# 4               35649853  127726714     Scott  2017-04-26  New Orleans, LA
# 5     557502553052386952   12305030     Jason  2014-02-16  New Orleans, LA
# ...                  ...        ...       ...         ...              ...
# 7051            29336328  220963373    Marlee  2018-10-16      Hammond, LA
# 7052            29516680    2591964   Celeste  2012-06-09  New Orleans, LA
# 7053            29779203  103153653    Robert  2016-11-09  New Orleans, LA
# 7054            29799160   15524853    Meggan  2014-05-14  New Orleans, LA
# 7055            29878721    5958207    Martha  2013-04-16  New Orleans, LA
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 1                   NaN                NaN                 100%
# 2        within an hour               100%                 100%
# 3        within an hour               100%                  NaN
# 4                   NaN                NaN                  NaN
# 5        within an hour               100%                  94%
# ...                 ...                ...                  ...
# 7051                NaN                NaN                  NaN
# 7052                NaN                NaN                  NaN
# 7053                NaN                NaN                  NaN
# 7054                NaN                NaN                  NaN
# 7055                NaN                NaN                  NaN
#
#      host_is_superhost  host_listings_count  ...  accommodates  \
# 1                    t                    5  ...             1
# 2                    t                    2  ...            10
# 3                    f                    1  ...             6
# 4                    f                    4  ...             4
# 5                    t                    1  ...             2
# ...                ...                  ...  ...           ...
# 7051                 f                    1  ...             7
# 7052                 f                    1  ...             8
# 7053                 f                    3  ...             4
# 7054                 f                    3  ...             3
# 7055                 f                    1  ...             6
#
#       bathrooms_text bedrooms beds  \
# 1      1 shared bath      1.0  1.0
# 2            2 baths      3.0  3.0
# 3            2 baths      3.0  5.0
# 4             1 bath      2.0  2.0
# 5     1 private bath      1.0  1.0
# ...              ...      ...  ...
# 7051         2 baths      2.0  4.0
# 7052         2 baths      3.0  3.0
# 7053          1 bath      2.0  2.0
# 7054         2 baths      2.0  2.0
# 7055       1.5 baths      2.0  3.0
#
#                                               amenities  price  \
# 1     ["Smoke alarm", "Clothing storage: closet", "D...   42.0
# 2     ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  263.0
# 3     ["Air conditioning", "TV", "Indoor fireplace",...  255.0
# 4     ["Hair dryer", "Air conditioning", "Essentials...  100.0
# 5     ["Hair dryer", "Air conditioning", "Smoke alar...   90.0
# ...                                                 ...    ...
# 7051  ["Smoke alarm", "Refrigerator", "Coffee maker"...  149.0
# 7052  ["Smoke alarm", "Babysitter recommendations", ...  140.0
# 7053  ["Smoke alarm", "Refrigerator", "Patio or balc...   69.0
# 7054  ["Smoke alarm", "Refrigerator", "Patio or balc...   71.0
# 7055  ["Smoke alarm", "Refrigerator", "Shampoo", "Se...  135.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 1                     2                 5.00                              5
# 2                    24                 4.71                              2
# 3                     0                  NaN                              1
# 4                     1                 5.00                              2
# 5                    27                 4.89                              1
# ...                 ...                  ...                            ...
# 7051                 20                 4.60                              1
# 7052                  1                 4.00                              1
# 7053                 19                 4.89                              1
# 7054                 39                 4.92                              2
# 7055                  4                 4.75                              1
#
#       num_bath
# 1          1.0
# 2          2.0
# 3          2.0
# 4          1.0
# 5          1.0
# ...        ...
# 7051       2.0
# 7052       2.0
# 7053       1.0
# 7054       2.0
# 7055       1.5
#
# [7048 rows x 29 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  3.,  2., nan,  4.,  5.,  6.,  9.,  7., 11.,  8., 10., 15.,
#        17., 18., 25., 23.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  3.,  5.,  2.,  4., nan,  8.,  7.,  6., 10.,  9., 13., 17.,
#        12., 16., 11., 14., 15., 20., 21., 24., 19., 31.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                       id    host_id              host_name  host_since  \
# 9               52655969   49568908                 Robert  2015-11-21
# 25              39487985  120132877                  David  2017-03-10
# 50    579636870207674260  442922842  Canal Express Studios  2022-01-31
# 69    580258457203568391  442922842  Canal Express Studios  2022-01-31
# 90              19472402   12613718      Matthew & Miranda  2014-02-26
# ...                  ...        ...                    ...         ...
# 6978            23397681  157921349                  James  2017-11-08
# 7018            25511034    1918545                  Henry  2012-03-13
# 7027            26888889  140393442                 Dorise  2017-07-14
# 7034            28158610   98693456                  James  2016-10-07
# 7035            28153695   98693456                  James  2016-10-07
#
#                     host_location host_response_time host_response_rate  \
# 9                    New York, NY       within a day               100%
# 25    Setauket- East Setauket, NY     within an hour                90%
# 50                            NaN     within an hour               100%
# 69                            NaN     within an hour               100%
# 90                    Chicago, IL     within an hour               100%
# ...                           ...                ...                ...
# 6978              New Orleans, LA                NaN                NaN
# 7018              New Orleans, LA                NaN                NaN
# 7027              New Orleans, LA                NaN                NaN
# 7034                          NaN                NaN                NaN
# 7035                          NaN                NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 9                     50%                 t                    4  ...
# 25                    97%                 t                   45  ...
# 50                    99%                 f                   14  ...
# 69                    99%                 f                   14  ...
# 90                   100%                 f                  343  ...
# ...                   ...               ...                  ...  ...
# 6978                  NaN                 f                   10  ...
# 7018                  NaN                 f                    1  ...
# 7027                  NaN                 f                    2  ...
# 7034                  NaN                 f                    5  ...
# 7035                  NaN                 f                    5  ...
#
#       accommodates bathrooms_text bedrooms beds  \
# 9                4         1 bath      NaN  1.0
# 25               4  1 shared bath      NaN  2.0
# 50               4         1 bath      NaN  2.0
# 69               3         1 bath      NaN  2.0
# 90               2         1 bath      NaN  1.0
# ...            ...            ...      ...  ...
# 6978             2         1 bath      NaN  1.0
# 7018             2         1 bath      NaN  1.0
# 7027             2         1 bath      NaN  1.0
# 7034             2         1 bath      NaN  1.0
# 7035             2         1 bath      NaN  1.0
#
#                                               amenities  price  \
# 9     ["Air conditioning", "Smoke alarm", "Essential...  100.0
# 25    ["Hair dryer", "Air conditioning", "Smoke alar...  150.0
# 50    ["Hair dryer", "Air conditioning", "Essentials...  115.0
# 69    ["Hair dryer", "Air conditioning", "Essentials...   94.0
# 90    ["Hair dryer", "Air conditioning", "Essentials...  106.0
# ...                                                 ...    ...
# 6978  ["Smoke alarm", "Coffee maker", "Shampoo", "Se...   65.0
# 7018  ["Smoke alarm", "Refrigerator", "Patio or balc...  100.0
# 7027  ["Smoke alarm", "Refrigerator", "Coffee maker"...   95.0
# 7034  ["Smoke alarm", "Refrigerator", "Coffee maker"...   75.0
# 7035  ["Smoke alarm", "Refrigerator", "Coffee maker"...   75.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 9                     2                 5.00                              3
# 25                    0                  NaN                              3
# 50                    8                 4.13                             14
# 69                    7                 4.14                             14
# 90                    0                  NaN                              2
# ...                 ...                  ...                            ...
# 6978                 73                 4.67                              6
# 7018                 28                 4.93                              1
# 7027                 56                 4.98                              2
# 7034                 52                 4.83                              4
# 7035                 54                 4.63                              4
#
#       num_bath
# 9          1.0
# 25         1.0
# 50         1.0
# 69         1.0
# 90         1.0
# ...        ...
# 6978       1.0
# 7018       1.0
# 7027       1.0
# 7034       1.0
# 7035       1.0
#
# [304 rows x 29 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                       id    host_id               host_name  host_since  \
# 15              42670637   93924717                   Diana  2016-09-06
# 44    589710011371284658  342910048                  LiivUP  2020-03-31
# 145              9979215   48187766                   Olive  2015-11-04
# 363             42538906  338825631                 Elliott  2020-02-25
# 846   563629325142763733   64823547         Brenna And Nick  2016-03-28
# 959             42692683  325629344                 Dorothy  2020-01-08
# 1079            52533707  185244265  One Stop Property Shop  2018-04-19
# 1299  635419755040311462   64823547         Brenna And Nick  2016-03-28
# 1336            41804195   65665251                Jeanette  2016-04-03
# 1750  823866116424585046  243202376                 Terrene  2019-02-14
# 1882            43206042  180010620                Rathbone  2018-03-22
# 1922            38490971   64823547         Brenna And Nick  2016-03-28
# 1948            45734440  218602737    Sonder (New Orleans)  2018-10-03
# 2169  565317486488599327  218602737    Sonder (New Orleans)  2018-10-03
# 2273            42453009   12757448                  Marcus  2014-03-03
# 2288            43206039  180010620                Rathbone  2018-03-22
# 2290            43206037  180010620                Rathbone  2018-03-22
# 2408            44490051  218602737    Sonder (New Orleans)  2018-10-03
# 2459            45701752  218602737    Sonder (New Orleans)  2018-10-03
# 2525            43206041  180010620                Rathbone  2018-03-22
# 2610            51327436  129883350                  Kyndel  2017-05-11
# 2614            45701696  218602737    Sonder (New Orleans)  2018-10-03
# 2722            40704090  218602737    Sonder (New Orleans)  2018-10-03
# 2783            49128233  218602737    Sonder (New Orleans)  2018-10-03
# 2905            48105205  342206187          Magnolia Hotel  2020-03-21
# 2945            32253694   91115529                   Julie  2016-08-21
# 3079            49128136  218602737    Sonder (New Orleans)  2018-10-03
# 3106  547886846556386403  218602737    Sonder (New Orleans)  2018-10-03
# 3335            42738761  339221024                    Ryan  2020-02-27
# 3703            50325864   22896374                Jonathan  2014-10-23
# 3747            42453917  214257933                 Mariana  2018-09-08
# 3818            54316788   64823547         Brenna And Nick  2016-03-28
# 4042            32449177   21050084                Reginald  2014-09-07
# 4253            53200118   60139676                 Matthew  2016-02-23
# 4572            22882224  118004286                 Colleen  2017-02-25
# 4620            32136199   35395756                    Kpvr  2015-06-09
# 4885            52389887    4617893                    Kyle  2013-01-07
# 5202            47743151  260671536             Christopher  2019-05-08
# 5397  619484876738281698  218602737    Sonder (New Orleans)  2018-10-03
# 5435            34120230  218602737    Sonder (New Orleans)  2018-10-03
# 5456  565315042588331684  218602737    Sonder (New Orleans)  2018-10-03
# 5482            48283549  162234887                   Viola  2017-12-11
# 5487  619596833971771564  218602737    Sonder (New Orleans)  2018-10-03
# 5597            51966209  218602737    Sonder (New Orleans)  2018-10-03
# 6041            50960719   49452897                    Lisa  2015-11-19
# 6053            51558982  417226297                   Sarah  2021-08-06
# 6097  562957805140895010  218602737    Sonder (New Orleans)  2018-10-03
# 6101  568842614329774827  218602737    Sonder (New Orleans)  2018-10-03
# 6459  568837706187037853  218602737    Sonder (New Orleans)  2018-10-03
# 6527            45484687   25140095                Margitta  2014-12-23
# 6701            45701724  218602737    Sonder (New Orleans)  2018-10-03
# 6818            14988761   12027981                  Ashley  2014-02-07
#
#         host_location  host_response_time host_response_rate  \
# 15       New York, NY                 NaN                NaN
# 44    Baton Rouge, LA      within an hour               100%
# 145   New Orleans, LA      within an hour               100%
# 363   New Orleans, LA  within a few hours               100%
# 846   New Orleans, LA      within an hour               100%
# 959   New Orleans, LA      within an hour               100%
# 1079       Harvey, LA      within an hour               100%
# 1299  New Orleans, LA      within an hour               100%
# 1336      Slidell, LA                 NaN                NaN
# 1750              NaN        within a day               100%
# 1882  New Orleans, LA      within an hour               100%
# 1922  New Orleans, LA      within an hour               100%
# 1948  New Orleans, LA      within an hour                99%
# 2169  New Orleans, LA      within an hour                99%
# 2273  New Orleans, LA      within an hour               100%
# 2288  New Orleans, LA      within an hour               100%
# 2290  New Orleans, LA      within an hour               100%
# 2408  New Orleans, LA      within an hour                99%
# 2459  New Orleans, LA      within an hour                99%
# 2525  New Orleans, LA      within an hour               100%
# 2610  New Orleans, LA      within an hour                95%
# 2614  New Orleans, LA      within an hour                99%
# 2722  New Orleans, LA      within an hour                99%
# 2783  New Orleans, LA      within an hour                99%
# 2905  New Orleans, LA      within an hour                94%
# 2945      Lincoln, NE      within an hour               100%
# 3079  New Orleans, LA      within an hour                99%
# 3106  New Orleans, LA      within an hour                99%
# 3335              NaN                 NaN                NaN
# 3703  New Orleans, LA      within an hour               100%
# 3747  New Orleans, LA      within an hour                67%
# 3818  New Orleans, LA      within an hour               100%
# 4042  New Orleans, LA      within an hour               100%
# 4253  New Orleans, LA  within a few hours               100%
# 4572  New Orleans, LA      within an hour               100%
# 4620  New Orleans, LA  within a few hours                88%
# 4885  New Orleans, LA  within a few hours                90%
# 5202  New Orleans, LA  within a few hours               100%
# 5397  New Orleans, LA      within an hour                99%
# 5435  New Orleans, LA      within an hour                99%
# 5456  New Orleans, LA      within an hour                99%
# 5482  New Orleans, LA      within an hour               100%
# 5487  New Orleans, LA      within an hour                99%
# 5597  New Orleans, LA      within an hour                99%
# 6041              NaN  within a few hours               100%
# 6053              NaN                 NaN                NaN
# 6097  New Orleans, LA      within an hour                99%
# 6101  New Orleans, LA      within an hour                99%
# 6459  New Orleans, LA      within an hour                99%
# 6527  New Orleans, LA      within an hour               100%
# 6701  New Orleans, LA      within an hour                99%
# 6818  New Orleans, LA                 NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 15                    NaN                 f                    1  ...
# 44                   100%                 t                   16  ...
# 145                   86%                 f                   24  ...
# 363                   94%                 t                    1  ...
# 846                  100%                 t                   78  ...
# 959                  100%                 t                    2  ...
# 1079                 100%                 t                   28  ...
# 1299                 100%                 t                   78  ...
# 1336                 100%                 f                    5  ...
# 1750                  77%                 f                    2  ...
# 1882                 100%                 t                    6  ...
# 1922                 100%                 t                   78  ...
# 1948                  99%                 f                   81  ...
# 2169                  99%                 f                   81  ...
# 2273                  86%                 f                    2  ...
# 2288                 100%                 t                    6  ...
# 2290                 100%                 t                    6  ...
# 2408                  99%                 f                   81  ...
# 2459                  99%                 f                   81  ...
# 2525                 100%                 t                    6  ...
# 2610                  99%                 t                   37  ...
# 2614                  99%                 f                   81  ...
# 2722                  99%                 f                   81  ...
# 2783                  99%                 f                   81  ...
# 2905                  94%                 f                   13  ...
# 2945                  67%                 f                   18  ...
# 3079                  99%                 f                   81  ...
# 3106                  99%                 f                   81  ...
# 3335                  NaN                 f                    1  ...
# 3703                 100%                 t                    1  ...
# 3747                  89%                 f                    3  ...
# 3818                 100%                 t                   78  ...
# 4042                 100%                 f                    5  ...
# 4253                  91%                 t                    2  ...
# 4572                  88%                 t                    3  ...
# 4620                  97%                 f                   10  ...
# 4885                  77%                 f                    1  ...
# 5202                 100%                 t                    1  ...
# 5397                  99%                 f                   81  ...
# 5435                  99%                 f                   81  ...
# 5456                  99%                 f                   81  ...
# 5482                 100%                 f                    1  ...
# 5487                  99%                 f                   81  ...
# 5597                  99%                 f                   81  ...
# 6041                 100%                 f                   31  ...
# 6053                  NaN                 f                    3  ...
# 6097                  99%                 f                   81  ...
# 6101                  99%                 f                   81  ...
# 6459                  99%                 f                   81  ...
# 6527                  99%                 t                    3  ...
# 6701                  99%                 f                   81  ...
# 6818                  NaN                 f                    8  ...
#
#       accommodates    bathrooms_text bedrooms beds  \
# 15               6           2 baths      2.0  NaN
# 44               4           2 baths      2.0  NaN
# 145              3     1 shared bath      1.0  NaN
# 363              4            1 bath      2.0  NaN
# 846              2            1 bath      1.0  NaN
# 959              2     1 shared bath      1.0  NaN
# 1079             2    1 private bath      1.0  NaN
# 1299             2            1 bath      1.0  NaN
# 1336             2  1.5 shared baths      1.0  NaN
# 1750             6           2 baths      2.0  NaN
# 1882             6    1 private bath      2.0  NaN
# 1922             2            1 bath      1.0  NaN
# 1948             2           0 baths      NaN  NaN
# 2169             6           2 baths      3.0  NaN
# 2273             2            1 bath      1.0  NaN
# 2288             2    1 private bath      NaN  NaN
# 2290             2    1 private bath      NaN  NaN
# 2408             4           2 baths      2.0  NaN
# 2459             2            1 bath      NaN  NaN
# 2525             4    1 private bath      2.0  NaN
# 2610             2            1 bath      1.0  NaN
# 2614             2            1 bath      NaN  NaN
# 2722             6         2.5 baths      2.0  NaN
# 2783             4            1 bath      2.0  NaN
# 2905             4    1 private bath      1.0  NaN
# 2945             4            1 bath      1.0  NaN
# 3079             4            1 bath      2.0  NaN
# 3106             4            1 bath      1.0  NaN
# 3335             4            1 bath      1.0  NaN
# 3703             2            1 bath      1.0  NaN
# 3747             2     1 shared bath      1.0  NaN
# 3818             2            1 bath      1.0  NaN
# 4042             2            1 bath      1.0  NaN
# 4253             2            1 bath      1.0  NaN
# 4572             2            1 bath      1.0  NaN
# 4620             2            1 bath      1.0  NaN
# 4885             2            1 bath      1.0  NaN
# 5202             2            1 bath      1.0  NaN
# 5397             2     1 shared bath      NaN  NaN
# 5435             4           2 baths      2.0  NaN
# 5456             4           2 baths      2.0  NaN
# 5482             5            1 bath      2.0  NaN
# 5487             4            1 bath      NaN  NaN
# 5597             2            1 bath      1.0  NaN
# 6041             1     1 shared bath      1.0  NaN
# 6053             4            1 bath      1.0  NaN
# 6097             4           2 baths      2.0  NaN
# 6101             2            1 bath      1.0  NaN
# 6459             2            1 bath      NaN  NaN
# 6527            12           4 baths      6.0  NaN
# 6701             2            1 bath      1.0  NaN
# 6818             2            1 bath      1.0  NaN
#
#                                               amenities  price  \
# 15    ["Smoke alarm", "Hot tub", "Pool", "Shampoo", ...  140.0
# 44    ["Hair dryer", "Air conditioning", "Shampoo", ...  283.0
# 145   ["Hair dryer", "Air conditioning", "Essentials...   49.0
# 363   ["Smoke alarm", "Refrigerator", "Patio or balc...  155.0
# 846   ["Smoke alarm", "Refrigerator", "Coffee maker"...   43.0
# 959   ["Smoke alarm", "Refrigerator", "Coffee maker"...   99.0
# 1079  ["Smoke alarm", "Refrigerator", "Coffee maker"...   97.0
# 1299  ["Smoke alarm", "Refrigerator", "Shampoo", "Se...   70.0
# 1336  ["Hair dryer", "Air conditioning", "Essentials...  257.0
# 1750  ["Air conditioning", "Smoke alarm", "Fire exti...  209.0
# 1882  ["Smoke alarm", "Refrigerator", "Patio or balc...   90.0
# 1922  ["Smoke alarm", "Babysitter recommendations", ...   90.0
# 1948  ["Smoke alarm", "Refrigerator", "Coffee maker"...  166.0
# 2169  ["Smoke alarm", "Refrigerator", "Coffee maker"...  379.0
# 2273  ["Smoke alarm", "Refrigerator", "Bed linens", ...  158.0
# 2288  ["Smoke alarm", "Refrigerator", "Coffee maker"...  263.0
# 2290  ["Smoke alarm", "Refrigerator", "Coffee maker"...  253.0
# 2408  ["Smoke alarm", "Refrigerator", "Coffee maker"...  296.0
# 2459  ["Smoke alarm", "Refrigerator", "Patio or balc...  215.0
# 2525  ["Smoke alarm", "Refrigerator", "Coffee maker"...  283.0
# 2610  ["Smoke alarm", "Refrigerator", "Coffee maker"...  217.0
# 2614  ["Smoke alarm", "Refrigerator", "Patio or balc...  188.0
# 2722  ["Smoke alarm", "Refrigerator", "Coffee maker"...  425.0
# 2783  ["Smoke alarm", "Refrigerator", "Coffee maker"...  425.0
# 2905  ["Smoke alarm", "Shampoo", "Self check-in", "W...  132.0
# 2945  ["Smoke alarm", "Refrigerator", "Coffee maker"...  300.0
# 3079  ["Smoke alarm", "Refrigerator", "Coffee maker"...  387.0
# 3106  ["Smoke alarm", "Refrigerator", "Patio or balc...  279.0
# 3335  ["Air conditioning", "Smoke alarm", "Essential...  175.0
# 3703  ["Air conditioning", "Smoke alarm", "Essential...  103.0
# 3747  ["Smoke alarm", "Refrigerator", "Coffee maker"...   65.0
# 3818  ["Smoke alarm", "Babysitter recommendations", ...   63.0
# 4042  ["Hair dryer", "Air conditioning", "Essentials...   74.0
# 4253  ["Smoke alarm", "Refrigerator", "Coffee maker"...   80.0
# 4572  ["Smoke alarm", "Refrigerator", "Patio or balc...  113.0
# 4620  ["Smoke alarm", "Refrigerator", "Self check-in...   65.0
# 4885  ["Smoke alarm", "Refrigerator", "Clothing stor...  120.0
# 5202  ["Smoke alarm", "Refrigerator", "HDTV", "Shamp...  160.0
# 5397  ["Hair dryer", "Air conditioning", "Essentials...  192.0
# 5435  ["Smoke alarm", "Refrigerator", "Patio or balc...  367.0
# 5456  ["Smoke alarm", "Refrigerator", "Coffee maker"...  316.0
# 5482  ["Smoke alarm", "Host greets you", "Clothing s...  220.0
# 5487  ["Hair dryer", "Air conditioning", "Essentials...  231.0
# 5597  ["Smoke alarm", "Refrigerator", "Coffee maker"...  189.0
# 6041  ["Refrigerator", "Patio or balcony", "Coffee m...   29.0
# 6053  ["Smoke alarm", "Refrigerator", "Coffee maker"...  100.0
# 6097  ["Smoke alarm", "Refrigerator", "Patio or balc...  362.0
# 6101  ["Smoke alarm", "Refrigerator", "Patio or balc...  249.0
# 6459  ["Smoke alarm", "Refrigerator", "Coffee maker"...  207.0
# 6527  ["Smoke alarm", "Refrigerator", "Coffee maker"...  332.0
# 6701  ["Smoke alarm", "Refrigerator", "Patio or balc...  194.0
# 6818  ["Smoke alarm", "Refrigerator", "Coffee maker"...  125.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 15                    0                  NaN                              1
# 44                    7                 4.57                             16
# 145                  88                 4.59                             24
# 363                  18                 4.89                              1
# 846                   3                 5.00                             74
# 959                  22                 4.77                              2
# 1079                  1                 5.00                             22
# 1299                  2                 5.00                             74
# 1336                  0                  NaN                              5
# 1750                  0                  NaN                              2
# 1882                  5                 5.00                              6
# 1922                182                 4.76                             74
# 1948                555                 4.46                             78
# 2169                733                 4.50                             78
# 2273                  1                 5.00                              2
# 2288                 23                 4.48                              6
# 2290                 10                 4.50                              6
# 2408                166                 4.67                             78
# 2459                250                 4.57                             78
# 2525                  9                 4.67                              6
# 2610                 20                 4.65                              9
# 2614                422                 4.44                             78
# 2722                 67                 4.45                             78
# 2783                422                 4.53                             78
# 2905                 16                 4.75                             13
# 2945                  3                 5.00                             17
# 3079                129                 4.61                             78
# 3106                 53                 4.62                             78
# 3335                  0                  NaN                              1
# 3703                 63                 4.83                              1
# 3747                  5                 5.00                              3
# 3818                  2                 5.00                             74
# 4042                  0                  NaN                              5
# 4253                  5                 5.00                              2
# 4572                118                 4.81                              3
# 4620                  9                 4.56                              9
# 4885                 12                 5.00                              1
# 5202                 11                 5.00                              1
# 5397                 36                 4.25                             78
# 5435                187                 4.45                             78
# 5456                 97                 4.41                             78
# 5482                  6                 5.00                              1
# 5487                 18                 4.28                             78
# 5597                559                 4.34                             78
# 6041                  0                  NaN                             24
# 6053                  0                  NaN                              1
# 6097                138                 4.64                             78
# 6101                 15                 4.33                             78
# 6459                 44                 4.39                             78
# 6527                  0                  NaN                              3
# 6701                 49                 4.73                             78
# 6818                208                 4.79                              5
#
#       num_bath
# 15         2.0
# 44         2.0
# 145        1.0
# 363        1.0
# 846        1.0
# 959        1.0
# 1079       1.0
# 1299       1.0
# 1336       1.5
# 1750       2.0
# 1882       1.0
# 1922       1.0
# 1948       0.0
# 2169       2.0
# 2273       1.0
# 2288       1.0
# 2290       1.0
# 2408       2.0
# 2459       1.0
# 2525       1.0
# 2610       1.0
# 2614       1.0
# 2722       2.5
# 2783       1.0
# 2905       1.0
# 2945       1.0
# 3079       1.0
# 3106       1.0
# 3335       1.0
# 3703       1.0
# 3747       1.0
# 3818       1.0
# 4042       1.0
# 4253       1.0
# 4572       1.0
# 4620       1.0
# 4885       1.0
# 5202       1.0
# 5397       1.0
# 5435       2.0
# 5456       2.0
# 5482       1.0
# 5487       1.0
# 5597       1.0
# 6041       1.0
# 6053       1.0
# 6097       2.0
# 6101       1.0
# 6459       1.0
# 6527       4.0
# 6701       1.0
# 6818       1.0
#
# [52 rows x 29 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[
    (updated_df['id'] == 22882224) | 
    (updated_df['id'] == 54316788) | 
    (updated_df['id'] == 562957805140895010) 
]
# Out:
#                       id    host_id             host_name  host_since  \
# 3818            54316788   64823547       Brenna And Nick  2016-03-28
# 4572            22882224  118004286               Colleen  2017-02-25
# 6097  562957805140895010  218602737  Sonder (New Orleans)  2018-10-03
#
#         host_location host_response_time host_response_rate  \
# 3818  New Orleans, LA     within an hour               100%
# 4572  New Orleans, LA     within an hour               100%
# 6097  New Orleans, LA     within an hour                99%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 3818                 100%                 t                   78  ...
# 4572                  88%                 t                    3  ...
# 6097                  99%                 f                   81  ...
#
#       accommodates bathrooms_text bedrooms beds  \
# 3818             2         1 bath      1.0  1.0
# 4572             2         1 bath      1.0  1.0
# 6097             4        2 baths      2.0  2.0
#
#                                               amenities  price  \
# 3818  ["Smoke alarm", "Babysitter recommendations", ...   63.0
# 4572  ["Smoke alarm", "Refrigerator", "Patio or balc...  113.0
# 6097  ["Smoke alarm", "Refrigerator", "Patio or balc...  362.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 3818                  2                 5.00                             74
# 4572                118                 4.81                              3
# 6097                138                 4.64                             78
#
#       num_bath
# 3818       1.0
# 4572       1.0
# 6097       2.0
#
# [3 rows x 29 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  3.,  5.,  2.,  4.,  8.,  7.,  6., 10.,  9., 13., 17., 12.,
#         0., 16., 11., 14., 15., 20., 21., 24., 19., 31.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  3.,  2.,  4.,  5.,  6.,  9.,  7., 11.,  8.,  0., 10., 15.,
#        17., 18., 25., 23.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['host_since'] == 'N/A']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['host_since'].unique()
# Out:
# array(['2018-11-25', '2019-02-20', '2012-12-17', ..., '2012-06-09',
#        '2016-11-09', '2013-04-16'], dtype=object)

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 1794 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 1794

# %%
updated_df['host_location'].unique()
# Out:
# array(['New Orleans, LA', 'Nola, Italy', 'unknown', 'New York, NY',
#        'Metairie, LA', 'Violet, LA', 'Setauket- East Setauket, NY',
#        'Baton Rouge, LA', 'Orlando, FL', 'Oak Park, IL', 'Chicago, IL',
#        'Ontario, CA', 'Lafayette, LA', 'Slidell, LA', 'Gretna, LA',
#        'Austin, TX', 'Plantation, FL', 'Pennsylvania, United States',
#        'United States', 'London, United Kingdom', 'Asheville, NC',
#        'Tampa, FL', 'Picayune, MS', 'Harvey, LA', 'Albuquerque, NM',
#        'Cedar Lake, IN', 'Bluffton, SC', 'Houston, TX', 'Semmes, AL',
#        'Union City, GA', 'Norfolk, VA', 'Pegram, TN', 'Tustin, CA',
#        'Portland, OR', 'Baltimore, MD', 'Emeryville, CA', 'Denver, CO',
#        'Natchitoches, LA', 'Illinois City, IL', 'Atlanta, GA',
#        'San Francisco, CA', 'Lake Charles, LA', 'Erie, CO', 'Dallas, TX',
#        'Mandeville, LA', 'New York, United States', 'Las Vegas, NV',
#        'Oakland, CA', 'Miramar, FL', 'Louisiana, United States',
#        'Harbor, OR', 'Pensacola, FL', 'Birmingham, AL', 'Arabi, LA',
#        'Redondo Beach, CA', 'Mission Viejo, CA', 'Covington, LA',
#        'Culver City, CA', 'Hammond, LA', 'West Palm Beach, FL',
#        'Kenner, LA', 'Los Angeles, CA', 'Scottsdale, AZ', 'Townsend, GA',
#        'Jefferson, LA', 'Inglewood, CA', 'Palo Alto, CA', 'Gulfport, MS',
#        'Miami, FL', 'Ashburn, VA', 'Sarasota, FL', 'Hackettstown, NJ',
#        'Duluth, GA', 'Kittery, ME', 'Nashville, TN', 'Charlotte, NC',
#        'Urbana, IL', 'Albany, NY', 'McKinney, TX', 'Marietta, GA',
#        'New Britain, PA', 'Georgia, United States', 'New Braunfels, TX',
#        'Spokane, WA', 'Frisco, TX', 'Jaco, Costa Rica',
#        'Bay St. Louis, MS', 'Marrero, LA', 'Hamburg, LA',
#        'California, United States', 'Gonzales, LA', 'Flowery Branch, GA',
#        'Mountain View, CA', 'Paris, France', 'Winter Garden, FL',
#        'Nassau, Bahamas', 'Gig Harbor, WA', 'Chalmette, LA',
#        'Homestead, FL', 'Madison, WI', 'Greenlawn, NY', 'Boulder, CO',
#        'Memphis, TN', 'San Diego, CA', 'Fort Lauderdale, FL',
#        'Delray Beach, FL', 'Ventura, CA', 'Hattiesburg, MS',
#        'Saint Petersburg, FL', 'Clinton Township, MI', 'Savannah, GA',
#        'San Antonio, TX', 'Destin, FL', 'San Mateo, CA', 'Washington, DC',
#        'Calistoga, CA', 'Long Beach, CA', 'Wimberley, TX',
#        'Fort Collins, CO', 'Richmond, VA', 'Lincoln, NE',
#        'Massachusetts, United States', 'Coushatta, LA', 'Nome, AK',
#        'Alpharetta, GA', 'Phoenix, AZ', 'Little River, SC',
#        'Maryland, United States', 'Florida, United States',
#        'St. Louis, MO', 'Boston, MA', 'Myrtle Beach, SC', 'Seaside, CA',
#        'Missouri, United States', 'Charleston, SC', 'Sacramento, CA',
#        'Rochester, NY', 'Grants Pass, OR', 'Lexington, KY', 'Raymond, MS',
#        'Edwardsville, IL', 'West Sacramento, CA', 'Pittsburgh, PA',
#        'Williamsburg, VA', 'Lubbock, TX', 'Oxford, MS',
#        'Donaldsonville, LA', 'New Smyrna Beach, FL', 'Coldwater, Canada',
#        "D'Iberville, MS", 'Indianapolis, IN', 'Pelahatchie, MS',
#        'Destrehan, LA', 'Bonita, CA', 'Walker, LA', 'Menifee, CA',
#        'Gulf Breeze, FL', 'Saint Rose, LA', 'Salt Lake City, UT',
#        'Bethesda, MD', 'Fort Worth, TX', 'Berkeley, CA',
#        'Diamond Bar, CA', 'Melbourne, FL', 'Pensacola Beach, FL',
#        'Kalama, WA', 'Brooksville, FL', 'New Buffalo, MI',
#        'Farmersville, TX', 'Folsom, LA', 'Santa Monica, CA',
#        'Somerville, MA', 'Georgetown, TX', 'Yemassee, SC', 'LaPlace, LA',
#        'Stateline, NV', 'Manhattan Beach, CA', 'Fayetteville, AR',
#        'Rincón, Puerto Rico', 'Bovina Center, NY', 'Summerfield, NC',
#        'Lexington, SC', 'Conifer, CO', 'Katy, TX', 'Kihei, HI',
#        'Avondale, LA', 'Spain', 'Spring, TX', 'Bloomington, IN',
#        'Navarre, FL', 'Alameda, CA', 'Frederick, MD', 'Jonesboro, AR',
#        'Fairhope, AL', 'Belle Chasse, LA', 'Stafford, VA',
#        'Oceanside, CA', 'Congo', 'Johannesburg, South Africa',
#        'Crestwood, KY', 'Madison, AL', 'Honolulu, HI', 'Crowley, LA',
#        'Redwood City, CA', 'Hewlett, NY', 'Biloxi, MS', 'Chanhassen, MN',
#        'Gray, LA', 'San Jose, CA', 'Madison, VA', 'Signal Mountain, TN',
#        'Cincinnati, OH', 'Niagara Falls, NY', 'Los Gatos, CA',
#        'New Jersey, United States', 'Japan', 'San Rafael, CA',
#        'Seattle, WA', 'Ithaca, NY', 'Winnipeg, Canada', 'Raleigh, NC',
#        'Saint James, NY', 'Baldwin, MD', 'Otterup, Denmark', 'Esmont, VA',
#        'East Lansing, MI', 'Calgary, Canada', 'Palos Verdes Estates, CA'],
#       dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 4059

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   5,    2,    1,    4,    3,  212,    7,   45,  419,   12,   16,
#         343,   14,   27,   63,   11,   24,   17,   20,    9,  904,   15,
#           8,   10,   18,  119,  201,   30,   75,   31,    6,   61,   28,
#          41,   68,  536,   78,   21,   46,   37,  202,   84,   19,  147,
#          53,  735,  365, 3291,   39,   43,  117,  167,   81,   13, 2642,
#          22,   92,   29,   23,  449,   25,   97,  166,  112, 2508,  226,
#         330,   44,  187,   70,  374,  225,  630,   36,  132,   58,   50,
#         355,  559,   51,   52,   40, 2072,   38,   42,  152,   62])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   8,    2,    1,    6,    3,    4,  265,   23,    7,   57,    5,
#         570,   13,   20,   18,  471,   15,   33,   21,    9,   75,   25,
#          35,   12,   24,   56,   11, 1622,   10,   19,   62,  122,  239,
#          30,   48,   81,   42,   65,   28,  198,  782,   14,  181,   52,
#          38,  364,   86,  351,   73,   16,   34,   93, 1417,  838, 4527,
#          54,  196,   17,   41,  417,   31,  153,   26,  536,   29,   27,
#          51, 8331,   32,   22,  147,   53,   39,  491,   37,   78,  110,
#          43,  167,  161, 2750,   79,  252, 1115,   61,  286,  298,  375,
#         238,  244,  736,  190,  150,   64,  106,  392,  662,  102,   46,
#        2268,   47,   55,  323,   77,   66,   90,   84,  205])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone', 'work_email']", "['email', 'phone']",
#        "['phone']", "['phone', 'work_email']", '[]', "['email']"],
#       dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
#                       id    host_id         host_name  host_since  \
# 1677            26556038   16694390              Beth  2016-05-20
# 4344            26448282   16694390              Beth  2016-05-20
# 4660  806434116599513282  496567001            Edward  2023-01-17
# 5942            40611713  314702788  Hospitality NOLA  2019-12-05
# 5945            40633979  314702788  Hospitality NOLA  2019-12-05
# 5968            40704451  314702788  Hospitality NOLA  2019-12-05
#
#         host_location  host_response_time host_response_rate  \
# 1677  New Orleans, LA      within an hour               100%
# 4344  New Orleans, LA      within an hour               100%
# 4660          unknown  a few days or more                 0%
# 5942          unknown                 NaN                NaN
# 5945          unknown                 NaN                NaN
# 5968          unknown                 NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 1677                  93%                 t                    2  ...
# 4344                  93%                 t                    2  ...
# 4660                   0%                 f                    1  ...
# 5942                  NaN                 f                    3  ...
# 5945                  NaN                 f                    3  ...
# 5968                  NaN                 f                    3  ...
#
#       accommodates bathrooms_text bedrooms beds  \
# 1677             2  1 shared bath      1.0  1.0
# 4344             2         1 bath      1.0  1.0
# 4660             6         1 bath      2.0  3.0
# 5942             8        2 baths      3.0  3.0
# 5945             4      1.5 baths      1.0  2.0
# 5968             6        2 baths      2.0  2.0
#
#                                               amenities  price  \
# 1677  ["Smoke alarm", "Refrigerator", "Coffee maker"...  109.0
# 4344  ["Smoke alarm", "Refrigerator", "Patio or balc...  129.0
# 4660  ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  269.0
# 5942  ["Smoke alarm", "Refrigerator", "Coffee maker"...  242.0
# 5945  ["Smoke alarm", "Refrigerator", "Patio or balc...  187.0
# 5968  ["Smoke alarm", "Refrigerator", "Coffee maker"...  295.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 1677                 56                 4.96                              2
# 4344                 76                 4.95                              2
# 4660                  0                  NaN                              1
# 5942                  0                  NaN                              3
# 5945                  0                  NaN                              3
# 5968                  0                  NaN                              3
#
#       num_bath
# 1677       1.0
# 4344       1.0
# 4660       1.0
# 5942       2.0
# 5945       1.5
# 5968       2.0
#
# [6 rows x 29 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone', 'work_email']", "['email', 'phone']",
#        "['phone']", "['phone', 'work_email']", 'None', "['email']"],
#       dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  5,   2,   1,   3, 100,   7,  12,   4,  16,  14,  27,  58,   9,
#         24,  26,  15,   8,  10,   6,  29,  28,  67,  13,  38,  20,  37,
#         83,  22,  74,  11,  19,  50,  17,  78,  18,  41,  40,  34])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['New Orleans, Louisiana, United States', nan,
#        'New Orleans , Louisiana, United States',
#        'ByWater-Marigny, New Orleans , Louisiana, United States',
#        'Arabi, Louisiana, United States', 'New Orleans, United States',
#        'New Orleans , La, United States',
#        'ByWater-Marigny, New Orleans, Louisiana, United States',
#        'New Orleans, Louisiana, US, Louisiana, United States',
#        'New orleans, Louisiana, United States',
#        'New Orleans,, La, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 2029

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Little Woods', 'Hollygrove', 'Broadmoor',
#        'Marlyville - Fontainbleau', 'Bywater', 'Mid-City', 'Lakeview',
#        'Treme - Lafitte', 'Dillard', 'Seventh Ward', 'Mcdonogh',
#        'St. Roch', 'Central Business District', 'Central City',
#        'French Quarter', 'Audubon', 'Bayou St. John', 'St. Claude',
#        'East Riverside', 'Fairgrounds', 'Uptown', 'Fillmore',
#        'Village De Lest', 'St. Thomas Dev', 'Gentilly Terrace',
#        'Tulane - Gravier', 'Irish Channel', 'Black Pearl', 'Plum Orchard',
#        'Touro', 'Lower Garden District', 'Garden District',
#        'St.  Anthony', 'Holy Cross', 'Leonidas', 'Marigny', 'Behrman',
#        'Milneburg', 'West Riverside', 'City Park', 'Pines Village',
#        'Algiers Point', 'East Carrollton', 'U.S. Naval Base',
#        'Lake Catherine', 'West End', 'West Lake Forest', 'Milan',
#        'Desire Area', 'Freret', 'Old Aurora', 'Read Blvd East',
#        'Lakeshore - Lake Vista', 'Gert Town', 'Tall Timbers - Brechtel',
#        'Pontchartrain Park', 'Navarre', 'B. W. Cooper',
#        'Lower Ninth Ward', 'Read Blvd West', 'Lake Terrace & Oaks',
#        'Gentilly Woods', 'St. Bernard Area', 'Florida Area', 'Whitney',
#        'New Aurora - English Turn', 'Dixon'], dtype=object)

# %%
updated_df['neighbourhood_cleansed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### We are going to drop neighbourhood column for NOLA Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # host_response_time

# %%
updated_df['host_response_time'].unique()
# Out:
# array([nan, 'within an hour', 'within a few hours', 'within a day',
#        'a few days or more'], dtype=object)

# %% [markdown]
# # host_response_rate

# %%
updated_df['host_response_rate'].unique()
# Out:
# array([nan, '100%', '90%', '74%', '80%', '92%', '78%', '97%', '0%', '95%',
#        '99%', '38%', '50%', '33%', '96%', '64%', '69%', '98%', '83%',
#        '89%', '82%', '91%', '88%', '60%', '94%', '86%', '85%', '70%',
#        '93%', '75%', '67%', '71%', '79%', '25%', '72%', '87%', '61%',
#        '43%', '22%', '30%', '13%'], dtype=object)

# %% [markdown]
# # host_acceptance_rate

# %%
updated_df['host_acceptance_rate'].unique()
# Out:
# array(['100%', nan, '94%', '96%', '82%', '50%', '99%', '98%', '81%', '0%',
#        '97%', '89%', '46%', '93%', '88%', '86%', '80%', '71%', '92%',
#        '33%', '85%', '15%', '1%', '83%', '91%', '77%', '73%', '64%',
#        '62%', '75%', '90%', '58%', '70%', '31%', '95%', '28%', '63%',
#        '84%', '42%', '79%', '72%', '67%', '87%', '65%', '57%', '49%',
#        '40%', '23%', '56%', '78%', '20%', '44%', '25%', '69%', '68%',
#        '43%', '17%', '60%', '76%', '74%', '9%', '35%', '66%', '4%', '45%',
#        '55%', '48%', '38%', '53%', '13%', '47%'], dtype=object)

# %% [markdown]
# # Adding new columns for city
#
# Add new column and put 'New Orleans' for all rows for later joining purpose

# %%
updated_df['city'] = 'New Orleans'
updated_df.head()
# Out:
#                    id    host_id host_name  host_since    host_location  \
# 1            54052921  227505133       Dan  2018-11-25  New Orleans, LA
# 2  611584572696788093  244418201    Jabari  2019-02-20      Nola, Italy
# 3  806067969324909110    4423079       Guy  2012-12-17  New Orleans, LA
# 4            35649853  127726714     Scott  2017-04-26  New Orleans, LA
# 5  557502553052386952   12305030     Jason  2014-02-16  New Orleans, LA
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 1                NaN                NaN                 100%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                  NaN
# 4                NaN                NaN                  NaN
# 5     within an hour               100%                  94%
#
#   host_is_superhost  host_listings_count  ...  bathrooms_text bedrooms beds  \
# 1                 t                    5  ...   1 shared bath      1.0  1.0
# 2                 t                    2  ...         2 baths      3.0  3.0
# 3                 f                    1  ...         2 baths      3.0  5.0
# 4                 f                    4  ...          1 bath      2.0  2.0
# 5                 t                    1  ...  1 private bath      1.0  1.0
#
#                                            amenities  price  \
# 1  ["Smoke alarm", "Clothing storage: closet", "D...   42.0
# 2  ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  263.0
# 3  ["Air conditioning", "TV", "Indoor fireplace",...  255.0
# 4  ["Hair dryer", "Air conditioning", "Essentials...  100.0
# 5  ["Hair dryer", "Air conditioning", "Smoke alar...   90.0
#
#    number_of_reviews  review_scores_value calculated_host_listings_count  \
# 1                  2                 5.00                              5
# 2                 24                 4.71                              2
# 3                  0                  NaN                              1
# 4                  1                 5.00                              2
# 5                 27                 4.89                              1
#
#    num_bath         city
# 1       1.0  New Orleans
# 2       2.0  New Orleans
# 3       2.0  New Orleans
# 4       1.0  New Orleans
# 5       1.0  New Orleans
#
# [5 rows x 29 columns]

# %% [markdown]
# # Count number of amenities

# %%
import ast

# Convert the 'amenities' string to a list using ast.literal_eval
updated_df['amenities_list'] = updated_df['amenities'].apply(lambda x: ast.literal_eval(x))

# Count the number of amenities in each list and create a new column with these counts
updated_df['amenities_count'] = updated_df['amenities_list'].apply(lambda x: len(x))

updated_df.drop('amenities_list', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#                    id    host_id host_name  host_since    host_location  \
# 1            54052921  227505133       Dan  2018-11-25  New Orleans, LA
# 2  611584572696788093  244418201    Jabari  2019-02-20      Nola, Italy
# 3  806067969324909110    4423079       Guy  2012-12-17  New Orleans, LA
# 4            35649853  127726714     Scott  2017-04-26  New Orleans, LA
# 5  557502553052386952   12305030     Jason  2014-02-16  New Orleans, LA
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 1                NaN                NaN                 100%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                  NaN
# 4                NaN                NaN                  NaN
# 5     within an hour               100%                  94%
#
#   host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 1                 t                    5  ...       1.0  1.0
# 2                 t                    2  ...       3.0  3.0
# 3                 f                    1  ...       3.0  5.0
# 4                 f                    4  ...       2.0  2.0
# 5                 t                    1  ...       1.0  1.0
#
#                                            amenities  price number_of_reviews  \
# 1  ["Smoke alarm", "Clothing storage: closet", "D...   42.0                 2
# 2  ["Smoke alarm", "Refrigerator", "Shampoo", "Cl...  263.0                24
# 3  ["Air conditioning", "TV", "Indoor fireplace",...  255.0                 0
# 4  ["Hair dryer", "Air conditioning", "Essentials...  100.0                 1
# 5  ["Hair dryer", "Air conditioning", "Smoke alar...   90.0                27
#
#    review_scores_value  calculated_host_listings_count num_bath         city  \
# 1                 5.00                               5      1.0  New Orleans
# 2                 4.71                               2      2.0  New Orleans
# 3                  NaN                               1      2.0  New Orleans
# 4                 5.00                               2      1.0  New Orleans
# 5                 4.89                               1      1.0  New Orleans
#
#   amenities_count
# 1              67
# 2              54
# 3               7
# 4              18
# 5              14
#
# [5 rows x 30 columns]

# %%
# sanity check

see = updated_df.loc[updated_df['id'] == 806067969324909110]


amenities_text = see['amenities'].iloc[0]

# Print the extracted 'amenities' list
print(amenities_text)
# Out:
# ["Air conditioning", "TV", "Indoor fireplace", "Wifi", "Washer", "Free parking on premises", "Kitchen"]

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                   0
# host_id                              0
# host_name                            0
# host_since                           0
# host_location                        0
# host_response_time                1154
# host_response_rate                1154
# host_acceptance_rate               976
# host_is_superhost                    0
# host_listings_count                  0
# host_total_listings_count            0
# host_verifications                   0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# number_of_reviews                    0
# review_scores_value                883
# calculated_host_listings_count       0
# num_bath                             0
# city                                 0
# amenities_count                      0
# dtype: int64

# %%
# Save as a new csv file
updated_df.to_csv('clean-data/listings_detailed_clean_neworleans.csv', index=False)
