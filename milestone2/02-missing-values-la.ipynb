# %% [markdown]
# # Los Angeles

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/Los Angeles/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (42451, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (42451, 29)

# %%
# Save as a new csv file
listings_detailed.to_csv('listings_detailed_clean_la.csv', index=False)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 10]
filtered_df
# Out:
#                        id    host_id host_name  host_since    host_location  \
# 3450              8954605   46218841     Spyro  2015-10-10     Glendale, CA
# 7121             38491365  177333046   Carmine  2018-03-08   Long Beach, CA
# 10565             9476994   49119691   Roberta  2015-11-15     Pasadena, CA
# 25253            48400268   14105430    Marcel  2014-04-10  Los Angeles, CA
# 26117            50380922  213959518    Blanca  2018-09-06  Los Angeles, CA
# 28482            50177386   33772749      Will  2015-05-19   Long Beach, CA
# 29223            50999233  136613504     Laila  2017-06-23  Los Angeles, CA
# 29479  580384048712284299   64081146     Wendy  2016-03-22   Long Beach, CA
# 38987            23132645   72573217   Allison  2016-05-17  Los Angeles, CA
# 42423  800992081953714938    4691557      Cary  2013-01-13  Los Angeles, CA
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 3450                  NaN                NaN                  NaN
# 7121                  NaN                NaN                  NaN
# 10565        within a day                50%                  76%
# 25253                 NaN                NaN                  NaN
# 26117      within an hour                99%                 100%
# 28482      within an hour               100%                  75%
# 29223                 NaN                NaN                  NaN
# 29479  within a few hours               100%                  50%
# 38987                 NaN                NaN                  NaN
# 42423      within an hour               100%                  67%
#
#       host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 3450                  f                  1.0  ...             2       NaN
# 7121                  f                  3.0  ...             1       NaN
# 10565                 f                  2.0  ...             2       NaN
# 25253                 f                  1.0  ...             2       NaN
# 26117                 f                 16.0  ...             2       NaN
# 28482                 t                 10.0  ...             2       NaN
# 29223                 f                  1.0  ...             2       NaN
# 29479                 f                  1.0  ...             2       NaN
# 38987                 f                  1.0  ...             1       NaN
# 42423                 f                  2.0  ...             3       NaN
#
#          bathrooms_text bedrooms beds  \
# 3450            3 baths      4.0  4.0
# 7121   1.5 shared baths      1.0  2.0
# 10565         1.5 baths      1.0  1.0
# 25253     1 shared bath      1.0  1.0
# 26117     1 shared bath      1.0  1.0
# 28482     1 shared bath      1.0  1.0
# 29223            1 bath      1.0  1.0
# 29479    1 private bath      1.0  1.0
# 38987            1 bath      NaN  1.0
# 42423            1 bath      1.0  2.0
#
#                                                amenities  price  \
# 3450   ["Ethernet connection", "Smoke alarm", "Washer...   10.0
# 7121   ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   10.0
# 10565  ["Ethernet connection", "Smoke alarm", "Washer...   10.0
# 25253                                                 []   10.0
# 26117  ["Smoke alarm", "Shampoo", "55\" HDTV with Net...   10.0
# 28482  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   10.0
# 29223  ["Hot tub", "Wifi", "Outdoor dining area", "Ca...   10.0
# 29479  ["Valley view", "Central heating", "Smoke alar...   10.0
# 38987  ["Wifi", "Gym", "Smoke alarm", "Washer", "Heat...   10.0
# 42423  ["Fast wifi \u2013 417 Mbps", "Central heating...   10.0
#
#        number_of_reviews review_scores_value  calculated_host_listings_count
# 3450                   4                5.00                               1
# 7121                   5                5.00                               3
# 10565                 61                4.93                               2
# 25253                  1                5.00                               1
# 26117                  7                4.57                              16
# 28482                  3                5.00                              10
# 29223                  0                 NaN                               1
# 29479                  0                 NaN                               1
# 38987                  0                 NaN                               1
# 42423                  0                 NaN                               2
#
# [10 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 14

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#              id    host_id                        host_name  host_since  \
# 1574   42829972  299524070           Glendale Express Hotel  2019-10-02
# 3233   43247438  309273784                      LA Best Inn  2019-11-13
# 8128   48535258  391634388                            Anuja  2021-03-08
# 10049  42384662  296569793               Viceroy L’Ermitage  2019-09-20
# 12644  42229033  311439116                       Nite Inn @  2019-11-22
# 14610  42829631   98347870  Beverly Hills Plaza Hotel & Spa  2016-10-06
# 25927  46396590  375439118                      Shore Hotel  2020-11-12
# 26189  43096355  306014339           The Prospect Hollywood  2019-11-01
# 27366  40561078  209561894                     Gold Diggers  2018-08-14
# 28165  43247459  323989168      Lexen Hotel North Hollywood  2020-01-03
# 28236  40561079  272064927                   The LINE Hotel  2019-06-28
# 29002  41740614  269304681                      Hotel Erwin  2019-06-17
# 32343  42228983  311453463                     El Patio Inn  2019-11-22
# 39462  46393222  375341994                           Daniel  2020-11-11
#
#          host_location host_response_time host_response_rate  \
# 1574      Glendale, CA                NaN                NaN
# 3233   Los Angeles, CA                NaN                NaN
# 8128               NaN                NaN                NaN
# 10049              NaN                NaN                NaN
# 12644              NaN     within an hour               100%
# 14610              NaN                NaN                NaN
# 25927              NaN     within an hour               100%
# 26189  Los Angeles, CA     within an hour               100%
# 27366  Los Angeles, CA     within an hour               100%
# 28165              NaN                NaN                NaN
# 28236              NaN                NaN                NaN
# 29002  Los Angeles, CA     within an hour               100%
# 32343              NaN     within an hour               100%
# 39462              NaN     within an hour               100%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 1574                   NaN               NaN                  2.0  ...
# 3233                   NaN               NaN                  4.0  ...
# 8128                   NaN               NaN                  2.0  ...
# 10049                 100%               NaN                  9.0  ...
# 12644                 100%               NaN                  6.0  ...
# 14610                  NaN               NaN                  2.0  ...
# 25927                  35%               NaN                  7.0  ...
# 26189                 100%               NaN                  2.0  ...
# 27366                  98%               NaN                 13.0  ...
# 28165                  NaN               NaN                  3.0  ...
# 28236                  NaN               NaN                  5.0  ...
# 29002                  99%               NaN                  5.0  ...
# 32343                  98%               NaN                  4.0  ...
# 39462                 100%               NaN                  5.0  ...
#
#        accommodates bathrooms bathrooms_text bedrooms beds  \
# 1574              0       NaN            NaN      NaN  NaN
# 3233              0       NaN            NaN      NaN  NaN
# 8128              0       NaN            NaN      NaN  NaN
# 10049             2       NaN            NaN      NaN  NaN
# 12644             8       NaN            NaN      NaN  NaN
# 14610             0       NaN            NaN      NaN  NaN
# 25927             0       NaN            NaN      NaN  NaN
# 26189             0       NaN            NaN      NaN  NaN
# 27366             2       NaN            NaN      NaN  NaN
# 28165             0       NaN            NaN      NaN  NaN
# 28236             4       NaN            NaN      NaN  NaN
# 29002             4       NaN            NaN      NaN  NaN
# 32343             5       NaN            NaN      NaN  NaN
# 39462             0       NaN            NaN      NaN  NaN
#
#                                                amenities  price  \
# 1574   ["Smoke alarm", "Laundry services", "Complimen...    0.0
# 3233   ["Safe", "Bed sheets and pillows", "Carbon mon...    0.0
# 8128                                                  []    0.0
# 10049  ["Mini fridge", "Baby bath", "Smoke alarm", "N...    0.0
# 12644  ["Limited housekeeping \u2014 on request", "Mi...    0.0
# 14610  ["Onsite restaurant \u2014 Le Petit Caf\u00e9 ...    0.0
# 25927  ["Limited housekeeping \u2014 on request", "Sm...    0.0
# 26189  ["Smoke alarm", "Complimentary self parking", ...    0.0
# 27366  ["Sonos sound system", "Mini fridge", "Smoke a...    0.0
# 28165  ["42\" HDTV", "Safe", "Bed sheets and pillows"...    0.0
# 28236  ["Baby safety gates", "Sauna", "Steam room", "...    0.0
# 29002  ["Limited housekeeping \u2014 on request", "Mi...    0.0
# 32343  ["Limited housekeeping \u2014 on request", "Mi...    0.0
# 39462  ["Limited housekeeping \u2014 on request", "Mi...    0.0
#
#        number_of_reviews review_scores_value  calculated_host_listings_count
# 1574                  16                3.50                               1
# 3233                   1                1.00                               1
# 8128                   0                 NaN                               1
# 10049                 10                4.20                               1
# 12644                 45                4.20                               1
# 14610                  0                 NaN                               1
# 25927                  3                4.33                               1
# 26189                 61                4.75                               1
# 27366                111                4.70                               2
# 28165                  0                 NaN                               1
# 28236                  8                4.00                               1
# 29002                158                4.48                               1
# 32343                 16                4.19                               1
# 39462                 13                4.85                               1
#
# [14 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#              id    host_id                        host_name  host_since  \
# 1574   42829972  299524070           Glendale Express Hotel  2019-10-02
# 3233   43247438  309273784                      LA Best Inn  2019-11-13
# 8128   48535258  391634388                            Anuja  2021-03-08
# 14610  42829631   98347870  Beverly Hills Plaza Hotel & Spa  2016-10-06
# 25927  46396590  375439118                      Shore Hotel  2020-11-12
# 26189  43096355  306014339           The Prospect Hollywood  2019-11-01
# 28165  43247459  323989168      Lexen Hotel North Hollywood  2020-01-03
# 39462  46393222  375341994                           Daniel  2020-11-11
#
#          host_location host_response_time host_response_rate  \
# 1574      Glendale, CA                NaN                NaN
# 3233   Los Angeles, CA                NaN                NaN
# 8128               NaN                NaN                NaN
# 14610              NaN                NaN                NaN
# 25927              NaN     within an hour               100%
# 26189  Los Angeles, CA     within an hour               100%
# 28165              NaN                NaN                NaN
# 39462              NaN     within an hour               100%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 1574                   NaN               NaN                  2.0  ...
# 3233                   NaN               NaN                  4.0  ...
# 8128                   NaN               NaN                  2.0  ...
# 14610                  NaN               NaN                  2.0  ...
# 25927                  35%               NaN                  7.0  ...
# 26189                 100%               NaN                  2.0  ...
# 28165                  NaN               NaN                  3.0  ...
# 39462                 100%               NaN                  5.0  ...
#
#        accommodates bathrooms bathrooms_text bedrooms beds  \
# 1574              0       NaN            NaN      NaN  NaN
# 3233              0       NaN            NaN      NaN  NaN
# 8128              0       NaN            NaN      NaN  NaN
# 14610             0       NaN            NaN      NaN  NaN
# 25927             0       NaN            NaN      NaN  NaN
# 26189             0       NaN            NaN      NaN  NaN
# 28165             0       NaN            NaN      NaN  NaN
# 39462             0       NaN            NaN      NaN  NaN
#
#                                                amenities  price  \
# 1574   ["Smoke alarm", "Laundry services", "Complimen...    0.0
# 3233   ["Safe", "Bed sheets and pillows", "Carbon mon...    0.0
# 8128                                                  []    0.0
# 14610  ["Onsite restaurant \u2014 Le Petit Caf\u00e9 ...    0.0
# 25927  ["Limited housekeeping \u2014 on request", "Sm...    0.0
# 26189  ["Smoke alarm", "Complimentary self parking", ...    0.0
# 28165  ["42\" HDTV", "Safe", "Bed sheets and pillows"...    0.0
# 39462  ["Limited housekeeping \u2014 on request", "Mi...    0.0
#
#        number_of_reviews review_scores_value  calculated_host_listings_count
# 1574                  16                3.50                               1
# 3233                   1                1.00                               1
# 8128                   0                 NaN                               1
# 14610                  0                 NaN                               1
# 25927                  3                4.33                               1
# 26189                 61                4.75                               1
# 28165                  0                 NaN                               1
# 39462                 13                4.85                               1
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 14

# %%
cleaned_listings.shape
# Out:
# (42437, 29)

# %% [markdown]
# # Count 'amenities'

# %%
import ast
def count_amenities(amenities_str):
    try:
        # Convert the string representation of the list back into a list
        amenities_list = ast.literal_eval(amenities_str)
        # Return the count of items in the list
        return len(amenities_list)
    except (ValueError, SyntaxError):
        # In case of any error during conversion, return 0 (or you may choose to return NaN)
        return 0

# Apply the function to each row in the 'amenities' column and create a new column 'amenities_count'
cleaned_listings['amenities_count'] = cleaned_listings['amenities'].apply(count_amenities)

# %%
cleaned_listings['amenities_count']
# Out:
# 0        10
# 1        15
# 2        19
# 3        58
# 4        56
#          ..
# 42446    73
# 42447    33
# 42448    19
# 42449    41
# 42450    35
# Name: amenities_count, Length: 42437, dtype: int64

# %% [markdown]
# # Add 'city' column

# %%
# Add in a city column to each dataframe so that we can use this as part of the primary key/use it to conduct groupby for
# future EDA or additional analysis as final table will contain all of our listings data
cleaned_listings['city'] = 'Los Angeles'

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['3.5 baths', '1 shared bath', '1 bath', '2 baths', 'Half-bath',
#        '2.5 baths', '3 baths', '1 private bath', '1.5 shared baths',
#        '1.5 baths', '5 baths', '0 baths', '6 baths', '2 shared baths',
#        '4 baths', '7.5 baths', '5.5 baths', '4.5 baths', '0 shared baths',
#        '11 baths', '2.5 shared baths', nan, '8 baths', 'Shared half-bath',
#        '3 shared baths', '7 baths', '8.5 baths', '8 shared baths',
#        '6.5 baths', '9 baths', '11 shared baths', '3.5 shared baths',
#        '9.5 baths', '10 baths', '11.5 baths', '5 shared baths',
#        '4 shared baths', '8.5 shared baths', 'Private half-bath',
#        '5.5 shared baths', '21.5 baths', '13.5 baths', '4.5 shared baths',
#        '12 baths', '21 baths', '20 baths', '10 shared baths',
#        '12.5 baths', '10.5 baths', '13 baths', '15 baths',
#        '11.5 shared baths'], dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['3.5 baths' '1 shared bath' '1 bath' '2 baths' '0.5 baths' '2.5 baths'
#  '3 baths' '1 private bath' '1.5 shared baths' '1.5 baths' '5 baths'
#  '0 baths' '6 baths' '2 shared baths' '4 baths' '7.5 baths' '5.5 baths'
#  '4.5 baths' '0 shared baths' '11 baths' '2.5 shared baths' '' '8 baths'
#  '3 shared baths' '7 baths' '8.5 baths' '8 shared baths' '6.5 baths'
#  '9 baths' '11 shared baths' '3.5 shared baths' '9.5 baths' '10 baths'
#  '11.5 baths' '5 shared baths' '4 shared baths' '8.5 shared baths'
#  '5.5 shared baths' '21.5 baths' '13.5 baths' '4.5 shared baths'
#  '12 baths' '21 baths' '20 baths' '10 shared baths' '12.5 baths'
#  '10.5 baths' '13 baths' '15 baths' '11.5 shared baths']

# %%
count_half_baths = (cleaned_listings['bathrooms_text'] == '0.5 baths').sum()
count_half_baths
# Out:
# 95

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#                        id    host_id                   host_name  host_since  \
# 359              47159462    2288402                          Ug  2012-05-04
# 1084             39705326  271698446                      Robert  2019-06-27
# 1140              1053404    5799839                     Barbara  2013-04-06
# 2939             52989672  428985128                     Xueping  2021-10-25
# 4142   708127514159735039  446995407                       Vicky  2022-02-26
# 8247   732599207114852422  446995407                       Vicky  2022-02-26
# 9045             51382976    3097566                       Frist  2012-07-30
# 10528              405296    2019725                      Larisa  2012-03-27
# 11893            45383114   69113169                         Olt  2016-04-26
# 12978               69015     341419                      Sharda  2011-01-09
# 14628            40117496   10055368                       Nazak  2013-11-16
# 15445            19870804  128635026             Broadlind Hotel  2017-05-03
# 16343              688583    3515462                      Walter  2012-09-09
# 16769            48904220    7760022                    Jennifer  2013-07-27
# 17587            29441778   58056241                         Jad  2016-02-09
# 19222            28079484   58056241                         Jad  2016-02-09
# 21737            54117350    3248466                      Monica  2012-08-13
# 21840             2146019   10954840                      Nicole  2014-01-01
# 22936              241906    1242157                   Catherine  2011-10-03
# 23809            49557957  136538649                       Hanna  2017-06-23
# 24690            49599757  136203024                       Kelly  2017-06-21
# 26486            52335811    3097566                       Frist  2012-07-30
# 27638            53547177    1511137                    Emma.  V  2011-12-16
# 29547               79832      28569                      Robert  2009-07-29
# 34629            48273586   89737443                      Rafael  2016-08-13
# 38977            19801464  131471979                    Jennifer  2017-05-22
# 39993            24221825  178480382  Avalon Hotel Beverly Hills  2018-03-14
#
#            host_location  host_response_time host_response_rate  \
# 359      Los Angeles, CA                 NaN                NaN
# 1084     Los Angeles, CA                 NaN                NaN
# 1140     Los Angeles, CA                 NaN                NaN
# 2939                 NaN                 NaN                NaN
# 4142                 NaN      within an hour               100%
# 8247                 NaN      within an hour               100%
# 9045     Los Angeles, CA      within an hour                98%
# 10528    Los Angeles, CA        within a day               100%
# 11893    Los Angeles, CA                 NaN                NaN
# 12978     Chennai, India                 NaN                NaN
# 14628  Beverly Hills, CA                 NaN                NaN
# 15445     Long Beach, CA      within an hour               100%
# 16343    Los Angeles, CA  within a few hours               100%
# 16769    Los Angeles, CA                 NaN                NaN
# 17587  Beverly Hills, CA                 NaN                NaN
# 19222  Beverly Hills, CA                 NaN                NaN
# 21737    Los Angeles, CA  within a few hours               100%
# 21840    Los Angeles, CA                 NaN                NaN
# 22936    Los Angeles, CA                 NaN                NaN
# 23809                NaN                 NaN                NaN
# 24690      Inglewood, CA                 NaN                NaN
# 26486    Los Angeles, CA      within an hour                98%
# 27638  Laguna Niguel, CA      within an hour               100%
# 29547    Los Angeles, CA                 NaN                NaN
# 34629         Downey, CA  within a few hours               100%
# 38977    Los Angeles, CA                 NaN                NaN
# 39993  Beverly Hills, CA                 NaN                NaN
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 359                    NaN                 f                  2.0  ...
# 1084                   NaN                 f                  1.0  ...
# 1140                   NaN                 f                  1.0  ...
# 2939                   NaN                 f                  2.0  ...
# 4142                  100%                 f                  6.0  ...
# 8247                  100%                 f                  6.0  ...
# 9045                   80%                 f                 43.0  ...
# 10528                  50%                 f                  1.0  ...
# 11893                  NaN                 f                  1.0  ...
# 12978                  NaN                 f                  1.0  ...
# 14628                  NaN                 f                  1.0  ...
# 15445                  98%                 f                 20.0  ...
# 16343                  95%                 t                  1.0  ...
# 16769                  NaN                 f                  1.0  ...
# 17587                  NaN                 f                  8.0  ...
# 19222                  NaN                 f                  8.0  ...
# 21737                 100%                 f                  1.0  ...
# 21840                  NaN                 f                  1.0  ...
# 22936                  NaN                 f                  1.0  ...
# 23809                  NaN                 f                  3.0  ...
# 24690                   0%                 f                  1.0  ...
# 26486                  80%                 f                 43.0  ...
# 27638                  98%                 f                 23.0  ...
# 29547                  NaN                 f                  1.0  ...
# 34629                  91%                 t                  2.0  ...
# 38977                  NaN                 f                  3.0  ...
# 39993                 100%                 f                  3.0  ...
#
#        bathrooms_text bedrooms beds  \
# 359                        1.0  1.0
# 1084                       NaN  NaN
# 1140                       1.0  1.0
# 2939                       NaN  NaN
# 4142                       1.0  1.0
# 8247                       1.0  1.0
# 9045                       1.0  2.0
# 10528                      1.0  1.0
# 11893                      1.0  1.0
# 12978                      1.0  1.0
# 14628                      1.0  1.0
# 15445                      2.0  2.0
# 16343                      1.0  1.0
# 16769                      NaN  1.0
# 17587                      2.0  4.0
# 19222                      2.0  4.0
# 21737                      1.0  NaN
# 21840                      NaN  NaN
# 22936                      1.0  NaN
# 23809                      1.0  1.0
# 24690                      NaN  1.0
# 26486                      1.0  1.0
# 27638                      1.0  1.0
# 29547                      1.0  1.0
# 34629                      1.0  1.0
# 38977                      2.0  2.0
# 39993                      1.0  2.0
#
#                                                amenities  price  \
# 359    ["Wifi", "Carbon monoxide alarm", "Smoke alarm...  240.0
# 1084           ["Hangers", "Essentials", "Pets allowed"]   40.0
# 1140   ["TV with standard cable", "Hot tub", "Wifi", ...  115.0
# 2939   ["Smoke alarm", "Shampoo", "Kitchen", "Hair dr...  120.0
# 4142   ["Central heating", "Smoke alarm", "Washer", "...   99.0
# 8247   ["Wifi", "Indoor fireplace", "Carbon monoxide ...   99.0
# 9045   ["Smoke alarm", "Washer", "Shampoo", "Hair dry...   65.0
# 10528  ["TV with standard cable", "Hot tub", "Wifi", ...   89.0
# 11893  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...  145.0
# 12978                   ["Air conditioning", "Elevator"]  901.0
# 14628  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...  150.0
# 15445  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...  446.0
# 16343  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   95.0
# 16769  ["Indoor fireplace", "Carbon monoxide alarm", ...  184.0
# 17587  ["Ethernet connection", "Gym", "Smoke alarm", ...  199.0
# 19222  ["Ethernet connection", "Gym", "Baby bath", "W...  198.0
# 21737  ["Smoke alarm", "82\" HDTV with Netflix, Amazo...  904.0
# 21840                                                 []  125.0
# 22936                                                 []  200.0
# 23809  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...   50.0
# 24690  ["Hot tub", "Wifi", "Carbon monoxide alarm", "...   95.0
# 26486  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   69.0
# 27638  ["Ethernet connection", "Smoke alarm", "Shampo...   55.0
# 29547  ["Bed linens", "TV with standard cable", "Wifi...  110.0
# 34629  ["Mini fridge", "Smoke alarm", "Washer", "Free...   70.0
# 38977  ["Hot tub", "Wifi", "Indoor fireplace", "Gym",...  225.0
# 39993  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...  949.0
#
#       number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 359                   0                  NaN                               2
# 1084                  1                 1.00                               1
# 1140                  0                  NaN                               1
# 2939                  1                 1.00                               2
# 4142                 16                 4.94                               6
# 8247                  3                 4.67                               6
# 9045                  0                  NaN                              38
# 10528                32                 4.74                               1
# 11893                 0                  NaN                               1
# 12978                 0                  NaN                               1
# 14628                 1                  NaN                               1
# 15445                38                 4.74                              20
# 16343               162                 4.92                               1
# 16769                 0                  NaN                               1
# 17587                29                 4.18                               8
# 19222                17                 4.44                               8
# 21737                 4                 5.00                               1
# 21840                 0                  NaN                               1
# 22936                 0                  NaN                               1
# 23809                 0                  NaN                               3
# 24690                 0                  NaN                               1
# 26486                 1                 4.00                              38
# 27638                 3                 5.00                              23
# 29547               484                 4.91                               1
# 34629                 7                 5.00                               2
# 38977                 0                  NaN                               3
# 39993                 0                  NaN                               3
#
#       amenities_count         city
# 359                12  Los Angeles
# 1084                3  Los Angeles
# 1140               12  Los Angeles
# 2939               27  Los Angeles
# 4142               33  Los Angeles
# 8247               11  Los Angeles
# 9045               33  Los Angeles
# 10528              10  Los Angeles
# 11893              29  Los Angeles
# 12978               2  Los Angeles
# 14628              19  Los Angeles
# 15445              33  Los Angeles
# 16343              26  Los Angeles
# 16769              10  Los Angeles
# 17587              50  Los Angeles
# 19222              51  Los Angeles
# 21737              22  Los Angeles
# 21840               0  Los Angeles
# 22936               0  Los Angeles
# 23809              18  Los Angeles
# 24690              20  Los Angeles
# 26486              26  Los Angeles
# 27638              38  Los Angeles
# 29547              16  Los Angeles
# 34629              36  Los Angeles
# 38977              20  Los Angeles
# 39993              16  Los Angeles
#
# [27 rows x 31 columns]

# %%
empty_bathrooms_text_ids = cleaned_listings[cleaned_listings['bathrooms_text'] == '']['id']
print(len(empty_bathrooms_text_ids))
# Out:
# 27

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#                        id  bedrooms  beds  bathrooms_text
# 0      777451666060243581       4.0   3.0       3.5 baths
# 1      698097753730921190       1.0   1.0   1 shared bath
# 2                13063118       1.0   1.0          1 bath
# 3                39337076       1.0   1.0   1 shared bath
# 4                13077628       3.0   4.0         2 baths
# ...                   ...       ...   ...             ...
# 42446            17286704       1.0   1.0   1 shared bath
# 42447  751077061221390362       1.0   1.0       2.5 baths
# 42448  663030240787490751       1.0   1.0   1 shared bath
# 42449            15876540       1.0   1.0  1 private bath
# 42450  625415450215801684       5.0   1.0  3 shared baths
#
# [42437 rows x 4 columns]

# %%
# # check for the previous NA rows in bathrooms text
filled_cleaned_listings[filled_cleaned_listings['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                        id    host_id                   host_name  host_since  \
# 359              47159462    2288402                          Ug  2012-05-04
# 1084             39705326  271698446                      Robert  2019-06-27
# 1140              1053404    5799839                     Barbara  2013-04-06
# 2939             52989672  428985128                     Xueping  2021-10-25
# 4142   708127514159735039  446995407                       Vicky  2022-02-26
# 8247   732599207114852422  446995407                       Vicky  2022-02-26
# 9045             51382976    3097566                       Frist  2012-07-30
# 10528              405296    2019725                      Larisa  2012-03-27
# 11893            45383114   69113169                         Olt  2016-04-26
# 12978               69015     341419                      Sharda  2011-01-09
# 14628            40117496   10055368                       Nazak  2013-11-16
# 15445            19870804  128635026             Broadlind Hotel  2017-05-03
# 16343              688583    3515462                      Walter  2012-09-09
# 16769            48904220    7760022                    Jennifer  2013-07-27
# 17587            29441778   58056241                         Jad  2016-02-09
# 19222            28079484   58056241                         Jad  2016-02-09
# 21737            54117350    3248466                      Monica  2012-08-13
# 21840             2146019   10954840                      Nicole  2014-01-01
# 22936              241906    1242157                   Catherine  2011-10-03
# 23809            49557957  136538649                       Hanna  2017-06-23
# 24690            49599757  136203024                       Kelly  2017-06-21
# 26486            52335811    3097566                       Frist  2012-07-30
# 27638            53547177    1511137                    Emma.  V  2011-12-16
# 29547               79832      28569                      Robert  2009-07-29
# 34629            48273586   89737443                      Rafael  2016-08-13
# 38977            19801464  131471979                    Jennifer  2017-05-22
# 39993            24221825  178480382  Avalon Hotel Beverly Hills  2018-03-14
#
#            host_location  host_response_time host_response_rate  \
# 359      Los Angeles, CA                 NaN                NaN
# 1084     Los Angeles, CA                 NaN                NaN
# 1140     Los Angeles, CA                 NaN                NaN
# 2939                 NaN                 NaN                NaN
# 4142                 NaN      within an hour               100%
# 8247                 NaN      within an hour               100%
# 9045     Los Angeles, CA      within an hour                98%
# 10528    Los Angeles, CA        within a day               100%
# 11893    Los Angeles, CA                 NaN                NaN
# 12978     Chennai, India                 NaN                NaN
# 14628  Beverly Hills, CA                 NaN                NaN
# 15445     Long Beach, CA      within an hour               100%
# 16343    Los Angeles, CA  within a few hours               100%
# 16769    Los Angeles, CA                 NaN                NaN
# 17587  Beverly Hills, CA                 NaN                NaN
# 19222  Beverly Hills, CA                 NaN                NaN
# 21737    Los Angeles, CA  within a few hours               100%
# 21840    Los Angeles, CA                 NaN                NaN
# 22936    Los Angeles, CA                 NaN                NaN
# 23809                NaN                 NaN                NaN
# 24690      Inglewood, CA                 NaN                NaN
# 26486    Los Angeles, CA      within an hour                98%
# 27638  Laguna Niguel, CA      within an hour               100%
# 29547    Los Angeles, CA                 NaN                NaN
# 34629         Downey, CA  within a few hours               100%
# 38977    Los Angeles, CA                 NaN                NaN
# 39993  Beverly Hills, CA                 NaN                NaN
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 359                    NaN                 f                  2.0  ...
# 1084                   NaN                 f                  1.0  ...
# 1140                   NaN                 f                  1.0  ...
# 2939                   NaN                 f                  2.0  ...
# 4142                  100%                 f                  6.0  ...
# 8247                  100%                 f                  6.0  ...
# 9045                   80%                 f                 43.0  ...
# 10528                  50%                 f                  1.0  ...
# 11893                  NaN                 f                  1.0  ...
# 12978                  NaN                 f                  1.0  ...
# 14628                  NaN                 f                  1.0  ...
# 15445                  98%                 f                 20.0  ...
# 16343                  95%                 t                  1.0  ...
# 16769                  NaN                 f                  1.0  ...
# 17587                  NaN                 f                  8.0  ...
# 19222                  NaN                 f                  8.0  ...
# 21737                 100%                 f                  1.0  ...
# 21840                  NaN                 f                  1.0  ...
# 22936                  NaN                 f                  1.0  ...
# 23809                  NaN                 f                  3.0  ...
# 24690                   0%                 f                  1.0  ...
# 26486                  80%                 f                 43.0  ...
# 27638                  98%                 f                 23.0  ...
# 29547                  NaN                 f                  1.0  ...
# 34629                  91%                 t                  2.0  ...
# 38977                  NaN                 f                  3.0  ...
# 39993                 100%                 f                  3.0  ...
#
#        bathrooms_text bedrooms beds  \
# 359          1.0 bath      1.0  1.0
# 1084           1 bath      NaN  NaN
# 1140         1.0 bath      1.0  1.0
# 2939           1 bath      NaN  NaN
# 4142         1.0 bath      1.0  1.0
# 8247         1.0 bath      1.0  1.0
# 9045         1.0 bath      1.0  2.0
# 10528        1.0 bath      1.0  1.0
# 11893        1.0 bath      1.0  1.0
# 12978        1.0 bath      1.0  1.0
# 14628        1.0 bath      1.0  1.0
# 15445        2.0 bath      2.0  2.0
# 16343        1.0 bath      1.0  1.0
# 16769        0.5 bath      NaN  1.0
# 17587        2.0 bath      2.0  4.0
# 19222        2.0 bath      2.0  4.0
# 21737        1.0 bath      1.0  NaN
# 21840          1 bath      NaN  NaN
# 22936        1.0 bath      1.0  NaN
# 23809        1.0 bath      1.0  1.0
# 24690        0.5 bath      NaN  1.0
# 26486        1.0 bath      1.0  1.0
# 27638        1.0 bath      1.0  1.0
# 29547        1.0 bath      1.0  1.0
# 34629        1.0 bath      1.0  1.0
# 38977        2.0 bath      2.0  2.0
# 39993        1.0 bath      1.0  2.0
#
#                                                amenities  price  \
# 359    ["Wifi", "Carbon monoxide alarm", "Smoke alarm...  240.0
# 1084           ["Hangers", "Essentials", "Pets allowed"]   40.0
# 1140   ["TV with standard cable", "Hot tub", "Wifi", ...  115.0
# 2939   ["Smoke alarm", "Shampoo", "Kitchen", "Hair dr...  120.0
# 4142   ["Central heating", "Smoke alarm", "Washer", "...   99.0
# 8247   ["Wifi", "Indoor fireplace", "Carbon monoxide ...   99.0
# 9045   ["Smoke alarm", "Washer", "Shampoo", "Hair dry...   65.0
# 10528  ["TV with standard cable", "Hot tub", "Wifi", ...   89.0
# 11893  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...  145.0
# 12978                   ["Air conditioning", "Elevator"]  901.0
# 14628  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...  150.0
# 15445  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...  446.0
# 16343  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   95.0
# 16769  ["Indoor fireplace", "Carbon monoxide alarm", ...  184.0
# 17587  ["Ethernet connection", "Gym", "Smoke alarm", ...  199.0
# 19222  ["Ethernet connection", "Gym", "Baby bath", "W...  198.0
# 21737  ["Smoke alarm", "82\" HDTV with Netflix, Amazo...  904.0
# 21840                                                 []  125.0
# 22936                                                 []  200.0
# 23809  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...   50.0
# 24690  ["Hot tub", "Wifi", "Carbon monoxide alarm", "...   95.0
# 26486  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...   69.0
# 27638  ["Ethernet connection", "Smoke alarm", "Shampo...   55.0
# 29547  ["Bed linens", "TV with standard cable", "Wifi...  110.0
# 34629  ["Mini fridge", "Smoke alarm", "Washer", "Free...   70.0
# 38977  ["Hot tub", "Wifi", "Indoor fireplace", "Gym",...  225.0
# 39993  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...  949.0
#
#       number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 359                   0                  NaN                               2
# 1084                  1                 1.00                               1
# 1140                  0                  NaN                               1
# 2939                  1                 1.00                               2
# 4142                 16                 4.94                               6
# 8247                  3                 4.67                               6
# 9045                  0                  NaN                              38
# 10528                32                 4.74                               1
# 11893                 0                  NaN                               1
# 12978                 0                  NaN                               1
# 14628                 1                  NaN                               1
# 15445                38                 4.74                              20
# 16343               162                 4.92                               1
# 16769                 0                  NaN                               1
# 17587                29                 4.18                               8
# 19222                17                 4.44                               8
# 21737                 4                 5.00                               1
# 21840                 0                  NaN                               1
# 22936                 0                  NaN                               1
# 23809                 0                  NaN                               3
# 24690                 0                  NaN                               1
# 26486                 1                 4.00                              38
# 27638                 3                 5.00                              23
# 29547               484                 4.91                               1
# 34629                 7                 5.00                               2
# 38977                 0                  NaN                               3
# 39993                 0                  NaN                               3
#
#       amenities_count         city
# 359                12  Los Angeles
# 1084                3  Los Angeles
# 1140               12  Los Angeles
# 2939               27  Los Angeles
# 4142               33  Los Angeles
# 8247               11  Los Angeles
# 9045               33  Los Angeles
# 10528              10  Los Angeles
# 11893              29  Los Angeles
# 12978               2  Los Angeles
# 14628              19  Los Angeles
# 15445              33  Los Angeles
# 16343              26  Los Angeles
# 16769              10  Los Angeles
# 17587              50  Los Angeles
# 19222              51  Los Angeles
# 21737              22  Los Angeles
# 21840               0  Los Angeles
# 22936               0  Los Angeles
# 23809              18  Los Angeles
# 24690              20  Los Angeles
# 26486              26  Los Angeles
# 27638              38  Los Angeles
# 29547              16  Los Angeles
# 34629              36  Los Angeles
# 38977              20  Los Angeles
# 39993              16  Los Angeles
#
# [27 rows x 31 columns]

# %% [markdown]
# Note: Looking back to the oringinal data original data, the entries with id '49229073' was deleted in the begging as it had 0 accomodates

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#        bathrooms_text  num_bath
# 0           3.5 baths       3.5
# 1       1 shared bath       1.0
# 2              1 bath       1.0
# 3       1 shared bath       1.0
# 4             2 baths       2.0
# ...               ...       ...
# 42446   1 shared bath       1.0
# 42447       2.5 baths       2.5
# 42448   1 shared bath       1.0
# 42449  1 private bath       1.0
# 42450  3 shared baths       3.0
#
# [42437 rows x 2 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 32 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 3.5,  1. ,  2. ,  0.5,  2.5,  3. ,  1.5,  5. ,  0. ,  6. ,  4. ,
#         7.5,  5.5,  4.5, 11. ,  8. ,  7. ,  8.5,  6.5,  9. ,  9.5, 10. ,
#        11.5, 21.5, 13.5, 12. , 21. , 20. , 12.5, 10.5, 13. , 15. ])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df.head()
# Out:
#                    id    host_id host_name  host_since  \
# 0  777451666060243581  490709958      Dana  2022-12-08
# 1  698097753730921190  444692513     Hanna  2022-02-12
# 2            13063118   41736985      Beth  2015-08-17
# 3            39337076  208375458       Jae  2018-08-09
# 4            13077628    4182067    Jeremy  2012-11-18
#
#              host_location host_response_time host_response_rate  \
# 0                      NaN     within an hour               100%
# 1                      NaN     within an hour               100%
# 2                      NaN     within an hour               100%
# 3  Rancho Palos Verdes, CA     within an hour               100%
# 4               Malibu, CA     within an hour               100%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  ...  bedrooms  \
# 0                   0%                 f                  1.0  ...       4.0
# 1                 100%                 t                  4.0  ...       1.0
# 2                  86%                 f                 15.0  ...       1.0
# 3                  99%                 t                  4.0  ...       1.0
# 4                  NaN                 f                  1.0  ...       3.0
#
#   beds                                          amenities   price  \
# 0  3.0  ["Wifi", "Exercise equipment", "Carbon monoxid...   399.0
# 1  1.0  ["Bed linens", "Wifi", "Carbon monoxide alarm"...    46.0
# 2  1.0  ["Shared hot tub", "Wifi", "Refrigerator", "Gy...   408.0
# 3  1.0  ["Smoke alarm", "Freezer", "Shampoo", "Park vi...    80.0
# 4  4.0  ["Sonos sound system", "Central heating", "Smo...  2138.0
#
#   number_of_reviews review_scores_value  calculated_host_listings_count  \
# 0                 0                 NaN                               1
# 1                 5                4.40                               4
# 2                53                4.83                              10
# 3                44                4.82                               4
# 4                15                4.36                               1
#
#    amenities_count         city  num_bath
# 0               10  Los Angeles       3.5
# 1               15  Los Angeles       1.0
# 2               19  Los Angeles       1.0
# 3               58  Los Angeles       1.0
# 4               56  Los Angeles       2.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 4.,  1.,  3., nan,  2.,  5.,  6.,  7.,  8., 11.,  9., 12., 13.,
#        10., 24., 23., 16.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 3.,  1.,  4.,  2., nan,  5.,  7.,  6.,  9., 11.,  8., 10., 12.,
#        20., 19., 15., 13., 16., 24., 32., 17., 14., 21., 50., 18.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                        id    host_id host_name  host_since  \
# 10               49043337  202801114     Guido  2018-07-16
# 11                2943450     114555     Annet  2010-04-27
# 49     663097266091425758  210632612     Scott  2018-08-20
# 52     840053916898021945  211899887  Mauricio  2018-08-26
# 55     820495083192405533  497709887  Lourdson  2023-01-24
# ...                   ...        ...       ...         ...
# 42337            13032893   54354899    Regina  2016-01-12
# 42343            51760564   26196192       Jon  2015-01-16
# 42354            14466452   70829936  Michelle  2016-05-07
# 42411            20890567  147106089  Hometang  2017-08-21
# 42439            33661740  253700089    Sylvie  2019-04-06
#
#                    host_location  host_response_time host_response_rate  \
# 10     California, United States      within an hour               100%
# 11                    Lomita, CA      within an hour               100%
# 49          Huntington Beach, CA  a few days or more                 0%
# 52                Long Beach, CA      within an hour                89%
# 55                           NaN      within an hour               100%
# ...                          ...                 ...                ...
# 42337            Los Angeles, CA      within an hour               100%
# 42343            Los Angeles, CA      within an hour               100%
# 42354            Los Angeles, CA      within an hour               100%
# 42411            Los Angeles, CA      within an hour               100%
# 42439               Whittier, CA      within an hour               100%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 10                    100%                 f                  2.0  ...
# 11                     97%                 t                  1.0  ...
# 49                    100%                 f                  1.0  ...
# 52                     98%                 f                  5.0  ...
# 55                     NaN                 f                  1.0  ...
# ...                    ...               ...                  ...  ...
# 42337                 100%                 t                  2.0  ...
# 42343                 100%                 t                  3.0  ...
# 42354                  89%                 f                  1.0  ...
# 42411                  97%                 t                  6.0  ...
# 42439                 100%                 t                  1.0  ...
#
#        bedrooms beds                                          amenities  \
# 10          NaN  NaN  ["Smoking allowed", "Wifi", "Pets allowed", "K...
# 11          NaN  2.0  ["Ethernet connection", "Mini fridge", "Free d...
# 49          NaN  1.0                   ["Security cameras on property"]
# 52          NaN  1.0  ["Wifi", "Dedicated workspace", "Air condition...
# 55          NaN  1.0                                                 []
# ...         ...  ...                                                ...
# 42337       NaN  2.0  ["Ethernet connection", "Fast wifi \u2013 329 ...
# 42343       NaN  1.0  ["Smoke alarm", "Freezer", "Shampoo", "Wine gl...
# 42354       NaN  4.0  ["Central heating", "Smoke alarm", "Freezer", ...
# 42411       NaN  2.0  ["Smoke alarm", "Bread maker", "Shampoo", "Kit...
# 42439       NaN  2.0  ["Ethernet connection", "Coffee maker: drip co...
#
#         price number_of_reviews review_scores_value  \
# 10     1000.0                 0                 NaN
# 11      195.0               185                4.94
# 49       35.0                 0                 NaN
# 52       94.0                 0                 NaN
# 55       74.0                 0                 NaN
# ...       ...               ...                 ...
# 42337   160.0               368                4.78
# 42343   200.0                 5                4.60
# 42354   116.0               182                4.97
# 42411   162.0               147                4.75
# 42439   115.0               113                4.98
#
#        calculated_host_listings_count  amenities_count         city  num_bath
# 10                                  1                5  Los Angeles       0.5
# 11                                  1               77  Los Angeles       1.0
# 49                                  1                1  Los Angeles       0.0
# 52                                  5                5  Los Angeles       1.0
# 55                                  1                0  Los Angeles       1.0
# ...                               ...              ...          ...       ...
# 42337                               1               50  Los Angeles       1.0
# 42343                               3               49  Los Angeles       1.0
# 42354                               1               40  Los Angeles       1.0
# 42411                               4               40  Los Angeles       1.0
# 42439                               1               61  Los Angeles       1.0
#
# [3605 rows x 31 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                        id    host_id             host_name  host_since  \
# 10               49043337  202801114                 Guido  2018-07-16
# 110              48865514  134267499              StayCozy  2017-06-09
# 141              42517485  106980640                  Rose  2016-12-12
# 153              42866036   34666172                 Maria  2015-05-31
# 156              45195301  343535252                     J  2020-04-09
# ...                   ...        ...                   ...         ...
# 42104            16393418   94384746                Justin  2016-09-09
# 42336            49567342  253105222  Sonder (Los Angeles)  2019-04-03
# 42379            44999114  102870708                Joseph  2016-11-07
# 42390  807897329584457702  488672310                  Juan  2022-11-21
# 42440  749972739436606060  485807541                Blanca  2022-10-31
#
#                    host_location host_response_time host_response_rate  \
# 10     California, United States     within an hour               100%
# 110    California, United States     within an hour                96%
# 141              Los Angeles, CA     within an hour               100%
# 153                 Whittier, CA                NaN                NaN
# 156             Sierra Madre, CA                NaN                NaN
# ...                          ...                ...                ...
# 42104         West Hollywood, CA     within an hour               100%
# 42336            Los Angeles, CA     within an hour                99%
# 42379                        NaN     within an hour               100%
# 42390                        NaN     within an hour               100%
# 42440                        NaN     within an hour               100%
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 10                    100%                 f                  2.0  ...
# 110                    90%                 f                103.0  ...
# 141                    97%                 f                 21.0  ...
# 153                    NaN                 f                  7.0  ...
# 156                    NaN                 f                  1.0  ...
# ...                    ...               ...                  ...  ...
# 42104                 100%                 t                  3.0  ...
# 42336                  99%                 f                 45.0  ...
# 42379                  95%                 f                  5.0  ...
# 42390                 100%                 f                  2.0  ...
# 42440                 100%                 f                  3.0  ...
#
#        bedrooms beds                                          amenities  \
# 10          NaN  NaN  ["Smoking allowed", "Wifi", "Pets allowed", "K...
# 110         NaN  NaN  ["Hangers", "Wifi", "Carbon monoxide alarm", "...
# 141         1.0  NaN  ["Gym", "Smoke alarm", "Washer", "Shampoo", "K...
# 153         1.0  NaN  ["Carbon monoxide alarm", "Smoke alarm", "Lock...
# 156         NaN  NaN                                ["Smoking allowed"]
# ...         ...  ...                                                ...
# 42104       1.0  NaN  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...
# 42336       1.0  NaN  ["Bed linens", "Carbon monoxide alarm", "Smoke...
# 42379       1.0  NaN  ["Smoke alarm", "Paid dryer \u2013 In building...
# 42390       2.0  NaN  ["Central heating", "Smoke alarm", "Shampoo", ...
# 42440       3.0  NaN  ["Smoke alarm", "Washer", "Freezer", "Kitchen"...
#
#         price number_of_reviews review_scores_value  \
# 10     1000.0                 0                 NaN
# 110      65.0                 2                5.00
# 141      40.0                 6                5.00
# 153      33.0                 0                 NaN
# 156      51.0                 0                 NaN
# ...       ...               ...                 ...
# 42104   131.0                45                4.91
# 42336   291.0                 9                3.78
# 42379   136.0                 9                4.44
# 42390   232.0                 3                5.00
# 42440   296.0                 7                4.57
#
#        calculated_host_listings_count  amenities_count         city  num_bath
# 10                                  1                5  Los Angeles       0.5
# 110                               102               14  Los Angeles       1.0
# 141                                17               23  Los Angeles       1.0
# 153                                 4                9  Los Angeles       1.0
# 156                                 1                1  Los Angeles       0.0
# ...                               ...              ...          ...       ...
# 42104                               3               16  Los Angeles       1.0
# 42336                              30               18  Los Angeles       1.0
# 42379                               5               33  Los Angeles       1.0
# 42390                               2               29  Los Angeles       2.0
# 42440                               3               39  Los Angeles       3.0
#
# [583 rows x 31 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[updated_df['id'].isin(empty_bathrooms_text_ids)]
# Out:
#                        id    host_id                   host_name  host_since  \
# 359              47159462    2288402                          Ug  2012-05-04
# 1084             39705326  271698446                      Robert  2019-06-27
# 1140              1053404    5799839                     Barbara  2013-04-06
# 2939             52989672  428985128                     Xueping  2021-10-25
# 4142   708127514159735039  446995407                       Vicky  2022-02-26
# 8247   732599207114852422  446995407                       Vicky  2022-02-26
# 9045             51382976    3097566                       Frist  2012-07-30
# 10528              405296    2019725                      Larisa  2012-03-27
# 11893            45383114   69113169                         Olt  2016-04-26
# 12978               69015     341419                      Sharda  2011-01-09
# 14628            40117496   10055368                       Nazak  2013-11-16
# 15445            19870804  128635026             Broadlind Hotel  2017-05-03
# 16343              688583    3515462                      Walter  2012-09-09
# 16769            48904220    7760022                    Jennifer  2013-07-27
# 17587            29441778   58056241                         Jad  2016-02-09
# 19222            28079484   58056241                         Jad  2016-02-09
# 21737            54117350    3248466                      Monica  2012-08-13
# 21840             2146019   10954840                      Nicole  2014-01-01
# 22936              241906    1242157                   Catherine  2011-10-03
# 23809            49557957  136538649                       Hanna  2017-06-23
# 24690            49599757  136203024                       Kelly  2017-06-21
# 26486            52335811    3097566                       Frist  2012-07-30
# 27638            53547177    1511137                    Emma.  V  2011-12-16
# 29547               79832      28569                      Robert  2009-07-29
# 34629            48273586   89737443                      Rafael  2016-08-13
# 38977            19801464  131471979                    Jennifer  2017-05-22
# 39993            24221825  178480382  Avalon Hotel Beverly Hills  2018-03-14
#
#            host_location  host_response_time host_response_rate  \
# 359      Los Angeles, CA                 NaN                NaN
# 1084     Los Angeles, CA                 NaN                NaN
# 1140     Los Angeles, CA                 NaN                NaN
# 2939                 NaN                 NaN                NaN
# 4142                 NaN      within an hour               100%
# 8247                 NaN      within an hour               100%
# 9045     Los Angeles, CA      within an hour                98%
# 10528    Los Angeles, CA        within a day               100%
# 11893    Los Angeles, CA                 NaN                NaN
# 12978     Chennai, India                 NaN                NaN
# 14628  Beverly Hills, CA                 NaN                NaN
# 15445     Long Beach, CA      within an hour               100%
# 16343    Los Angeles, CA  within a few hours               100%
# 16769    Los Angeles, CA                 NaN                NaN
# 17587  Beverly Hills, CA                 NaN                NaN
# 19222  Beverly Hills, CA                 NaN                NaN
# 21737    Los Angeles, CA  within a few hours               100%
# 21840    Los Angeles, CA                 NaN                NaN
# 22936    Los Angeles, CA                 NaN                NaN
# 23809                NaN                 NaN                NaN
# 24690      Inglewood, CA                 NaN                NaN
# 26486    Los Angeles, CA      within an hour                98%
# 27638  Laguna Niguel, CA      within an hour               100%
# 29547    Los Angeles, CA                 NaN                NaN
# 34629         Downey, CA  within a few hours               100%
# 38977    Los Angeles, CA                 NaN                NaN
# 39993  Beverly Hills, CA                 NaN                NaN
#
#       host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 359                    NaN                 f                  2.0  ...
# 1084                   NaN                 f                  1.0  ...
# 1140                   NaN                 f                  1.0  ...
# 2939                   NaN                 f                  2.0  ...
# 4142                  100%                 f                  6.0  ...
# 8247                  100%                 f                  6.0  ...
# 9045                   80%                 f                 43.0  ...
# 10528                  50%                 f                  1.0  ...
# 11893                  NaN                 f                  1.0  ...
# 12978                  NaN                 f                  1.0  ...
# 14628                  NaN                 f                  1.0  ...
# 15445                  98%                 f                 20.0  ...
# 16343                  95%                 t                  1.0  ...
# 16769                  NaN                 f                  1.0  ...
# 17587                  NaN                 f                  8.0  ...
# 19222                  NaN                 f                  8.0  ...
# 21737                 100%                 f                  1.0  ...
# 21840                  NaN                 f                  1.0  ...
# 22936                  NaN                 f                  1.0  ...
# 23809                  NaN                 f                  3.0  ...
# 24690                   0%                 f                  1.0  ...
# 26486                  80%                 f                 43.0  ...
# 27638                  98%                 f                 23.0  ...
# 29547                  NaN                 f                  1.0  ...
# 34629                  91%                 t                  2.0  ...
# 38977                  NaN                 f                  3.0  ...
# 39993                 100%                 f                  3.0  ...
#
#        bedrooms beds                                          amenities  \
# 359         1.0  1.0  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...
# 1084        1.0  1.0          ["Hangers", "Essentials", "Pets allowed"]
# 1140        1.0  1.0  ["TV with standard cable", "Hot tub", "Wifi", ...
# 2939        1.0  1.0  ["Smoke alarm", "Shampoo", "Kitchen", "Hair dr...
# 4142        1.0  1.0  ["Central heating", "Smoke alarm", "Washer", "...
# 8247        1.0  1.0  ["Wifi", "Indoor fireplace", "Carbon monoxide ...
# 9045        1.0  2.0  ["Smoke alarm", "Washer", "Shampoo", "Hair dry...
# 10528       1.0  1.0  ["TV with standard cable", "Hot tub", "Wifi", ...
# 11893       1.0  1.0  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...
# 12978       1.0  1.0                   ["Air conditioning", "Elevator"]
# 14628       1.0  1.0  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...
# 15445       2.0  2.0  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...
# 16343       1.0  1.0  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...
# 16769       1.0  1.0  ["Indoor fireplace", "Carbon monoxide alarm", ...
# 17587       2.0  4.0  ["Ethernet connection", "Gym", "Smoke alarm", ...
# 19222       2.0  4.0  ["Ethernet connection", "Gym", "Baby bath", "W...
# 21737       1.0  1.0  ["Smoke alarm", "82\" HDTV with Netflix, Amazo...
# 21840       1.0  1.0                                                 []
# 22936       1.0  1.0                                                 []
# 23809       1.0  1.0  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...
# 24690       1.0  1.0  ["Hot tub", "Wifi", "Carbon monoxide alarm", "...
# 26486       1.0  1.0  ["Smoke alarm", "Washer", "Shampoo", "Kitchen"...
# 27638       1.0  1.0  ["Ethernet connection", "Smoke alarm", "Shampo...
# 29547       1.0  1.0  ["Bed linens", "TV with standard cable", "Wifi...
# 34629       1.0  1.0  ["Mini fridge", "Smoke alarm", "Washer", "Free...
# 38977       2.0  2.0  ["Hot tub", "Wifi", "Indoor fireplace", "Gym",...
# 39993       1.0  2.0  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...
#
#        price number_of_reviews review_scores_value  \
# 359    240.0                 0                 NaN
# 1084    40.0                 1                1.00
# 1140   115.0                 0                 NaN
# 2939   120.0                 1                1.00
# 4142    99.0                16                4.94
# 8247    99.0                 3                4.67
# 9045    65.0                 0                 NaN
# 10528   89.0                32                4.74
# 11893  145.0                 0                 NaN
# 12978  901.0                 0                 NaN
# 14628  150.0                 1                 NaN
# 15445  446.0                38                4.74
# 16343   95.0               162                4.92
# 16769  184.0                 0                 NaN
# 17587  199.0                29                4.18
# 19222  198.0                17                4.44
# 21737  904.0                 4                5.00
# 21840  125.0                 0                 NaN
# 22936  200.0                 0                 NaN
# 23809   50.0                 0                 NaN
# 24690   95.0                 0                 NaN
# 26486   69.0                 1                4.00
# 27638   55.0                 3                5.00
# 29547  110.0               484                4.91
# 34629   70.0                 7                5.00
# 38977  225.0                 0                 NaN
# 39993  949.0                 0                 NaN
#
#        calculated_host_listings_count  amenities_count         city  num_bath
# 359                                 2               12  Los Angeles       1.0
# 1084                                1                3  Los Angeles       1.0
# 1140                                1               12  Los Angeles       1.0
# 2939                                2               27  Los Angeles       1.0
# 4142                                6               33  Los Angeles       1.0
# 8247                                6               11  Los Angeles       1.0
# 9045                               38               33  Los Angeles       1.0
# 10528                               1               10  Los Angeles       1.0
# 11893                               1               29  Los Angeles       1.0
# 12978                               1                2  Los Angeles       1.0
# 14628                               1               19  Los Angeles       1.0
# 15445                              20               33  Los Angeles       2.0
# 16343                               1               26  Los Angeles       1.0
# 16769                               1               10  Los Angeles       0.5
# 17587                               8               50  Los Angeles       2.0
# 19222                               8               51  Los Angeles       2.0
# 21737                               1               22  Los Angeles       1.0
# 21840                               1                0  Los Angeles       1.0
# 22936                               1                0  Los Angeles       1.0
# 23809                               3               18  Los Angeles       1.0
# 24690                               1               20  Los Angeles       0.5
# 26486                              38               26  Los Angeles       1.0
# 27638                              23               38  Los Angeles       1.0
# 29547                               1               16  Los Angeles       1.0
# 34629                               2               36  Los Angeles       1.0
# 38977                               3               20  Los Angeles       2.0
# 39993                               3               16  Los Angeles       1.0
#
# [27 rows x 31 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 3.,  1.,  4.,  2.,  5.,  7.,  6.,  0.,  9., 11.,  8., 10., 12.,
#        20., 19., 15., 13., 16., 24., 32., 17., 14., 21., 50., 18.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 4.,  1.,  3.,  2.,  5.,  0.,  6.,  7.,  8., 11.,  9., 12., 13.,
#        10., 24., 23., 16.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 2 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2022-12-08', '2022-02-12', '2015-08-17', ..., '2012-08-16',
#        '2011-03-18', '2023-01-16'], dtype=object)

# %%
updated_df[updated_df['host_since'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 8453 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 8453

# %%
updated_df['host_location'].unique()
# Out:
# array(['unknown', 'Rancho Palos Verdes, CA', 'Malibu, CA',
#        'Los Angeles, CA', 'Chino, CA', 'Lake Los Angeles, CA',
#        'Torrance, CA', 'California, United States', 'Lomita, CA',
#        'Whittier, CA', 'Lancaster, CA', 'Walnut, CA', 'Russ Place, CA',
#        'Santa Clarita, CA', 'San Francisco, CA', 'Marina del Rey, CA',
#        'Rowland Heights, CA', 'Toronto, Canada', 'La Mirada, CA',
#        'Carson, CA', 'Long Beach, CA', 'Hermosa Beach, CA',
#        'Pasadena, CA', 'Huntington Beach, CA', 'Hallandale Beach, FL',
#        'Calabasas, CA', 'Jackson, MS', 'Quartz Hill, CA', 'Monrovia, CA',
#        'Arcadia, CA', 'Redondo Beach, CA', 'Monterey Park, CA',
#        'Fullerton, CA', 'Agoura Hills, CA', 'Portland, OR',
#        'Lawndale, CA', 'Gardena, CA', 'Beverly Hills, CA', 'Altadena, CA',
#        'Pomona, CA', 'West Hollywood, CA', 'Istanbul, Turkey',
#        'El Segundo, CA', 'New York, NY', 'Sierra Madre, CA',
#        'Glendora, CA', 'Agua Dulce, CA', 'Costa Mesa, CA',
#        'San Gabriel, CA', 'Temecula, CA', 'West Rancho Dominguez, CA',
#        'Denver, CO', 'Fort Lauderdale, FL', 'Fremont, CA',
#        'Diamond Bar, CA', 'Las Vegas, NV', 'Miami Beach, FL',
#        'Austin, TX', 'Sacramento, CA', 'Plymouth Meeting, PA',
#        'Nassau, Bahamas', 'Pico Rivera, CA', 'Downey, CA', 'Glendale, CA',
#        'Rosemead, CA', 'Chino Hills, CA', 'West Covina, CA',
#        'Hacienda Heights, CA', 'Bossier City, LA', 'Hidden Hills, CA',
#        'Hawthorne, CA', 'İstanbul, Turkey', 'Westlake Village, CA',
#        'Culver City, CA', 'Palos Verdes Estates, CA', 'Avalon, CA',
#        'Temple City, CA', 'Santa Monica, CA', 'Cerritos, CA',
#        'Tustin, CA', 'La Habra, CA', 'Pittsburgh, PA',
#        'Florida, United States', 'Compton, CA', 'Claremont, CA',
#        'San Diego, CA', 'Thousand Oaks, CA', 'Norwalk, CA', 'Artesia, CA',
#        'La Puente, CA', 'Thailand', 'Corona, CA', 'Hamar, Norway',
#        'Fort Worth, TX', 'Bellflower, CA', 'Rolling Hills, CA',
#        'Buena Park, CA', 'Laguna Hills, CA', 'Newport Beach, CA',
#        'Peoria, AZ', 'El Monte, CA', 'Inglewood, CA', 'Florence, KY',
#        'San Dimas, CA', 'St Louis, MO', 'Orange, CA',
#        'Tel Aviv-Yafo, Israel', 'Norfolk, VA', 'Topanga, CA',
#        'Mountain View, CA', 'Brentwood, CA', 'Shingle Springs, CA',
#        'Coudersport, PA', 'Alhambra, CA', 'Leona Valley, CA',
#        'Covina, CA', 'South Pasadena, CA', 'San Fernando, CA',
#        'Santa Cruz, CA', 'Allentown, PA', 'Guadalajara, Mexico',
#        'London, United Kingdom', 'Sun Valley, ID', 'Irvine, CA',
#        'Phoenix, AZ', 'San Juan Capistrano, CA', 'Lynwood, CA',
#        'Stockholm, Sweden', 'Woodland, CA', 'England, United Kingdom',
#        'California', 'Berlin, Germany', 'Cathedral City, CA',
#        'Palmdale, CA', 'South Gate, CA', 'Yerevan, Armenia',
#        'United States', 'Arizona, United States', 'Azusa, CA',
#        'Antelope, CA', 'Turin, Italy', 'Lawrence, KS', 'Paradise, CA',
#        'Manhattan Beach, CA', 'Brampton, Canada', 'Islandia, NY',
#        'Mancos, CO', 'Paris, France', 'New York, United States',
#        'Duarte, CA', 'Atlanta, GA', 'Detroit, MI', 'San Luis Obispo, CA',
#        'Baldwin Park, CA', 'Lake Hughes, CA',
#        'Yeonggwang-gun, South Korea', 'Rancho Mirage, CA',
#        'Belvedere, CA', 'Winter Garden, FL', 'Tahoe City, CA',
#        'Lexington, MA', 'Miami, FL', 'Madrid, Spain', 'Bellevue, WA',
#        'Rio de Janeiro, Brazil', 'Fall Creek, OR', 'Riverside, CA',
#        'New Rochelle, NY', 'Hawaii, United States', 'Chicago, IL',
#        'Murrieta, CA', 'Sarasota, FL', 'India', 'Anaheim, CA',
#        'Corpus Christi, TX', 'Missouri City, TX', 'Cambria, CA',
#        'Cypress, CA', 'South El Monte, CA', 'Santa Clara, CA',
#        'Benicia, CA', 'Pleasanton, CA', 'La Verne, CA', 'Rockville, MD',
#        'Birmingham, AL', 'Paramount, CA', 'California City, CA',
#        'La Cañada Flintridge, CA', 'Brea, CA', 'Chapel Hill, NC',
#        'Sydney, Australia', 'Sofia, Bulgaria', 'Athens, Greece',
#        'Daytona Beach, FL', 'Greenwich, CT', 'Santa Barbara, CA',
#        'Seattle, WA', 'Yorba Linda, CA', 'Mexico City, Mexico',
#        'Rialto, CA', 'Jacksonville, FL', 'Lisbon, Portugal',
#        'Portola Valley, CA', 'Mill Valley, CA', 'Cleveland, OH',
#        'Elizabeth Lake, CA', 'St. Louis, MO', 'Washington, DC',
#        'Santa Ana, CA', 'Newport News, VA', 'Puebla, Mexico',
#        'Morristown, NJ', 'Great Neck Plaza, NY', 'Columbia, SC',
#        'Napa, CA', 'San Marino, CA', 'Alafaya, FL', 'Del Sur, CA',
#        'Rancho Cucamonga, CA', 'Homeland, CA', 'Darby, PA',
#        'Cincinnati, OH', 'Charlottesville, VA', 'Tacoma, WA',
#        'Burbank, CA', 'Bend, OR', 'Hawthorne, NJ', 'Mableton, GA',
#        'Haleiwa, HI', 'Irwindale, CA', 'Hong Kong', 'Cambridge, MA',
#        'Oak Park, IL', 'New Orleans, LA', 'Signal Hill, CA',
#        'St. George, UT', 'Hingham, MA', 'New Territories, Hong Kong',
#        'City of Industry, CA', 'Los Angeles County, CA', 'Jonesboro, GA',
#        'Pearland, TX', 'Laguna Beach, CA', 'Ontario, CA',
#        'Springfield, CA', 'Emeryville, CA', 'Honolulu, HI',
#        'Big Bear Lake, CA', 'Windermere, FL', 'Kathmandu, Nepal',
#        'Lithonia, GA', 'Virginia Beach, VA', 'Wexford, PA',
#        'Thunder Bay, Canada', 'Reims, France', 'Palm Springs, CA',
#        'Ann Arbor, MI', 'Pequannock Township, NJ', 'Knoxville, TN',
#        'Nevada, United States', 'Beveridge, Australia',
#        'Santiago Metropolitan Region, Chile', 'Montecito, CA',
#        'Aventura, FL', 'Acton, CA', 'Khabarovsk, Russia', 'Baltimore, MD',
#        'Lake Charles, LA', 'Dallas, TX', 'Wake Forest, NC',
#        'Jurupa Valley, CA', 'Dayton, OH', 'Salt Lake City, UT',
#        'Charlotte, NC', 'Rancho Santa Margarita, CA', 'Commerce City, CO',
#        'Traverse City, MI', 'Oxnard, CA', 'Morganton, NC',
#        'Chesterfield, MO', 'Tuxedo Park, NY', 'Laos', 'San Jose, CA',
#        'Sausalito, CA', 'Saint Anton am Arlberg, Austria', 'Lakewood, CA',
#        'Nashville, TN', 'Scottsdale, AZ', 'Ventura, CA', 'Frisco, TX',
#        'Moreno Valley, CA', 'Tempe, AZ', 'Oceanside, CA', 'Boston, MA',
#        'Ojai, CA', 'Carlsbad, CA', 'Upland, CA', 'Tucson, AZ',
#        'Hyattsville, MD', 'Ypsilanti, MI',
#        'San Miguel de Allende, Mexico', 'Happy Valley, OR', 'Tigard, OR',
#        'Princeton, NJ', 'Vancouver, Canada', 'Elk Grove, CA',
#        'Weehawken, NJ', 'Litchfield Park, AZ', 'Chandler, AZ',
#        'Peoria, IL', 'La Crescenta-Montrose, CA',
#        'Rolling Hills Estates, CA', 'Bogotá, Colombia',
#        'Mission Viejo, CA', 'Pismo Beach, CA', 'Cambridge Springs, PA',
#        'Memphis, TN', 'Bakersfield, CA', 'Agde, France',
#        'East Los Angeles, CA', 'Tualatin, OR', 'WINNETKA, CA',
#        'Fresno, CA', 'Dubai, United Arab Emirates', 'Barbados',
#        'Stevenson Ranch, CA', 'Aspen, CO', 'Tallahassee, FL',
#        'New Canaan, CT', 'San Antonio, TX', 'Parker, CO', 'Fontana, CA',
#        'Montebello, CA', 'Stone Mountain, GA', 'Gibsons, Canada',
#        'Fairbanks, AK', 'Sandy, UT', 'Long Grove, IL',
#        'Colorado Springs, CO', 'Palm Desert, CA', 'Lafayette, CA',
#        'United Arab Emirates', 'Reno, NV', 'Little Falls, NJ',
#        'New South Wales, Australia', 'Oranjestad, Aruba',
#        'São Paulo, Brazil', 'New Zealand', 'Del Aire, CA',
#        'San Mateo, CA', 'Amsterdam, Netherlands', 'Simi Valley, CA',
#        'El Sobrante, CA', 'New Taipei City, Taiwan', 'Universal City, CA',
#        'Carolina, Puerto Rico', 'Reykjavík, Iceland',
#        'Seoul, South Korea', 'Budapest, Hungary', 'Monaco', 'Venice, CA',
#        'Walnut Creek, CA', 'Placentia, CA', 'Camarillo, CA', 'Utica, NY',
#        'Philadelphia, PA', 'Sebastopol, CA', 'Hackensack, NJ',
#        'Minneapolis, MN', 'Conwy, United Kingdom', 'Berkeley, CA',
#        'Meito Ward, Japan', 'Mississauga, Canada', 'Santa Fe, NM',
#        'Venice, Italy', 'Taiwan Province, Taiwan', 'Oakland, CA',
#        'Castaic, CA', 'Konárovice, Czechia', 'Kyiv, Ukraine',
#        'United Kingdom', 'Tunis, Tunisia',
#        'Autonomous City of Buenos Aires, Argentina', 'Bloomington, IN',
#        'Industry, CA', 'Ocean Park, WA', 'Colfax, CA',
#        'La Habra Heights, CA', 'Hollywood, FL', 'Verona, Italy',
#        'Moab, UT', 'Saint Paul, MN', 'Chesapeake, VA', 'Montreal, Canada',
#        'San Ramon, CA', 'Barrie, Canada', 'Bethesda, MD',
#        'Mammoth Lakes, CA', 'Dearborn Heights, MI', 'Jones, OK',
#        'Bell Gardens, CA', 'Juniper Hills, CA', 'Hawaiian Gardens, CA',
#        'Bell, CA', 'Chennai, India', 'Commerce, CA', 'Burnaby, Canada',
#        'Smyrna, TN', 'Albany, CA', 'Zhuzhou, China', 'Athens, LA',
#        'Huntington Park, CA', 'Auckland, New Zealand', 'Houston, TX',
#        'Woodside, CA', 'Bloomfield Hills, MI', 'Taos, NM',
#        'Kaohsiung City, Taiwan', 'Billings, MT',
#        'Maroochydore, Australia', 'Prague, Czechia', 'Wrightwood, CA',
#        'Soquel, CA', 'Santa Fe Springs, CA', 'China', 'Odessa, TX',
#        'Germantown, MD', 'Steamboat Springs, CO', 'Montclair, NJ',
#        'Cottesloe, Australia', 'Castellón de la Plana, Spain',
#        'East Hampton, NY', 'Even Yehuda, Israel', 'Orland Park, IL',
#        'Morocco, IN', 'Vitoria-Gasteiz, Spain', 'Clarksville, TN',
#        'Morristown, TN', 'Columbia, MD', 'Alpine, NJ', 'Schilde, Belgium',
#        'Maywood, CA', 'Split, Croatia', 'Norman, OK', 'San Clemente, CA',
#        'Anchorage, AK', 'Yardley, PA', 'Overland Park, KS',
#        'Southfield, MI', 'Lyme, CT', 'Tarragona, Spain',
#        'Palos Verdes Peninsula, CA', 'North Miami Beach, FL',
#        'Boulder, CO', 'Palo Alto, CA', 'Moscow, Russia',
#        'Maryland, United States', 'South Jordan, UT', 'Plantation, FL',
#        'Vienna, VA', 'Gothenburg, Sweden', 'Costa Rica',
#        'Bali, Indonesia', 'Morro Bay, CA', 'Vista, CA', 'Clearwater, FL',
#        'Powell, WY', 'Boca Raton, FL', 'Boise, ID',
#        'Sterling Heights, MI', 'Tokyo, Japan', 'San Juan, Puerto Rico',
#        'Milan, Italy', 'King of Prussia, PA', 'Vaughan, Canada',
#        'Stuart, FL', 'Providence, RI', 'San Francisco, Mexico',
#        'Orlando, FL', 'Julian, CA', 'Lincoln City, OR',
#        'Melrose Park, IL', 'West Sacramento, CA', 'Addis Ababa, Ethiopia',
#        'Terra Alta, WV', 'View Park-Windsor Hills, CA',
#        'San Bernardino, CA', 'Park City, UT', 'San José, Costa Rica',
#        'Millersville, MD', 'West Tisbury, MA', 'Gilroy, CA',
#        'Victoria, Australia', 'Ahmedabad, India', 'Greenville, SC',
#        'La Crosse, WI', 'Exeter, NH', 'Macon, GA', 'Seal Beach, CA',
#        'Bay Islands Department, Honduras', 'Bron, France',
#        'Pennsylvania, United States', 'Columbus, OH', 'Charleston, SC',
#        'Las Vegas, NM', 'Fall River, MA', 'Garden Grove, CA',
#        'Westwood, CA', 'Santo Domingo, Dominican Republic',
#        'Idaho, United States', 'Arlington Heights, IL',
#        'Peachtree City, GA', 'Québec, Canada', 'Millbury, OH',
#        'Redmond, WA', 'East Lansdowne, PA', 'Copenhagen, Denmark',
#        'Milwaukee, WI', 'Tampa, FL', 'City Terrace, CA', 'Kihei, HI',
#        'Connecticut, United States', 'Eugene, OR', 'South Africa',
#        'Nacogdoches, TX', 'Monte Nido, CA', 'Montana, United States',
#        'Henderson, NV', 'Val Verde, CA', 'Ellicott City, MD',
#        'Vancouver, WA', 'Banning, CA', 'Charlestown, RI',
#        'Fountain Valley, CA', 'Rome, Italy', 'Joshua Tree, CA',
#        'Winter Park, FL', 'Douglasville, GA', 'Foster City, CA',
#        'Bangladesh', 'Windsor, Canada', 'Puerto Rico', 'Bothell, WA',
#        'White Plains, NY', 'Kirkland, WA', 'Florham Park, NJ',
#        'Niceville, FL', 'Auburn, CA', 'Samara, Russia', 'Trenton, NJ',
#        'Solana Beach, CA', 'Hamburg, Germany', 'Lake Arrowhead, CA',
#        'Little Rock, AR', 'Palos Heights, IL', 'Willow Creek, CA',
#        'Del Rey, CA', 'Franklinton, LA', 'Lindenwold, NJ',
#        'Mount Prospect, IL', 'Plano, TX', 'Lennox, CA', 'Henrico, VA',
#        'Porterville, CA', 'Worcester, MA', 'New Jersey, United States',
#        'Jersey City, NJ', 'Fountain Hills, AZ', 'Dublin, Ireland',
#        'Taipei City, Taiwan', 'Italy', 'Laughlin, NV', 'Bardstown, KY',
#        'Valyermo, CA', 'Laguna Niguel, CA', 'Colonie, NY',
#        'Los Alamos, CA', 'Wofford Heights, CA',
#        'Tennessee, United States', 'Miranda, CA', 'Berea, OH',
#        'La Palma, CA', 'Indio, CA', 'Gold Coast, Australia',
#        'Arlington, VA', 'Massapequa Park, NY', 'Alexandria, VA',
#        'Seongnam-si, South Korea', 'Newark, CA', 'Perris, CA',
#        'Massachusetts, United States', 'Guilford, VT', 'Bowie, MD',
#        'Ladera Heights, CA', 'South Portland, ME', 'Clovis, CA',
#        'Wilson, WY', 'Mumbai, India', 'Maine, United States',
#        'Melbourne, Australia', 'Pomona, NY', 'Leawood, KS',
#        'Fort Collins, CO', 'Pascagoula, MS', 'East Lansing, MI',
#        'Madison, WI', 'Yucca Valley, CA', 'San Marino',
#        'Walnut Grove, CA', 'Sonoma, CA', 'Folsom, CA',
#        'Porto District, Portugal', 'Los Alamitos, CA', 'Gävle, Sweden',
#        'Huntsville, AL', 'Sunnyvale, CA', 'Rutland, VT', 'McLean, VA',
#        'New Castle, DE', 'Naperville, IL', 'Dakar, Senegal',
#        'Maroubra, Australia', "Saint Julian's, Malta", 'Dana Point, CA',
#        'Del Monte Forest, CA', 'Highland Park, CA', 'Truckee, CA',
#        'Zürich, Switzerland', 'Danville, CA', 'New Hope, PA',
#        'Monterey, CA', 'Markham, Canada', 'Savannah, GA',
#        'St Petersburg, FL', 'LaSalle, IL', 'Viet Tri, Vietnam',
#        'De Soto, MO', 'Northampton, MA', 'Sayulita, Mexico',
#        'Indianapolis, IN', 'Delray Beach, FL', 'Sleepy Hollow, NY',
#        'Accra, Ghana', 'Lake Elsinore, CA', 'Menlo Park, CA',
#        'Bozeman, MT', 'Laredo, TX', 'Beachwood, OH', 'Richmond, VA',
#        'Davis, CA', 'Haddonfield, NJ', 'Solvang, CA', 'Yakima, WA',
#        'Cupertino, CA', 'Highland Park, NJ', 'Lompoc, CA',
#        'Naucalpan de Juárez, Mexico', 'South Lake Tahoe, CA',
#        'Smithfield, NC', 'Santa Fe, TN', 'Calamvale, Australia',
#        'Elkhart, IN', 'Red Hill, Australia', 'Evanston, IL', 'Moraga, CA',
#        'Decatur, GA', 'Sevierville, TN', 'Dallas, GA', 'Bushnell, FL',
#        'El Cajon, CA', 'Munich, Germany', 'Nelson, Canada', 'Pawlet, VT',
#        'Argentina', 'Trieste, Italy', 'Mesa, AZ',
#        'Idyllwild-Pine Cove, CA', 'Kagel Canyon, CA',
#        'Brighton, Australia', 'Myrtle Beach, SC', 'Banten, Indonesia',
#        'Edmonton, Canada', 'Bellingham, WA', 'James Place, ID',
#        'Pensacola, FL', 'Trumbull, CT', 'Cordova Bay, Canada',
#        'Clarksburg, MO', 'Amalapuram, India', 'Littlerock, CA',
#        'Düsseldorf, Germany', 'Pinole, CA', 'Princeville, HI',
#        'Angels Camp, CA', 'Latina, Italy', 'Longview, WA', 'Portland, ME',
#        'Sherborn, MA', 'Fair Oaks, CA', 'Beijing, China', 'Dothan, AL',
#        'Toledo, OH', 'Easton, PA', 'Los Gatos, CA', 'Chisinau, Moldova',
#        'Cairo, Egypt', 'Wuhan, China', 'Kansas City, MO',
#        'Middletown, CT', 'Australia', 'Lyons, NY', 'Three Rivers, CA',
#        'Virginia, United States', 'Richmond, CA', 'Wailea-Makena, HI',
#        'Syracuse, NY', 'Los Altos, CA', 'Roselle, IL', 'New Bedford, MA',
#        'Sioux Falls, SD', 'Wellesley, MA', 'Green Valley, CA',
#        'Los Olivos, CA', 'Calgary, Canada', 'North Hollywood, CA',
#        'Tobyhanna, PA', 'Falmouth, MA', 'Los Angeles', 'East Point, GA',
#        'Boerne, TX', 'Franklin, MA', 'Murcia, Spain', 'Bochum, Germany',
#        'Nueva Italia de Ruiz, Mexico', 'Cannes, France', 'Colton, CA',
#        'Benbrook, TX', 'Bentonville, AR', 'Baton Rouge, LA', 'Houma, LA',
#        'Earth City, MO', 'Brescia, Italy', 'Topanga Canyon, CA',
#        'Northbrook, IL', 'Cheshire, CT', 'Mérida, Mexico',
#        'Discovery Bay, CA', 'Rohnert Park, CA',
#        'Saint Peter Port, Guernsey', 'Rocklin, CA',
#        'British Columbia, Canada', 'Durham, NC', 'Reserve, LA',
#        'Montpelier, VT', 'Flower Mound, TX', 'Katy, TX', 'Jamaica',
#        'Suisun City, CA', 'Buenos Aires, Argentina',
#        'Ciales, Puerto Rico', 'Maryville, TN', 'Winston-Salem, NC',
#        'Treasure Island, FL', 'Weymouth, MA', 'Daly City, CA',
#        'Rogers, AR', 'Calumet, OK', 'Cave Creek, AZ',
#        'Medellín, Colombia', 'Hayward, CA', 'Pflugerville, TX',
#        'Stockton, CA', 'Victorville, CA', 'Branford, CT', 'Flossmoor, IL',
#        'Montclair, CA', 'Bass Lake, CA', 'Jeddah, Saudi Arabia',
#        'El Paso, TX', 'Finland', 'Morgantown, WV', 'Laurel, MD',
#        'Aliso Viejo, CA', 'Palmyra, ME', 'Jackson, WY', 'Parker, AZ',
#        'Lima, Peru', 'Chula Vista, CA', 'Mendocino, CA', 'Bolsena, Italy',
#        'Winchester, CA', 'Notre Dame, IN', 'Punta Mita, Mexico',
#        'Crestline, CA', 'Placerville, CA', 'Olds, Canada',
#        'San Pablo, CA', 'Nambe, NM', 'Amarillo, TX', 'Fallbrook, CA',
#        'Huntingdon, United Kingdom', 'State of Rio de Janeiro, Brazil'],
#       dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %%
updated_df[updated_df['host_location'] ==' ']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, amenities_count, city, num_bath]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 145 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 27983

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 2 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([1.000e+00, 4.000e+00, 1.500e+01, 3.000e+00, 2.000e+00, 3.600e+01,
#        4.500e+01, 1.200e+01, 1.900e+01, 5.000e+00, 3.500e+01, 6.000e+00,
#        8.000e+00, 2.400e+01, 1.300e+01, 5.000e+01, 1.700e+01, 9.000e+00,
#        6.500e+01, 6.070e+02, 4.000e+01, 5.500e+01, 2.500e+01, 5.800e+01,
#        1.030e+02, 7.000e+00, 1.000e+01, 1.005e+03, 2.000e+01, 1.400e+01,
#        6.650e+02, 6.800e+01, 2.900e+01, 5.600e+01, 2.100e+01, 1.290e+02,
#        6.600e+01, 6.000e+01, 1.430e+02, 7.000e+01, 7.740e+02, 5.100e+01,
#        4.800e+01, 3.300e+01, 6.610e+02, 5.400e+01, 2.690e+02, 1.100e+01,
#        4.300e+01, 2.200e+01, 2.800e+01, 5.900e+01, 1.600e+01, 3.800e+01,
#        3.900e+01, 2.300e+01, 2.700e+01, 2.631e+03, 4.784e+03, 8.900e+01,
#        1.510e+03, 9.600e+01, 9.400e+01, 1.150e+02, 5.700e+01, 1.730e+02,
#        3.400e+01, 4.600e+01, 3.000e+01, 3.700e+01, 2.600e+01, 1.800e+01,
#        7.990e+02, 7.700e+01, 2.072e+03, 6.400e+01, 3.286e+03, 2.040e+02,
#        4.200e+01, 7.200e+01, 3.100e+01, 7.300e+01, 8.000e+01, 4.400e+01,
#        1.360e+02, 1.120e+02, 5.200e+02, 4.100e+01, 6.300e+01, 1.349e+03,
#        2.890e+02, 1.040e+02, 3.700e+02, 5.200e+01, 1.530e+02, 6.700e+01,
#        5.300e+01, 1.110e+02, 4.900e+01, 2.900e+02, 8.500e+01, 1.720e+02,
#        4.700e+01, 9.000e+01, 3.200e+01, 9.100e+01, 5.600e+02, 3.820e+02,
#        3.870e+02, 1.680e+02, 6.200e+01, 1.900e+02, 1.000e+02, 7.500e+01,
#        0.000e+00, 2.970e+02, 7.100e+01, 4.840e+02, 1.650e+02, 6.900e+01,
#        1.090e+02])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 2 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([1.000e+00, 5.000e+00, 2.200e+01, 6.000e+00, 4.000e+00, 1.900e+01,
#        2.000e+00, 4.000e+01, 3.000e+00, 1.850e+02, 3.300e+01, 9.000e+00,
#        2.300e+01, 1.120e+02, 1.100e+01, 8.800e+01, 8.000e+00, 4.200e+01,
#        7.000e+00, 2.400e+01, 6.500e+01, 1.800e+01, 8.700e+01, 1.200e+01,
#        2.900e+01, 6.900e+01, 9.820e+02, 7.400e+01, 1.170e+02, 2.800e+01,
#        1.700e+02, 1.000e+01, 1.007e+03, 2.500e+01, 6.760e+02, 9.100e+01,
#        1.060e+02, 2.700e+01, 8.750e+02, 5.600e+01, 7.200e+01, 2.450e+02,
#        7.700e+01, 2.100e+01, 1.600e+01, 6.100e+01, 2.130e+02, 3.700e+01,
#        1.496e+03, 9.900e+01, 1.190e+02, 5.800e+01, 1.745e+03, 5.700e+01,
#        1.300e+01, 3.100e+02, 3.600e+01, 5.500e+01, 1.700e+01, 3.000e+01,
#        5.900e+01, 1.090e+02, 6.300e+01, 3.200e+01, 8.316e+03, 5.323e+03,
#        2.950e+02, 1.964e+03, 1.500e+01, 1.070e+02, 2.200e+02, 3.500e+01,
#        1.400e+01, 1.830e+02, 1.670e+02, 3.100e+01, 1.240e+02, 4.500e+01,
#        4.600e+01, 6.640e+02, 1.590e+02, 1.130e+02, 5.300e+01, 2.600e+01,
#        5.000e+01, 1.357e+03, 8.900e+01, 2.268e+03, 9.400e+01, 1.310e+02,
#        2.000e+01, 9.200e+01, 3.900e+01, 4.525e+03, 5.400e+01, 7.300e+01,
#        2.320e+02, 3.400e+01, 4.400e+01, 2.490e+02, 4.900e+01, 8.000e+01,
#        1.210e+02, 5.200e+01, 1.000e+02, 2.370e+02, 5.100e+01, 8.100e+01,
#        1.960e+02, 1.950e+02, 1.020e+02, 3.800e+01, 4.100e+01, 1.030e+02,
#        4.700e+01, 8.570e+02, 4.300e+01, 9.000e+01, 2.583e+03, 4.800e+01,
#        6.200e+01, 4.540e+02, 2.230e+02, 1.013e+03, 7.000e+01, 8.600e+01,
#        1.110e+02, 3.230e+02, 2.100e+02, 7.800e+01, 5.180e+02, 1.250e+02,
#        6.600e+01, 6.700e+01, 1.550e+02, 2.530e+02, 9.200e+02, 5.630e+02,
#        3.550e+02, 1.870e+02, 2.170e+02, 7.950e+02, 1.040e+02, 6.460e+02,
#        4.630e+02, 1.050e+02, 1.150e+02, 6.000e+01, 1.770e+02, 8.500e+01,
#        6.400e+01, 2.830e+02, 6.250e+02, 3.010e+02, 8.400e+01, 0.000e+00,
#        4.090e+02, 1.230e+02, 1.530e+02, 5.580e+02, 1.290e+02, 8.300e+01,
#        4.010e+02, 1.480e+02, 4.170e+02, 1.080e+02, 7.100e+01, 1.400e+02,
#        1.260e+02, 1.140e+02, 8.200e+01, 1.300e+02, 9.300e+01, 7.900e+01,
#        1.500e+02])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['phone']", "['email', 'phone']",
#        "['email', 'phone', 'work_email']", "['phone', 'work_email']",
#        "['email']", '[]', 'None'], dtype=object)

# %%
updated_df[updated_df['host_verifications'] == '[]']
# Out:
#              id    host_id host_name  host_since    host_location  \
# 4193   20470416  299073616    Patrik  2019-09-30          unknown
# 5156   24231542  299073616    Patrik  2019-09-30          unknown
# 12536   2110830    4086579     Pablo  2012-11-07  Los Angeles, CA
# 14688  44595088  360916271   Rebecca  2020-08-06   Long Beach, CA
# 18725  47472448  263297093     Dorna  2019-05-21  Los Angeles, CA
# 22659  39757424  305582795      Rada  2019-10-30          unknown
# 29530  20473154  217695242     Helen  2018-09-28          unknown
# 32475  42646093  299739906      Alex  2019-10-03          unknown
# 33487  43179913  172946356      Nery  2018-02-12  Los Angeles, CA
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 4193                 NaN                NaN                   0%
# 5156                 NaN                NaN                   0%
# 12536                NaN                NaN                  NaN
# 14688                NaN                NaN                  NaN
# 18725                NaN                NaN                 100%
# 22659                NaN                NaN                  NaN
# 29530                NaN                NaN                  31%
# 32475                NaN                NaN                  NaN
# 33487                NaN                NaN                  NaN
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 4193                  f                  2.0  ...       5.0  6.0
# 5156                  f                  2.0  ...       3.0  3.0
# 12536                 f                  1.0  ...       1.0  1.0
# 14688                 f                  1.0  ...       3.0  2.0
# 18725                 f                  1.0  ...       2.0  2.0
# 22659                 f                  1.0  ...       1.0  1.0
# 29530                 f                  1.0  ...       3.0  4.0
# 32475                 f                  2.0  ...       2.0  1.0
# 33487                 f                  1.0  ...       1.0  1.0
#
#                                                amenities   price  \
# 4193   ["Sauna", "Gym", "Steam room", "Washer", "Brea...  9995.0
# 5156   ["Dryer", "Free parking garage on premises", "...  6995.0
# 12536  ["TV with standard cable", "Hot tub", "Wifi", ...   135.0
# 14688  ["Wifi", "Gym", "Carbon monoxide alarm", "Smok...   180.0
# 18725  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...   375.0
# 22659  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...   129.0
# 29530  ["Ironing board", "Washer", "Breakfast bar", "...  2295.0
# 32475  ["Hot tub", "Wifi", "Gym", "Smoke alarm", "Was...   100.0
# 33487  ["Smoking allowed", "Wifi", "Heating", "Essent...   200.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count  \
# 4193                  0                 NaN                               2
# 5156                  0                 NaN                               2
# 12536                 2                 5.0                               1
# 14688                 0                 NaN                               1
# 18725                 1                 5.0                               1
# 22659                 0                 NaN                               1
# 29530                 3                 NaN                               1
# 32475                 0                 NaN                               1
# 33487                 0                 NaN                               1
#
#        amenities_count         city  num_bath
# 4193                28  Los Angeles       5.5
# 5156                20  Los Angeles       4.5
# 12536               12  Los Angeles       1.5
# 14688               16  Los Angeles       3.0
# 18725               19  Los Angeles       2.0
# 22659               16  Los Angeles       1.0
# 29530               28  Los Angeles       3.5
# 32475               16  Los Angeles       1.0
# 33487               14  Los Angeles       1.0
#
# [9 rows x 31 columns]

# %%
# Replace '[]' with None in 'host_verifications' column
updated_df['host_verifications'] = updated_df['host_verifications'].replace('[]', "None")

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['phone']", "['email', 'phone']",
#        "['email', 'phone', 'work_email']", "['phone', 'work_email']",
#        "['email']", 'None'], dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 2 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([   1,    4,   10,    2,   22,    3,   12,    5,   28,    8,   24,
#          11,   27,    6,   64,   37,   55,   19,   54,  102,    7, 1003,
#          13,  663,   66,   43,   29,   56,    9,   17,  129,   15,   60,
#          70,   14,   79,   47,   16,   38,   21,   18,   59,   39,   30,
#         717,   35,  134,   87,   42,   20,  110,   34,   32,   48,   31,
#          25,   68,   46,   45,   40,   73,   80,   62,  136,   23,   52,
#          78,   36,   63,   76,   51,   81,   26,   50,   75,   57,  109])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
#              id   host_id host_name  host_since host_location  \
# 11232  10034835  23571738       NaN  March 2023       unknown
# 35307   6900415  36159573       NaN  March 2023       unknown
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 11232                NaN                NaN                  NaN
# 35307                NaN                NaN                  NaN
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 11232                 f                  1.0  ...       1.0  1.0
# 35307                 f                  1.0  ...       1.0  2.0
#
#                                                amenities price  \
# 11232  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...  41.0
# 35307  ["Wifi", "Washer", "Essentials", "Fire extingu...  99.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count  \
# 11232                 2                 NaN                               1
# 35307                 0                 NaN                               1
#
#        amenities_count         city  num_bath
# 11232               12  Los Angeles       1.0
# 35307                8  Los Angeles       1.0
#
# [2 rows x 31 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
#              id   host_id host_name  host_since host_location  \
# 11232  10034835  23571738       NaN  March 2023       unknown
# 35307   6900415  36159573       NaN  March 2023       unknown
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 11232                NaN                NaN                  NaN
# 35307                NaN                NaN                  NaN
#
#       host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 11232                 f                  1.0  ...       1.0  1.0
# 35307                 f                  1.0  ...       1.0  2.0
#
#                                                amenities price  \
# 11232  ["Wifi", "Carbon monoxide alarm", "Smoke alarm...  41.0
# 35307  ["Wifi", "Washer", "Essentials", "Fire extingu...  99.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count  \
# 11232                 2                 NaN                               1
# 35307                 0                 NaN                               1
#
#        amenities_count         city  num_bath
# 11232               12  Los Angeles       1.0
# 35307                8  Los Angeles       1.0
#
# [2 rows x 31 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['f', 't', nan], dtype=object)

# %%
na = updated_df['host_has_profile_pic'].isnull().sum()
print(f'There are {na} missing values in the "host_has_profile_pic" column.')

updated_df['host_has_profile_pic'].fillna('f', inplace=True)
# Out:
# There are 2 missing values in the "host_has_profile_pic" column.

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array([nan, 'Rancho Palos Verdes, California, United States',
#        'Los Angeles, California, United States',
#        'Torrance, California, United States',
#        'Lomita, California, United States',
#        'Whittier, California, United States',
#        'Norwalk, California, United States',
#        'Lancaster, California, United States',
#        'Malibu, California, United States',
#        'Lynwood, California, United States',
#        'Downey, California, United States',
#        'Diamond Bar, California, United States',
#        'Walnut, California, United States',
#        'Bellflower, California, United States',
#        'Santa Clarita, California, United States',
#        'Hawaiian Gardens, California, United States',
#        'Redondo Beach, California, United States',
#        'Montebello, California, United States',
#        'Monterey Park, California, United States',
#        'Agoura Hills, California, United States',
#        'Hawthorne, California, United States',
#        'Gardena, California, United States',
#        'Glendale, California, United States',
#        'Castaic, California, United States',
#        'West Hollywood, California, United States',
#        'Pasadena, California, United States',
#        'Altadena, California, United States',
#        'Agua Dulce, California, United States',
#        'Beverly Hills, California, United States',
#        'Bell, California, United States',
#        'Compton, California, United States',
#        'West covina, California, United States',
#        'Burbank, California, United States',
#        'Pomona, California, United States',
#        'San Gabriel, California, United States',
#        'Long Beach, California, United States',
#        'Palmdale, California, United States',
#        'Alhambra, California, United States',
#        'San Pedro, California, United States',
#        'Avalon, California, United States',
#        'Quartz Hill, California, United States',
#        'Pico Rivera, California, United States',
#        'San Pedro Los Angeles, California, United States',
#        'La Puente, California, United States',
#        'Westlake Village, California, United States',
#        'Palos Verdes Peninsula, California, United States',
#        'San Pedro , California, United States',
#        'Marina del Rey, California, United States',
#        'Cerritos, California, United States',
#        'Hacienda Heights, California, United States',
#        'La Habra Heights, California, United States',
#        'El Monte, California, United States',
#        'Acton, California, United States',
#        'Claremont, California, United States',
#        'Rowland Heights, California, United States',
#        'Sherman Oaks, California, United States',
#        'South Gate, California, United States',
#        'La Verne, California, United States',
#        'Van Nuys, California, United States',
#        'Resada, Los Angeles, California, United States',
#        'Topanga, California, United States',
#        'Carson, California, United States',
#        'Azusa, California, United States',
#        'El Segundo, California, United States',
#        'Santa Monica, California, United States',
#        '罗兰高地, California, United States',
#        'Baldwin Park, California, United States',
#        'Calabasas, California, United States',
#        'Inglewood, California, United States',
#        'South El Monte, California, United States',
#        'Green Valley, California, United States',
#        'Reseda, California, United States',
#        'Artesia, California, United States',
#        'South Pasadena, California, United States',
#        'West Hollywood , California, United States',
#        'Montrose, California, United States',
#        'Stevenson Ranch, California, United States',
#        'West Carson, California, United States',
#        'Covina, California, United States',
#        'Culver City, California, United States',
#        'San Dimas, California, United States',
#        'Sherman Oaks, Los Angeles, California, United States',
#        'Manhattan Beach, California, United States',
#        'LOS ANGELES, California, United States',
#        'Los Angeles County, California, United States',
#        'Arcadia, California, United States',
#        'Duarte, California, United States',
#        'Winnetka, California, United States',
#        'Topanga Canyon, California, United States',
#        'Valencia, California, United States',
#        'Reseda , California, United States',
#        'Lake Los Angeles, California, United States',
#        'Valley Village, California, United States',
#        'Rowland Hghts, California, United States',
#        'Montclair, California, United States',
#        'La Cañada Flintridge, California, United States',
#        'Los Angeles , California, United States',
#        'San Fernando, California, United States',
#        'san Gabriel/Rosemead, California, United States',
#        'Los Angeles, Ca, United States',
#        'Glendale , California, United States',
#        'Echo Park, Los Angeles, California, United States',
#        'Redo do beach, California, United States',
#        'Lake Hughes, California, United States',
#        'Mount Baldy, California, United States',
#        'Woodland Hills, Los Angeles, California, United States',
#        '埃尔蒙特, California, United States',
#        'Lawndale, California, United States',
#        'Woodland Hills , California, United States',
#        'Universal City, California, United States',
#        'Woodland Hills, California, United States',
#        'North Hollywood, California, United States',
#        'Del Aire, California, United States',
#        'Valley Glen, California, United States',
#        'Paramount, California, United States',
#        'Sylmar, California, United States',
#        'Rolling Hills Estates, California, United States',
#        'Mar Vista, California, United States',
#        'Highland Park, California, United States',
#        'Sunset Plaza Hollywood Hills , California, United States',
#        'echo park, California, United States',
#        'Sherman Oaks , California, United States',
#        'Diamond Bar, CA 91765, California, United States',
#        'SAN PEDRO, California, United States',
#        'Rowland Heights, 加州, United States',
#        'City of Industry, California, United States',
#        'Rosemead, California, United States',
#        'Valencia , California, United States',
#        'San Pedro Los Angeles , California, United States',
#        'Phillips Ranch, California, United States',
#        'San Pedro, CA, California, United States',
#        'valencia, California, United States',
#        'Woodland Hls, California, United States',
#        'Reseda, Los Angeles , California, United States',
#        'Buena Park, California, United States',
#        '罗兰岗, California, United States',
#        'Tarzana, California, United States',
#        'Los angeles, California, United States',
#        'Lennox, California, United States',
#        'Reseda,Los Angeles, California, United States',
#        'Santa Clarita , California, United States',
#        'Westchester, California, United States',
#        'West Covina, California, United States',
#        'La Crescenta-Montrose, California, United States',
#        'View Park-Windsor Hills, California, United States',
#        'South Pasadena, CA  , United States',
#        'Signal Hill, California, United States',
#        'Windsor Hills, California, United States',
#        'Hermosa Beach, California, United States',
#        'Burbank, Los Angeles, California, United States',
#        'Temple City, California, United States',
#        'San Fernando Valley, California, United States',
#        'West Puente Valley, California, United States',
#        'Rosemead unit , California, United States',
#        'Monrovia, California, United States',
#        'Palos Verdes Estates, California, United States',
#        'VENICE, California, United States',
#        'View Park, California, United States',
#        'Pacific Palisades, California, United States',
#        'Hollywood, California, United States',
#        'Venice, California, United States',
#        'Vernon, California, United States',
#        'venice, California, United States',
#        'Studio City, California, United States',
#        'Lakewood, California, United States',
#        'Huntington Park, California, United States',
#        'East Los Angeles, California, United States',
#        'Glendora, California, United States',
#        'Venice , California, United States',
#        '蒙诺维亚, California, United States',
#        'Littlerock, California, United States',
#        'Commerce, California, United States',
#        'Sierra Madre, California, United States',
#        'Avocado Heights, California, United States',
#        'Los Angeles , Ca, United States',
#        'Malibu Canyon/Monte Nido, California, United States',
#        'Playa Del Rey, California, United States',
#        'Canoga Park, California, United States',
#        'Encino, California, United States',
#        'Van Nuys , California, United States',
#        '阿卡迪亚, California, United States',
#        'Wrightwood, California, United States',
#        'Los Angeles/ Hollywood , California, United States',
#        'Venice Beach, California, United States',
#        'Playa Vista , California, United States',
#        'Los Angeles/Burbank/Toluca Lake, California, United States',
#        'Pacific Palisades, Los Angeles, California, United States',
#        'North Hollywood , California, United States',
#        'Venice Beach, Los Angeles, California, United States',
#        'Maywood, California, United States',
#        'Bell Gardens, California, United States',
#        'Harbor City, California, United States',
#        'North Hollywood Los Angeles Studio City, California, United States',
#        'Cudahy, California, United States',
#        'La Mirada, California, United States',
#        'San Marino, California, United States',
#        'Culver city, California, United States',
#        'Gardena , California, United States',
#        'LaTuna Canyon, California, United States',
#        'Playa del Rey, California, United States',
#        'Hollywood , California, United States',
#        'Valley village , California, United States',
#        'Tarzana , California, United States',
#        'Arcadia , California, United States',
#        'Studio city, California, United States',
#        'NORTH HOLLYWOOD, California, United States',
#        'Toluca lake, California, United States',
#        ' North Hollywood, California, United States',
#        'Hollywood Hills, California, United States',
#        'Thousand Oaks, California, United States',
#        'Los Angeles,, California, United States',
#        'Lake Balboa , California, United States',
#        'Long Beach , California, United States',
#        'Silver Lake, Los Angeles, California, United States',
#        'Los Feliz, Los Angeles, California, United States',
#        'Los Angeles, ca, United States',
#        'Coronado, California, United States',
#        'Hawthorne , California, United States',
#        'Los Angeles/La Crescenta, California, United States',
#        'Sun Valley, California, United States',
#        'Santa Fe Springs, California, United States',
#        'Bixby Knolls , California, United States',
#        'Pacific palisades, California, United States',
#        'N Hollywood, California, United States',
#        'los angles, california, United States',
#        'Sherwood Forest, California, United States',
#        'Leona Valley, California, United States',
#        'Pearblossom, California, United States',
#        'Northridge, California, United States',
#        'Valyermo, California, United States',
#        'South Whittier, California, United States',
#        'Long Beach, Ca, United States',
#        'studio city, California, United States',
#        'Hidden Hills, California, United States',
#        'Val Verde, California, United States',
#        'Cudahy, Ca, United States', 'Malibu , California, United States',
#        '沃尔纳特, California, United States',
#        'El Porto, California, United States',
#        'Venice, Los Angeles, California, United States',
#        'Westwood , California, United States',
#        '洛杉矶, California, United States',
#        'Los Angeles, Tarzana , California, United States',
#        'arcadia, California, United States',
#        'Studio City , California, United States',
#        'Toluca Lake, California, United States',
#        'Los Angeles, Hollywood Hills, California, United States',
#        'north hollywood, California, United States',
#        'east edna PI.Covina, California, United States',
#        'Van Nuys , Ca, United States', 'Llano, California, United States',
#        'Sunland, California, United States',
#        'woodland hills, California, United States',
#        'Lakewood, Ca, United States',
#        'North hollywood, California, United States',
#        'LA, California, United States',
#        'Azusa , California, United States',
#        'Venice , Los Angeles, California, United States',
#        'Sherman oaks, California, United States',
#        'Simi Valley, California, United States',
#        'Lake View Terrace , California, United States',
#        'GRANADA HILLS, California, United States',
#        'Playa del rey, California, United States',
#        'Century city, California, United States',
#        'STUDIO CITY, California, United States',
#        'South Bay, California, United States',
#        'Monterey park, California, United States',
#        'valley village, California, United States',
#        'Los Angeles / Valley Village / North Hollywood , California, United States',
#        'Woodland Hills (Los Angeles), California, United States',
#        'Panorama , California, United States',
#        'Pasadena, Los Angeles, California, United States',
#        'Lake Balboa, California, United States',
#        'North Hills, California, United States',
#        'Tujunga, California, United States',
#        'West Los Angeles, California, United States',
#        'san pedro, California, United States',
#        'Wilmington, California, United States',
#        'Beverly Hills , California, United States',
#        'Altadena , California, United States',
#        'Beverly Hills/ Los Angeles, California, United States',
#        '因達斯特里, California, United States',
#        'Granada Hills, California, United States',
#        'hacienda height, ca, United States',
#        'Canoga Park , California, United States',
#        'Reseda, Los Angeles, California, United States',
#        'LOS ANGELES , California, United States',
#        'Mission Hills, California, United States',
#        'Rolling Hills, California, United States',
#        'Redondo Beach,, California, United States',
#        'Canyon country , California, United States',
#        'Van nuys, California, United States',
#        'Ladera Heights, California, United States',
#        'Bel Air, California, United States',
#        'Glendale, California, US, California, United States',
#        'Torrance/ Redondo Beach , California, United States',
#        'Los Angeles Suburbs, California, United States',
#        'California, United States',
#        'Santa Clarita (Canyon Country), California, United States'],
#       dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 17479

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Castaic Canyons', 'Pomona', 'Rancho Palos Verdes', 'Malibu',
#        'San Pedro', 'Diamond Bar', 'West Compton',
#        'Northeast Antelope Valley', 'West Carson',
#        'Unincorporated Santa Susana Mountains', 'Lomita', 'Whittier',
#        'Norwalk', 'Rolling Hills Estates', 'Lancaster', 'Artesia',
#        'Bellflower', 'La Puente', 'Gardena', 'Lynwood', 'Downey',
#        'Palmdale', 'Southeast Antelope Valley',
#        'Unincorporated Santa Monica Mountains', 'San Fernando',
#        'Santa Clarita', 'Walnut', 'Bell Gardens', 'Carson',
#        'Stevenson Ranch', 'Palos Verdes Estates', 'Acton', 'Quartz Hill',
#        'Porter Ranch', 'Granada Hills', 'Hawaiian Gardens',
#        'Vermont Knolls', 'Northridge', 'Hacienda Heights', 'Torrance',
#        'Rowland Heights', 'South San Gabriel', 'Montebello',
#        'West Covina', 'Monterey Park', 'Vermont Square',
#        'Florence-Firestone', 'Agoura Hills', 'Vernon', 'Brentwood',
#        'Pacific Palisades', 'Hawthorne', 'La Verne', 'Claremont',
#        'Westwood', 'Reseda', 'Long Beach', 'Encino', 'Lakewood',
#        'Altadena', 'Redondo Beach', 'Downtown', 'Boyle Heights',
#        'Glendale', 'Ridge Route', 'Hollywood Hills', 'Venice', 'Alhambra',
#        'Santa Monica', 'Mar Vista', 'Hollywood Hills West',
#        'West Hollywood', 'Pasadena', 'Sherman Oaks', 'East Hollywood',
#        'Beverly Hills', 'Hollywood', 'Mid-Wilshire', 'Carthay',
#        'North Hollywood', 'Westlake', 'Echo Park', 'Silver Lake',
#        'East Los Angeles', 'Glendora', 'Lopez/Kagel Canyons',
#        'Agua Dulce', 'Beverly Crest', 'Pico-Robertson', 'Marina del Rey',
#        'Bell', 'Wilmington', 'San Gabriel', 'Burbank', 'Green Meadows',
#        'Sylmar', 'East San Gabriel', 'Valley Glen', 'Fairfax',
#        'Beverly Grove', 'Broadway-Manchester', 'Pacoima', 'Vermont Vista',
#        'El Sereno', 'Watts', 'Unincorporated Catalina Island', 'Compton',
#        'Commerce', 'Pico Rivera', 'South Whittier',
#        'South San Jose Hills', 'Rosemead', 'El Monte', 'Harbor Gateway',
#        'Valinda', 'Vermont-Slauson', 'Studio City', 'North Hills',
#        'Huntington Park', 'Lake Los Angeles', 'Sun Valley',
#        'Westlake Village', 'Highland Park', 'Historic South-Central',
#        'Sawtelle', 'Cheviot Hills', 'Hyde Park', 'Rolling Hills',
#        'West Adams', 'Avalon', 'Elysian Valley', 'Tujunga',
#        'Valley Village', 'Koreatown', 'Cerritos', 'Paramount',
#        'Lake Balboa', 'Eagle Rock', 'La Habra Heights', 'Winnetka',
#        'Temple City', 'West Hills', 'Arcadia', 'Tujunga Canyons',
#        'San Dimas', 'South Gate', 'Harvard Heights', 'Westmont',
#        'Topanga', 'Adams-Normandie', 'Mission Hills', 'Industry',
#        'Westchester', 'Citrus', 'Canoga Park', 'Chinatown',
#        'Jefferson Park', 'Harbor City', 'Exposition Park', 'El Segundo',
#        'Santa Fe Springs', 'Baldwin Park', 'Calabasas', 'Del Rey',
#        'Gramercy Park', 'Playa del Rey', 'Woodland Hills', 'Duarte',
#        'Inglewood', 'South El Monte', 'Green Valley', 'Atwater Village',
#        'Elysian Park', 'Sunland', 'South Pasadena', 'Toluca Lake',
#        'Charter Oak', 'Culver City', 'Northwest Antelope Valley',
#        'West Whittier-Los Nietos', 'Leimert Park', 'Los Feliz',
#        'Walnut Park', 'Panorama City', 'Playa Vista',
#        'Chesterfield Square', 'Montecito Heights', 'Azusa', 'Palms',
#        'Harvard Park', 'Lincoln Heights', 'Veterans Administration',
#        'Windsor Square', 'Angeles Crest', 'Lawndale', 'Manhattan Beach',
#        'Tarzana', 'Del Aire', 'Elizabeth Lake', 'Lake Hughes',
#        'Ladera Heights', 'Rancho Dominguez', 'Mid-City', 'Universal City',
#        'West Los Angeles', 'Castaic', 'Pico-Union', 'Hancock Park',
#        'Bel-Air', 'Shadow Hills', 'Signal Hill', 'Lennox',
#        'La Crescenta-Montrose', 'La Canada Flintridge',
#        'View Park-Windsor Hills', 'Sepulveda Basin', 'Century City',
#        'Arlington Heights', 'Baldwin Hills/Crenshaw', 'Hermosa Beach',
#        'Rancho Park', 'Manchester Square', 'Van Nuys',
#        'West Puente Valley', 'San Pasqual', 'Glassell Park',
#        'Mount Washington', 'Monrovia', 'San Marino', 'Larchmont',
#        'Chatsworth', 'Maywood', 'Willowbrook', 'University Park',
#        'Leona Valley', 'South Park', 'Covina', 'Central-Alameda',
#        'Cypress Park', 'Mayflower Village', 'Hidden Hills', 'Val Verde',
#        'Beverlywood', 'Northwest Palmdale', 'Avocado Heights',
#        'East Pasadena', 'Irwindale', 'East Whittier', 'La Mirada',
#        'Sierra Madre', 'Arleta', 'North Whittier', 'Alondra Park',
#        'Athens', 'Griffith Park', 'North El Monte', 'Florence',
#        'Chatsworth Reservoir', 'Desert View Highlands', 'Vincent',
#        'Sun Village', 'Cudahy', 'Lake View Terrace', 'Hasley Canyon',
#        'East Compton'], dtype=object)

# %% [markdown]
# ### We are going to drop neighbourhood column for LA Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                             2
# host_since                            0
# host_location                         0
# host_response_time                 9368
# host_response_rate                 9368
# host_acceptance_rate               8337
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_verifications                    0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighbourhood_cleansed                0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# bathrooms_text                        0
# bedrooms                              0
# beds                                  0
# amenities                             0
# price                                 0
# number_of_reviews                     0
# review_scores_value               11926
# calculated_host_listings_count        0
# amenities_count                       0
# city                                  0
# num_bath                              0
# dtype: int64

# %% [markdown]
# # Save the Final Dataframe

# %%
updated_df.to_csv('data/listings_detailed_after_na_la.csv', index=False)
