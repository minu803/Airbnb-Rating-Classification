# %% [markdown]
# # Chicago

# %%
import pandas as pd
import numpy as np

# %%
listings_detailed = pd.read_csv('usa/Chicago/listings_detailed.csv')

# %%
listings_detailed.shape
# Out:
# (7747, 75)

# %% [markdown]
# # Delete Unnecessary Columns

# %%
# Columns you want to keep
columns_to_keep = [
    'id', 'host_id', 'host_name', 'host_since', 'host_location', 
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
    'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
    'price', 'number_of_reviews', 'review_scores_value', 'calculated_host_listings_count'
]

# Dropping the columns that are not in 'columns_to_keep'
listings_detailed = listings_detailed[columns_to_keep]

# %%
listings_detailed.shape
# Out:
# (7747, 29)

# %% [markdown]
# # Remove Entries where 'price' and 'accomodates' is zero / NA

# %% [markdown]
# ## Pre-processing on 'price' column

# %%
# Remove the dollar sign from the price column and change the type to float
listings_detailed['price'] = listings_detailed['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Test: Correct filtering expression
filtered_df = listings_detailed[listings_detailed['price'] == 10]
filtered_df
# Out:
#                       id    host_id          host_name  host_since  \
# 975             20235190  127235673               Alex  2017-04-23
# 1029            20869579  127235673               Alex  2017-04-23
# 3200            45487005    6962723              Shane  2013-06-17
# 5152  600622184724170928  100782278  Chicago Furnished  2016-10-22
# 7017  779953812225353399  170551048                Lyn  2018-01-29
#
#       host_location  host_response_time host_response_rate  \
# 975     Chicago, IL      within an hour                92%
# 1029    Chicago, IL      within an hour                92%
# 3200  United States                 NaN                NaN
# 5152            NaN  within a few hours                98%
# 7017    Chicago, IL      within an hour               100%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 975                  100%                 f                   10  ...
# 1029                 100%                 f                   10  ...
# 3200                  NaN                 f                    1  ...
# 5152                  97%                 t                   34  ...
# 7017                  99%                 t                   23  ...
#
#       accommodates bathrooms    bathrooms_text bedrooms beds  \
# 975              2       NaN  1.5 shared baths      1.0  1.0
# 1029             2       NaN     1 shared bath      1.0  1.0
# 3200             1       NaN         Half-bath      NaN  1.0
# 5152             5       NaN            1 bath      2.0  2.0
# 7017             2       NaN            1 bath      NaN  1.0
#
#                                               amenities  price  \
# 975   ["Self check-in", "32\" HDTV with HBO Max, Hul...   10.0
# 1029  ["Self check-in", "32\" HDTV with HBO Max, Hul...   10.0
# 3200  ["Heating", "Air conditioning", "Outdoor dinin...   10.0
# 5152  ["Samsung stainless steel gas stove", "Fast wi...   10.0
# 7017  ["Laundromat nearby", "Radiant heating", "Dedi...   10.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 975                  51                4.72                               8
# 1029                 37                4.33                               8
# 3200                  0                 NaN                               1
# 5152                  1                5.00                              34
# 7017                  1                1.00                              23
#
# [5 rows x 29 columns]

# %%
price_zero_or_na_count = listings_detailed['price'].isnull().sum() + (listings_detailed['price'] == 0).sum()
print(price_zero_or_na_count)
# Out:
# 2

# %%
# Filter listings where price is either null or equals 0
listings_detailed.loc[listings_detailed['price'].isnull() | (listings_detailed['price'] == 0)]
# Out:
#             id    host_id                        host_name  host_since  \
# 2778  41740623  273328293                       The Hoxton  2019-07-03
# 2966  43078540  315027620  Found Hotel Chicago River North  2019-12-06
#
#      host_location host_response_time host_response_rate host_acceptance_rate  \
# 2778           NaN     within an hour               100%                 100%
# 2966   Chicago, IL     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 2778               NaN                    2  ...             2       NaN
# 2966                 f                    6  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 2778            NaN      NaN  NaN
# 2966            NaN      NaN  NaN
#
#                                               amenities  price  \
# 2778  ["Bed sheets and pillows", "45\" HDTV", "First...    0.0
# 2966  ["Hair dryer", "Smoke alarm", "Carbon monoxide...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 2778                 68                4.69                               1
# 2966                875                4.33                               2
#
# [2 rows x 29 columns]

# %%
# Filter listings where accommodates is either null or equals 0
listings_detailed.loc[listings_detailed['accommodates'].isnull() | (listings_detailed['accommodates'] == 0)]
# Out:
#             id    host_id                        host_name  host_since  \
# 2966  43078540  315027620  Found Hotel Chicago River North  2019-12-06
#
#      host_location host_response_time host_response_rate host_acceptance_rate  \
# 2966   Chicago, IL     within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 2966                 f                    6  ...             0       NaN
#
#      bathrooms_text bedrooms beds  \
# 2966            NaN      NaN  NaN
#
#                                               amenities  price  \
# 2966  ["Hair dryer", "Smoke alarm", "Carbon monoxide...    0.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 2966                875                4.33                               2
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Create Function to Identify the Zero/NA values and Remove them

# %%
def clean_listings(df):
    """
    Removes listings from the dataframe where price is zero/NA or accommodates is zero/NA.
    Counts the number of listings removed based on these criteria.
    
    Parameters:
    - df: A pandas DataFrame with the listings data.
    
    Returns:
    - cleaned_df: The cleaned DataFrame with the specified entries removed.
    - count_removed: The number of listings removed based on the criteria.
    """
    
    # Convert price from string to float
    df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
    
    # Find entries to remove based on conditions
    to_remove = df[(df['price'] == 0) | (df['price'].isna()) | (df['accommodates'] == 0) | (df['accommodates'].isna())]
    
    # Count the number of listings to remove
    count_removed = len(to_remove)

    print(f"Number of listings removed: {count_removed}")
    
    # Remove the entries from the DataFrame
    cleaned_df = df.drop(to_remove.index)
    
    return cleaned_df

# %%
# Test the clean_listings function
cleaned_listings = clean_listings(listings_detailed)
# Out:
# Number of listings removed: 2

# %%
cleaned_listings.head()
# Out:
#         id  host_id            host_name  host_since host_location  \
# 0     2384     2613              Rebecca  2008-08-29   Chicago, IL
# 1  1772920  9297431  Inn At Wrigleyville  2013-10-08   Chicago, IL
# 2  1773021  9297431  Inn At Wrigleyville  2013-10-08   Chicago, IL
# 3  1773025  9297431  Inn At Wrigleyville  2013-10-08   Chicago, IL
# 4  1810118  9483312                 Ryan  2013-10-17   Chicago, IL
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour               100%                  97%
# 1     within an hour               100%                 100%
# 2     within an hour               100%                 100%
# 3     within an hour               100%                 100%
# 4     within an hour               100%                 100%
#
#   host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 0                 t                    1  ...             1       NaN
# 1                 t                    6  ...             7       NaN
# 2                 t                    6  ...             9       NaN
# 3                 t                    6  ...             9       NaN
# 4                 t                    2  ...             3       NaN
#
#    bathrooms_text bedrooms beds  \
# 0   1 shared bath      1.0  1.0
# 1         2 baths      3.0  5.0
# 2         2 baths      4.0  5.0
# 3         2 baths      4.0  5.0
# 4  1 private bath      1.0  1.0
#
#                                            amenities  price  \
# 0  ["Dedicated workspace", "Host greets you", "Ba...   90.0
# 1  ["Oven", "Baking sheet", "Host greets you", "F...  379.0
# 2  ["Laundromat nearby", "Oven", "Baking sheet", ...  479.0
# 3  ["Oven", "Baking sheet", "Host greets you", "F...  479.0
# 4  ["Self check-in", "Dedicated workspace", "Chil...   79.0
#
#    number_of_reviews review_scores_value  calculated_host_listings_count
# 0                212                4.93                               1
# 1                 13                4.58                               6
# 2                 26                4.85                               6
# 3                 21                4.76                               6
# 4                355                4.88                               2
#
# [5 rows x 29 columns]

# %%
cleaned_listings.shape
# Out:
# (7745, 29)

# %% [markdown]
# # Impute 'bathroom_text'

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# - 0 shared bath -> 0
# - half bath -> 0.5
# - private half bath -> 0.5
# - shared half bath -> 0.5

# %%
cleaned_listings['bathrooms_text'].unique()
# Out:
# array(['1 shared bath', '2 baths', '1 private bath', '1 bath',
#        '1.5 shared baths', '11 shared baths', '1.5 baths', '2.5 baths',
#        '3 baths', '2 shared baths', '0 shared baths', nan, '3.5 baths',
#        '2.5 shared baths', '3 shared baths', '4 baths',
#        'Shared half-bath', '4.5 baths', '0 baths', '5 baths',
#        'Private half-bath', '11.5 shared baths', '4 shared baths',
#        '6.5 baths', '7 baths', '5.5 baths', '6 baths', '12.5 baths',
#        'Half-bath', '10 baths', '9.5 baths', '7.5 baths', '8 baths',
#        '8.5 baths'], dtype=object)

# %%
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].astype(str)
# Convert 'bathrooms_text' column to strings, treating NaN as empty strings
cleaned_listings['bathrooms_text'] = listings_detailed['bathrooms_text'].fillna('').astype(str)
cleaned_listings
# Verifying the conversion
print(cleaned_listings['bathrooms_text'].dtype)
# Out:
# object

# %% [markdown]
# #### Changing non-numeric bathrooms to numeric values

# %%
# Replace specific strings in 'bathrooms_text' column
cleaned_listings['bathrooms_text'] = cleaned_listings['bathrooms_text'].replace({
    'Half-bath': '0.5 baths',
    'Private half-bath': '0.5 baths',
    'Shared half-bath': '0.5 baths'
})

# Check the unique values to verify the changes
unique_bathrooms = cleaned_listings['bathrooms_text'].unique()
print(unique_bathrooms)
# Out:
# ['1 shared bath' '2 baths' '1 private bath' '1 bath' '1.5 shared baths'
#  '11 shared baths' '1.5 baths' '2.5 baths' '3 baths' '2 shared baths'
#  '0 shared baths' '' '3.5 baths' '2.5 shared baths' '3 shared baths'
#  '4 baths' '0.5 baths' '4.5 baths' '0 baths' '5 baths' '11.5 shared baths'
#  '4 shared baths' '6.5 baths' '7 baths' '5.5 baths' '6 baths' '12.5 baths'
#  '10 baths' '9.5 baths' '7.5 baths' '8 baths' '8.5 baths']

# %% [markdown]
# ### Check for the Nan for bathrooms_text

# %%
cleaned_listings[cleaned_listings['bathrooms_text']=='']
# Out:
#             id    host_id host_name  host_since host_location  \
# 124    4793938   24705990      Rick  2014-12-10   Chicago, IL
# 1629  28510810      81779     Laura  2010-02-16   Chicago, IL
# 1630  28510957      81779     Laura  2010-02-16   Chicago, IL
# 1631  28511244      81779     Laura  2010-02-16   Chicago, IL
# 1632  28511296      81779     Laura  2010-02-16   Chicago, IL
# 1633  28511402      81779     Laura  2010-02-16   Chicago, IL
# 1634  28511620      81779     Laura  2010-02-16   Chicago, IL
# 1635  28511708      81779     Laura  2010-02-16   Chicago, IL
# 1636  28511827      81779     Laura  2010-02-16   Chicago, IL
# 1637  28511937      81779     Laura  2010-02-16   Chicago, IL
# 3089  44175548  344404176      Amyn  2020-04-21  Glenview, IL
# 7734   1732652    3965428       Rob  2012-10-24   Chicago, IL
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 124      within an hour                90%                 100%
# 1629     within an hour               100%                  99%
# 1630     within an hour               100%                  99%
# 1631     within an hour               100%                  99%
# 1632     within an hour               100%                  99%
# 1633     within an hour               100%                  99%
# 1634     within an hour               100%                  99%
# 1635     within an hour               100%                  99%
# 1636     within an hour               100%                  99%
# 1637     within an hour               100%                  99%
# 3089                NaN                NaN                  NaN
# 7734     within an hour               100%                  74%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 124                  t                   11  ...             4       NaN
# 1629                 t                   10  ...             2       NaN
# 1630                 t                   10  ...             2       NaN
# 1631                 t                   10  ...             3       NaN
# 1632                 t                   10  ...             2       NaN
# 1633                 t                   10  ...             3       NaN
# 1634                 t                   10  ...             2       NaN
# 1635                 t                   10  ...             3       NaN
# 1636                 t                   10  ...             2       NaN
# 1637                 t                   10  ...             2       NaN
# 3089                 f                    5  ...             2       NaN
# 7734                 t                   83  ...             2       NaN
#
#      bathrooms_text bedrooms beds  \
# 124                      2.0  2.0
# 1629                     1.0  1.0
# 1630                     1.0  1.0
# 1631                     1.0  1.0
# 1632                     1.0  1.0
# 1633                     1.0  1.0
# 1634                     1.0  1.0
# 1635                     1.0  1.0
# 1636                     1.0  1.0
# 1637                     1.0  1.0
# 3089                     1.0  1.0
# 7734                     1.0  1.0
#
#                                               amenities  price  \
# 124   ["Self check-in", "Children\u2019s books and t...  239.0
# 1629  ["Heating - split type ductless system", "Pack...  178.0
# 1630  ["Heating - split type ductless system", "Beek...  164.0
# 1631  ["Heating - split type ductless system", "Pack...  190.0
# 1632  ["Heating - split type ductless system", "Pack...  180.0
# 1633  ["Pack \u2019n play/Travel crib - available up...  178.0
# 1634  ["Heating - split type ductless system", "Pack...  202.0
# 1635  ["Heating - split type ductless system", "Pack...  160.0
# 1636  ["Pack \u2019n play/Travel crib - available up...  173.0
# 1637  ["Pack \u2019n play/Travel crib - available up...  185.0
# 3089  ["Hair dryer", "Hot water", "Smoke alarm", "Ca...  250.0
# 7734  ["Self check-in", "Oven", "First aid kit", "Be...  153.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 124                  82                4.84                              11
# 1629                  5                4.60                              10
# 1630                 17                4.65                              10
# 1631                  3                5.00                              10
# 1632                  4                4.75                              10
# 1633                 22                4.77                              10
# 1634                 10                4.80                              10
# 1635                 37                4.76                              10
# 1636                  5                4.60                              10
# 1637                 21                4.76                              10
# 3089                  1                1.00                               4
# 7734                  7                4.50                              75
#
# [12 rows x 29 columns]

# %% [markdown]
# ### function to fill in NULL values in bathrooms_text
#
# 1. Use the 'bedrooms'
# 2. if the 'bedrooms' column is also NA, fill in NAs with 1/'beds' column

# %%
def fill_missing_bathrooms(df):
    """
    Fills missing or empty 'bathrooms_text' values in the DataFrame.
    - Uses the 'bedrooms' value if available.
    - If 'bedrooms' is also missing, uses half the 'beds' value.
    """
    # Loop through each row in DataFrame
    for index, row in df.iterrows():
        # Check if 'bathrooms_text' is NaN or an empty string
        if pd.isnull(row['bathrooms_text']) or row['bathrooms_text'] == '':
            # Use 'bedrooms' if not NaN and not 0
            if not pd.isnull(row['bedrooms']) and row['bedrooms'] != 0:
                df.at[index, 'bathrooms_text'] = str(row['bedrooms']) + ' bath'
            # If 'bedrooms' is NaN or 0, use half the 'beds' value
            elif not pd.isnull(row['beds']) and row['beds'] != 0:
                # Calculate half the beds and format it to match the bathroom text style
                half_beds_as_baths = row['beds'] / 2
                df.at[index, 'bathrooms_text'] = str(half_beds_as_baths) + ' bath'
            # If both 'bedrooms' and 'beds' are not available, set a default value
            else:
                df.at[index, 'bathrooms_text'] = '1 bath' # Default value or consider another logic
                
    return df

# %%
filled_cleaned_listings = fill_missing_bathrooms(cleaned_listings)

# %%
filled_cleaned_listings[['id', 'bedrooms', 'beds', 'bathrooms_text']]
# Out:
#            id  bedrooms  beds    bathrooms_text
# 0        2384       1.0   1.0     1 shared bath
# 1     1772920       3.0   5.0           2 baths
# 2     1773021       4.0   5.0           2 baths
# 3     1773025       4.0   5.0           2 baths
# 4     1810118       1.0   1.0    1 private bath
# ...       ...       ...   ...               ...
# 7742    25879       2.0   3.0            1 bath
# 7743    28749       3.0   3.0           2 baths
# 7744    37738       1.0   1.0  1.5 shared baths
# 7745    71930       1.0   1.0     1 shared bath
# 7746    84042       1.0   1.0     1 shared bath
#
# [7745 rows x 4 columns]

# %%
# check for the previous NA rows in bathrooms text
filled_cleaned_listings[
    (filled_cleaned_listings['id'] == 4793938) | 
    (filled_cleaned_listings['id'] == 28510810) | 
    (filled_cleaned_listings['id'] == 28510957) | 
    (filled_cleaned_listings['id'] == 28511244) |
    (filled_cleaned_listings['id'] == 28511296) | 
    (filled_cleaned_listings['id'] == 28511402) | 
    (filled_cleaned_listings['id'] == 1732652) 
]
# Out:
#             id   host_id host_name  host_since host_location  \
# 124    4793938  24705990      Rick  2014-12-10   Chicago, IL
# 1629  28510810     81779     Laura  2010-02-16   Chicago, IL
# 1630  28510957     81779     Laura  2010-02-16   Chicago, IL
# 1631  28511244     81779     Laura  2010-02-16   Chicago, IL
# 1632  28511296     81779     Laura  2010-02-16   Chicago, IL
# 1633  28511402     81779     Laura  2010-02-16   Chicago, IL
# 7734   1732652   3965428       Rob  2012-10-24   Chicago, IL
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 124      within an hour                90%                 100%
# 1629     within an hour               100%                  99%
# 1630     within an hour               100%                  99%
# 1631     within an hour               100%                  99%
# 1632     within an hour               100%                  99%
# 1633     within an hour               100%                  99%
# 7734     within an hour               100%                  74%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms  \
# 124                  t                   11  ...             4       NaN
# 1629                 t                   10  ...             2       NaN
# 1630                 t                   10  ...             2       NaN
# 1631                 t                   10  ...             3       NaN
# 1632                 t                   10  ...             2       NaN
# 1633                 t                   10  ...             3       NaN
# 7734                 t                   83  ...             2       NaN
#
#      bathrooms_text bedrooms beds  \
# 124        2.0 bath      2.0  2.0
# 1629       1.0 bath      1.0  1.0
# 1630       1.0 bath      1.0  1.0
# 1631       1.0 bath      1.0  1.0
# 1632       1.0 bath      1.0  1.0
# 1633       1.0 bath      1.0  1.0
# 7734       1.0 bath      1.0  1.0
#
#                                               amenities  price  \
# 124   ["Self check-in", "Children\u2019s books and t...  239.0
# 1629  ["Heating - split type ductless system", "Pack...  178.0
# 1630  ["Heating - split type ductless system", "Beek...  164.0
# 1631  ["Heating - split type ductless system", "Pack...  190.0
# 1632  ["Heating - split type ductless system", "Pack...  180.0
# 1633  ["Pack \u2019n play/Travel crib - available up...  178.0
# 7734  ["Self check-in", "Oven", "First aid kit", "Be...  153.0
#
#       number_of_reviews review_scores_value  calculated_host_listings_count
# 124                  82                4.84                              11
# 1629                  5                4.60                              10
# 1630                 17                4.65                              10
# 1631                  3                5.00                              10
# 1632                  4                4.75                              10
# 1633                 22                4.77                              10
# 7734                  7                4.50                              75
#
# [7 rows x 29 columns]

# %% [markdown]
# ### Function to make numerical values for # of bath

# %%
def add_numerical_bathrooms_column(df, column_name):
    """
    Adds a new column 'num_bath' to the DataFrame based on the numerical values extracted from the specified column.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - column_name: str - The name of the column containing bathroom text descriptions.

    Returns:
    - pd.DataFrame - The original DataFrame with an additional 'num_bath' column.
    """
    # Extract numerical part from the specified column and convert to float
    df['num_bath'] = df[column_name].str.extract('([0-9]+\.?[0-9]*)').astype(float)
    return df

# %%
updated_df = add_numerical_bathrooms_column(filled_cleaned_listings, 'bathrooms_text')
print(updated_df[['bathrooms_text', 'num_bath']])
# Out:
#         bathrooms_text  num_bath
# 0        1 shared bath       1.0
# 1              2 baths       2.0
# 2              2 baths       2.0
# 3              2 baths       2.0
# 4       1 private bath       1.0
# ...                ...       ...
# 7742            1 bath       1.0
# 7743           2 baths       2.0
# 7744  1.5 shared baths       1.5
# 7745     1 shared bath       1.0
# 7746     1 shared bath       1.0
#
# [7745 rows x 2 columns]

# %%
updated_df
# Out:
#            id  host_id             host_name  host_since host_location  \
# 0        2384     2613               Rebecca  2008-08-29   Chicago, IL
# 1     1772920  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 2     1773021  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 3     1773025  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 4     1810118  9483312                  Ryan  2013-10-17   Chicago, IL
# ...       ...      ...                   ...         ...           ...
# 7742    25879   101521                   Red  2010-03-31   Chicago, IL
# 7743    28749    27506                 Lauri  2009-07-25         Italy
# 7744    37738   162364         Mat And Randy  2010-07-09   Chicago, IL
# 7745    71930   334241  Michael And Veronica  2011-01-03   Chicago, IL
# 7746    84042   334241  Michael And Veronica  2011-01-03   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  97%
# 1         within an hour               100%                 100%
# 2         within an hour               100%                 100%
# 3         within an hour               100%                 100%
# 4         within an hour               100%                 100%
# ...                  ...                ...                  ...
# 7742  within a few hours               100%                  75%
# 7743  within a few hours               100%                  85%
# 7744                 NaN                NaN                  NaN
# 7745      within an hour                90%                  97%
# 7746      within an hour                90%                  97%
#
#      host_is_superhost  host_listings_count  ...  bathrooms    bathrooms_text  \
# 0                    t                    1  ...        NaN     1 shared bath
# 1                    t                    6  ...        NaN           2 baths
# 2                    t                    6  ...        NaN           2 baths
# 3                    t                    6  ...        NaN           2 baths
# 4                    t                    2  ...        NaN    1 private bath
# ...                ...                  ...  ...        ...               ...
# 7742                 f                    8  ...        NaN            1 bath
# 7743                 t                    1  ...        NaN           2 baths
# 7744                 f                    2  ...        NaN  1.5 shared baths
# 7745                 t                    2  ...        NaN     1 shared bath
# 7746                 t                    2  ...        NaN     1 shared bath
#
#      bedrooms beds                                          amenities  price  \
# 0         1.0  1.0  ["Dedicated workspace", "Host greets you", "Ba...   90.0
# 1         3.0  5.0  ["Oven", "Baking sheet", "Host greets you", "F...  379.0
# 2         4.0  5.0  ["Laundromat nearby", "Oven", "Baking sheet", ...  479.0
# 3         4.0  5.0  ["Oven", "Baking sheet", "Host greets you", "F...  479.0
# 4         1.0  1.0  ["Self check-in", "Dedicated workspace", "Chil...   79.0
# ...       ...  ...                                                ...    ...
# 7742      2.0  3.0  ["Self check-in", "Dedicated workspace", "Oven...   86.0
# 7743      3.0  3.0  ["Self check-in", "Oven", "Baking sheet", "Fir...  157.0
# 7744      1.0  1.0  ["Self check-in", "Dedicated workspace", "Oven...  110.0
# 7745      1.0  1.0  ["Laundromat nearby", "Dedicated workspace", "...   84.0
# 7746      1.0  1.0  ["Dedicated workspace", "Oven", "Baking sheet"...   89.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                   212                 4.93                              1
# 1                    13                 4.58                              6
# 2                    26                 4.85                              6
# 3                    21                 4.76                              6
# 4                   355                 4.88                              2
# ...                 ...                  ...                            ...
# 7742                 51                 4.35                              3
# 7743                169                 4.67                              1
# 7744                250                 4.98                              2
# 7745                101                 4.80                              2
# 7746                124                 4.86                              2
#
#       num_bath
# 0          1.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          1.0
# ...        ...
# 7742       1.0
# 7743       2.0
# 7744       1.5
# 7745       1.0
# 7746       1.0
#
# [7745 rows x 30 columns]

# %%
updated_df['num_bath'].isnull().sum()
# Out:
# 0

# %%
updated_df[updated_df['num_bath'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 30 columns]

# %%
updated_df['num_bath'].unique()
# Out:
# array([ 1. ,  2. ,  1.5, 11. ,  2.5,  3. ,  0. ,  3.5,  4. ,  0.5,  4.5,
#         5. , 11.5,  6.5,  7. ,  5.5,  6. , 12.5, 10. ,  9.5,  7.5,  8. ,
#         8.5])

# %%
# delete bathrooms column
updated_df.drop('bathrooms', axis=1, inplace=True)

# %%
updated_df
# Out:
#            id  host_id             host_name  host_since host_location  \
# 0        2384     2613               Rebecca  2008-08-29   Chicago, IL
# 1     1772920  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 2     1773021  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 3     1773025  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 4     1810118  9483312                  Ryan  2013-10-17   Chicago, IL
# ...       ...      ...                   ...         ...           ...
# 7742    25879   101521                   Red  2010-03-31   Chicago, IL
# 7743    28749    27506                 Lauri  2009-07-25         Italy
# 7744    37738   162364         Mat And Randy  2010-07-09   Chicago, IL
# 7745    71930   334241  Michael And Veronica  2011-01-03   Chicago, IL
# 7746    84042   334241  Michael And Veronica  2011-01-03   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  97%
# 1         within an hour               100%                 100%
# 2         within an hour               100%                 100%
# 3         within an hour               100%                 100%
# 4         within an hour               100%                 100%
# ...                  ...                ...                  ...
# 7742  within a few hours               100%                  75%
# 7743  within a few hours               100%                  85%
# 7744                 NaN                NaN                  NaN
# 7745      within an hour                90%                  97%
# 7746      within an hour                90%                  97%
#
#      host_is_superhost  host_listings_count  ...  accommodates  \
# 0                    t                    1  ...             1
# 1                    t                    6  ...             7
# 2                    t                    6  ...             9
# 3                    t                    6  ...             9
# 4                    t                    2  ...             3
# ...                ...                  ...  ...           ...
# 7742                 f                    8  ...             6
# 7743                 t                    1  ...             6
# 7744                 f                    2  ...             2
# 7745                 t                    2  ...             2
# 7746                 t                    2  ...             2
#
#         bathrooms_text bedrooms beds  \
# 0        1 shared bath      1.0  1.0
# 1              2 baths      3.0  5.0
# 2              2 baths      4.0  5.0
# 3              2 baths      4.0  5.0
# 4       1 private bath      1.0  1.0
# ...                ...      ...  ...
# 7742            1 bath      2.0  3.0
# 7743           2 baths      3.0  3.0
# 7744  1.5 shared baths      1.0  1.0
# 7745     1 shared bath      1.0  1.0
# 7746     1 shared bath      1.0  1.0
#
#                                               amenities  price  \
# 0     ["Dedicated workspace", "Host greets you", "Ba...   90.0
# 1     ["Oven", "Baking sheet", "Host greets you", "F...  379.0
# 2     ["Laundromat nearby", "Oven", "Baking sheet", ...  479.0
# 3     ["Oven", "Baking sheet", "Host greets you", "F...  479.0
# 4     ["Self check-in", "Dedicated workspace", "Chil...   79.0
# ...                                                 ...    ...
# 7742  ["Self check-in", "Dedicated workspace", "Oven...   86.0
# 7743  ["Self check-in", "Oven", "Baking sheet", "Fir...  157.0
# 7744  ["Self check-in", "Dedicated workspace", "Oven...  110.0
# 7745  ["Laundromat nearby", "Dedicated workspace", "...   84.0
# 7746  ["Dedicated workspace", "Oven", "Baking sheet"...   89.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                   212                 4.93                              1
# 1                    13                 4.58                              6
# 2                    26                 4.85                              6
# 3                    21                 4.76                              6
# 4                   355                 4.88                              2
# ...                 ...                  ...                            ...
# 7742                 51                 4.35                              3
# 7743                169                 4.67                              1
# 7744                250                 4.98                              2
# 7745                101                 4.80                              2
# 7746                124                 4.86                              2
#
#       num_bath
# 0          1.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          1.0
# ...        ...
# 7742       1.0
# 7743       2.0
# 7744       1.5
# 7745       1.0
# 7746       1.0
#
# [7745 rows x 29 columns]

# %% [markdown]
# # Impute Bedrooms and Beds

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  3.,  4.,  2.,  6., nan,  5.,  7.,  9., 12., 10.,  8., 11.])

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  5.,  2.,  4.,  3., 10.,  8.,  9.,  6., 11.,  7., nan, 18.,
#        17., 14., 15., 12., 13., 21., 20., 19., 24., 16.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
#                       id    host_id host_name  host_since host_location  \
# 62               3485081   11848299     Anton  2014-02-01   Chicago, IL
# 69               3666681    3965428       Rob  2012-10-24   Chicago, IL
# 167              5861971   11710780    Robert  2014-01-27   Chicago, IL
# 190              6363328   33154489      Sara  2015-05-11   Chicago, IL
# 217              6588681    5212119      Mark  2013-02-24   Chicago, IL
# ...                  ...        ...       ...         ...           ...
# 7607  843634450900497936  144369871     Cinny  2017-08-04           NaN
# 7617  844403551944794676  252408635     Andie  2019-03-31   Chicago, IL
# 7619  845594853964391358  343454544     Janay  2020-04-08   Chicago, IL
# 7625  846400873610326525  490752710      Nell  2022-12-08   Chicago, IL
# 7708             1096191    6023157  Nataliya  2013-04-21   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 62                   NaN                NaN                 100%
# 69        within an hour               100%                  74%
# 167       within an hour               100%                  99%
# 190   within a few hours                93%                  54%
# 217       within an hour               100%                  97%
# ...                  ...                ...                  ...
# 7607                 NaN                NaN                  NaN
# 7617      within an hour                98%                  99%
# 7619        within a day                50%                  80%
# 7625      within an hour                96%                 100%
# 7708      within an hour               100%                 100%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 62                   f                    2  ...             3         1 bath
# 69                   t                   83  ...             2         1 bath
# 167                  t                    2  ...             4         1 bath
# 190                  f                    1  ...             2         1 bath
# 217                  t                    1  ...             2         1 bath
# ...                ...                  ...  ...           ...            ...
# 7607                 f                    6  ...             2         1 bath
# 7617                 f                   34  ...             2         1 bath
# 7619                 f                    2  ...             2         1 bath
# 7625                 f                    3  ...             2         1 bath
# 7708                 f                    1  ...             2         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 62        NaN  1.0  ["Oven", "Host greets you", "Private entrance"...  112.0
# 69        NaN  1.0  ["Self check-in", "Oven", "Carbon monoxide ala...  170.0
# 167       NaN  3.0  ["Self check-in", "Dedicated workspace", "Oven...   72.0
# 190       NaN  1.0  ["Self check-in", "Dedicated workspace", "Oven...   85.0
# 217       NaN  1.0  ["Self check-in", "Children\u2019s books and t...   82.0
# ...       ...  ...                                                ...    ...
# 7607      NaN  1.0  ["Smoke alarm", "Carbon monoxide alarm", "Kitc...   91.0
# 7617      NaN  1.0  ["Self check-in", "Dedicated workspace", "Oven...   78.0
# 7619      NaN  2.0  ["Dedicated workspace", "Oven", "Host greets y...   89.0
# 7625      NaN  1.0  ["Oven", "First aid kit", "Bed linens", "Condi...   90.0
# 7708      NaN  1.0  ["Public or shared beach access", "Laundromat ...   50.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 62                  180                 4.50                              2
# 69                   14                 4.46                             75
# 167                 172                 4.69                              2
# 190                 205                 4.82                              1
# 217                 429                 4.87                              1
# ...                 ...                  ...                            ...
# 7607                  0                  NaN                              2
# 7617                  0                  NaN                             31
# 7619                  0                  NaN                              1
# 7625                  0                  NaN                              2
# 7708                 75                 4.75                              1
#
#       num_bath
# 62         1.0
# 69         1.0
# 167        1.0
# 190        1.0
# 217        1.0
# ...        ...
# 7607       1.0
# 7617       1.0
# 7619       1.0
# 7625       1.0
# 7708       1.0
#
# [581 rows x 29 columns]

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
#                       id    host_id         host_name  host_since  \
# 687             15496152   45828803      Heather + JP  2015-10-05
# 712             15735536   25553049             Emily  2015-01-03
# 1001            20503258   68127227             Rocio  2016-04-20
# 1220            23376509  174206662       MaTennessee  2018-02-19
# 1223            23467251     691000             Nonya  2011-06-11
# ...                  ...        ...               ...         ...
# 7470  832728479157812136   25662899             Missy  2015-01-05
# 7491  834183947687691462    8244394              Lina  2013-08-18
# 7498  835066647677257371   85647159   Masato Or Akiko  2016-07-24
# 7520  837651273534264559  435105119  Sonder (Chicago)  2021-12-07
# 7521  837654001202334074  435105119  Sonder (Chicago)  2021-12-07
#
#          host_location  host_response_time host_response_rate  \
# 687        Chicago, IL      within an hour               100%
# 712   Elmwood Park, IL      within an hour               100%
# 1001       Chicago, IL                 NaN                NaN
# 1220       Chicago, IL                 NaN                NaN
# 1223       Chicago, IL  within a few hours               100%
# ...                ...                 ...                ...
# 7470       Chicago, IL                 NaN                NaN
# 7491       Chicago, IL      within an hour               100%
# 7498       Chicago, IL      within an hour               100%
# 7520       Chicago, IL      within an hour                96%
# 7521       Chicago, IL      within an hour                96%
#
#      host_acceptance_rate host_is_superhost  host_listings_count  ...  \
# 687                   99%                 t                    2  ...
# 712                   91%                 t                    2  ...
# 1001                  NaN                 f                    1  ...
# 1220                  NaN                 f                    3  ...
# 1223                  96%                 f                   11  ...
# ...                   ...               ...                  ...  ...
# 7470                  NaN                 f                    3  ...
# 7491                 100%                 f                    1  ...
# 7498                 100%                 f                    5  ...
# 7520                  99%                 f                   31  ...
# 7521                  99%                 f                   31  ...
#
#       accommodates  bathrooms_text bedrooms beds  \
# 687              3          1 bath      NaN  NaN
# 712              5       1.5 baths      3.0  NaN
# 1001             2          1 bath      1.0  NaN
# 1220             2   1 shared bath      1.0  NaN
# 1223             4  2 shared baths      1.0  NaN
# ...            ...             ...      ...  ...
# 7470             1          1 bath      1.0  NaN
# 7491             3          1 bath      1.0  NaN
# 7498             3  1 private bath      NaN  NaN
# 7520             4          1 bath      1.0  NaN
# 7521             2          1 bath      NaN  NaN
#
#                                               amenities   price  \
# 687   ["Self check-in", "Laundromat nearby", "Dedica...   112.0
# 712   ["Self check-in", "Oven", "Baking sheet", "Pri...   190.0
# 1001  ["Hair dryer", "Smoke alarm", "Carbon monoxide...  1200.0
# 1220  ["Children\u2019s books and toys", "Oven", "Fi...    50.0
# 1223  ["Self check-in", "Oven", "Baking sheet", "Fir...    25.0
# ...                                                 ...     ...
# 7470  ["Self check-in", "Dedicated workspace", "Firs...    72.0
# 7491  ["Self check-in", "Dedicated workspace", "Blen...    67.0
# 7498  ["Self check-in", "Children\u2019s books and t...    50.0
# 7520  ["Self check-in", "Fast wifi \u2013 56 Mbps", ...   277.0
# 7521  ["Self check-in", "Dedicated workspace", "Bed ...   160.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 687                 269                 4.90                              2
# 712                  32                 4.97                              2
# 1001                  0                  NaN                              1
# 1220                 11                 4.55                              3
# 1223                 32                 4.91                             11
# ...                 ...                  ...                            ...
# 7470                  0                  NaN                              1
# 7491                  0                  NaN                              1
# 7498                  1                 5.00                              5
# 7520                  0                  NaN                             31
# 7521                  0                  NaN                             31
#
#       num_bath
# 687        1.0
# 712        1.5
# 1001       1.0
# 1220       1.0
# 1223       2.0
# ...        ...
# 7470       1.0
# 7491       1.0
# 7498       1.0
# 7520       1.0
# 7521       1.0
#
# [64 rows x 29 columns]

# %%
def update_bedrooms_and_beds(df):
    """
    Updates the 'bedrooms' and 'beds' columns based on the conditions:
    1. If 'bedrooms' is null, set it to the rounded up value of 'num_bath'.
    2. If 'beds' is null, copy the value from 'bedrooms'.
    """
    # Rule 1: If bedrooms is NaN, round up 'num_bath' to nearest integer and assign to 'bedrooms'
    df.loc[df['bedrooms'].isnull(), 'bedrooms'] = np.ceil(df['num_bath'])
    
    # Rule 2: If beds is NaN, copy the value from 'bedrooms'
    df.loc[df['beds'].isnull(), 'beds'] = df['bedrooms']
    
    return df

# %%
updated_df = update_bedrooms_and_beds(updated_df)

# %%
# check for the previous NA rows in bedrooms
updated_df[
    (updated_df['id'] == 3485081) | 
    (updated_df['id'] == 3666681) | 
    (updated_df['id'] == 5861971) | 
    (updated_df['id'] == 6363328) |
    (updated_df['id'] == 6588681) | 
    (updated_df['id'] == 843634450900497936) | 
    (updated_df['id'] == 844403551944794676) 
]
# Out:
#                       id    host_id host_name  host_since host_location  \
# 62               3485081   11848299     Anton  2014-02-01   Chicago, IL
# 69               3666681    3965428       Rob  2012-10-24   Chicago, IL
# 167              5861971   11710780    Robert  2014-01-27   Chicago, IL
# 190              6363328   33154489      Sara  2015-05-11   Chicago, IL
# 217              6588681    5212119      Mark  2013-02-24   Chicago, IL
# 7607  843634450900497936  144369871     Cinny  2017-08-04           NaN
# 7617  844403551944794676  252408635     Andie  2019-03-31   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 62                   NaN                NaN                 100%
# 69        within an hour               100%                  74%
# 167       within an hour               100%                  99%
# 190   within a few hours                93%                  54%
# 217       within an hour               100%                  97%
# 7607                 NaN                NaN                  NaN
# 7617      within an hour                98%                  99%
#
#      host_is_superhost  host_listings_count  ...  accommodates bathrooms_text  \
# 62                   f                    2  ...             3         1 bath
# 69                   t                   83  ...             2         1 bath
# 167                  t                    2  ...             4         1 bath
# 190                  f                    1  ...             2         1 bath
# 217                  t                    1  ...             2         1 bath
# 7607                 f                    6  ...             2         1 bath
# 7617                 f                   34  ...             2         1 bath
#
#      bedrooms beds                                          amenities  price  \
# 62        1.0  1.0  ["Oven", "Host greets you", "Private entrance"...  112.0
# 69        1.0  1.0  ["Self check-in", "Oven", "Carbon monoxide ala...  170.0
# 167       1.0  3.0  ["Self check-in", "Dedicated workspace", "Oven...   72.0
# 190       1.0  1.0  ["Self check-in", "Dedicated workspace", "Oven...   85.0
# 217       1.0  1.0  ["Self check-in", "Children\u2019s books and t...   82.0
# 7607      1.0  1.0  ["Smoke alarm", "Carbon monoxide alarm", "Kitc...   91.0
# 7617      1.0  1.0  ["Self check-in", "Dedicated workspace", "Oven...   78.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 62                  180                 4.50                              2
# 69                   14                 4.46                             75
# 167                 172                 4.69                              2
# 190                 205                 4.82                              1
# 217                 429                 4.87                              1
# 7607                  0                  NaN                              2
# 7617                  0                  NaN                             31
#
#       num_bath
# 62         1.0
# 69         1.0
# 167        1.0
# 190        1.0
# 217        1.0
# 7607       1.0
# 7617       1.0
#
# [7 rows x 29 columns]

# %%
updated_df['beds'].unique()
# Out:
# array([ 1.,  5.,  2.,  4.,  3., 10.,  8.,  9.,  6., 11.,  7., 18., 17.,
#        14., 15., 12., 13., 21., 20., 19., 24., 16.])

# %%
updated_df[updated_df['beds'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['bedrooms'].unique()
# Out:
# array([ 1.,  3.,  4.,  2.,  6.,  5.,  7.,  9., 12., 10.,  8.,  0., 11.])

# %%
updated_df[updated_df['bedrooms'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_since

# %%
# check the number of missing values
na = updated_df['host_since'].isnull().sum()
print(f'There are {na} missing values in the "host_since" column.')

# Fill missing values with the most recent date
most_recent_date = pd.to_datetime(updated_df['host_since']).max().strftime("%B %Y")
updated_df['host_since'].fillna(most_recent_date, inplace=True)
# Out:
# There are 0 missing values in the "host_since" column.

# %%
updated_df['host_since'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_since'].unique()
# Out:
# array(['2008-08-29', '2013-10-08', '2013-10-17', ..., '2009-10-18',
#        '2009-07-25', '2011-01-03'], dtype=object)

# %% [markdown]
# # host_location

# %%
# check the number of missing values
na = updated_df['host_location'].isnull().sum()
print(f'There are {na} missing values in the "host_location" column.')

# Fill missing values with 'unknown'
updated_df['host_location'].fillna("unknown", inplace=True)
# Out:
# There are 1391 missing values in the "host_location" column.

# %%
updated_df['host_location'].isnull().sum()
# Out:
# 0

# %%
count_unknown_location = (updated_df['host_location'] == 'unknown').sum()
count_unknown_location
# Out:
# 1391

# %%
updated_df['host_location'].unique()
# Out:
# array(['Chicago, IL', 'Northfield, IL', 'Boulder, CO', 'Boise, ID',
#        'United States', 'Illinois, United States', 'Long Beach, CA',
#        'Honolulu, HI', 'Lisle, IL', 'Connecticut, United States',
#        'Munster, IN', 'unknown', 'Madrid, Spain', 'Vancouver, Canada',
#        'Rockville, MD', 'Evanston, Illinois', 'Barrington, IL',
#        'Evergreen Park, IL', 'Oak Park, IL', 'Northbrook, IL',
#        'Aurora, IL', 'Austin, TX', 'Tucson, AZ', 'Jacksonville, FL',
#        'Anchorage, AK', 'Walnut, CA', 'Los Angeles, CA', 'Charlotte, NC',
#        'Naperville, IL', 'Las Vegas, NV', 'Birmingham, MI',
#        'Saint Ignatius, MT', 'Pinehurst, NC', 'Phoenix, AZ',
#        'Atlanta, GA', 'Downers Grove, IL', 'Linda, CA',
#        'Elmwood Park, IL', 'Kalamazoo, MI', 'Carolina, Puerto Rico',
#        'Naples, FL', 'Paris, France', 'Salt Lake City, UT',
#        'Schaumburg, IL', 'Glen Ellyn, IL', 'Montreal, Canada',
#        'Denver, CO', 'Andover, MA', 'Whitewater, WI', 'San Antonio, TX',
#        'Tampa, FL', 'Seattle, WA', 'Baltimore, MD', 'Glenview, IL',
#        'Greendale, WI', 'Washington, DC', 'Williamstown, MA',
#        'Fort Lauderdale, FL', 'Hoffman Estates, IL', 'San Diego, CA',
#        'East Saint Louis, IL', 'Cleveland, OH', 'Oak Lawn, IL',
#        'Bloomington, IN', 'Zanesville, OH', 'New York, NY',
#        'Homer Glen, IL', 'Houston, TX', 'Arlington Heights, IL',
#        'Merrionette Park, IL', 'New York, United States',
#        'Somerville, NJ', 'Cicero, IL', 'Toronto, Canada', 'Whiting, IN',
#        'Dyer, IN', 'Cedar City, UT', 'Oakland, CA', 'Normal, IL',
#        'Rockport, ME', 'China', 'Mission Viejo, CA', 'San Jose, CA',
#        'Parkville, MO', 'Philadelphia, PA', 'Cincinnati, OH',
#        'Boston, MA', 'Kasilof, AK', 'Flossmoor, IL', 'Palos Park, IL',
#        'Buenos Aires, Argentina', 'Maywood, IL', 'Oak Hill, VA',
#        'Santa Barbara, CA', 'Madison, WI', 'Lincolnwood, IL',
#        'Riverside, CA', 'Asheville, NC', 'East Lansing, MI',
#        'Sandwich, IL', 'Miami Beach, FL', 'Minneapolis, MN',
#        'Elmhurst, IL', 'Dallas, TX', 'Glen Arbor, MI', 'Belmont, CA',
#        'Brooklyn, NY', 'United Kingdom', 'Tunja, Colombia',
#        'Mérida, Mexico', 'Monee, IL', 'Santa Monica, CA',
#        'Wilkes-Barre, PA', 'Oxford, FL', 'Middleton, WI',
#        'Kansas City, MO', 'Darien, IL', 'Crest Hill, IL',
#        'Park Ridge, IL', 'Bloomingdale, IL', 'Nashville, TN',
#        'Batavia, IL', 'Lansing, IL', 'Berwyn, IL', 'Melbourne, Australia',
#        'Hinsdale, IL', 'Campbell, CA', 'Forest Park, IL', 'Tacoma, WA',
#        'Evesham Township, NJ', 'Calumet City, IL', 'Plainfield, IL',
#        'Norridge, IL', 'Niles, IL', 'St Petersburg, FL', 'Miami, FL',
#        'Springfield, IL', 'San Francisco, CA', 'Palm Beach, FL',
#        'Gurnee, IL', 'South Holland, IL', 'Rome, Italy',
#        'California, United States', 'Wood Dale, IL',
#        'Indian Head Park, IL', 'Morton Grove, IL', 'Ann Arbor, MI',
#        'Hacienda Heights, CA', 'Chico, CA', 'Tbilisi, Georgia',
#        'Hoboken, NJ', 'Milan, Italy', 'Coconut Creek, FL', 'Westmont, IL',
#        'Burbank, IL', 'Malibu, CA', 'Countryside, IL',
#        'Incline Village, NV', 'Tinley Park, IL', 'Clarkston, GA',
#        'Channahon, IL', 'Charleston, SC', 'East Chicago, IN',
#        'La Habra, CA', 'Grand Prairie, TX', 'Arlington, TX',
#        'Queensbury, NY', 'South Bend, IN', 'Provo, UT', 'Lyons, IL',
#        'American Canyon, CA', 'Milwaukee, WI', 'Portland, OR',
#        'Nahant, MA', 'Bellwood, IL', 'Harwood Heights, IL',
#        'Richland, MO', 'Port St. Joe, FL', 'Detroit, MI', 'Skokie, IL',
#        'Palos Hills, IL', 'Canton, OH', 'Carol Stream, IL',
#        'Knoxville, TN', 'Champaign, IL', 'Stockholm, Sweden',
#        'Richton Park, IL', 'Kankakee, IL', 'High Point, NC',
#        'Frankfort, IL', 'Pittsburgh, PA', 'Island Lake, IL',
#        'Wauconda, IL', 'Huntington Beach, CA', 'Wayne, IL',
#        'Heidelberg, Germany', 'Jackson, MS', 'Hammond, IN',
#        'Bradenton, FL', 'Riverside, IL', 'New Orleans, LA',
#        'Bogota, Colombia', 'Des Plaines, IL',
#        'West Bloomfield Township, MI', 'Simi Valley, CA', 'St. Louis, MO',
#        'Crystal Lake, IL', 'Orlando, FL', 'Providence, RI',
#        'Evanston, IL', 'Bergen, Norway', 'Chandler, AZ', 'Lafayette, LA',
#        'Scottsdale, AZ', 'La Cañada Flintridge, CA', 'Albuquerque, NM',
#        'West Chicago, IL', 'Indiana, United States', 'La Grange Park, IL',
#        'Berkeley, CA', 'Mount Vernon, NY', 'East Point, GA',
#        'Dearborn, MI', 'Grand Rapids, MI', 'Bolingbrook, IL', 'Italy'],
#       dtype=object)

# %%
updated_df[updated_df['host_location'] =='']
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_is_superhost

# %%
# check the number of missing values
na = updated_df['host_is_superhost'].isnull().sum()
print(f'There are {na} missing values in the "host_is_superhost" column.')

updated_df['host_is_superhost'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_is_superhost" column.

# %%
updated_df['host_is_superhost'].isnull().sum()
# Out:
# 0

# %%
count_unknown_super = (updated_df['host_is_superhost'] == 'f').sum()
count_unknown_super
# Out:
# 4896

# %%
updated_df['host_is_superhost'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # host_listings_count

# %%
na = updated_df['host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_listings_count" column.')

updated_df['host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_listings_count" column.

# %%
updated_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_listings_count'].unique()
# Out:
# array([   1,    6,    2,    8,   83,    3,   17,    5,   41,    4,   10,
#           7,   14,   11,   13,    9,   23,   18,   12,   32,  120,   21,
#          24,   28,   15,   63,   16,   51,   25,   35,   48,  158,   34,
#           0,   22, 4807,   27,   66,  161,   20,   31,  138,  246,   19,
#          53,   64, 1328,   62, 2621,   99,   43,   40,   30,   26,   73,
#         156,   46,  449,   68,  285,  171])

# %% [markdown]
# # host_total_listings_count

# %%
na = updated_df['host_total_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "host_total_listings_count" column.')

updated_df['host_total_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "host_total_listings_count" column.

# %%
updated_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
updated_df['host_total_listings_count'].unique()
# Out:
# array([   1,    6,    2,    3,   12,  224,    5,    4,   11,   31,   42,
#           8,   17,    7,   19,   21,   10,   24,   14,   18,   82,   16,
#          38,    9,   15,   41,   72,   22,  171,   13,   66,   25,   52,
#          44,   99,  139,   33,  186,   37,   23,   26,   29,   54,   96,
#          68,  184,    0, 5358,   70,  182,   35,   34,   28,  176,  294,
#         104,   60,   67,   55, 2034,   43,   53,   69, 8342,  123,   46,
#          20,   64,  118,  327,   56,   36,  491,   47,   86,  564,  423,
#          97,   78])

# %% [markdown]
# # host_verifications

# %%
na = updated_df['host_verifications'].isnull().sum()
print(f'There are {na} missing values in the "host_verifications" column.')

updated_df['host_verifications'].fillna("None", inplace=True)
# Out:
# There are 0 missing values in the "host_verifications" column.

# %%
updated_df['host_verifications'].unique()
# Out:
# array(["['email', 'phone']", "['email', 'phone', 'work_email']",
#        "['phone', 'work_email']", "['phone']", "['email']"], dtype=object)

# %% [markdown]
# # host_identity_verified

# %%
na = updated_df['host_identity_verified'].isnull().sum()
print(f'There are {na} missing values in the "host_identity_verified" column.')

updated_df['host_identity_verified'].fillna("f", inplace=True)
# Out:
# There are 0 missing values in the "host_identity_verified" column.

# %%
updated_df['host_identity_verified'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # calculated_host_listings_count

# %%
na = updated_df['calculated_host_listings_count'].isnull().sum()
print(f'There are {na} missing values in the "calculated_host_listings_count" column.')

updated_df['calculated_host_listings_count'].fillna(1, inplace=True)
# Out:
# There are 0 missing values in the "calculated_host_listings_count" column.

# %%
updated_df['calculated_host_listings_count'].unique()
# Out:
# array([  1,   6,   2,   8,  75,   3,  15,   5,  21,   4,  10,  14,  11,
#         13,   9,  22,  18,  12,   7,  32,  24,  63,  17,  16,  27,  23,
#         34,  19, 658,  39,  31,  25,  38,  30,  64,  33,  47,  40])

# %% [markdown]
# # host_name

# %%
updated_df[updated_df['host_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # host_has_profile_pic

# %%
updated_df[updated_df['host_has_profile_pic'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_name, host_since, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, latitude, longitude, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, price, number_of_reviews, review_scores_value, calculated_host_listings_count, num_bath]
# Index: []
#
# [0 rows x 29 columns]

# %%
updated_df['host_has_profile_pic'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# # Neighborhood

# %%
updated_df['neighbourhood'].unique()
# Out:
# array(['Chicago, Illinois, United States', nan,
#        'Oak Park, Illinois, United States',
#        'Chicago Heights, Illinois, United States',
#        'Chicago , Illinois, United States',
#        'Bucktown, Chicago, Illinois, United States',
#        'Oak Lawn, Illinois, United States', 'Chicago, United States',
#        'Rogers Park, Il, United States',
#        'Santa Barbara, California, United States',
#        'Chicago, Il, United States', 'Norridge, Illinois, United States',
#        'Harwood Heights, Illinois, United States',
#        '芝加哥, Illinois, United States',
#        'Evergreen Park, Illinois, United States'], dtype=object)

# %%
updated_df['neighbourhood'].isnull().sum()
# Out:
# 2296

# %%
updated_df['neighbourhood_cleansed'].unique()
# Out:
# array(['Hyde Park', 'Lake View', 'Woodlawn', 'Lincoln Park', 'Avondale',
#        'Near South Side', 'Logan Square', 'West Town', 'Humboldt Park',
#        'Lower West Side', 'Kenwood', 'North Center', 'Portage Park',
#        'Near West Side', 'Lincoln Square', 'Washington Park',
#        'South Lawndale', 'Loop', 'Morgan Park', 'Dunning',
#        'Near North Side', 'West Lawn', 'South Shore', 'Rogers Park',
#        'Edgewater', 'East Garfield Park', 'Irving Park', 'West Ridge',
#        'Grand Boulevard', 'Bridgeport', 'Uptown', 'Armour Square',
#        'Albany Park', 'South Deering', 'Pullman', 'West Garfield Park',
#        'Hermosa', 'Mckinley Park', 'Douglas', 'Hegewisch', 'West Elsdon',
#        'Jefferson Park', 'Ashburn', 'Greater Grand Crossing',
#        'North Lawndale', 'Norwood Park', 'Garfield Ridge', 'Austin',
#        'North Park', 'Belmont Cragin', 'Oakland', 'Archer Heights',
#        'Edison Park', 'Brighton Park', 'Englewood', 'Beverly',
#        'Chicago Lawn', 'South Chicago', 'West Englewood',
#        'Mount Greenwood', 'Montclare', 'Chatham', 'Roseland',
#        'Calumet Heights', 'Fuller Park', 'Ohare', 'West Pullman',
#        'Auburn Gresham', 'New City', 'Avalon Park', 'Burnside',
#        'Clearing', 'Gage Park', 'Forest Glen', 'Washington Heights',
#        'East Side'], dtype=object)

# %%
updated_df['neighbourhood_cleansed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### We are going to drop neighbourhood column for Chicago Dataset

# %%
updated_df.drop('neighbourhood', axis=1, inplace=True)

# %% [markdown]
# # host_response_time

# %%
updated_df['host_response_time'].unique()
# Out:
# array(['within an hour', nan, 'within a day', 'a few days or more',
#        'within a few hours'], dtype=object)

# %% [markdown]
# # host_response_rate

# %%
updated_df['host_response_rate'].unique()
# Out:
# array(['100%', nan, '0%', '94%', '92%', '67%', '50%', '80%', '90%', '98%',
#        '13%', '91%', '93%', '20%', '70%', '96%', '88%', '83%', '87%',
#        '97%', '33%', '40%', '75%', '95%', '60%', '99%', '84%', '69%',
#        '22%', '86%', '89%', '63%', '73%', '79%', '64%', '85%', '25%',
#        '71%', '78%', '72%', '17%', '30%', '58%', '82%'], dtype=object)

# %% [markdown]
# # host_acceptance_rate

# %%
# host_acceptance_rate
updated_df['host_acceptance_rate'].unique()
# Out:
# array(['97%', '100%', '18%', '25%', '74%', '89%', '71%', '99%', '85%',
#        '92%', nan, '57%', '91%', '94%', '69%', '50%', '96%', '43%', '78%',
#        '80%', '95%', '0%', '87%', '81%', '75%', '90%', '20%', '98%',
#        '86%', '66%', '73%', '67%', '33%', '76%', '88%', '93%', '82%',
#        '46%', '54%', '58%', '55%', '64%', '39%', '52%', '13%', '53%',
#        '68%', '83%', '51%', '44%', '60%', '84%', '40%', '23%', '30%',
#        '63%', '31%', '17%', '41%', '70%', '42%', '48%', '72%', '36%',
#        '56%', '11%', '62%', '79%', '77%', '29%', '61%', '1%', '65%',
#        '45%', '21%', '15%'], dtype=object)

# %% [markdown]
# # review_scores_value

# %%
updated_df['review_scores_value'].unique()
# Out:
# array([4.93, 4.58, 4.85, 4.76, 4.88, 4.59, 4.61, 3.  , 4.62, 4.7 , 4.67,
#        4.84, 4.56, 4.72, 4.48, 4.6 , 4.57, 4.81, 4.79, 4.97, 4.8 , 4.  ,
#        4.77,  nan, 4.89, 4.73, 4.63, 4.68, 4.78, 4.75, 4.82, 4.66, 4.5 ,
#        4.87, 4.9 , 4.83, 4.91, 4.51, 4.71, 4.17, 5.  , 3.8 , 4.46, 4.86,
#        4.52, 4.96, 4.94, 4.45, 4.74, 4.64, 4.69, 4.55, 4.92, 4.98, 4.65,
#        4.36, 4.4 , 3.75, 4.95, 4.29, 4.54, 4.42, 4.44, 4.53, 4.43, 4.33,
#        3.67, 4.1 , 4.39, 4.3 , 4.34, 3.5 , 4.2 , 4.31, 4.38, 4.21, 4.47,
#        3.25, 3.78, 4.32, 3.89, 2.5 , 4.14, 3.33, 4.49, 1.  , 4.25, 4.18,
#        3.96, 3.6 , 4.99, 4.35, 4.41, 3.57, 3.83, 4.22, 4.28, 2.  , 4.06,
#        4.27, 4.16, 4.23, 4.26, 4.24, 3.7 , 3.93, 3.88, 3.2 , 3.77, 3.73,
#        4.08, 3.95, 3.71, 4.13, 4.02, 4.19, 3.4 , 4.37, 3.84, 4.15, 3.82,
#        4.09, 4.05, 3.79, 4.11, 3.22, 3.56, 3.43, 3.3 , 3.27, 3.13, 3.17,
#        2.67, 3.91])

# %% [markdown]
# # Adding new columns for city
#
# Add new column and put 'Chicago' for all rows for later joining purpose

# %%
updated_df['city'] = 'Chicago'

# %%
updated_df
# Out:
#            id  host_id             host_name  host_since host_location  \
# 0        2384     2613               Rebecca  2008-08-29   Chicago, IL
# 1     1772920  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 2     1773021  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 3     1773025  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 4     1810118  9483312                  Ryan  2013-10-17   Chicago, IL
# ...       ...      ...                   ...         ...           ...
# 7742    25879   101521                   Red  2010-03-31   Chicago, IL
# 7743    28749    27506                 Lauri  2009-07-25         Italy
# 7744    37738   162364         Mat And Randy  2010-07-09   Chicago, IL
# 7745    71930   334241  Michael And Veronica  2011-01-03   Chicago, IL
# 7746    84042   334241  Michael And Veronica  2011-01-03   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  97%
# 1         within an hour               100%                 100%
# 2         within an hour               100%                 100%
# 3         within an hour               100%                 100%
# 4         within an hour               100%                 100%
# ...                  ...                ...                  ...
# 7742  within a few hours               100%                  75%
# 7743  within a few hours               100%                  85%
# 7744                 NaN                NaN                  NaN
# 7745      within an hour                90%                  97%
# 7746      within an hour                90%                  97%
#
#      host_is_superhost  host_listings_count  ...    bathrooms_text bedrooms  \
# 0                    t                    1  ...     1 shared bath      1.0
# 1                    t                    6  ...           2 baths      3.0
# 2                    t                    6  ...           2 baths      4.0
# 3                    t                    6  ...           2 baths      4.0
# 4                    t                    2  ...    1 private bath      1.0
# ...                ...                  ...  ...               ...      ...
# 7742                 f                    8  ...            1 bath      2.0
# 7743                 t                    1  ...           2 baths      3.0
# 7744                 f                    2  ...  1.5 shared baths      1.0
# 7745                 t                    2  ...     1 shared bath      1.0
# 7746                 t                    2  ...     1 shared bath      1.0
#
#      beds                                          amenities  price  \
# 0     1.0  ["Dedicated workspace", "Host greets you", "Ba...   90.0
# 1     5.0  ["Oven", "Baking sheet", "Host greets you", "F...  379.0
# 2     5.0  ["Laundromat nearby", "Oven", "Baking sheet", ...  479.0
# 3     5.0  ["Oven", "Baking sheet", "Host greets you", "F...  479.0
# 4     1.0  ["Self check-in", "Dedicated workspace", "Chil...   79.0
# ...   ...                                                ...    ...
# 7742  3.0  ["Self check-in", "Dedicated workspace", "Oven...   86.0
# 7743  3.0  ["Self check-in", "Oven", "Baking sheet", "Fir...  157.0
# 7744  1.0  ["Self check-in", "Dedicated workspace", "Oven...  110.0
# 7745  1.0  ["Laundromat nearby", "Dedicated workspace", "...   84.0
# 7746  1.0  ["Dedicated workspace", "Oven", "Baking sheet"...   89.0
#
#       number_of_reviews  review_scores_value calculated_host_listings_count  \
# 0                   212                 4.93                              1
# 1                    13                 4.58                              6
# 2                    26                 4.85                              6
# 3                    21                 4.76                              6
# 4                   355                 4.88                              2
# ...                 ...                  ...                            ...
# 7742                 51                 4.35                              3
# 7743                169                 4.67                              1
# 7744                250                 4.98                              2
# 7745                101                 4.80                              2
# 7746                124                 4.86                              2
#
#       num_bath     city
# 0          1.0  Chicago
# 1          2.0  Chicago
# 2          2.0  Chicago
# 3          2.0  Chicago
# 4          1.0  Chicago
# ...        ...      ...
# 7742       1.0  Chicago
# 7743       2.0  Chicago
# 7744       1.5  Chicago
# 7745       1.0  Chicago
# 7746       1.0  Chicago
#
# [7745 rows x 29 columns]

# %% [markdown]
# # Count number of amenities

# %%
import ast

# Convert the 'amenities' string to a list using ast.literal_eval
updated_df['amenities_list'] = updated_df['amenities'].apply(lambda x: ast.literal_eval(x))

# Count the number of amenities in each list and create a new column with these counts
updated_df['amenities_count'] = updated_df['amenities_list'].apply(lambda x: len(x))

updated_df.drop('amenities_list', axis=1, inplace=True)

# %%
updated_df
# Out:
#            id  host_id             host_name  host_since host_location  \
# 0        2384     2613               Rebecca  2008-08-29   Chicago, IL
# 1     1772920  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 2     1773021  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 3     1773025  9297431   Inn At Wrigleyville  2013-10-08   Chicago, IL
# 4     1810118  9483312                  Ryan  2013-10-17   Chicago, IL
# ...       ...      ...                   ...         ...           ...
# 7742    25879   101521                   Red  2010-03-31   Chicago, IL
# 7743    28749    27506                 Lauri  2009-07-25         Italy
# 7744    37738   162364         Mat And Randy  2010-07-09   Chicago, IL
# 7745    71930   334241  Michael And Veronica  2011-01-03   Chicago, IL
# 7746    84042   334241  Michael And Veronica  2011-01-03   Chicago, IL
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  97%
# 1         within an hour               100%                 100%
# 2         within an hour               100%                 100%
# 3         within an hour               100%                 100%
# 4         within an hour               100%                 100%
# ...                  ...                ...                  ...
# 7742  within a few hours               100%                  75%
# 7743  within a few hours               100%                  85%
# 7744                 NaN                NaN                  NaN
# 7745      within an hour                90%                  97%
# 7746      within an hour                90%                  97%
#
#      host_is_superhost  host_listings_count  ...  bedrooms beds  \
# 0                    t                    1  ...       1.0  1.0
# 1                    t                    6  ...       3.0  5.0
# 2                    t                    6  ...       4.0  5.0
# 3                    t                    6  ...       4.0  5.0
# 4                    t                    2  ...       1.0  1.0
# ...                ...                  ...  ...       ...  ...
# 7742                 f                    8  ...       2.0  3.0
# 7743                 t                    1  ...       3.0  3.0
# 7744                 f                    2  ...       1.0  1.0
# 7745                 t                    2  ...       1.0  1.0
# 7746                 t                    2  ...       1.0  1.0
#
#                                               amenities  price  \
# 0     ["Dedicated workspace", "Host greets you", "Ba...   90.0
# 1     ["Oven", "Baking sheet", "Host greets you", "F...  379.0
# 2     ["Laundromat nearby", "Oven", "Baking sheet", ...  479.0
# 3     ["Oven", "Baking sheet", "Host greets you", "F...  479.0
# 4     ["Self check-in", "Dedicated workspace", "Chil...   79.0
# ...                                                 ...    ...
# 7742  ["Self check-in", "Dedicated workspace", "Oven...   86.0
# 7743  ["Self check-in", "Oven", "Baking sheet", "Fir...  157.0
# 7744  ["Self check-in", "Dedicated workspace", "Oven...  110.0
# 7745  ["Laundromat nearby", "Dedicated workspace", "...   84.0
# 7746  ["Dedicated workspace", "Oven", "Baking sheet"...   89.0
#
#      number_of_reviews  review_scores_value  calculated_host_listings_count  \
# 0                  212                 4.93                               1
# 1                   13                 4.58                               6
# 2                   26                 4.85                               6
# 3                   21                 4.76                               6
# 4                  355                 4.88                               2
# ...                ...                  ...                             ...
# 7742                51                 4.35                               3
# 7743               169                 4.67                               1
# 7744               250                 4.98                               2
# 7745               101                 4.80                               2
# 7746               124                 4.86                               2
#
#      num_bath     city amenities_count
# 0         1.0  Chicago              48
# 1         2.0  Chicago              38
# 2         2.0  Chicago              34
# 3         2.0  Chicago              34
# 4         1.0  Chicago              46
# ...       ...      ...             ...
# 7742      1.0  Chicago              40
# 7743      2.0  Chicago              44
# 7744      1.5  Chicago              40
# 7745      1.0  Chicago              43
# 7746      1.0  Chicago              36
#
# [7745 rows x 30 columns]

# %% [markdown]
# # Final look into missing values

# %%
updated_df.isnull().sum()
# Out:
# id                                   0
# host_id                              0
# host_name                            0
# host_since                           0
# host_location                        0
# host_response_time                1000
# host_response_rate                1000
# host_acceptance_rate               759
# host_is_superhost                    0
# host_listings_count                  0
# host_total_listings_count            0
# host_verifications                   0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_cleansed               0
# latitude                             0
# longitude                            0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# amenities                            0
# price                                0
# number_of_reviews                    0
# review_scores_value               1507
# calculated_host_listings_count       0
# num_bath                             0
# city                                 0
# amenities_count                      0
# dtype: int64

# %%
# Save as a new csv file
updated_df.to_csv('clean-data/listings_detailed_clean_chicago.csv', index=False)
